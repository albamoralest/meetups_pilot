# %% [markdown]
# # Query complementary information

# %%
import json
import os
import pandas as pd
from _datetime import date
from datetime import datetime
import time
from operator import itemgetter
from pandas import json_normalize 
import numpy as np
import sys

# wikidata api 
from SPARQLWrapper import SPARQLWrapper, JSON
# from qwikidata.sparql import return_sparql_query_results

# For DBpedia spotlight, PPE entities
import requests
import pycurl
from urllib.request import urlopen
from urllib.parse import quote

# %% [markdown]
# #### Process DBpedial Spotlight entity annotation: functions

# %%
# using DBPedia spotlight to search for entities
# URL for local installation of DBpedia spotlight
urlAnnotation = 'http://dbpedia-spotlight.en:80/rest/annotate/'
# urlAnnotation = 'http://dbpedia-spotlight.en:2222/rest/annotate/' ## not working

# if using KMi sparql endpoint
# urlAnnotation = 'https://whise.kmi.open.ac.uk/rest/annotate'

# setting headers and parameters not using DBpedia categories
def setDbPediaAnnotationServiceParameters(text):
    """ Se parameters for querying Dbpedia
    args: text - text to be analysed
    return: headers
            params
    """
    headers = {
        'Accept':'application/json',
        "content-type":"application/x-www-form-urlencoded"
    }

    params = {
        'confidence': '0.4',
        "text":text,
    }
    return headers, params

# setting headers and parameters, filtering by categories
def setDbPediaAnnotationServiceParametersTypes(text,types):
    """ Se parameters for querying Dbpedia
    args: text - text to be annotated
        types: different categories of entities
    return: headers
            params
    """
    headers = {
        'Accept':'application/json',
        "content-type":"application/x-www-form-urlencoded"
    }

    params = {
        'types' : types,
        'confidence': '0.35',
        "text":text,
    }
    return headers, params

# return response in JSON format
def queryDBPediaAnnotation(url,header,params):
    try:
        response = requests.post(url,headers=header, params=params).json()
        
    except Exception as ex:
        if hasattr(ex, 'message'):
            print(ex.message)
        else:
            print(ex)
        raise Exception(ex)
    # finally:
        # print(response)

    return response

def executeQueryDbpedia(q, f='application/json'):
    epr = "http://dbpedia.org/sparql"
    try:
        params = {'query': q}
        resp = requests.get(epr, params=params, headers={'Accept': f})
    #    return resp.text
        return resp
    except Exception as e:
        print(e, file=sys.stdout)
        raise

def queryGeoLocationInformation(uri):
    values = []
    variables = []
#     SELECT * WHERE {
#     VALUES ?s { <http://dbpedia.org/resource/Finland> }

#     OPTIONAL { ?s <http://www.w3.org/2003/01/geo/wgs84_pos#lat> ?lat } .
#     OPTIONAL { ?s <http://www.w3.org/2003/01/geo/wgs84_pos#long> ?long } .
#     OPTIONAL { ?s rdfs:label ?label .  FILTER langMatches( lang(?label), "EN" )  } .
#      OPTIONAL { ?s dbo:thumbnail ?image } .
#     }
    query_text = """SELECT * WHERE { VALUES ?s { <"""+uri+"""> } OPTIONAL { ?s <http://www.w3.org/2003/01/geo/wgs84_pos#lat> ?lat } . 
    OPTIONAL { ?s <http://www.w3.org/2003/01/geo/wgs84_pos#long> ?long } . OPTIONAL { ?s rdfs:label ?label .  FILTER langMatches( lang(?label),"+'"EN"'+" )  } . 
    OPTIONAL { ?s dbo:thumbnail ?image } . }"""
    # print(query_text)
    # {'head': {'link': [], 'vars': ['s', 'lat', 'long', 'label', 'image']}, 'results': 
    #  {'distinct': False, 'ordered': True, 'bindings': 
    #   [{'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/London'}, 
    #     'lat': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#float', 'value': '51.5072'}, 
    #     'long': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#float', 'value': '-0.1275'}, 
    #     'label': {'type': 'literal', 'xml:lang': 'en', 'value': 'London'}, 
    #     'image': {'type': 'uri', 'value': 'http://commons.wikimedia.org/wiki/Special:FilePath/London_Montage_L.jpg?width=300'}}]}}
    results = executeQueryDbpedia(query_text).json()
    # print(results)
    # if query returns a response
    if len(results['results']['bindings']) == 0:
        print("No entity", uri)
    else:
        # return a list, with [lat, long]
        result_list = list(results['results']['bindings'])[0]
        variables = list(results['head']['vars'])
        for label in variables:
            if label in result_list:
                values.append(result_list[label]['value'])
            else:
                values.append(np.NaN)
    return variables,values

def queryBiographyInformation(uri):
    values = []
    variables = []
    # SELECT * WHERE {
    # VALUES ?s { <http://dbpedia.org/resource/Louis_Jordan> }
    # OPTIONAL { ?s rdfs:label ?label .  FILTER langMatches( lang(?label), "EN" )  } .
    #  OPTIONAL { ?s dbo:thumbnail ?image } .
    # OPTIONAL { ?s dbp:birthDate ?dob } .
    # OPTIONAL { ?s dbp:deathDate ?dod } .
    # OPTIONAL { ?s dbo:wikiPageID ?wikiId } .
    # OPTIONAL { ?s dbo:abstract ?abstract .  FILTER langMatches( lang(?abstract), "EN" ) } .
    # }
    query_text = """SELECT * WHERE { VALUES ?s { <"""+uri+"""> } OPTIONAL { ?s rdfs:label ?label .  FILTER langMatches( lang(?label), "EN" )  } . 
    OPTIONAL { ?s dbo:thumbnail ?image } . OPTIONAL { ?s dbp:birthDate ?birthdate } . OPTIONAL { ?s dbp:deathDate ?deathdate } . 
    OPTIONAL { ?s owl:sameAs ?wikidataId . FILTER regex (?wikidataId, "http://www.wikidata.org/entity/" ) }
    OPTIONAL { ?s dbo:abstract ?abstract .  FILTER langMatches( lang(?abstract), "EN" ) } . }"""
    # print(query_text)
    results = executeQueryDbpedia(query_text).json()
    # print(results)
    # if query returns a response
    if len(results['results']['bindings']) == 0:
        print("No entity", uri)
    else:
        # return a list, with [lat, long]
        result_list = list(results['results']['bindings'])[0]
        variables = list(results['head']['vars'])
        for label in variables:
            if label in result_list:
                if (label=='birthdate' or label=='deathdate'):
                    if evaluateDateFormat(result_list[label]['value']):
                        values.append(result_list[label]['value'])
                    else:
                        values.append(np.NaN)
                else:
                    values.append(result_list[label]['value'])
            else:
                values.append(np.NaN)
    return variables,values
   
def setWikidateParams(query):
    endpoint_url = "https://query.wikidata.org/sparql"
    user_agent = "Polifonia-MEETUPSPilot0.1 (https://polifonia-project.eu/pilots/meetups/; alba.morales-tirado@open.ac.uk) /%s.%s" % (sys.version_info[0], sys.version_info[1])
    # TODO adjust user agent; see https://w.wiki/CX6
    sparql = SPARQLWrapper(endpoint_url, agent=user_agent)
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    return sparql.query().convert()

def queryWikidataEndpoint(uri):
    values = []
    variables = []
    # """SELECT * WHERE { <http://www.wikidata.org/entity/Q212692> wdt:P569 ?birthdate ; 
    # OPTIONAL { <http://www.wikidata.org/entity/Q212692> wdt:P570 ?deathdate } . }"""
    sparql_query = """SELECT * WHERE { <"""+uri+"""> wdt:P569 ?birthdate ; 
    OPTIONAL { <"""+uri+"""> wdt:P570 ?deathdate } . }"""
    # print(sparql_query)
    # results = return_sparql_query_results(sparql_query)
    results = setWikidateParams(sparql_query)
    # print(results)
    
    if len(results['results']['bindings']) == 0:
        print("No entity", uri)
    else:
        # return a list, with [lat, long]
        result_list = list(results['results']['bindings'])[0]
        variables = list(results['head']['vars'])
        for label in variables:
            if label in result_list:
                # values.append(result_list[label]['value'])
                values.append(result_list[label]['value'].split("T",1)[0])
                # dic['birthdate'].split("T",1)[0]
            else:
                values.append(np.NaN)
    return variables,values

def evaluateDateFormat(dateValue):
    # initializing format
    format = "%Y-%m-%d"
    # checking if format matches the date
    res = True
    # using try-except to check for truth value
    try:
        res = bool(datetime.strptime(dateValue, format))
    except ValueError:
        res = False
    return res

# %%
labels,values = queryBiographyInformation("http://dbpedia.org/resource/Anton_Rubinstein")
# values, labels = queryBiographyInformation("http://dbpedia.org/resource/Edward_Elgar")

dictionary = dict(zip(labels,values))
print(dictionary)
lab, val = queryWikidataEndpoint("http://www.wikidata.org/entity/Q5703377")
dic = dict(zip(lab, val))
print(dic)
# Out:
# {'s': 'http://dbpedia.org/resource/Anton_Rubinstein', 'label': 'Anton Rubinstein', 'image': 'http://commons.wikimedia.org/wiki/Special:FilePath/rubinstein_repin.jpg?width=300', 'birthdate': nan, 'deathdate': nan, 'wikidataId': 'http://www.wikidata.org/entity/Q87567', 'abstract': "Anton Grigoryevich Rubinstein (Russian: Антон Григорьевич Рубинштейн, tr. Anton Grigor'evič Rubinštejn; 28 November [O.S. 16 November] 1829 – 20 November [O.S. 8 November] 1894) was a Russian pianist, composer and conductor who became a pivotal figure in Russian culture when he founded the Saint Petersburg Conservatory. He was the elder brother of Nikolai Rubinstein, who founded the Moscow Conservatory. As a pianist, Rubinstein ranks among the great 19th-century keyboard virtuosos. He became most famous for his series of historical recitals—seven enormous, consecutive concerts covering the history of piano music. Rubinstein played this series throughout Russia and Eastern Europe and in the United States when he toured there. Although best remembered as a pianist and educator (most notably in the latter as the composition teacher of Tchaikovsky), Rubinstein was also a prolific composer throughout much of his life. He wrote 20 operas, the best known of which is The Demon. He composed many other works, including five piano concertos, six symphonies and many solo piano works along with a substantial output of works for chamber ensemble."}
# {'birthdate': '1931-01-01', 'deathdate': nan}

# %%
# print(dic['birthdate'])
# format_string = "%Y/%m/%dT%H:%M:%SZ"
# date_obj = datetime.strptime(dic['birthdate'], format_string).date()
# print(date_obj)
print(dic['birthdate'].split("T",1)[0])


 
# printing result
print("Does date match format? : " + str(res))
# Out:
# 1931-01-01
# The original string is : --11-28
# Does date match format? : False

# %% [markdown]
# ### 1. Information about places, geo-coordinates from DBpedia

# %%
# use chunk to load a small number of files in memory
for chunk in pd.read_csv('list_wikiIdSample.csv', chunksize=10):
    df_files = pd.DataFrame()
    df_files['file_name'] = chunk['file_name']

    # for each file/biography in the list, read its sentences 
    # and annotated the entities using the configured sparql endpoint
    for file_name in df_files.itertuples():
        print(file_name.file_name)
        # Read file with segmented sentences
        if os.path.isfile('geoLocationInformation/'+file_name.file_name):
            print("Already exists. Next.")
        else:
            if os.path.isfile('meetupsAnnotations/'+file_name.file_name):
                biography_df = pd.read_csv('meetupsAnnotations/'+file_name.file_name)
                entities_df = pd.DataFrame()
                # for each sentence in the biography
                for sentence_row in biography_df.itertuples():
                    # read people and places entities
                    meetupCandidatePP_df = pd.read_csv('extractedEntitiesPersonPlaceOnly/'+file_name.file_name.replace(".txt",".csv"))
                    # read coref results
                    # print(len(meetupCandidatePP_df))
                    # validate if coreference doc exist
                    if os.path.isfile('meetupsCorefOutputPP/'+file_name.file_name):
                        tempCoref_df = pd.read_csv('meetupsCorefOutputPP/'+file_name.file_name)
                        # concat values
                        temp_candidate = pd.concat([meetupCandidatePP_df, tempCoref_df], sort=False)
                    else:
                        print("No coref doc",file_name.file_name)
                        temp_candidate = meetupCandidatePP_df.copy()
                    temp_candidate = temp_candidate.query("paragraphIndex=={} & sentenceIndex=={} & entType == 'place'".format(sentence_row.paragraphIndex,
                                                                                                                 sentence_row.sentenceIndex))
                    
                    if temp_candidate.empty:
                        print("No place entities.",file_name.file_name)
                    else:
                        for place in temp_candidate.itertuples():
                            # return a list, with [lat, long]
                            labels,values = queryGeoLocationInformation(place.URI)
                            # print(labels,values)
                            if len(values) > 0:
                                row_dict = dict(zip(labels, values))
                                    
                                # print(dictionary)
                                # datarow = pd.Series(data={'URI':place.URI,'lat':coordinates[0],
                                                          # 'long':coordinates[1]})
                                datarow = pd.Series(data=row_dict)
                                entities_df = entities_df.append(datarow, ignore_index=True)
                if not entities_df.empty:
                    entities_df.drop_duplicates(subset=['s'],inplace=True)
                    entities_df.to_csv('geoLocationInformation/'+file_name.file_name,index=False)
                else:
                    print("No coordinates retrieved for biography. ",file_name.file_name)
            else:
                print("No meetups",file_name.file_name)
            
    print("waiting...")
    time.sleep(20)
# Out:
# 10085.csv
# Already exists. Next.
# 9039.csv
# Already exists. Next.
# 21511.csv
# Already exists. Next.
# 45181.csv
# Already exists. Next.
# 49644.csv
# Already exists. Next.
# 50350.csv
# Already exists. Next.
# 57520.csv
# Already exists. Next.
# 99636.csv
# Already exists. Next.
# 180714.csv
# Already exists. Next.
# 312443.csv
# Already exists. Next.
# waiting...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_71784/3751025463.py in <module>
#      56
#      57     print("waiting...")
# ---> 58     time.sleep(20)
#
# KeyboardInterrupt:

# %% [markdown]
# ### 2. Biography subject information

# %%
# use chunk to load a small number of files in memory
for chunk in pd.read_csv('list_wikiIdSample.csv', chunksize=50):
    df_files = pd.DataFrame()
    df_files['file_name'] = chunk['file_name']

    # for each file/biography in the list, read its sentences 
    # and annotated the entities using the configured sparql endpoint
    for file_name in df_files.itertuples():
        print(file_name.file_name)
        # Read file with segmented sentences
        if os.path.isfile('peopleComplementaryInformation/'+file_name.file_name):
            print("Already exists. Next.")
        else:
            # if os.path.isfile('meetupsAnnotations/'+file_name.file_name):
            #     biography_df = pd.read_csv('meetupsAnnotations/'+file_name.file_name)
            entities_df = pd.DataFrame()
            # for each sentence in the biography
            # for sentence_row in biography_df.itertuples():
                # read people and places entities
            meetupCandidatePP_df = pd.read_csv('extractedEntitiesPersonPlaceOnly/'+file_name.file_name.replace(".txt",".csv"))
            # read coref results
            # print(len(meetupCandidatePP_df))
            # validate if coreference doc exist
            if os.path.isfile('meetupsCorefOutputPP/'+file_name.file_name):
                tempCoref_df = pd.read_csv('meetupsCorefOutputPP/'+file_name.file_name)
                # concat values
                temp_candidate = pd.concat([meetupCandidatePP_df, tempCoref_df], sort=False)
            else:
                print("No coref doc",file_name.file_name)
                temp_candidate = meetupCandidatePP_df.copy()
            temp_candidate = temp_candidate.query("entType == 'person'")
            temp_candidate.drop_duplicates(subset=['URI'],inplace=True)
            
            if temp_candidate.empty:
                print("No person entities.",file_name.file_name)
            else:
                print("Query entities",len(temp_candidate))
                count = 0
                for person in temp_candidate.itertuples():
                    # return a list, with [lat, long]
                    # print(person.URI)
                    labels,values = queryBiographyInformation(person.URI)
                    # print(labels,values)
                    if len(values) > 0:
                        row_dict = dict(zip(labels, values))
                        # if birth or death date empty query wikidata
                        if str(row_dict['birthdate']) == "nan" and str(row_dict['wikidataId']) != "nan":
                            # print(row_dict['wikidataId'])
                            lab, val = queryWikidataEndpoint(row_dict['wikidataId'])
                            row_dates = dict(zip(lab, val))
                            if len(val) > 0:
                                row_dict['birthdate'] = row_dates['birthdate']
                                row_dict['deathdate'] = row_dates['deathdate']

                        datarow = pd.Series(data=row_dict)
                        entities_df = entities_df.append(datarow, ignore_index=True)
                        count +=1
                    if divmod(count, 50)[1] == 0:
                        print("waiting entity...")
                        time.sleep(10)    
            if not entities_df.empty:
                entities_df.to_csv('peopleComplementaryInformation/'+file_name.file_name,index=False)
            else:
                print("No info retrieved for biography. ",file_name.file_name)
            # else:
            #     print("No people",file_name.file_name)
            
    print("waiting biography...")
    time.sleep(20)
# Out:
# 10085.csv
# Already exists. Next.
# 9039.csv
# Already exists. Next.
# 21511.csv
# Already exists. Next.
# 45181.csv
# Already exists. Next.
# 49644.csv
# Already exists. Next.
# 50350.csv
# Already exists. Next.
# 57520.csv
# Already exists. Next.
# 99636.csv
# Already exists. Next.
# 180714.csv
# Already exists. Next.
# 312443.csv
# Already exists. Next.
# 2444917.csv
# Already exists. Next.
# 608845.csv
# Already exists. Next.
# 1048151.csv
# Already exists. Next.
# 2232977.csv
# Already exists. Next.
# 1913885.csv
# Already exists. Next.
# 1790990.csv
# Already exists. Next.
# 409969.csv
# Already exists. Next.
# 1709886.csv
# Already exists. Next.
# 1551347.csv
# Already exists. Next.
# 50782750.csv
# Already exists. Next.
# 181946.csv
# Already exists. Next.
# 579599.csv
# Already exists. Next.
# 50963136.csv
# Already exists. Next.
# 226142.csv
# Already exists. Next.
# 1422240.csv
# Already exists. Next.
# 1174545.csv
# Already exists. Next.
# 70020.csv
# Already exists. Next.
# 752694.csv
# Already exists. Next.
# 312781.csv
# Already exists. Next.
# 2898019.csv
# Already exists. Next.
# 2253021.csv
# Already exists. Next.
# 3450382.csv
# Already exists. Next.
# 2553865.csv
# Already exists. Next.
# 3263983.csv
# Already exists. Next.
# 2320846.csv
# Already exists. Next.
# 144624.csv
# Already exists. Next.
# 827409.csv
# Already exists. Next.
# 50902387.csv
# Already exists. Next.
# 671637.csv
# Already exists. Next.
# 562392.csv
# Already exists. Next.
# 1396921.csv
# Already exists. Next.
# 2815597.csv
# Already exists. Next.
# 858538.csv
# Already exists. Next.
# 2269540.csv
# Already exists. Next.
# 1205991.csv
# Already exists. Next.
# 701860.csv
# Already exists. Next.
# 2334176.csv
# Already exists. Next.
# 252147.csv
# Already exists. Next.
# 652114.csv
# Already exists. Next.
# 320685.csv
# Already exists. Next.
# waiting biography...
# 8716.csv
# Already exists. Next.
# 3606266.csv
# Already exists. Next.
# 576282.csv
# Already exists. Next.
# 1232492.csv
# Already exists. Next.
# 113049.csv
# Already exists. Next.
# 43165.csv
# Already exists. Next.
# 3770842.csv
# Already exists. Next.
# 221191.csv
# Already exists. Next.
# 1491559.csv
# Already exists. Next.
# 1790137.csv
# Already exists. Next.
# 529161.csv
# Already exists. Next.
# 167975.csv
# Already exists. Next.
# 3126224.csv
# Already exists. Next.
# 78231.csv
# Already exists. Next.
# 1022191.csv
# Already exists. Next.
# 154038.csv
# Already exists. Next.
# 223497.csv
# Already exists. Next.
# 356414.csv
# Already exists. Next.
# 2625004.csv
# Already exists. Next.
# 1359335.csv
# Already exists. Next.
# 3081864.csv
# Already exists. Next.
# 2450365.csv
# Already exists. Next.
# 63747.csv
# Already exists. Next.
# 739770.csv
# Already exists. Next.
# 1566844.csv
# Already exists. Next.
# 50230.csv
# Already exists. Next.
# 439467.csv
# Already exists. Next.
# 181985.csv
# Already exists. Next.
# 2296293.csv
# Already exists. Next.
# 2520364.csv
# Already exists. Next.
# 2682932.csv
# Already exists. Next.
# 3302723.csv
# Already exists. Next.
# 51560453.csv
# Already exists. Next.
# 891378.csv
# Already exists. Next.
# 3236079.csv
# Already exists. Next.
# 1914666.csv
# Already exists. Next.
# 1593504.csv
# Already exists. Next.
# 152097.csv
# Already exists. Next.
# 720273.csv
# Already exists. Next.
# 419012.csv
# Already exists. Next.
# 51012206.csv
# Already exists. Next.
# 1234422.csv
# Already exists. Next.
# 994118.csv
# Already exists. Next.
# 1181499.csv
# Already exists. Next.
# 341837.csv
# Already exists. Next.
# 788959.csv
# Already exists. Next.
# 1394504.csv
# Already exists. Next.
# 3818460.csv
# Already exists. Next.
# 52077607.csv
# Already exists. Next.
# 156414.csv
# Already exists. Next.
# waiting biography...
# 3648861.csv
# Already exists. Next.
# 1322881.csv
# Already exists. Next.
# 1009725.csv
# Already exists. Next.
# 371878.csv
# Already exists. Next.
# 208956.csv
# Already exists. Next.
# 2657736.csv
# Already exists. Next.
# 623861.csv
# Already exists. Next.
# 3126438.csv
# Already exists. Next.
# 68308.csv
# Already exists. Next.
# 489381.csv
# Already exists. Next.
# 1113259.csv
# Already exists. Next.
# 806373.csv
# Already exists. Next.
# 284825.csv
# Already exists. Next.
# 2370955.csv
# Already exists. Next.
# 2750379.csv
# Already exists. Next.
# 1433271.csv
# Already exists. Next.
# 756836.csv
# Already exists. Next.
# 51264363.csv
# Already exists. Next.
# 165726.csv
# Already exists. Next.
# 165113.csv
# Already exists. Next.
# 313835.csv
# Already exists. Next.
# 140632.csv
# Already exists. Next.
# 325790.csv
# Already exists. Next.
# 67892.csv
# Already exists. Next.
# 604117.csv
# Already exists. Next.
# 966302.csv
# Already exists. Next.
# 2508330.csv
# Already exists. Next.
# 1474046.csv
# Already exists. Next.
# 554770.csv
# Already exists. Next.
# 196217.csv
# Already exists. Next.
# 2704521.csv
# Already exists. Next.
# 575924.csv
# Already exists. Next.
# 2771033.csv
# Already exists. Next.
# 52811631.csv
# Already exists. Next.
# 526281.csv
# Already exists. Next.
# 2865559.csv
# Already exists. Next.
# 450629.csv
# Already exists. Next.
# 50893532.csv
# Already exists. Next.
# 1013900.csv
# Already exists. Next.
# 2416191.csv
# Already exists. Next.
# 3452637.csv
# Already exists. Next.
# 173225.csv
# Already exists. Next.
# 632683.csv
# Already exists. Next.
# 991714.csv
# Already exists. Next.
# 1254002.csv
# Already exists. Next.
# 618129.csv
# Already exists. Next.
# 1052490.csv
# Already exists. Next.
# 54878.csv
# Already exists. Next.
# 3143897.csv
# Already exists. Next.
# 1023303.csv
# Already exists. Next.
# waiting biography...
# 44459.csv
# Already exists. Next.
# 481738.csv
# Already exists. Next.
# 2236628.csv
# Already exists. Next.
# 1359293.csv
# Already exists. Next.
# 712322.csv
# Already exists. Next.
# 310022.csv
# Already exists. Next.
# 50798971.csv
# Already exists. Next.
# 1566892.csv
# Already exists. Next.
# 1497012.csv
# Already exists. Next.
# 52011352.csv
# Already exists. Next.
# 2659909.csv
# Already exists. Next.
# 933559.csv
# Already exists. Next.
# 2825270.csv
# Already exists. Next.
# 3365880.csv
# Already exists. Next.
# 50674376.csv
# Already exists. Next.
# 825643.csv
# Already exists. Next.
# 1338619.csv
# Already exists. Next.
# 615348.csv
# Already exists. Next.
# 12945.csv
# Already exists. Next.
# 874862.csv
# Already exists. Next.
# 3141790.csv
# Already exists. Next.
# 838629.csv
# Already exists. Next.
# 492026.csv
# Already exists. Next.
# 2351271.csv
# Already exists. Next.
# 3394339.csv
# Already exists. Next.
# 512518.csv
# Already exists. Next.
# 1429918.csv
# Already exists. Next.
# 716617.csv
# Already exists. Next.
# 1296456.csv
# Already exists. Next.
# 3514919.csv
# Already exists. Next.
# 1127222.csv
# Already exists. Next.
# 50655124.csv
# Already exists. Next.
# 1733863.csv
# Already exists. Next.
# 58067.csv
# Already exists. Next.
# 1758540.csv
# Already exists. Next.
# 1730644.csv
# Already exists. Next.
# 1213916.csv
# Already exists. Next.
# 155965.csv
# Already exists. Next.
# 189182.csv
# Already exists. Next.
# 1073691.csv
# Already exists. Next.
# 1253793.csv
# Already exists. Next.
# 49906.csv
# Already exists. Next.
# 5033.csv
# Already exists. Next.
# 647545.csv
# Already exists. Next.
# 100273.csv
# Already exists. Next.
# 1263963.csv
# Already exists. Next.
# 442318.csv
# Already exists. Next.
# 1098118.csv
# Already exists. Next.
# 648294.csv
# Already exists. Next.
# 918090.csv
# Already exists. Next.
# waiting biography...
# 868762.csv
# Already exists. Next.
# 1321577.csv
# Already exists. Next.
# 553740.csv
# Already exists. Next.
# 523339.csv
# Already exists. Next.
# 20405.csv
# Already exists. Next.
# 50734876.csv
# Already exists. Next.
# 18571.csv
# Already exists. Next.
# 238175.csv
# Already exists. Next.
# 950070.csv
# Already exists. Next.
# 1597545.csv
# Already exists. Next.
# 1599087.csv
# Already exists. Next.
# 437777.csv
# Already exists. Next.
# 1786533.csv
# Already exists. Next.
# 797572.csv
# Already exists. Next.
# 652155.csv
# Already exists. Next.
# 3236194.csv
# Already exists. Next.
# 655613.csv
# Already exists. Next.
# 3064783.csv
# Already exists. Next.
# 7672.csv
# Already exists. Next.
# 43823.csv
# Already exists. Next.
# 3521750.csv
# Already exists. Next.
# 379324.csv
# Already exists. Next.
# 2441284.csv
# Already exists. Next.
# 3606301.csv
# Already exists. Next.
# 346303.csv
# Already exists. Next.
# 1070521.csv
# Already exists. Next.
# 280945.csv
# Already exists. Next.
# 1798531.csv
# Already exists. Next.
# 52191236.csv
# No coref doc 52191236.csv
# No person entities. 52191236.csv
# No info retrieved for biography.  52191236.csv
# 262463.csv
# Already exists. Next.
# 52170176.csv
# Already exists. Next.
# 345114.csv
# Already exists. Next.
# 1049483.csv
# Already exists. Next.
# 2871279.csv
# Already exists. Next.
# 442116.csv
# Already exists. Next.
# 3212385.csv
# Already exists. Next.
# 259159.csv
# Already exists. Next.
# 1234606.csv
# Already exists. Next.
# 741791.csv
# Already exists. Next.
# 50929631.csv
# Already exists. Next.
# 592841.csv
# Already exists. Next.
# 1560872.csv
# Already exists. Next.
# 1790603.csv
# Already exists. Next.
# 559163.csv
# Already exists. Next.
# 176912.csv
# Already exists. Next.
# 782651.csv
# Already exists. Next.
# 150095.csv
# Already exists. Next.
# 221558.csv
# Already exists. Next.
# 2474795.csv
# Already exists. Next.
# 1410438.csv
# Already exists. Next.
# waiting biography...
# 39467.csv
# Already exists. Next.
# 1456343.csv
# Already exists. Next.
# 413078.csv
# Already exists. Next.
# 166529.csv
# Already exists. Next.
# 523975.csv
# Already exists. Next.
# 52007703.csv
# Already exists. Next.
# 52269.csv
# Already exists. Next.
# 2539541.csv
# Already exists. Next.
# 1540074.csv
# Already exists. Next.
# 1561694.csv
# Already exists. Next.
# 344562.csv
# Already exists. Next.
# 391522.csv
# Already exists. Next.
# 2334505.csv
# Already exists. Next.
# 870413.csv
# Already exists. Next.
# 715167.csv
# Already exists. Next.
# 42203.csv
# Already exists. Next.
# 19318.csv
# Already exists. Next.
# 366362.csv
# Already exists. Next.
# 948305.csv
# Already exists. Next.
# 625857.csv
# Already exists. Next.
# 585649.csv
# Already exists. Next.
# 486934.csv
# Already exists. Next.
# 1808209.csv
# Already exists. Next.
# 984106.csv
# Already exists. Next.
# 76252.csv
# Already exists. Next.
# 220271.csv
# Already exists. Next.
# 1439437.csv
# Already exists. Next.
# 52926317.csv
# Already exists. Next.
# 192024.csv
# Already exists. Next.
# 1215145.csv
# Already exists. Next.
# 1569660.csv
# Already exists. Next.
# 248708.csv
# Already exists. Next.
# 3372135.csv
# Already exists. Next.
# 51382438.csv
# Already exists. Next.
# 8300.csv
# Already exists. Next.
# 1788051.csv
# Already exists. Next.
# 70986.csv
# Already exists. Next.
# 3337272.csv
# Already exists. Next.
# 3301109.csv
# Already exists. Next.
# 630312.csv
# Already exists. Next.
# 399509.csv
# Already exists. Next.
# 277731.csv
# Already exists. Next.
# 347201.csv
# Already exists. Next.
# 459887.csv
# Already exists. Next.
# 1188821.csv
# Already exists. Next.
# 250370.csv
# Already exists. Next.
# 177220.csv
# Already exists. Next.
# 850294.csv
# Already exists. Next.
# 2423427.csv
# Already exists. Next.
# 51055506.csv
# Already exists. Next.
# waiting biography...
# 399102.csv
# Already exists. Next.
# 984982.csv
# Already exists. Next.
# 3696100.csv
# Already exists. Next.
# 3418089.csv
# Already exists. Next.
# 1142145.csv
# Already exists. Next.
# 165697.csv
# Already exists. Next.
# 512497.csv
# Already exists. Next.
# 505799.csv
# Already exists. Next.
# 647820.csv
# Already exists. Next.
# 3079914.csv
# Already exists. Next.
# 719979.csv
# Already exists. Next.
# 734633.csv
# Already exists. Next.
# 316711.csv
# Already exists. Next.
# 1118112.csv
# Already exists. Next.
# 232719.csv
# Already exists. Next.
# 90447.csv
# Already exists. Next.
# 370445.csv
# Already exists. Next.
# 1186480.csv
# Already exists. Next.
# 52114060.csv
# Already exists. Next.
# 1129635.csv
# Already exists. Next.
# 1093129.csv
# Already exists. Next.
# 245879.csv
# Already exists. Next.
# 770812.csv
# Already exists. Next.
# 51449857.csv
# Already exists. Next.
# 3547359.csv
# Already exists. Next.
# 3596773.csv
# Already exists. Next.
# 51033485.csv
# Already exists. Next.
# 3561690.csv
# Already exists. Next.
# 100487.csv
# Already exists. Next.
# 2401011.csv
# Already exists. Next.
# 2385870.csv
# Already exists. Next.
# 1595398.csv
# Already exists. Next.
# 166331.csv
# Already exists. Next.
# 3266294.csv
# Already exists. Next.
# 488800.csv
# Already exists. Next.
# 7585.csv
# Already exists. Next.
# 3757644.csv
# Already exists. Next.
# 3190132.csv
# Already exists. Next.
# 790333.csv
# Already exists. Next.
# 2755844.csv
# Already exists. Next.
# 3280230.csv
# Already exists. Next.
# 2591808.csv
# Already exists. Next.
# 350673.csv
# Already exists. Next.
# 1354212.csv
# Already exists. Next.
# 1598663.csv
# Already exists. Next.
# 2850239.csv
# Already exists. Next.
# 314487.csv
# Already exists. Next.
# 540027.csv
# Already exists. Next.
# 556410.csv
# Already exists. Next.
# 2484677.csv
# Already exists. Next.
# waiting biography...
# 3488554.csv
# Already exists. Next.
# 364506.csv
# Already exists. Next.
# 671985.csv
# Already exists. Next.
# 343176.csv
# Already exists. Next.
# 198362.csv
# Already exists. Next.
# 194903.csv
# Already exists. Next.
# 351206.csv
# Already exists. Next.
# 2451984.csv
# Already exists. Next.
# 777352.csv
# Already exists. Next.
# 981787.csv
# Already exists. Next.
# 1343880.csv
# Already exists. Next.
# 2558336.csv
# Already exists. Next.
# 52266861.csv
# Already exists. Next.
# 67379.csv
# Already exists. Next.
# 984900.csv
# Already exists. Next.
# 493715.csv
# Already exists. Next.
# 2341385.csv
# Already exists. Next.
# 1876457.csv
# Already exists. Next.
# 49370.csv
# Already exists. Next.
# 1413746.csv
# Already exists. Next.
# 3136059.csv
# Already exists. Next.
# 907187.csv
# Already exists. Next.
# 525151.csv
# Already exists. Next.
# 877017.csv
# Already exists. Next.
# 2457905.csv
# Already exists. Next.
# 736528.csv
# Already exists. Next.
# 3583583.csv
# Already exists. Next.
# 277524.csv
# Already exists. Next.
# 3620666.csv
# Already exists. Next.
# 728429.csv
# Already exists. Next.
# 306480.csv
# Already exists. Next.
# 240002.csv
# Already exists. Next.
# 1056463.csv
# Already exists. Next.
# 3622246.csv
# Already exists. Next.
# 45450.csv
# Already exists. Next.
# 1147577.csv
# Already exists. Next.
# 290808.csv
# Already exists. Next.
# 1148248.csv
# Already exists. Next.
# 827624.csv
# Already exists. Next.
# 2563311.csv
# Already exists. Next.
# 2911472.csv
# Already exists. Next.
# 936912.csv
# Already exists. Next.
# 3228328.csv
# Already exists. Next.
# 1271437.csv
# Already exists. Next.
# 10671.csv
# Already exists. Next.
# 52527037.csv
# Already exists. Next.
# 51328130.csv
# Already exists. Next.
# 1228021.csv
# Already exists. Next.
# 544455.csv
# Already exists. Next.
# 711489.csv
# Already exists. Next.
# waiting biography...
# 1758122.csv
# Already exists. Next.
# 528652.csv
# Already exists. Next.
# 164481.csv
# Already exists. Next.
# 149935.csv
# Already exists. Next.
# 50452.csv
# Already exists. Next.
# 1196793.csv
# Already exists. Next.
# 51082587.csv
# Already exists. Next.
# 1433411.csv
# Already exists. Next.
# 1425206.csv
# Already exists. Next.
# 17902.csv
# Already exists. Next.
# 2706101.csv
# Already exists. Next.
# 413210.csv
# Already exists. Next.
# 1253783.csv
# Already exists. Next.
# 52811997.csv
# Already exists. Next.
# 3779497.csv
# Already exists. Next.
# 289669.csv
# Already exists. Next.
# 2233161.csv
# No coref doc 2233161.csv
# Query entities 7
# 238765.csv
# Query entities 61
# No entity http://www.wikidata.org/entity/Q17011395
# waiting entity...
# No entity http://www.wikidata.org/entity/Q35230
# No entity http://www.wikidata.org/entity/Q7692317
# No entity http://www.wikidata.org/entity/Q52954
# No entity http://www.wikidata.org/entity/Q3064924
# No entity http://www.wikidata.org/entity/Q7256276
# No entity http://www.wikidata.org/entity/Q190
# 2343819.csv
# Query entities 5
# 1826921.csv
# Query entities 21
# No entity http://www.wikidata.org/entity/Q46185
# No entity http://www.wikidata.org/entity/Q190
# No entity http://www.wikidata.org/entity/Q43482
# 3683614.csv
# Query entities 25
# No entity http://www.wikidata.org/entity/Q52954
# No entity http://www.wikidata.org/entity/Q327591
# No entity http://www.wikidata.org/entity/Q93190
# No entity http://www.wikidata.org/entity/Q4676716
# 1588479.csv
# No coref doc 1588479.csv
# Query entities 9
# No entity http://www.wikidata.org/entity/Q46185
# No entity http://www.wikidata.org/entity/Q181508
# 265877.csv
# Query entities 50
# No entity http://www.wikidata.org/entity/Q3467762
# No entity http://www.wikidata.org/entity/Q1929614
# No entity http://www.wikidata.org/entity/Q1048625
# No entity http://www.wikidata.org/entity/Q100321220
# No entity http://www.wikidata.org/entity/Q3064924
# No entity http://www.wikidata.org/entity/Q2379868
# waiting entity...
# 46038.csv
# Query entities 67
# waiting entity...
# No entity http://www.wikidata.org/entity/Q93190
# No entity http://www.wikidata.org/entity/Q21
# No entity http://www.wikidata.org/entity/Q311396
# No entity http://www.wikidata.org/entity/Q14211
# No entity http://www.wikidata.org/entity/Q180095
# No entity http://www.wikidata.org/entity/Q157188
# No entity http://www.wikidata.org/entity/Q61002
# 3986.csv
# Query entities 141
# No entity http://www.wikidata.org/entity/Q6754430
# No entity http://www.wikidata.org/entity/Q8013890
# waiting entity...
# No entity http://www.wikidata.org/entity/Q3467762
# No entity http://www.wikidata.org/entity/Q5931812
# waiting entity...
# No entity http://www.wikidata.org/entity/Q683754
# No entity http://www.wikidata.org/entity/Q1753094
# No entity http://www.wikidata.org/entity/Q61002
# No entity http://www.wikidata.org/entity/Q12888135
# No entity http://www.wikidata.org/entity/Q21
# No entity http://www.wikidata.org/entity/Q190
# No entity http://www.wikidata.org/entity/Q25
# No entity http://www.wikidata.org/entity/Q727002
# No entity http://www.wikidata.org/entity/Q912994
# No entity http://www.wikidata.org/entity/Q1048625
# No entity http://www.wikidata.org/entity/Q583809
# No entity http://www.wikidata.org/entity/Q1058375
# No entity http://www.wikidata.org/entity/Q12859263
# No entity http://www.wikidata.org/entity/Q473194
# No entity http://www.wikidata.org/entity/Q178122
# No entity http://www.wikidata.org/entity/Q854022
# No entity http://www.wikidata.org/entity/Q1127126
# No entity http://www.wikidata.org/entity/Q3897647
# 3816378.csv
# Query entities 15
# 1338168.csv
# Query entities 50
# No entity http://www.wikidata.org/entity/Q390776
# No entity http://www.wikidata.org/entity/Q1324254
# No entity http://www.wikidata.org/entity/Q190
# No entity http://www.wikidata.org/entity/Q172324
# No entity http://www.wikidata.org/entity/Q220340
# waiting entity...
# 103566.csv
# Query entities 47
# No entity http://www.wikidata.org/entity/Q912994
# No entity http://www.wikidata.org/entity/Q4698345
# No entity http://www.wikidata.org/entity/Q98560886
# No entity http://www.wikidata.org/entity/Q124964
# No entity http://www.wikidata.org/entity/Q2347975
# No entity http://www.wikidata.org/entity/Q1428637
# No entity http://www.wikidata.org/entity/Q1062485
# No entity http://www.wikidata.org/entity/Q181508
# 1065532.csv
# Query entities 22
# No entity http://www.wikidata.org/entity/Q1320883
# No entity http://www.wikidata.org/entity/Q15839121
# 2431461.csv
# No coref doc 2431461.csv
# Query entities 6
# No entity http://www.wikidata.org/entity/Q390776
# No entity http://www.wikidata.org/entity/Q209726
# 52557970.csv
# Query entities 9
# 1077508.csv
# Query entities 10
# No entity http://www.wikidata.org/entity/Q1414932
# No entity http://www.wikidata.org/entity/Q119621
# 597665.csv
# No coref doc 597665.csv
# Query entities 5
# 330103.csv
# Query entities 13
# 582519.csv
# Query entities 59
# No entity http://www.wikidata.org/entity/Q3064924
# waiting entity...
# No entity http://www.wikidata.org/entity/Q105891
# No entity http://www.wikidata.org/entity/Q1136507
# No entity http://www.wikidata.org/entity/Q743659
# No entity http://www.wikidata.org/entity/Q46185
# No entity http://www.wikidata.org/entity/Q185030
# No entity http://www.wikidata.org/entity/Q52954
# 351996.csv
# Query entities 55
# No entity http://www.wikidata.org/entity/Q315796
# No entity http://www.wikidata.org/entity/Q93190
# No entity http://www.wikidata.org/entity/Q1429537
# No entity http://www.wikidata.org/entity/Q842782
# waiting entity...
# No entity http://www.wikidata.org/entity/Q3031
# No entity http://www.wikidata.org/entity/Q5317167
# No entity http://www.wikidata.org/entity/Q960322
# 670076.csv
# Query entities 21
# No entity http://www.wikidata.org/entity/Q4610556
# No entity http://www.wikidata.org/entity/Q1187828
# No entity http://www.wikidata.org/entity/Q93190
# 833172.csv
# Query entities 27
# No entity http://www.wikidata.org/entity/Q180095
# No entity http://www.wikidata.org/entity/Q61002
# No entity http://www.wikidata.org/entity/Q181043
# 3798459.csv
# Query entities 24
# No entity http://www.wikidata.org/entity/Q1202416
# No entity http://www.wikidata.org/entity/Q627325
# 381560.csv
# Query entities 55
# No entity http://www.wikidata.org/entity/Q78987
# No entity http://www.wikidata.org/entity/Q670969
# No entity http://www.wikidata.org/entity/Q61002
# No entity http://www.wikidata.org/entity/Q46185
# No entity http://www.wikidata.org/entity/Q93190
# waiting entity...
# No entity http://www.wikidata.org/entity/Q701040
# No entity http://www.wikidata.org/entity/Q5303755
# No entity http://www.wikidata.org/entity/Q2736003
# 51940478.csv
# Query entities 4
# 537467.csv
# Query entities 14
# 50931287.csv
# No coref doc 50931287.csv
# Query entities 5
# 618069.csv
# Query entities 7
# 274424.csv
# Query entities 64
# waiting entity...
# No entity http://www.wikidata.org/entity/Q46185
# No entity http://www.wikidata.org/entity/Q5702833
# 1476033.csv
# Query entities 8
# 53408.csv
# Query entities 39
# No entity http://www.wikidata.org/entity/Q1938795
# No entity http://www.wikidata.org/entity/Q93190
# No entity http://www.wikidata.org/entity/Q204917
# No entity http://www.wikidata.org/entity/Q191931
# No entity http://www.wikidata.org/entity/Q4970706
# No entity http://www.wikidata.org/entity/Q159791
# No entity http://www.wikidata.org/entity/Q1649271
# 1503167.csv
# Query entities 38
# No entity http://www.wikidata.org/entity/Q190
# No entity http://www.wikidata.org/entity/Q637934
# No entity http://www.wikidata.org/entity/Q3031
# No entity http://www.wikidata.org/entity/Q7560
# No entity http://www.wikidata.org/entity/Q570600
# 2281945.csv
# Query entities 58
# No entity http://www.wikidata.org/entity/Q54006618
# No entity http://www.wikidata.org/entity/Q7565
# No entity http://www.wikidata.org/entity/Q12460259
# No entity http://www.wikidata.org/entity/Q190
# No entity http://www.wikidata.org/entity/Q3064924
# waiting entity...
# No entity http://www.wikidata.org/entity/Q46185
# No entity http://www.wikidata.org/entity/Q45792
# No entity http://www.wikidata.org/entity/Q174376
# 2800969.csv
# Query entities 13
# No entity http://www.wikidata.org/entity/Q201610
# No entity http://www.wikidata.org/entity/Q3031
# waiting biography...
# 113560.csv
# Query entities 17
# No entity http://www.wikidata.org/entity/Q121998
# 2490118.csv
# Query entities 43
# No entity http://www.wikidata.org/entity/Q209726
# No entity http://www.wikidata.org/entity/Q719120
# No entity http://www.wikidata.org/entity/Q2554364
# No entity http://www.wikidata.org/entity/Q5663900
# No entity http://www.wikidata.org/entity/Q178122
# No entity http://www.wikidata.org/entity/Q78987
# No entity http://www.wikidata.org/entity/Q6001615
# 3517771.csv
# No coref doc 3517771.csv
# Query entities 8
# 2891853.csv
# No coref doc 2891853.csv
# Query entities 8
# 2377280.csv
# Query entities 14
# 592843.csv
# Query entities 128
# No entity http://www.wikidata.org/entity/Q1879787
# waiting entity...
# waiting entity...
# No entity http://www.wikidata.org/entity/Q45792
# No entity http://www.wikidata.org/entity/Q3031
# No entity http://www.wikidata.org/entity/Q1309178
# No entity http://www.wikidata.org/entity/Q93190
# No entity http://www.wikidata.org/entity/Q21
# No entity http://www.wikidata.org/entity/Q190
# No entity http://www.wikidata.org/entity/Q854022
# No entity http://www.wikidata.org/entity/Q8161
# No entity http://www.wikidata.org/entity/Q2347975
# No entity http://www.wikidata.org/entity/Q7749836
# No entity http://www.wikidata.org/entity/Q518503
# No entity http://www.wikidata.org/entity/Q294660
# 754282.csv
# Query entities 32
# No entity http://www.wikidata.org/entity/Q186393
# No entity http://www.wikidata.org/entity/Q21
# No entity http://www.wikidata.org/entity/Q570600
# 50674114.csv
# Query entities 1
# 386760.csv
# Query entities 13
# No entity http://www.wikidata.org/entity/Q45792
# 52837049.csv
# Query entities 9
# No entity http://www.wikidata.org/entity/Q670969
# No entity http://www.wikidata.org/entity/Q46185
# 20484.csv
# Query entities 13
# 2437473.csv
# Query entities 20
# No entity http://www.wikidata.org/entity/Q128309
# No entity http://www.wikidata.org/entity/Q78987
# No entity http://www.wikidata.org/entity/Q203443
# 1391973.csv
# Query entities 52
# No entity http://www.wikidata.org/entity/Q2748714
# No entity http://www.wikidata.org/entity/Q7347143
# No entity http://www.wikidata.org/entity/Q4610556
# No entity http://www.wikidata.org/entity/Q582878
# No entity http://www.wikidata.org/entity/Q41767
# No entity http://www.wikidata.org/entity/Q93190
# No entity http://www.wikidata.org/entity/Q1428637
# No entity http://www.wikidata.org/entity/Q222344
# waiting entity...
# No entity http://www.wikidata.org/entity/Q1506823
# 89644.csv
# Query entities 138
# No entity http://www.wikidata.org/entity/Q529890
# No entity http://www.wikidata.org/entity/Q60769379
# No entity http://www.wikidata.org/entity/Q16650804
# waiting entity...
# waiting entity...
# No entity http://www.wikidata.org/entity/Q3246315
# No entity http://www.wikidata.org/entity/Q43414
# No entity http://www.wikidata.org/entity/Q3064924
# No entity http://www.wikidata.org/entity/Q7560
# No entity http://www.wikidata.org/entity/Q3031
# No entity http://www.wikidata.org/entity/Q510477
# No entity http://www.wikidata.org/entity/Q14560
# No entity http://www.wikidata.org/entity/Q570600
# No entity http://www.wikidata.org/entity/Q4886928
# No entity http://www.wikidata.org/entity/Q93190
# No entity http://www.wikidata.org/entity/Q1753094
# 621065.csv
# Query entities 41
# No entity http://www.wikidata.org/entity/Q61002
# No entity http://www.wikidata.org/entity/Q1062485
# No entity http://www.wikidata.org/entity/Q11404
# No entity http://www.wikidata.org/entity/Q1989225
# No entity http://www.wikidata.org/entity/Q45792
# No entity http://www.wikidata.org/entity/Q1948826
# 1000228.csv
# Query entities 15
# No entity http://www.wikidata.org/entity/Q1048625
# No entity http://www.wikidata.org/entity/Q21
# No entity http://www.wikidata.org/entity/Q486748
# No entity http://www.wikidata.org/entity/Q1404101
# 622305.csv
# Query entities 23
# No entity http://www.wikidata.org/entity/Q105891
# 37931.csv
# Query entities 39
# No entity http://www.wikidata.org/entity/Q1050350
# No entity http://www.wikidata.org/entity/Q781470
# No entity http://www.wikidata.org/entity/Q751845
# No entity http://www.wikidata.org/entity/Q578706
# No entity http://www.wikidata.org/entity/Q578781
# 50947405.csv
# No coref doc 50947405.csv
# Query entities 14
# No entity http://www.wikidata.org/entity/Q61002
# 759988.csv
# Query entities 5
# 515447.csv
# Query entities 106
# No entity http://www.wikidata.org/entity/Q19662915
# No entity http://www.wikidata.org/entity/Q4907223
# No entity http://www.wikidata.org/entity/Q3521481
# No entity http://www.wikidata.org/entity/Q20687316
# No entity http://www.wikidata.org/entity/Q99266990
# waiting entity...
# No entity http://www.wikidata.org/entity/Q19894300
# No entity http://www.wikidata.org/entity/Q684172
# No entity http://www.wikidata.org/entity/Q17065562
# No entity http://www.wikidata.org/entity/Q235102
# No entity http://www.wikidata.org/entity/Q380817
# No entity http://www.wikidata.org/entity/Q188618
# No entity http://www.wikidata.org/entity/Q42891
# No entity http://www.wikidata.org/entity/Q844066
# No entity http://www.wikidata.org/entity/Q55577673
# No entity http://www.wikidata.org/entity/Q185790
# No entity http://www.wikidata.org/entity/Q128335
# No entity http://www.wikidata.org/entity/Q131443
# No entity http://www.wikidata.org/entity/Q184128
# No entity http://www.wikidata.org/entity/Q1420806
# waiting entity...
# No entity http://www.wikidata.org/entity/Q145811
# No entity http://www.wikidata.org/entity/Q1123156
# No entity http://www.wikidata.org/entity/Q1670755
# No entity http://www.wikidata.org/entity/Q13160318
# No entity http://www.wikidata.org/entity/Q16949891
# 1774359.csv
# Query entities 16
# 707930.csv
# Query entities 53
# No entity http://www.wikidata.org/entity/Q93190
# waiting entity...
# No entity http://www.wikidata.org/entity/Q2793
# No entity http://www.wikidata.org/entity/Q181508
# No entity http://www.wikidata.org/entity/Q842782
# 1753869.csv
# Query entities 46
# No entity http://www.wikidata.org/entity/Q190
# No entity http://www.wikidata.org/entity/Q61002
# No entity http://www.wikidata.org/entity/Q797245
# No entity http://www.wikidata.org/entity/Q480
# 2960907.csv
# Query entities 33
# No entity http://www.wikidata.org/entity/Q21030365
# No entity http://www.wikidata.org/entity/Q223166
# No entity http://www.wikidata.org/entity/Q842782
# No entity http://www.wikidata.org/entity/Q16585114
# No entity http://www.wikidata.org/entity/Q193291
# No entity http://www.wikidata.org/entity/Q186506
# No entity http://www.wikidata.org/entity/Q5011
# No entity http://www.wikidata.org/entity/Q190
# No entity http://www.wikidata.org/entity/Q309481
# 696261.csv
# Query entities 6
# No entity http://www.wikidata.org/entity/Q21
# 2579694.csv
# Query entities 36
# No entity http://www.wikidata.org/entity/Q46185
# No entity http://www.wikidata.org/entity/Q190
# No entity http://www.wikidata.org/entity/Q856887
# No entity http://www.wikidata.org/entity/Q21
# No entity http://www.wikidata.org/entity/Q1062485
# No entity http://www.wikidata.org/entity/Q5230592
# 1092607.csv
# No coref doc 1092607.csv
# Query entities 29
# No entity http://www.wikidata.org/entity/Q33231
# No entity http://www.wikidata.org/entity/Q12570611
# No entity http://www.wikidata.org/entity/Q408832
# No entity http://www.wikidata.org/entity/Q115161670
# No entity http://www.wikidata.org/entity/Q190
# No entity http://www.wikidata.org/entity/Q1404101
# 1407035.csv
# No coref doc 1407035.csv
# Query entities 15
# No entity http://www.wikidata.org/entity/Q4745239
# 3180885.csv
# Query entities 13
# No entity http://www.wikidata.org/entity/Q1097769
# No entity http://www.wikidata.org/entity/Q190
# No entity http://www.wikidata.org/entity/Q93190
# 1787782.csv
# Query entities 9
# 1189627.csv
# Query entities 51
# No entity http://www.wikidata.org/entity/Q93190
# No entity http://www.wikidata.org/entity/Q82955
# No entity http://www.wikidata.org/entity/Q209726
# No entity http://www.wikidata.org/entity/Q808967
# No entity http://www.wikidata.org/entity/Q486839
# No entity http://www.wikidata.org/entity/Q4594605
# No entity http://www.wikidata.org/entity/Q14211
# No entity http://www.wikidata.org/entity/Q190
# No entity http://www.wikidata.org/entity/Q4182927
# No entity http://www.wikidata.org/entity/Q7560
# No entity http://www.wikidata.org/entity/Q12093185
# waiting entity...
# 1354864.csv
# Query entities 10
# 1733334.csv
# Query entities 15
# No entity http://www.wikidata.org/entity/Q1996635
# No entity http://www.wikidata.org/entity/Q327591
# 1451518.csv
# Query entities 49
# No entity http://www.wikidata.org/entity/Q12681
# No entity http://www.wikidata.org/entity/Q288728
# No entity http://www.wikidata.org/entity/Q100321220
# No entity http://www.wikidata.org/entity/Q173950
# 855002.csv
# Query entities 45
# No entity http://www.wikidata.org/entity/Q3467762
# No entity http://www.wikidata.org/entity/Q593995
# No entity http://www.wikidata.org/entity/Q1022293
# No entity http://www.wikidata.org/entity/Q178122
# No entity http://www.wikidata.org/entity/Q3925355
# 154959.csv
# Query entities 32
# No entity http://www.wikidata.org/entity/Q190103
# No entity http://www.wikidata.org/entity/Q1948826
# No entity http://www.wikidata.org/entity/Q45792
# No entity http://www.wikidata.org/entity/Q186506
# No entity http://www.wikidata.org/entity/Q40125
# 2834129.csv
# No coref doc 2834129.csv
# Query entities 12
# No entity http://www.wikidata.org/entity/Q7369015
# No entity http://www.wikidata.org/entity/Q270200
# 2864817.csv
# Query entities 26
# No entity http://www.wikidata.org/entity/Q16864871
# No entity http://www.wikidata.org/entity/Q2528142
# 1010943.csv
# Query entities 6
# No entity http://www.wikidata.org/entity/Q1429537
# No entity http://www.wikidata.org/entity/Q190
# 145644.csv
# Query entities 30
# 290117.csv
# Query entities 79
# No entity http://www.wikidata.org/entity/Q5524846
# No entity http://www.wikidata.org/entity/Q16229012
# waiting entity...
# No entity http://www.wikidata.org/entity/Q174376
# No entity http://www.wikidata.org/entity/Q46185
# No entity http://www.wikidata.org/entity/Q78987
# No entity http://www.wikidata.org/entity/Q570600
# No entity http://www.wikidata.org/entity/Q52954
# No entity http://www.wikidata.org/entity/Q3031
# No entity http://www.wikidata.org/entity/Q105891
# 209276.csv
# Query entities 32
# No entity http://www.wikidata.org/entity/Q201559
# No entity http://www.wikidata.org/entity/Q133067
# No entity http://www.wikidata.org/entity/Q1889
# No entity http://www.wikidata.org/entity/Q190
# 747500.csv
# Query entities 33
# No entity http://www.wikidata.org/entity/Q3031
# No entity http://www.wikidata.org/entity/Q209515
# No entity http://www.wikidata.org/entity/Q1429537
# No entity http://www.wikidata.org/entity/Q45792
# No entity http://www.wikidata.org/entity/Q46185
# No entity http://www.wikidata.org/entity/Q78987
# No entity http://www.wikidata.org/entity/Q21
# No entity http://www.wikidata.org/entity/Q7560
# No entity http://www.wikidata.org/entity/Q1514653
# 60907.csv
# Query entities 29
# 61641.csv
# Query entities 117
# waiting entity...
# No entity http://www.wikidata.org/entity/Q7151008
# No entity http://www.wikidata.org/entity/Q81422
# No entity http://www.wikidata.org/entity/Q210372
# No entity http://www.wikidata.org/entity/Q25
# waiting entity...
# No entity http://www.wikidata.org/entity/Q476713
# No entity http://www.wikidata.org/entity/Q7749836
# No entity http://www.wikidata.org/entity/Q1428637
# No entity http://www.wikidata.org/entity/Q23653
# No entity http://www.wikidata.org/entity/Q7764318
# No entity http://www.wikidata.org/entity/Q2190927
# No entity http://www.wikidata.org/entity/Q181598
# 1115155.csv
# Query entities 28
# No entity http://www.wikidata.org/entity/Q1062485
# 2985243.csv
# Query entities 66
# waiting entity...
# No entity http://www.wikidata.org/entity/Q1259115
# 3027978.csv
# Query entities 13
# No entity http://www.wikidata.org/entity/Q203209
# No entity http://www.wikidata.org/entity/Q52954
# 897299.csv
# Query entities 52
# No entity http://www.wikidata.org/entity/Q1309178
# No entity http://www.wikidata.org/entity/Q1048625
# No entity http://www.wikidata.org/entity/Q21
# No entity http://www.wikidata.org/entity/Q674564
# No entity http://www.wikidata.org/entity/Q719039
# No entity http://www.wikidata.org/entity/Q570600
# No entity http://www.wikidata.org/entity/Q7721081
# No entity http://www.wikidata.org/entity/Q93190
# waiting entity...
# waiting biography...
# 1058567.csv
# Query entities 9
# No entity http://www.wikidata.org/entity/Q4413332
# 8095.csv
# Query entities 21
# No entity http://www.wikidata.org/entity/Q82594
# No entity http://www.wikidata.org/entity/Q12681
# No entity http://www.wikidata.org/entity/Q190
# No entity http://www.wikidata.org/entity/Q6501380
# No entity http://www.wikidata.org/entity/Q570600
# No entity http://www.wikidata.org/entity/Q461406
# No entity http://www.wikidata.org/entity/Q18032659
# 8351.csv
# Query entities 46
# No entity http://www.wikidata.org/entity/Q81422
# No entity http://www.wikidata.org/entity/Q174376
# No entity http://www.wikidata.org/entity/Q61002
# No entity http://www.wikidata.org/entity/Q45792
# 1103482.csv
# Query entities 62
# No entity http://www.wikidata.org/entity/Q19662915
# No entity http://www.wikidata.org/entity/Q19663840
# waiting entity...
# No entity http://www.wikidata.org/entity/Q20687316
# No entity http://www.wikidata.org/entity/Q1755412
# No entity http://www.wikidata.org/entity/Q2961972
# No entity http://www.wikidata.org/entity/Q190
# 2508150.csv
# Query entities 6
# No entity http://www.wikidata.org/entity/Q1581457
# No entity http://www.wikidata.org/entity/Q390776
# 1605379.csv
# Query entities 12
# 154191.csv
# Query entities 76
# No entity http://www.wikidata.org/entity/Q6398900
# No entity http://www.wikidata.org/entity/Q12485474
# waiting entity...
# No entity http://www.wikidata.org/entity/Q1670755
# No entity http://www.wikidata.org/entity/Q1364673
# No entity http://www.wikidata.org/entity/Q190
# No entity http://www.wikidata.org/entity/Q35230
# 1520949.csv
# Query entities 11
# No entity http://www.wikidata.org/entity/Q842782
# 125311.csv
# Query entities 39
# No entity http://www.wikidata.org/entity/Q1391360
# No entity http://www.wikidata.org/entity/Q46185
# No entity http://www.wikidata.org/entity/Q1344174
# No entity http://www.wikidata.org/entity/Q5442485
# 703488.csv
# Query entities 83
# No entity http://www.wikidata.org/entity/Q108680255
# waiting entity...
# No entity http://www.wikidata.org/entity/Q16226328
# No entity http://www.wikidata.org/entity/Q1034298
# No entity http://www.wikidata.org/entity/Q46185
# No entity http://www.wikidata.org/entity/Q3031
# No entity http://www.wikidata.org/entity/Q16585114
# No entity http://www.wikidata.org/entity/Q185030
# No entity http://www.wikidata.org/entity/Q2165679
# 82413.csv
# Query entities 30
# No entity http://www.wikidata.org/entity/Q61002
# No entity http://www.wikidata.org/entity/Q14560
# No entity http://www.wikidata.org/entity/Q1723523
# No entity http://www.wikidata.org/entity/Q5710720
# No entity http://www.wikidata.org/entity/Q9410
# 1277042.csv
# Query entities 25
# No entity http://www.wikidata.org/entity/Q186506
# No entity http://www.wikidata.org/entity/Q172324
# 524048.csv
# Query entities 15
# No entity http://www.wikidata.org/entity/Q670969
# 103549.csv
# Query entities 39
# No entity http://www.wikidata.org/entity/Q7330575
# No entity http://www.wikidata.org/entity/Q45792
# No entity http://www.wikidata.org/entity/Q46185
# No entity http://www.wikidata.org/entity/Q7565
# No entity http://www.wikidata.org/entity/Q208141
# 188533.csv
# Query entities 44
# No entity http://www.wikidata.org/entity/Q109144363
# No entity http://www.wikidata.org/entity/Q46185
# No entity http://www.wikidata.org/entity/Q61046048
# No entity http://www.wikidata.org/entity/Q52954
# No entity http://www.wikidata.org/entity/Q258896
# No entity http://www.wikidata.org/entity/Q1338165
# No entity http://www.wikidata.org/entity/Q2384944
# 53133116.csv
# Query entities 8
# No entity http://www.wikidata.org/entity/Q1000808
# 2980522.csv
# Query entities 17
# No entity http://www.wikidata.org/entity/Q3031
# 205508.csv
# Query entities 123
# waiting entity...
# No entity http://www.wikidata.org/entity/Q355121
# No entity http://www.wikidata.org/entity/Q6241278
# waiting entity...
# No entity http://www.wikidata.org/entity/Q4610556
# No entity http://www.wikidata.org/entity/Q2379868
# No entity http://www.wikidata.org/entity/Q1062485
# No entity http://www.wikidata.org/entity/Q382616
# No entity http://www.wikidata.org/entity/Q190
# No entity http://www.wikidata.org/entity/Q93190
# No entity http://www.wikidata.org/entity/Q7749836
# No entity http://www.wikidata.org/entity/Q27888464
# 265883.csv
# Query entities 139
# No entity http://www.wikidata.org/entity/Q3467762
# waiting entity...
# waiting entity...
# No entity http://www.wikidata.org/entity/Q131774
# No entity http://www.wikidata.org/entity/Q1541894
# No entity http://www.wikidata.org/entity/Q7560
# No entity http://www.wikidata.org/entity/Q21
# No entity http://www.wikidata.org/entity/Q190
# No entity http://www.wikidata.org/entity/Q2708515
# No entity http://www.wikidata.org/entity/Q329455
# No entity http://www.wikidata.org/entity/Q2032573
# 3445142.csv
# Query entities 9
# No entity http://www.wikidata.org/entity/Q78987
# No entity http://www.wikidata.org/entity/Q105891
# 3594556.csv
# Query entities 10
# No entity http://www.wikidata.org/entity/Q208141
# 1239372.csv
# Query entities 19
# No entity http://www.wikidata.org/entity/Q1062485
# No entity http://www.wikidata.org/entity/Q390776
# 368130.csv
# Query entities 30
# No entity http://www.wikidata.org/entity/Q1775026
# No entity http://www.wikidata.org/entity/Q3031
# 18995.csv
# Query entities 265
# No entity http://www.wikidata.org/entity/Q12456579
# waiting entity...
# waiting entity...
# waiting entity...
# No entity http://www.wikidata.org/entity/Q105622037
# waiting entity...
# No entity http://www.wikidata.org/entity/Q96219240
# No entity http://www.wikidata.org/entity/Q56095
# No entity http://www.wikidata.org/entity/Q1420806
# No entity http://www.wikidata.org/entity/Q131774
# No entity http://www.wikidata.org/entity/Q1062485
# No entity http://www.wikidata.org/entity/Q29583
# waiting entity...
# No entity http://www.wikidata.org/entity/Q148442
# No entity http://www.wikidata.org/entity/Q309179
# No entity http://www.wikidata.org/entity/Q190
# No entity http://www.wikidata.org/entity/Q93190
# No entity http://www.wikidata.org/entity/Q570600
# No entity http://www.wikidata.org/entity/Q186517
# No entity http://www.wikidata.org/entity/Q6411883
# 3795474.csv
# Query entities 42
# No entity http://www.wikidata.org/entity/Q1022301
# 1209685.csv
# Query entities 14
# No entity http://www.wikidata.org/entity/Q3434088
# No entity http://www.wikidata.org/entity/Q309481
# 595133.csv
# Query entities 29
# No entity http://www.wikidata.org/entity/Q93190
# No entity http://www.wikidata.org/entity/Q6309015
# No entity http://www.wikidata.org/entity/Q795134
# No entity http://www.wikidata.org/entity/Q7749836
# 3358257.csv
# Query entities 4
# No entity http://www.wikidata.org/entity/Q8161
# 3585224.csv
# Query entities 43
# No entity http://www.wikidata.org/entity/Q208141
# No entity http://www.wikidata.org/entity/Q12681
# 2284844.csv
# Query entities 21
# No entity http://www.wikidata.org/entity/Q13359947
# 3535198.csv
# Query entities 31
# No entity http://www.wikidata.org/entity/Q327591
# No entity http://www.wikidata.org/entity/Q179294
# No entity http://www.wikidata.org/entity/Q167685
# No entity http://www.wikidata.org/entity/Q6583019
# 2536629.csv
# No coref doc 2536629.csv
# Query entities 6
# 1291515.csv
# Query entities 21
# 570296.csv
# Query entities 14
# No entity http://www.wikidata.org/entity/Q61002
# 757387.csv
# Query entities 21
# No entity http://www.wikidata.org/entity/Q21
# 574577.csv
# Query entities 36
# No entity http://www.wikidata.org/entity/Q3031
# No entity http://www.wikidata.org/entity/Q23653
# 1303365.csv
# Query entities 58
# No entity http://www.wikidata.org/entity/Q3265991
# waiting entity...
# No entity http://www.wikidata.org/entity/Q2541462
# 3347663.csv
# Query entities 51
# No entity http://www.wikidata.org/entity/Q112202470
# No entity http://www.wikidata.org/entity/Q21
# No entity http://www.wikidata.org/entity/Q1048625
# No entity http://www.wikidata.org/entity/Q258896
# No entity http://www.wikidata.org/entity/Q1062485
# waiting entity...
# 820730.csv
# No coref doc 820730.csv
# Query entities 31
# No entity http://www.wikidata.org/entity/Q327591
# 66585.csv
# Query entities 20
# No entity http://www.wikidata.org/entity/Q7910950
# No entity http://www.wikidata.org/entity/Q1707240
# No entity http://www.wikidata.org/entity/Q327591
# No entity http://www.wikidata.org/entity/Q46185
# 695584.csv
# Query entities 108
# waiting entity...
# No entity http://www.wikidata.org/entity/Q1062485
# waiting entity...
# No entity http://www.wikidata.org/entity/Q1366388
# No entity http://www.wikidata.org/entity/Q21
# No entity http://www.wikidata.org/entity/Q191931
# 240340.csv
# Query entities 52
# No entity http://www.wikidata.org/entity/Q1414932
# No entity http://www.wikidata.org/entity/Q445275
# No entity http://www.wikidata.org/entity/Q128309
# No entity http://www.wikidata.org/entity/Q93190
# No entity http://www.wikidata.org/entity/Q188689
# No entity http://www.wikidata.org/entity/Q6583019
# waiting entity...
# 393992.csv
# Query entities 26
# No entity http://www.wikidata.org/entity/Q183403
# No entity http://www.wikidata.org/entity/Q46185
# No entity http://www.wikidata.org/entity/Q52954
# 1384081.csv
# Query entities 42
# No entity http://www.wikidata.org/entity/Q1775026
# 2890708.csv
# Query entities 3
# 589925.csv
# Query entities 29
# No entity http://www.wikidata.org/entity/Q262337
# No entity http://www.wikidata.org/entity/Q5091785
# No entity http://www.wikidata.org/entity/Q191931
# 177771.csv
# Query entities 57
# No entity http://www.wikidata.org/entity/Q408284
# waiting entity...
# No entity http://www.wikidata.org/entity/Q1062485
# No entity http://www.wikidata.org/entity/Q3031
# No entity http://www.wikidata.org/entity/Q3387717
# 720783.csv
# Query entities 18
# No entity http://www.wikidata.org/entity/Q21
# No entity http://www.wikidata.org/entity/Q570600
# 2672499.csv
# Query entities 19
# No entity http://www.wikidata.org/entity/Q570600
# 679806.csv
# Query entities 22
# No entity http://www.wikidata.org/entity/Q1702518
# waiting biography...
# 787927.csv
# No coref doc 787927.csv
# Query entities 13
# No entity http://www.wikidata.org/entity/Q721983
# No entity http://www.wikidata.org/entity/Q1128240
# 331463.csv
# Query entities 38
# No entity http://www.wikidata.org/entity/Q730242
# No entity http://www.wikidata.org/entity/Q315796
# No entity http://www.wikidata.org/entity/Q17014120
# No entity http://www.wikidata.org/entity/Q45792
# No entity http://www.wikidata.org/entity/Q208762
# No entity http://www.wikidata.org/entity/Q174376
# 3587403.csv
# Query entities 13
# No entity http://www.wikidata.org/entity/Q6265679
# 1302505.csv
# Query entities 72
# waiting entity...
# No entity http://www.wikidata.org/entity/Q190
# No entity http://www.wikidata.org/entity/Q7560
# No entity http://www.wikidata.org/entity/Q41397
# No entity http://www.wikidata.org/entity/Q47231
# No entity http://www.wikidata.org/entity/Q210372
# 1828359.csv
# Query entities 26
# No entity http://www.wikidata.org/entity/Q234187
# No entity http://www.wikidata.org/entity/Q6970600
# No entity http://www.wikidata.org/entity/Q190
# 1529361.csv
# Query entities 79
# waiting entity...
# No entity http://www.wikidata.org/entity/Q93190
# No entity http://www.wikidata.org/entity/Q3031
# 1875304.csv
# Query entities 31
# No entity http://www.wikidata.org/entity/Q810480
# No entity http://www.wikidata.org/entity/Q721983
# 277090.csv
# Query entities 40
# No entity http://www.wikidata.org/entity/Q7298956
# No entity http://www.wikidata.org/entity/Q570600
# 3040579.csv
# Query entities 19
# 2872947.csv
# Query entities 17
# No entity http://www.wikidata.org/entity/Q721983
# 874840.csv
# Query entities 21
# 2751944.csv
# Query entities 9
# 57973.csv
# Query entities 51
# No entity http://www.wikidata.org/entity/Q5288459
# No entity http://www.wikidata.org/entity/Q2708515
# No entity http://www.wikidata.org/entity/Q47231
# No entity http://www.wikidata.org/entity/Q3858343
# No entity http://www.wikidata.org/entity/Q45792
# No entity http://www.wikidata.org/entity/Q21
# No entity http://www.wikidata.org/entity/Q1130740
# No entity http://www.wikidata.org/entity/Q968748
# waiting entity...
# No entity http://www.wikidata.org/entity/Q1859473
# 876268.csv
# Query entities 10
# No entity http://www.wikidata.org/entity/Q1062485
# 172563.csv
# Query entities 33
# No entity http://www.wikidata.org/entity/Q380714
# No entity http://www.wikidata.org/entity/Q1429537
# No entity http://www.wikidata.org/entity/Q213053
# 309084.csv
# Query entities 88
# waiting entity...
# No entity http://www.wikidata.org/entity/Q62019003
# No entity http://www.wikidata.org/entity/Q45792
# 772715.csv
# Query entities 60
# No entity http://www.wikidata.org/entity/Q21
# No entity http://www.wikidata.org/entity/Q61046048
# waiting entity...
# No entity http://www.wikidata.org/entity/Q4861115
# No entity http://www.wikidata.org/entity/Q105891
# No entity http://www.wikidata.org/entity/Q78987
# No entity http://www.wikidata.org/entity/Q1062485
# No entity http://www.wikidata.org/entity/Q46185
# No entity http://www.wikidata.org/entity/Q52954
# 1181295.csv
# Query entities 4
# 3197212.csv
# Query entities 36
# No entity http://www.wikidata.org/entity/Q670969
# No entity http://www.wikidata.org/entity/Q105891
# No entity http://www.wikidata.org/entity/Q212483
# No entity http://www.wikidata.org/entity/Q21
# No entity http://www.wikidata.org/entity/Q1408658
# No entity http://www.wikidata.org/entity/Q30687931
# 52006456.csv
# Query entities 6
# 3004631.csv
# Query entities 15
# No entity http://www.wikidata.org/entity/Q186506
# No entity http://www.wikidata.org/entity/Q17898
# No entity http://www.wikidata.org/entity/Q184128
# 866345.csv
# Query entities 10
# No entity http://www.wikidata.org/entity/Q186506
# No entity http://www.wikidata.org/entity/Q3031
# No entity http://www.wikidata.org/entity/Q339747
# 859482.csv
# Query entities 34
# No entity http://www.wikidata.org/entity/Q6178134
# No entity http://www.wikidata.org/entity/Q2731060
# No entity http://www.wikidata.org/entity/Q1723523
# No entity http://www.wikidata.org/entity/Q399999
# No entity http://www.wikidata.org/entity/Q165769
# 1354646.csv
# Query entities 14
# 1547707.csv
# Query entities 32
# No entity http://www.wikidata.org/entity/Q184874
# No entity http://www.wikidata.org/entity/Q1948826
# No entity http://www.wikidata.org/entity/Q186506
# No entity http://www.wikidata.org/entity/Q309481
# 726151.csv
# Query entities 33
# No entity http://www.wikidata.org/entity/Q603292
# No entity http://www.wikidata.org/entity/Q1062485
# No entity http://www.wikidata.org/entity/Q2245378
# 455818.csv
# Query entities 25
# No entity http://www.wikidata.org/entity/Q46185
# No entity http://www.wikidata.org/entity/Q93190
# No entity http://www.wikidata.org/entity/Q1428637
# No entity http://www.wikidata.org/entity/Q191954
# 2697408.csv
# Query entities 26
# No entity http://www.wikidata.org/entity/Q201664
# 2344136.csv
# Query entities 4
# 329722.csv
# Query entities 20
# No entity http://www.wikidata.org/entity/Q46185
# No entity http://www.wikidata.org/entity/Q93190
# No entity http://www.wikidata.org/entity/Q43414
# ...
# No entity http://www.wikidata.org/entity/Q16585114
# No entity http://www.wikidata.org/entity/Q78987
# 3180265.csv
# Query entities 18
# 164576.csv
# Query entities 49
# No entity http://www.wikidata.org/entity/Q61285
# No entity http://www.wikidata.org/entity/Q670969
# No entity http://www.wikidata.org/entity/Q61002
# No entity http://www.wikidata.org/entity/Q1062485
# No entity http://www.wikidata.org/entity/Q7565
# 354680.csv
# Query entities 61
# No entity http://www.wikidata.org/entity/Q258896
# waiting entity...
# No entity http://www.wikidata.org/entity/Q670969
# No entity http://www.wikidata.org/entity/Q46185
# No entity http://www.wikidata.org/entity/Q1062485
# No entity http://www.wikidata.org/entity/Q21
# No entity http://www.wikidata.org/entity/Q288342
# No entity http://www.wikidata.org/entity/Q7560
# No entity http://www.wikidata.org/entity/Q78987
# No entity http://www.wikidata.org/entity/Q43899138
# No entity http://www.wikidata.org/entity/Q20813618
# 1354841.csv
# Query entities 24
# No entity http://www.wikidata.org/entity/Q7560
# No entity http://www.wikidata.org/entity/Q174376
# No entity http://www.wikidata.org/entity/Q1495836
# No entity http://www.wikidata.org/entity/Q182436
# No entity http://www.wikidata.org/entity/Q2629392
# 1244554.csv
# No coref doc 1244554.csv
# Query entities 21
# 205720.csv
# Query entities 48
# No entity http://www.wikidata.org/entity/Q1322478
# No entity http://www.wikidata.org/entity/Q1062485
# No entity http://www.wikidata.org/entity/Q193666
# No entity http://www.wikidata.org/entity/Q93190
# No entity http://www.wikidata.org/entity/Q1140966
# 1285387.csv
# Query entities 26
# No entity http://www.wikidata.org/entity/Q45792
# 50876284.csv
# No coref doc 50876284.csv
# Query entities 4
# 420376.csv
# No coref doc 420376.csv
# Query entities 19
# No entity http://www.wikidata.org/entity/Q21
# No entity http://www.wikidata.org/entity/Q2918164
# No entity http://www.wikidata.org/entity/Q570600
# No entity http://www.wikidata.org/entity/Q7749836
# 322567.csv
# Query entities 32
# 2785324.csv
# Query entities 19
# No entity http://www.wikidata.org/entity/Q191954
# 171050.csv
# Query entities 34
# No entity http://www.wikidata.org/entity/Q201948
# No entity http://www.wikidata.org/entity/Q46185
# No entity http://www.wikidata.org/entity/Q192711
# 1194878.csv
# Query entities 46
# No entity http://www.wikidata.org/entity/Q93190
# No entity http://www.wikidata.org/entity/Q1062485
# No entity http://www.wikidata.org/entity/Q193666
# No entity http://www.wikidata.org/entity/Q600751
# 1097923.csv
# Query entities 21
# No entity http://www.wikidata.org/entity/Q11696
# No entity http://www.wikidata.org/entity/Q623386
# No entity http://www.wikidata.org/entity/Q146921
# No entity http://www.wikidata.org/entity/Q3387717
# 52625029.csv
# Query entities 18
# No entity http://www.wikidata.org/entity/Q21
# No entity http://www.wikidata.org/entity/Q1048625
# 392501.csv
# Query entities 39
# No entity http://www.wikidata.org/entity/Q688230
# No entity http://www.wikidata.org/entity/Q17898
# No entity http://www.wikidata.org/entity/Q1048625
# 9700.csv
# Query entities 32
# No entity http://www.wikidata.org/entity/Q21
# No entity http://www.wikidata.org/entity/Q406039
# No entity http://www.wikidata.org/entity/Q476713
# No entity http://www.wikidata.org/entity/Q570600
# No entity http://www.wikidata.org/entity/Q45792
# 3450589.csv
# Query entities 52
# No entity http://www.wikidata.org/entity/Q46185
# waiting entity...
# waiting biography...
# 1341923.csv
# Query entities 30
# No entity http://www.wikidata.org/entity/Q100321220
# No entity http://www.wikidata.org/entity/Q3031
# 1392224.csv
# Query entities 28
# No entity http://www.wikidata.org/entity/Q111240785
# No entity http://www.wikidata.org/entity/Q3031
# No entity http://www.wikidata.org/entity/Q191954
# 879937.csv
# Query entities 16
# 1505727.csv
# Query entities 14
# No entity http://www.wikidata.org/entity/Q23653
# 3217228.csv
# No coref doc 3217228.csv
# Query entities 25
# 143160.csv
# Query entities 34
# No entity http://www.wikidata.org/entity/Q934895
# No entity http://www.wikidata.org/entity/Q3064924
# 735176.csv
# Query entities 19
# No entity http://www.wikidata.org/entity/Q353673
# No entity http://www.wikidata.org/entity/Q190
# 97205.csv
# Query entities 52
# No entity http://www.wikidata.org/entity/Q3064924
# No entity http://www.wikidata.org/entity/Q7755357
# No entity http://www.wikidata.org/entity/Q339747
# No entity http://www.wikidata.org/entity/Q21
# No entity http://www.wikidata.org/entity/Q190
# No entity http://www.wikidata.org/entity/Q7560
# waiting entity...
# No entity http://www.wikidata.org/entity/Q309481
# 833109.csv
# Query entities 37
# No entity http://www.wikidata.org/entity/Q21030365
# No entity http://www.wikidata.org/entity/Q202027
# No entity http://www.wikidata.org/entity/Q3031
# No entity http://www.wikidata.org/entity/Q2927984
# 214233.csv
# Query entities 140
# No entity http://www.wikidata.org/entity/Q18706101
# waiting entity...
# No entity http://www.wikidata.org/entity/Q7611761
# waiting entity...
# No entity http://www.wikidata.org/entity/Q190
# No entity http://www.wikidata.org/entity/Q3031
# No entity http://www.wikidata.org/entity/Q842782
# No entity http://www.wikidata.org/entity/Q1062485
# No entity http://www.wikidata.org/entity/Q46185
# No entity http://www.wikidata.org/entity/Q93190
# No entity http://www.wikidata.org/entity/Q105891
# No entity http://www.wikidata.org/entity/Q3114821
# No entity http://www.wikidata.org/entity/Q186393
# No entity http://www.wikidata.org/entity/Q52954
# No entity http://www.wikidata.org/entity/Q7749836
# No entity http://www.wikidata.org/entity/Q1925786
# No entity http://www.wikidata.org/entity/Q131774
# 264312.csv
# Query entities 22
# No entity http://www.wikidata.org/entity/Q670969
# 1291198.csv
# Query entities 26
# No entity http://www.wikidata.org/entity/Q1237928
# No entity http://www.wikidata.org/entity/Q2516852
# No entity http://www.wikidata.org/entity/Q8161
# 2516568.csv
# No coref doc 2516568.csv
# Query entities 16
# No entity http://www.wikidata.org/entity/Q15479268
# 87603.csv
# Query entities 107
# No entity http://www.wikidata.org/entity/Q6514996
# waiting entity...
# No entity http://www.wikidata.org/entity/Q1201260
# No entity http://www.wikidata.org/entity/Q1062485
# waiting entity...
# No entity http://www.wikidata.org/entity/Q6583019
# No entity http://www.wikidata.org/entity/Q2384039
# No entity http://www.wikidata.org/entity/Q203443
# No entity http://www.wikidata.org/entity/Q842782
# No entity http://www.wikidata.org/entity/Q6794636
# 467101.csv
# Query entities 44
# No entity http://www.wikidata.org/entity/Q52954
# No entity http://www.wikidata.org/entity/Q7759155
# No entity http://www.wikidata.org/entity/Q46185
# No entity http://www.wikidata.org/entity/Q1428637
# No entity http://www.wikidata.org/entity/Q570600
# No entity http://www.wikidata.org/entity/Q18685786
# 777623.csv
# Query entities 18
# 423820.csv
# Query entities 6
# 2488161.csv
# Query entities 23
# No entity http://www.wikidata.org/entity/Q570600
# No entity http://www.wikidata.org/entity/Q426466
# 1850886.csv
# Query entities 6
# No entity http://www.wikidata.org/entity/Q1062485
# No entity http://www.wikidata.org/entity/Q5011
# 192739.csv
# Query entities 8
# No entity http://www.wikidata.org/entity/Q1128240
# 709620.csv
# Query entities 21
# No entity http://www.wikidata.org/entity/Q18663629
# 1010510.csv
# Query entities 77
# waiting entity...
# No entity http://www.wikidata.org/entity/Q178122
# No entity http://www.wikidata.org/entity/Q1183487
# No entity http://www.wikidata.org/entity/Q93190
# No entity http://www.wikidata.org/entity/Q327591
# No entity http://www.wikidata.org/entity/Q570600
# No entity http://www.wikidata.org/entity/Q657845
# 3516152.csv
# Query entities 57
# No entity http://www.wikidata.org/entity/Q15059471
# No entity http://www.wikidata.org/entity/Q52954
# waiting entity...
# No entity http://www.wikidata.org/entity/Q78987
# No entity http://www.wikidata.org/entity/Q2591645
# 1417421.csv
# Query entities 24
# No entity http://www.wikidata.org/entity/Q104554949
# No entity http://www.wikidata.org/entity/Q191578
# No entity http://www.wikidata.org/entity/Q114347149
# 702942.csv
# Query entities 5
# 817466.csv
# Query entities 9
# No entity http://www.wikidata.org/entity/Q64450
# 1043762.csv
# Query entities 13
# 1084179.csv
# Query entities 6
# No entity http://www.wikidata.org/entity/Q7922641
# 3529094.csv
# Query entities 13
# No entity http://www.wikidata.org/entity/Q45792
# 141330.csv
# Query entities 28
# No entity http://www.wikidata.org/entity/Q339747
# No entity http://www.wikidata.org/entity/Q8161
# 1372632.csv
# Query entities 13
# No entity http://www.wikidata.org/entity/Q131774
# 1107893.csv
# Query entities 8
# No entity http://www.wikidata.org/entity/Q1797162
# 460378.csv
# Query entities 23
# No entity http://www.wikidata.org/entity/Q210970
# No entity http://www.wikidata.org/entity/Q15362491
# 211626.csv
# Query entities 13
# 973172.csv
# Query entities 24
# No entity http://www.wikidata.org/entity/Q219625
# No entity http://www.wikidata.org/entity/Q1128240
# No entity http://www.wikidata.org/entity/Q755167
# No entity http://www.wikidata.org/entity/Q205683
# No entity http://www.wikidata.org/entity/Q112
# No entity http://www.wikidata.org/entity/Q695087
# No entity http://www.wikidata.org/entity/Q3359
# 1111730.csv
# Query entities 32
# No entity http://www.wikidata.org/entity/Q513309
# No entity http://www.wikidata.org/entity/Q3064924
# No entity http://www.wikidata.org/entity/Q202027
# No entity http://www.wikidata.org/entity/Q545412
# 52470803.csv
# Query entities 27
# No entity http://www.wikidata.org/entity/Q46185
# No entity http://www.wikidata.org/entity/Q7560
# No entity http://www.wikidata.org/entity/Q670969
# No entity http://www.wikidata.org/entity/Q61046048
# 50016.csv
# Query entities 89
# waiting entity...
# No entity http://www.wikidata.org/entity/Q2347975
# No entity http://www.wikidata.org/entity/Q1141526
# No entity http://www.wikidata.org/entity/Q93190
# No entity http://www.wikidata.org/entity/Q570600
# 226445.csv
# Query entities 40
# No entity http://www.wikidata.org/entity/Q46185
# No entity http://www.wikidata.org/entity/Q1048625
# No entity http://www.wikidata.org/entity/Q21
# No entity http://www.wikidata.org/entity/Q52954
# No entity http://www.wikidata.org/entity/Q128309
# No entity http://www.wikidata.org/entity/Q670969
# No entity http://www.wikidata.org/entity/Q191954
# No entity http://www.wikidata.org/entity/Q78987
# No entity http://www.wikidata.org/entity/Q309481
# 1150533.csv
# Query entities 44
# No entity http://www.wikidata.org/entity/Q31687
# No entity http://www.wikidata.org/entity/Q833899
# No entity http://www.wikidata.org/entity/Q106574748
# No entity http://www.wikidata.org/entity/Q833860
# No entity http://www.wikidata.org/entity/Q27914
# No entity http://www.wikidata.org/entity/Q42903827
# No entity http://www.wikidata.org/entity/Q1552579
# No entity http://www.wikidata.org/entity/Q185041
# No entity http://www.wikidata.org/entity/Q7560
# 1471350.csv
# No coref doc 1471350.csv
# Query entities 16
# No entity http://www.wikidata.org/entity/Q2763
# No entity http://www.wikidata.org/entity/Q93190
# 529813.csv
# Query entities 23
# No entity http://www.wikidata.org/entity/Q570600
# No entity http://www.wikidata.org/entity/Q1062485
# No entity http://www.wikidata.org/entity/Q16953351
# 243651.csv
# Query entities 76
# waiting entity...
# No entity http://www.wikidata.org/entity/Q7364565
# No entity http://www.wikidata.org/entity/Q45792
# No entity http://www.wikidata.org/entity/Q128309
# No entity http://www.wikidata.org/entity/Q1414932
# No entity http://www.wikidata.org/entity/Q11404
# No entity http://www.wikidata.org/entity/Q208421
# No entity http://www.wikidata.org/entity/Q211028
# 155107.csv
# Query entities 76
# waiting entity...
# No entity http://www.wikidata.org/entity/Q11985
# No entity http://www.wikidata.org/entity/Q192711
# No entity http://www.wikidata.org/entity/Q193291
# No entity http://www.wikidata.org/entity/Q190
# No entity http://www.wikidata.org/entity/Q46185
# No entity http://www.wikidata.org/entity/Q1252904
# No entity http://www.wikidata.org/entity/Q570600
# No entity http://www.wikidata.org/entity/Q309481
# No entity http://www.wikidata.org/entity/Q6652432
# 175068.csv
# Query entities 84
# waiting entity...
# No entity http://www.wikidata.org/entity/Q570600
# No entity http://www.wikidata.org/entity/Q35230
# No entity http://www.wikidata.org/entity/Q14435
# No entity http://www.wikidata.org/entity/Q7749836
# 168565.csv
# Query entities 139
# waiting entity...
# waiting entity...
# No entity http://www.wikidata.org/entity/Q6795972
# No entity http://www.wikidata.org/entity/Q670969
# No entity http://www.wikidata.org/entity/Q476713
# No entity http://www.wikidata.org/entity/Q46185
# No entity http://www.wikidata.org/entity/Q52954
# No entity http://www.wikidata.org/entity/Q78987
# 2345798.csv
# Query entities 9
# No entity http://www.wikidata.org/entity/Q570600
# 905775.csv
# Query entities 26
# No entity http://www.wikidata.org/entity/Q270200
# No entity http://www.wikidata.org/entity/Q78987
# No entity http://www.wikidata.org/entity/Q52954
# No entity http://www.wikidata.org/entity/Q21
# No entity http://www.wikidata.org/entity/Q678142
# 1453044.csv
# Query entities 96
# waiting entity...
# No entity http://www.wikidata.org/entity/Q270141
# No entity http://www.wikidata.org/entity/Q190
# No entity http://www.wikidata.org/entity/Q23653
# No entity http://www.wikidata.org/entity/Q12460259
# No entity http://www.wikidata.org/entity/Q2918164
# No entity http://www.wikidata.org/entity/Q45792
# No entity http://www.wikidata.org/entity/Q1420806
# 767288.csv
# Query entities 32
# No entity http://www.wikidata.org/entity/Q5091785
# No entity http://www.wikidata.org/entity/Q1128240
# waiting biography...
# 371868.csv
# Query entities 73
# waiting entity...
# No entity http://www.wikidata.org/entity/Q46185
# No entity http://www.wikidata.org/entity/Q2918164
# No entity http://www.wikidata.org/entity/Q181508
# No entity http://www.wikidata.org/entity/Q1107971
# 15766.csv
# Query entities 191
# waiting entity...
# waiting entity...
# waiting entity...
# No entity http://www.wikidata.org/entity/Q670969
# No entity http://www.wikidata.org/entity/Q570600
# No entity http://www.wikidata.org/entity/Q46185
# No entity http://www.wikidata.org/entity/Q226008
# No entity http://www.wikidata.org/entity/Q61002
# No entity http://www.wikidata.org/entity/Q1862087
# No entity http://www.wikidata.org/entity/Q11404
# No entity http://www.wikidata.org/entity/Q78987
# No entity http://www.wikidata.org/entity/Q8161
# No entity http://www.wikidata.org/entity/Q7749836
# No entity http://www.wikidata.org/entity/Q6763849
# No entity http://www.wikidata.org/entity/Q1062485
# No entity http://www.wikidata.org/entity/Q5165738
# No entity http://www.wikidata.org/entity/Q93190
# No entity http://www.wikidata.org/entity/Q701040
# No entity http://www.wikidata.org/entity/Q854022
# No entity http://www.wikidata.org/entity/Q16153408
# No entity http://www.wikidata.org/entity/Q2378505
# No entity http://www.wikidata.org/entity/Q2410935
# No entity http://www.wikidata.org/entity/Q4934764
# 699151.csv
# Query entities 13
# No entity http://www.wikidata.org/entity/Q190
# 760333.csv
# Query entities 17
# 185085.csv
# Query entities 9
# 167790.csv
# Query entities 127
# waiting entity...
# waiting entity...
# No entity http://www.wikidata.org/entity/Q1034298
# No entity http://www.wikidata.org/entity/Q23653
# No entity http://www.wikidata.org/entity/Q1062485
# No entity http://www.wikidata.org/entity/Q1975715
# No entity http://www.wikidata.org/entity/Q1236988
# No entity http://www.wikidata.org/entity/Q2917466
# No entity http://www.wikidata.org/entity/Q2030511
# No entity http://www.wikidata.org/entity/Q131774
# No entity http://www.wikidata.org/entity/Q2219692
# 300931.csv
# Query entities 38
# No entity http://www.wikidata.org/entity/Q7759155
# No entity http://www.wikidata.org/entity/Q93190
# No entity http://www.wikidata.org/entity/Q202027
# No entity http://www.wikidata.org/entity/Q105891
# No entity http://www.wikidata.org/entity/Q3064924
# 297375.csv
# Query entities 34
# No entity http://www.wikidata.org/entity/Q203443
# 1310858.csv
# Query entities 14
# No entity http://www.wikidata.org/entity/Q7560
# 185202.csv
# Query entities 27
# No entity http://www.wikidata.org/entity/Q7741459
# No entity http://www.wikidata.org/entity/Q1062485
# No entity http://www.wikidata.org/entity/Q708492
# No entity http://www.wikidata.org/entity/Q379269
# 2541302.csv
# No coref doc 2541302.csv
# Query entities 7
# waiting biography...

# %%
entities_df.info()
entities_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   s           70 non-null     object
#  1   label       70 non-null     object
#  2   image       62 non-null     object
#  3   birthdate   69 non-null     object
#  4   deathdate   59 non-null     object
#  5   wikidataId  69 non-null     object
#  6   abstract    69 non-null     object
# dtypes: object(7)
# memory usage: 4.0+ KB
#                                                    s                  label  \
# 0           http://dbpedia.org/resource/Saint_George           Saint George
# 1  http://dbpedia.org/resource/Johann_Nepomuk_Hummel  Johann Nepomuk Hummel
# 2   http://dbpedia.org/resource/Ludwig_van_Beethoven   Ludwig van Beethoven
# 3    http://dbpedia.org/resource/Madeleine_of_Valois    Madeleine of Valois
# 4        http://dbpedia.org/resource/Robert_Schumann        Robert Schumann
#
#                                                image             birthdate  \
# 0  http://commons.wikimedia.org/wiki/Special:File...  0275-01-01T00:00:00Z
# 1  http://commons.wikimedia.org/wiki/Special:File...            1778-11-14
# 2  http://commons.wikimedia.org/wiki/Special:File...  1770-12-16T00:00:00Z
# 3  http://commons.wikimedia.org/wiki/Special:File...            1520-08-10
# 4  http://commons.wikimedia.org/wiki/Special:File...            1810-06-08
#
#               deathdate                              wikidataId  \
# 0  0303-04-24T00:00:00Z   http://www.wikidata.org/entity/Q48438
# 1            1837-10-17  http://www.wikidata.org/entity/Q151953
# 2  1827-03-26T00:00:00Z     http://www.wikidata.org/entity/Q255
# 3            1537-07-07  http://www.wikidata.org/entity/Q231074
# 4            1856-07-29    http://www.wikidata.org/entity/Q7351
#
#                                             abstract
# 0  Saint George (Greek: Γεώργιος (Geórgios), Lati...
# 1  Johann Nepomuk Hummel (14 November 1778 – 17 O...
# 2  Ludwig van Beethoven (baptised 17 December 177...
# 3  Madeleine of France or Madeleine of Valois (10...
# 4  Robert Schumann (German: [ˈʁoːbɛʁt ˈʃuːman]; 8...
