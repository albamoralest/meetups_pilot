# %% [markdown]
# # Coreference task

# %% [markdown]
# This notebook processes text from biographies to execute a coreference task
#
# Pre-requirements:
# - Text organised in sentences
#
# Problem: missing entities in sentences, mainly due to pronoumns, reference to entities in previous paragraphs
# This applies for people, places and time references
#
# Our implementation:
#
#     - Step 1
#     - Step 2
#     - ...
#
#
#
# Input
#
# Output
#
# Requirements
# - Coreferee (spacyDevelopment): https://github.com/richardpaulhudson/coreferee
#     - !pip3 install coreferee
#     - !python3 -m pip3 install coreferee
#     - !python3 -m coreferee install en
#     - !python -m spacy download en_core_web_trf
#     - !python -m spacy download en_core_web_lg

# %%
#!pip3 install coreferee
#!python3 -m pip3 install coreferee
#!python3 -m coreferee install en
#!python -m spacy download en_core_web_trf
# !python -m spacy download en_core_web_lg
# Out:
# Collecting en-core-web-lg==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.5.0/en_core_web_lg-3.5.0-py3-none-any.whl (587.7 MB)
#      |████████████████████████████████| 587.7 MB 3.6 kB/s             ��████████▉   | 528.5 MB 35.0 MB/s eta 0:00:02
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in /opt/conda/lib/python3.9/site-packages (from en-core-web-lg==3.5.0) (3.5.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /opt/conda/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2.4.6)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /opt/conda/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (0.4.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /opt/conda/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (3.3.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /opt/conda/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (5.2.1)
# Requirement already satisfied: numpy>=1.15.0 in /opt/conda/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (1.20.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /opt/conda/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (1.8.2)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (21.2)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /opt/conda/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (8.1.9)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /opt/conda/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (3.0.12)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/conda/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (3.0.6)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (3.0.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/conda/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (1.0.6)
# Requirement already satisfied: pathy>=0.10.0 in /opt/conda/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (0.10.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /opt/conda/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2.0.8)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/conda/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (4.62.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (58.5.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/conda/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2.0.6)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /opt/conda/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (0.10.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /opt/conda/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (1.0.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/conda/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2.26.0)
# Requirement already satisfied: pyparsing<3,>=2.0.2 in /opt/conda/lib/python3.9/site-packages (from packaging>=20.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2.4.7)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (3.10.0.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (3.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/conda/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2.0.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /opt/conda/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /opt/conda/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (0.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /opt/conda/lib/python3.9/site-packages (from typer<0.8.0,>=0.3.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (8.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.9/site-packages (from jinja2->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2.0.1)
# Installing collected packages: en-core-web-lg
# Successfully installed en-core-web-lg-3.5.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')

# %%
import spacy
from spacy.tokens import Doc
from spacy import displacy
# Coreference object
nlp = spacy.load('en_core_web_trf')
nlp.add_pipe('coreferee')

# %%
import os
import pandas as pd
import re
import numpy as np

# %% [markdown]
# ### Identify complete and incomplete meetup sentences

# %%
# reading every CSV with indexed sentences
# return a list object of files in the given folder
files_list = [f for f in os.listdir('indexedSentences') if not f.startswith('.')]
# parse to dataframe
df_files = pd.DataFrame(files_list, columns=['file_name'])
# df_files.to_csv('totalBiographiesEntities.csv',index=False)

df_files.info()
df_files.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33309 entries, 0 to 33308
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   file_name  33309 non-null  object
# dtypes: object(1)
# memory usage: 260.4+ KB
#       file_name
# 0  10002116.csv
# 1  10004137.csv
# 2  10006387.csv
# 3   1000684.csv
# 4  10009278.csv

# %%
## testing, using one biography
df_files = df_files.query("file_name=='2444917.csv'")
df_files.to_csv('coreferenceBiographiesList.csv',index=False)
print(len(df_files))
# Out:
# 1

# %% [markdown]
# ### Identify if the sentence can be a meetup

# %%
def evaluateCandidateMeetupsEntities(biography_df):
    column_entities = ["meetup","people","place","timeExpression"]
    entities_df = pd.DataFrame(columns=column_entities)
    
    for sentence_row in biography_df.itertuples():
        # print(sentence_row.paragraphIndex)
        # print(sentence_row.sentenceIndex)
        # read people and places entities
        meetupCandidatePP_df = pd.read_csv('extractedEntitiesPersonPlaceOnly/'+file_name_item.file_name.replace(".txt",".csv"))
        
        tempCandidatePP_df = meetupCandidatePP_df.query("paragraphIndex=={} & sentenceIndex=={}".format(sentence_row.paragraphIndex,
                                                                                                     sentence_row.sentenceIndex))
        
        # if count > 0 then, we found some entities, this is a meetup candidate
        # meetup: Y - YES, N - NO, C - Candidate
        meetup = "N"
        entPeople = 0
        entPlaces = 0
        entTimeExpressions = 0

        if len(tempCandidatePP_df) > 0:
            # Next, evaluate if the candidate is complete or incomplete
            # tag as COM INC
            entPP = pd.unique(tempCandidatePP_df['entType'])

            for i in entPP:
                if i == "person":
                    entPeople = len(tempCandidatePP_df[tempCandidatePP_df.entType == i])
                elif i == "place":
                    entPlaces = len(tempCandidatePP_df[tempCandidatePP_df.entType == i])
         
        # read time entities
        meetupCandidateTime_df = pd.read_csv('extractedTimeExpressions/'+file_name_item.file_name.replace(".txt",".csv"))
        tempCandidateTime_df = meetupCandidateTime_df.query("paragraphIndex=={} & sentenceIndex=={}".format(sentence_row.paragraphIndex,
                                                                                                     sentence_row.sentenceIndex))
        if len(tempCandidateTime_df) > 0:
            entTimeExpressions = len(tempCandidateTime_df)

        if entPeople == 0 and entPlaces == 0 and entTimeExpressions == 0:
            meetup = "N"
            datarow = pd.Series(data={'meetup':meetup,'people':entPeople,'place':entPlaces,'timeExpression':entTimeExpressions})
            # dfnotfound = dfnotfound.append(datarow, ignore_index=True)
            entities_df = entities_df.append(datarow, ignore_index=True)
            continue
            
        if entPeople > 0 and entPlaces > 0 and entTimeExpressions > 0:
            meetup = "Y"
        else:
            meetup = "C"
          
        datarow = pd.Series(data={'meetup':meetup,'people':entPeople,'place':entPlaces,'timeExpression':entTimeExpressions})
        # dfnotfound = dfnotfound.append(datarow, ignore_index=True)
        entities_df = entities_df.append(datarow, ignore_index=True)

    # merge with data to identify the paragraph and sentences index information
    sentencesEntities_df = biography_df.copy(deep=True)
    sentencesEntities_df = sentencesEntities_df.join(entities_df)
    return sentencesEntities_df

# %% [markdown]
# ### Execute task to identify current entities numbers

# %%
# Reading the biographies in chunks of 50
# for chunk in pd.read_csv('coreferenceBiographiesList.csv', chunksize=50):
for chunk in pd.read_csv('list_wikiIdSample.csv', chunksize=50):
    df_file_name = pd.DataFrame()
    df_file_name['file_name'] = chunk['file_name']
    # for each file
    for file_name_item in df_file_name.itertuples():
        file_exists = os.path.isfile('indexedSentences/'+file_name_item.file_name.replace(".txt",".csv"))
        if file_exists:
            print(file_name_item.file_name.replace(".txt",".csv"))
            # read the biography organised by sentences
            biography_df = pd.read_csv('indexedSentences/'+file_name_item.file_name.replace(".txt",".csv"))
            # Read the file with all the identified entities
            # meetupEntitiesCandidate_df = pd.read_csv('extractedEntities/'+file_name_item.file_name.replace(".txt",".csv"))
            
            # entities_df = biography_df.copy(deep=True)
            
            # for each sentence in the biography, identify if they can be a 
            # meetup: Y - YES all entities present, N - NO zero entities, C - Candidate some entities
            # meetupsEval_df = evaluateCandidateMeetupsEntities(biography_df,meetupEntitiesCandidate_df)
            meetupsEval_df = evaluateCandidateMeetupsEntities(biography_df)
            
            # store results
            meetupsEval_df.to_csv('meetupsCandidatesBefCoref/'+file_name_item.file_name.replace(".txt",".csv"),index=False)
# Out:
# 608845.csv
# 2232977.csv
# 409969.csv
# 1551347.csv
# 579599.csv
# 1174545.csv
# 2898019.csv
# 3450382.csv
# 2553865.csv
# 2320846.csv
# 144624.csv
# 827409.csv
# 1396921.csv
# 2815597.csv
# 858538.csv
# 2269540.csv
# 701860.csv
# 2334176.csv
# 8716.csv
# 576282.csv
# 113049.csv
# 529161.csv
# 167975.csv
# 3126224.csv
# 78231.csv
# 1022191.csv
# 223497.csv
# 3081864.csv
# 63747.csv
# 739770.csv
# 1566844.csv
# 439467.csv
# 181985.csv
# 51560453.csv
# 3236079.csv
# 720273.csv
# 419012.csv
# 994118.csv
# 341837.csv
# 3818460.csv
# 2657736.csv
# 623861.csv
# 489381.csv
# 1113259.csv
# 1433271.csv
# 756836.csv
# 165726.csv
# 165113.csv
# 313835.csv
# 67892.csv
# 2704521.csv
# 2771033.csv
# 526281.csv
# 450629.csv
# 2416191.csv
# 173225.csv
# 632683.csv
# 991714.csv
# 1023303.csv
# 481738.csv
# 1566892.csv
# 2659909.csv
# 12945.csv
# 3141790.csv
# 838629.csv
# 492026.csv
# 512518.csv
# 1429918.csv
# 58067.csv
# 1213916.csv
# 155965.csv
# 1253793.csv
# 49906.csv
# 5033.csv
# 100273.csv
# 442318.csv
# 1098118.csv
# 1321577.csv
# 553740.csv
# 523339.csv
# 20405.csv
# 238175.csv
# 1599087.csv
# 1786533.csv
# 797572.csv
# 655613.csv
# 379324.csv
# 1070521.csv
# 262463.csv
# 259159.csv
# 1234606.csv
# 741791.csv
# 1560872.csv
# 1790603.csv
# 176912.csv
# 782651.csv
# 150095.csv
# 2474795.csv
# 1410438.csv
# 166529.csv
# 523975.csv
# 2539541.csv
# 1540074.csv
# 1561694.csv
# 344562.csv
# 391522.csv
# 870413.csv
# 42203.csv
# 19318.csv
# 625857.csv
# 585649.csv
# 984106.csv
# 1439437.csv
# 52926317.csv
# 192024.csv
# 51382438.csv
# 8300.csv
# 1788051.csv
# 70986.csv
# 630312.csv
# 399509.csv
# 277731.csv
# 459887.csv
# 250370.csv
# 177220.csv
# 850294.csv
# 2423427.csv
# 3696100.csv
# 1142145.csv
# 165697.csv
# 512497.csv
# 734633.csv
# 316711.csv
# 232719.csv
# 90447.csv
# 1129635.csv
# 3547359.csv
# 3596773.csv
# 100487.csv
# 1595398.csv
# 166331.csv
# 3266294.csv
# 2591808.csv
# 1598663.csv
# 2850239.csv
# 540027.csv
# 556410.csv
# 2484677.csv
# 3488554.csv
# 671985.csv
# 194903.csv
# 351206.csv
# 2451984.csv
# 777352.csv
# 1343880.csv
# 2558336.csv
# 1876457.csv
# 3136059.csv
# 877017.csv
# 277524.csv
# 1056463.csv
# 3622246.csv
# 1147577.csv
# 290808.csv
# 2911472.csv
# 936912.csv
# 544455.csv
# 164481.csv
# 1433411.csv
# 1253783.csv
# 52811997.csv
# 289669.csv
# 1826921.csv
# 3683614.csv
# 3816378.csv
# 2431461.csv
# 52557970.csv
# 582519.csv
# 351996.csv
# 3798459.csv
# 381560.csv
# 51940478.csv
# 537467.csv
# 274424.csv
# 1503167.csv
# 2281945.csv
# 2800969.csv
# 3517771.csv
# 2377280.csv
# 754282.csv
# 386760.csv
# 52837049.csv
# 20484.csv
# 2437473.csv
# 1391973.csv
# 89644.csv
# 2579694.csv
# 1407035.csv
# 3180885.csv
# 855002.csv
# 154959.csv
# 2834129.csv
# 290117.csv
# 61641.csv
# 1115155.csv
# 2985243.csv
# 703488.csv
# 82413.csv
# 524048.csv
# 103549.csv
# 188533.csv
# 53133116.csv
# 2980522.csv
# 205508.csv
# 265883.csv
# 368130.csv
# 3795474.csv
# 2284844.csv
# 2536629.csv
# 757387.csv
# 3347663.csv
# 66585.csv
# 695584.csv
# 240340.csv
# 393992.csv
# 1384081.csv
# 331463.csv
# 1529361.csv
# 1875304.csv
# 2872947.csv
# 874840.csv
# 57973.csv
# 772715.csv
# 3197212.csv
# 1547707.csv
# 726151.csv
# 80696.csv
# 3832645.csv
# 1047779.csv
# 2830223.csv
# 340945.csv
# 3130321.csv
# 267627.csv
# 706650.csv
# 38910.csv
# 415848.csv
# 472821.csv
# 2475284.csv
# 290850.csv
# 144196.csv
# 2900106.csv
# 143114.csv
# 2667535.csv
# 177293.csv
# 3791501.csv
# 50667561.csv
# 152557.csv
# 4737.csv
# 1882145.csv
# 3075.csv
# 2461503.csv
# 1745996.csv
# 3204508.csv
# 395739.csv
# 2833181.csv
# 20215.csv
# 2888557.csv
# 63283.csv
# 295574.csv
# 418568.csv
# 1561641.csv
# 299412.csv
# 1048172.csv
# 975107.csv
# 92450.csv
# 606115.csv
# 1399340.csv
# 1261779.csv
# 2642841.csv
# 762314.csv
# 1799252.csv
# 88371.csv
# 2667661.csv
# 56386.csv
# 46284.csv
# 51130819.csv
# 348348.csv
# 2584300.csv
# 328330.csv
# 168478.csv
# 577944.csv
# 559173.csv
# 375645.csv
# 2553132.csv
# 3419345.csv
# 581625.csv
# 593468.csv
# 1441938.csv
# 208803.csv
# 1413790.csv
# 1551249.csv
# 1068160.csv
# 3614145.csv
# 589693.csv
# 2706137.csv
# 577798.csv
# 840622.csv
# 363631.csv
# 51997395.csv
# 2464424.csv
# 3740.csv
# 186175.csv
# 162348.csv
# 2584673.csv
# 2322673.csv
# 86939.csv
# 60626.csv
# 3731062.csv
# 59216.csv
# 419739.csv
# 2455907.csv
# 630138.csv
# 98217.csv
# 558968.csv
# 1028178.csv
# 3026264.csv
# 939726.csv
# 1869640.csv
# 916486.csv
# 63517.csv
# 45968.csv
# 362368.csv
# 377171.csv
# 50420.csv
# 2330834.csv
# 137869.csv
# 1823012.csv
# 886285.csv
# 152195.csv
# 926691.csv
# 571468.csv
# 52520413.csv
# 98513.csv
# 1254005.csv
# 793333.csv
# 164398.csv
# 2722084.csv
# 910077.csv
# 2930053.csv
# 1600435.csv
# 2327936.csv
# 2266591.csv
# 205811.csv
# 147308.csv
# 1059399.csv
# 604066.csv
# 696825.csv
# 2875914.csv
# 2612142.csv
# 1479807.csv
# 588756.csv
# 3478434.csv
# 1403521.csv
# 3152159.csv
# 105767.csv
# 2811295.csv
# 2928274.csv
# 763791.csv
# 54268.csv
# 209161.csv
# 787997.csv
# 615031.csv
# 140417.csv
# 51311898.csv
# 980182.csv
# 2790693.csv
# 376223.csv
# 1420817.csv
# 891723.csv
# 1178548.csv
# 1562492.csv
# 2512661.csv
# 1320240.csv
# 1714150.csv
# 558203.csv
# 1035724.csv
# 194614.csv
# 70315.csv
# 3411455.csv
# 690900.csv
# 2524294.csv
# 18434.csv
# 878467.csv
# 1495782.csv
# 742176.csv
# 3682747.csv
# 2307312.csv
# 192586.csv
# 2519838.csv
# 328940.csv
# 997083.csv
# 1714891.csv
# 2974145.csv
# 2738707.csv
# 298563.csv
# 164576.csv
# 205720.csv
# 1285387.csv
# 50876284.csv
# 420376.csv
# 322567.csv
# 171050.csv
# 392501.csv
# 879937.csv
# 1505727.csv
# 3217228.csv
# 97205.csv
# 214233.csv
# 264312.csv
# 87603.csv
# 467101.csv
# 777623.csv
# 2488161.csv
# 192739.csv
# 141330.csv
# 1107893.csv
# 211626.csv
# 973172.csv
# 52470803.csv
# 50016.csv
# 226445.csv
# 529813.csv
# 243651.csv
# 155107.csv
# 175068.csv
# 168565.csv
# 2345798.csv
# 905775.csv
# 1453044.csv
# 371868.csv
# 15766.csv
# 300931.csv
# 297375.csv
# 185202.csv
# 2541302.csv
# 10085.csv
# 9039.csv

# %% [markdown]
# ## Coreference task

# %%
# executes coreference task. Input: text. Output: doc object
def executeCoref(text):
    doc = nlp(text)
    return doc

# Obtains the list of identified entities and their indexes in the text
# Input: doc object. Output: a list of lists. E.g., list([entity, indexes])
def indexCorefEntities(doc):
    indexes_coref = []
    for chain in doc._.coref_chains:
        indexes_temp = []
        resolve = False
        for mention in chain:
            for i in mention:
                indexes_temp.append(i)
        # indexes_temp = [doc._.coref_chains.resolve(doc[i])[0]] + indexes_temp 
            if not resolve:
                res1 = [doc._.coref_chains.resolve(doc[j]) for j in mention]
                res = list(filter((None).__ne__, res1))
                if len(res)>0:
                    resolve=True
        indexes_temp = res[0] + indexes_temp
        indexes_coref.append(indexes_temp)
    # print(indexes_coref)
    return indexes_coref

# coref_list format: [[Leipzig, 298, 338], [Elgar, 721, 729, 763, ]]
# output format:
#              token tokenIndex charIndex entType sentIndex corefEntityValue
# 0            Elgar          0         0  PERSON         0            Elgar
# 1               's          1         5                 0              NaN
# 2           mother          2         8                 0           mother
def parseDocToDf(doc, sentencesLength_list, coref_list):
    
    coref_details_df = pd.DataFrame(columns=['token','tokenIndex','charIndex','entType',
                                             'sentIndex'])
    sentIndex=0
    sentCharCount=0
    for token in doc:
        # the sentencesLength_list gives you a list with a number of string char count
        if (sentencesLength_list[sentIndex]-token.idx) == 0:
            sentCharCount += token.idx-sentCharCount
            sentIndex +=1
        #     print("change sentence",sentIndex)
        # print(token.idx, sentCharCount, token.idx-sentCharCount,sentencesLength_list[sentIndex])
        
        # add a line to restart the character index everytime it changes the sentence index
        
        # tokenIndex: index of the token in the paragraph
        # charIndex: index of the first token's character in the string
        datarow = pd.Series(data={'token':token.text,'tokenIndex':token.i,
                                  'charIndex':token.idx-sentCharCount,'entType':token.ent_type_,
                                 'sentIndex':sentIndex})
        coref_details_df = coref_details_df.append(datarow, ignore_index=True)
        # print(datarow)
    # Add a column to specify coref results: 
    coref_details_df['corefEntityValue'] = np.NaN
    for coref_item in coref_list:
        entityValue = ""
        for i, indexVal in enumerate(coref_item):
            # print(indexVal)
            if i == 0:
                entityValue = indexVal
                continue
            else:
                coref_details_df.at[indexVal,'corefEntityValue'] = entityValue
    return coref_details_df

# store coref results by biography
def storeCorefResults(doc_df, file_name):
    if os.path.isfile('cacheCoreferenceOutput/'+file_name.replace(".txt",".csv")):
        results = pd.read_csv('cacheCoreferenceOutput/'+file_name.replace(".txt",".csv"))
        results = results.append(doc_df, ignore_index=True)
        results.to_csv('cacheCoreferenceOutput/'+file_name.replace(".txt",".csv"),index=False)
    else:
        doc_df.to_csv('cacheCoreferenceOutput/'+file_name,index=False)
        
# store coref results by biography
# folder: cacheCoreferenceOutput/
def storeResults(doc_df, file_name, folder):
    if os.path.isfile(folder+file_name.replace(".txt",".csv")):
        results = pd.read_csv(folder+file_name.replace(".txt",".csv"))
        results = results.append(doc_df, ignore_index=True)
        results.to_csv(folder+file_name.replace(".txt",".csv"),index=False)
    else:
        doc_df.to_csv(folder+file_name,index=False)

# store doc objects results by biography, format: file_name_paragraphIndex - 10085_1
def storeCorefDocResults(doc, file_name,paragraph):
    doc.to_disk("cacheCoreferenceOutput/"+file_name.replace(".csv","")+"_"+str(paragraph)+".coref")
    
# retrieve doc              
def retriveCorefDocResults(file_name, paragraph):
    doc = Doc(nlp.vocab).from_disk("cacheCoreferenceOutput/"+file_name.replace(".csv","")+"_"+str(paragraph)+".coref")
    return doc

def validateCachedCorefObject(file_name, paragraph):
    if os.path.isfile('cacheCoreferenceOutput/'+file_name.replace(".csv","")+"_"+str(paragraph)+".coref"):
        return True
    else:
        return False
    
### Procesing text for coreference
# Concat all the sentences of a given paragraph
# Input: a df with all the sentences of a paragraph
# output: 1) a string concatenating all the sentences
# 2) a list with the lenght of each sentence, to be used to 
# identify the number of sentence in the paragraph
def obtainText_df(sentencesParagraph_df):
    text = ""
    sentencesLength_list = []
    for row_sent in sentencesParagraph_df.itertuples():
        text += row_sent.sentences + " "
        # print(len(text))
        sentencesLength_list.append(len(text))
    return text, sentencesLength_list

spacy.explain('NORP')
# NORP: Nationalities or religious or political groups
# GPE: Countries, cities, states
# LOC: Non-GPE locations, mountain ranges, bodies of water'
# PERSON: People, including fictional
# ORG: 'Companies, agencies, institutions, etc.'
# EVENT: Named hurricanes, battles, wars, sports events, etc.
# WORK_OF_ART: Titles of books, songs, etc.
# FAC: Buildings, airports, highways, bridges, etc.

# df = listTypeEntities(doc_coreferences)
# print(df)
# print(findTypeEntity(df,"ten"))
# print(findByTypeEntity(df,"DATE"))
    
# # doc = nlp("When Elgar was 29, he took on a new pupil, Caroline Alice Roberts, known as Alice, daughter of the late Major-General Sir Henry Roberts, and published author of verse and prose fiction. Eight years older than Elgar, Alice became his wife three years later.")
    
# temp_df = parseDocToDf(doc_coreferences,sentencesIndex_list,coreferences_index)
# # print(temp_df)
# # temp_df.info()
# print(indexCorefEntities(doc_coreferences))
# # print(parseDocToDf(doc_coreferences,sentencesIndex_list))
# # temp_df.tail(30)

# temp_df=temp_df.dropna(subset=['corefEntityValue'])
# temp_df.to_csv('cacheCoreferenceOutput/resultstest.csv',index=False)
# Out:
# 'Nationalities or religious or political groups'

# %%
# Obtains a list with the indexes of the tokens in the doc object
# Input: doc object. Output: list(token indexes), starts in zero
# def indexTextTokens(doc):
#     tok_list = list(token.text for token in doc)
#     # print(tok_list)
#     # print(tok_list[1])
#     return tok_list

# # Output: df
# def filterCorefByEntity(coref_df, value):
#     coref_df = coref_df.dropna(subset=['corefEntityValue'])
#     coref_df['corefEntityValue'] = coref_df['corefEntityValue'].astype(str)
#     return coref_df[coref_df['corefEntityValue'].str.contains(value)] 

# def validateEntityValue(coref_index,elementsCoref_df):
#     del_list = []
#     for ref in coref_index:
#         # ref[1] is the first index in coref results. E.g, [Elgar, 2,45,98] is 2
#         row_elementCoref = elementsCoref_df.iloc[[ref[1]]]
#         entType = str(row_elementCoref.entType)
        
#         if "PERSON" in entType or "DATE" in entType or "GPE" in entType:
#             pass
#         else:
#             del_list.append(ref)
#     for i in del_list:
#         coref_index.remove(i)
            
#     return coref_index

# # List the types of entities found in the text. Input: doc. Output: df [entity, entType]
# def listTypeEntities(doc):
#     # E.g., 
#     # W. H. "Billy" Reed PERSON
#     # Elgar PERSON
#     # English NORP
#     # Elgar PERSON
#     # about ten DATE
#     # forty years later DATE
#     # The Wand of Youth WORK_OF_ART
#     listEnts = []
#     # Find named entities, phrases and concepts
#     for entity in doc.ents:
#         element = [entity.text, entity.label_]
#         listEnts.append(element)
#         # print(entity.text, entity.label_)
#     return pd.DataFrame(listEnts, columns=['entity','entType']).drop_duplicates(keep='first')
        
# def findByEntity(entList_df, entity_string):
#     return entList_df[entList_df['entity'].str.contains(entity_string)] 

# def findByTypeEntity(entList_df, entType_string):
#     return entList_df[entList_df['entType'].str.contains(entType_string)]

# %%
# Use coreference results to add entities to its corresponding sentence
# corefItems_df: each row is a token, the df with all the indexes and tokens
def completionCorefSentence(corefItems_df, coref_index, paragraph_index, sentences_partial_df):
    coref_df = corefItems_df.dropna(subset=['corefEntityValue'])
    coref_df['corefEntityValue'] = coref_df['corefEntityValue'].astype(str)
    # print(coref_df)
    # loop coref results, using the entity found in coreference as guidance
    # [Elgar, 1, 13, 25]
    for coref_item in coref_index:
        # print(coref_item)
        # [Elgar, 1, 13, 25, 27, 47, 59, 83, 88, 93, 97, 111, 118, 124, 135, 149, 200]
        # filter and verify that entType contains one or more of the types of interest
        # if "PERSON" in entType or "DATE" in entType or "GPE" in entType:
        entityValue = str(coref_item[0])
        # print(entityValue)
        coref_temp_df = coref_df.loc[coref_df['corefEntityValue'].isin([entityValue])]
        # print(coref_temp_df)
        # # list unique values 
        # entTypes_list = coref_temp_df.entType.unique()
        # # print(entTypes_list)
        # Part 1: dedicated to People
        # Validate PERSON entType
        coref_person_df = coref_temp_df.loc[coref_temp_df['entType'].isin(['PERSON'])]
        # print(coref_person_df)
        if not coref_person_df.empty:
            # print("PERSON")
            executeCorefCompletionLowLevel(coref_item,coref_df,paragraph_index,entityValue,coref_person_df,"person",sentences_partial_df)
         
        # search for places
        coref_place_df = coref_temp_df.loc[coref_temp_df['entType'].isin(['GPE'])]
        if not coref_place_df.empty:
            # print("GPE")
            executeCorefCompletionLowLevel(coref_item,coref_df,paragraph_index,entityValue,coref_place_df,"place",sentences_partial_df)
                
            # Second case: first entity is always the one in index [1] of coref results and has the exact or similar entity value as found in coref
            
    # is this a linked entity? if is not a linked entity I may not be able to linked so for now if it is not in the coref results
    # then there is not more actions to take

    # Part 2: dedicated to time expressions
    # use listTypeEntities(doc_coreferences) to validate DATE entTypes

# # Extra step to validate entities
# def validateEntitiesType():
#     return 1

def executeCorefCompletionLowLevel(coref_item,coref_df,paragraph_index,entityValue,coref_temp_df,entType, sentences_partial_df):
    coref_strings  = [str(i) for i in coref_item]
    # token_list = coref_strings.remove(entityValue)
    token_list = coref_strings[1:len(coref_strings)]
    # print(token_list)
    # validation for entities that have more than one entity
    try:
        token_list = list(map(int, token_list))
    except Exception as e: 
        print(e)
        return
    # print(token_list)
    # filter only the indexes in the coref results
    #     [Clara, 24, 46]
    #    tokenIndex  token charIndex entType sentIndex corefEntityValue
    # 0          24  Clara       112  PERSON         0            Clara
    # 1          46  Clara         0  PERSON         2            Clara       
    coref_temp_df = coref_df.set_index(['tokenIndex'])
    coref_temp_df = coref_temp_df.loc[coref_temp_df.index.isin(token_list)]
    # now we have a df with all the tokens of the coref
    coref_temp_df = coref_temp_df.reset_index()
    # [tokenIndex, token, charIndex, entType, sentIndex, corefEntityValue]

    # Search for the linked entity in the extracted Person and Places entities
    linkedEntities_df = pd.read_csv('extractedEntitiesPersonPlaceOnly/'+file_name_item.file_name.replace(".txt",".csv"))

    # print("Filter:",paragraph_index,coref_temp_df.iloc[0]['sentIndex'],coref_temp_df.iloc[0]['charIndex'],coref_temp_df.iloc[0]['corefEntityValue'])
    # First case: first entity is always the one in index [0] of coref results and starts at the same offset and charIndex
    entity_row = linkedEntities_df.loc[(linkedEntities_df['paragraphIndex'] == paragraph_index) & 
                                       (linkedEntities_df['sentenceIndex'] == coref_temp_df.iloc[0]['sentIndex']) & 
                                       (linkedEntities_df['offset'] == coref_temp_df.iloc[0]['charIndex'])]
    # print(coref_temp_df,entity_row)
    if entity_row.empty:
        entity_row = linkedEntities_df.loc[(linkedEntities_df['paragraphIndex'] == paragraph_index) & 
                                       (linkedEntities_df['sentenceIndex'] == coref_temp_df.iloc[0]['sentIndex'])]
        entity_row = entity_row[entity_row['entity'].str.contains(coref_temp_df.iloc[0]['corefEntityValue'])]
        entity_row.sort_values(by=['paragraphIndex','sentenceIndex'],ascending=True,inplace=True)
        # print("EMPTY ROW",entity_row)
    if entity_row.empty:
        entity_row = linkedEntities_df.loc[(linkedEntities_df['paragraphIndex'] == paragraph_index)]
        entity_row = entity_row[entity_row['entity'].str.contains(coref_temp_df.iloc[0]['corefEntityValue'])]
        entity_row.sort_values(by=['paragraphIndex','sentenceIndex'],ascending=True,inplace=True)
        
    # if len(entity_row) > 1:
    #     entity_row = entity_row.iloc[0]

    # print("ENTIRY ROW",entity_row)
    # if len(entity_row) == 1:
    if len(entity_row) > 0:
        # print("coref_temp_df",coref_temp_df)
        # Extract only the rows that have the same sentence and paragraph
        linkedEntities_temp_df = linkedEntities_df.loc[(linkedEntities_df['paragraphIndex'] == paragraph_index)]
        linkedEntities_temp_df = linkedEntities_temp_df.set_index(['sentenceIndex'])
        linkedEntities_temp_df = linkedEntities_temp_df.loc[linkedEntities_temp_df.index.isin(coref_temp_df['sentIndex'].drop_duplicates().to_list())]
        linkedEntities_temp_df = linkedEntities_temp_df.reset_index()
        # print("linkedEntities_temp_df",linkedEntities_temp_df)
        # linkedEntities_temp_df = linkedEntities_temp_df.loc[(linkedEntities_temp_df['URI'] == entity_row.iloc[0]['URI'])]
        list_sentences_temp = linkedEntities_temp_df.loc[(linkedEntities_temp_df['URI'] == entity_row.iloc[0]['URI'])].drop_duplicates(subset=['sentenceIndex']).sentenceIndex.unique()
        list_sentences_coref = coref_temp_df.drop_duplicates(subset=['sentIndex']).sentIndex.unique()
        list_sentences = list(set(list_sentences_coref)-set(list_sentences_temp))

        # print("==1, DFs")
        # print(list_sentences_coref,list_sentences_temp,list_sentences)

        # repeat row with entity in each sentence
        if len(list_sentences) > 0:
            coref_temp_df = coref_temp_df.set_index(['sentIndex'])
            coref_temp_df = coref_temp_df.loc[coref_temp_df.index.isin(list_sentences)]
            coref_temp_df = coref_temp_df.reset_index()
            coref_temp_df.sort_values(by=['tokenIndex'],ascending=True,inplace=True)
            coref_temp_df.drop_duplicates(subset=['sentIndex'],inplace=True)
            coref_temp_df.rename(columns={'sentIndex': 'sentenceIndex'}, inplace=True)
            # print("coref_temp_df",coref_temp_df)
            
            new_linkedEntities_df = sentences_partial_df.set_index(['sentenceIndex'])
            new_linkedEntities_df = new_linkedEntities_df.loc[new_linkedEntities_df.index.isin(list_sentences)]
            new_linkedEntities_df = new_linkedEntities_df.reset_index()
            new_linkedEntities_df.sort_values(by=['sentenceIndex'],ascending=True,inplace=True)
            new_linkedEntities_df.drop_duplicates(subset=['sentenceIndex'],inplace=True)
            
            # print("new_linkedEntities_df",new_linkedEntities_df)
            new_linkedEntities_df = sentences_partial_df.merge(coref_temp_df, on='sentenceIndex',how="right")

            # new_linkedEntities_df.drop(columns=['entity','offset','entType_y','tokenIndex','token'], inplace=True)
            new_linkedEntities_df.drop(columns=['tokenIndex','token'], inplace=True)
            new_linkedEntities_df.rename(columns={'wikiId':'wikiPageID','corefEntityValue':'entity','charIndex': 'offset'}, inplace=True)

            new_linkedEntities_df['URI'] = entity_row.iloc[0]['URI']
            new_linkedEntities_df['support'] = np.NaN
            new_linkedEntities_df['types'] = entity_row.iloc[0]['types']
            new_linkedEntities_df['similarityScore'] = np.NaN
            new_linkedEntities_df['percentageOfSecondRank'] = np.NaN
            new_linkedEntities_df['entType']= entType
            # print(new_linkedEntities_df)

            storeResults(new_linkedEntities_df, file_name_item.file_name.replace(".txt",".csv"), 'meetupsCorefOutputPP/')

# %%
# Now move to run the coreference task
# Reading the biographies in chunks of 50
for chunk in pd.read_csv('list_wikiIdSample.csv', chunksize=50):
    df_file_name = pd.DataFrame()
    df_file_name['file_name'] = chunk['file_name']
    # for each file
    for file_name_item in df_file_name.itertuples():
        file_exists = os.path.isfile('indexedSentences/'+file_name_item.file_name.replace(".txt",".csv"))
        if file_exists:
            # print(file_name_item.file_name.replace(".txt",".csv"))
            
            sentences_df = pd.read_csv('indexedSentences/'+file_name_item.file_name.replace(".txt",".csv"))
            # obtain list of paragraphs
            paragraphIndexes_list = sentences_df.paragraphIndex.unique()
            # iterate the paragraphs
            for p_index in paragraphIndexes_list:
                # obtain a df with all the sentences that belong to a paragraph
                sentences_partial_df = sentences_df.query('paragraphIndex == {}'.format(p_index))
                # sentences_partial_df = sentences_df.query('paragraphIndex == 1')
                
                # format text
                text, sentencesIndex_list = obtainText_df(sentences_partial_df)
                # print(text)
                # execute coreference task
                # Validate first if already executed
                if validateCachedCorefObject(file_name_item.file_name, p_index):
                    # retrieve object
                    doc_coreferences = retriveCorefDocResults(file_name_item.file_name, p_index)
                    # print("retrieved")
                else:
                    doc_coreferences = executeCoref(text)
                    # store doc object
                    storeCorefDocResults(doc_coreferences, file_name_item.file_name,p_index)
                # format results: [entityCoref, [word(s) index]
                coreferences_index = indexCorefEntities(doc_coreferences)
                # print(coreferences_index)
                
                # obtain token and coref indexes
                elementsCoreference_df = parseDocToDf(doc_coreferences,sentencesIndex_list,coreferences_index)
                # store results, send the df and the file_name
                storeCorefResults(elementsCoreference_df, file_name_item.file_name)
                
                # before executing coreftask verify if it is cached and retrive all the data
                completionCorefSentence(elementsCoreference_df, coreferences_index,p_index,sentences_partial_df)
                # completionCorefSentence(elementsCoreference_df, coreferences_index,1)

                # store corefResults
                storeResults(elementsCoreference_df, file_name_item.file_name, 'cacheCoreferenceOutput/')
# Out:
# 2444917.csv
# retrieved
# [[Butt, 3, 34, 66]]
# /tmp/ipykernel_100/2006060584.py:19: DeprecationWarning: NotImplemented should not be used in a boolean context
#   res = list(filter((None).__ne__, res1))
# /tmp/ipykernel_100/2367422593.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   coref_df['corefEntityValue'] = coref_df['corefEntityValue'].astype(str)
# /tmp/ipykernel_100/2006060584.py:19: DeprecationWarning: NotImplemented should not be used in a boolean context
#   res = list(filter((None).__ne__, res1))
# [Butt, 3, 34, 66]
# PERSON
# Filter: 0 0 17 Butt
# ENTIRY ROW Empty DataFrame
# Columns: [URI, support, types, entity, offset, similarityScore, percentageOfSecondRank, sentence, sentenceIndex, paragraphIndex, section, entType, wikiPageID]
# Index: []
# retrieved
# [[Her, 0, 11], [recitalist, 6, 38, 46], [Gluck, 21, 29, 31]]
# /tmp/ipykernel_100/2367422593.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   coref_df['corefEntityValue'] = coref_df['corefEntityValue'].astype(str)
# [Her, 0, 11]
# [recitalist, 6, 38, 46]
# [Gluck, 21, 29, 31]
# PERSON
# Filter: 1 1 55 Gluck
# ENTIRY ROW                                                    URI  support  \
# 89   http://dbpedia.org/resource/Christoph_Willibal...     1290
# 109  http://dbpedia.org/resource/Christoph_Willibal...     1290
#
#                                     types entity  offset  similarityScore  \
# 89   DBpedia:Person,DBpedia:MusicalArtist  Gluck      55              1.0
# 109  DBpedia:Person,DBpedia:MusicalArtist  Gluck      55              1.0
#
#      percentageOfSecondRank  \
# 89             2.928648e-12
# 109            2.928648e-12
#
#                                               sentence  sentenceIndex  \
# 89   She appeared in only two operatic productions,...              1
# 109  She appeared in only two operatic productions,...              1
#
#      paragraphIndex section entType  wikiPageID
# 89                1     NaN  person     2444917
# 109               1     NaN  person     2444917
# coref_temp_df    tokenIndex  token charIndex entType sentIndex corefEntityValue
# 0          21  Gluck        55  PERSON         1            Gluck
# 1          29    her         9                 2            Gluck
# 2          31    she        20                 2            Gluck
# linkedEntities_temp_df    sentenceIndex                                                URI  support  \
# 0              1  http://dbpedia.org/resource/Christoph_Willibal...     1290
# 1              2      http://dbpedia.org/resource/Kennerley_Rumford       13
# 2              1  http://dbpedia.org/resource/Christoph_Willibal...     1290
# 3              2      http://dbpedia.org/resource/Kennerley_Rumford       13
#
#                                   types             entity  offset  \
# 0  DBpedia:Person,DBpedia:MusicalArtist              Gluck      55
# 1  DBpedia:Person,DBpedia:MusicalArtist  Kennerley Rumford      96
# 2  DBpedia:Person,DBpedia:MusicalArtist              Gluck      55
# 3  DBpedia:Person,DBpedia:MusicalArtist  Kennerley Rumford      96
#
#    similarityScore  percentageOfSecondRank  \
# 0              1.0            2.928648e-12
# 1              1.0            0.000000e+00
# 2              1.0            2.928648e-12
# 3              1.0            0.000000e+00
#
#                                             sentence  paragraphIndex section  \
# 0  She appeared in only two operatic productions,...               1     NaN
# 1  Later in her career she frequently appeared in...               1     NaN
# 2  She appeared in only two operatic productions,...               1     NaN
# 3  Later in her career she frequently appeared in...               1     NaN
#
#   entType  wikiPageID
# 0  person     2444917
# 1  person     2444917
# 2  person     2444917
# 3  person     2444917
# ==1, DFs
# [1 2] [1] [2]
# coref_temp_df    sentenceIndex  tokenIndex token charIndex entType corefEntityValue
# 0              2          29   her         9                    Gluck
# new_linkedEntities_df    sentenceIndex                                          sentences  \
# 0              2  Later in her career she frequently appeared in...
#
#    paragraphIndex section   wikiId
# 0               1     NaN  2444917
#                                            sentences  sentenceIndex  \
# 0  Later in her career she frequently appeared in...              2
#
#    paragraphIndex section  wikiPageID offset entType entity  \
# 0               1     NaN     2444917      9  person  Gluck
#
#                                                  URI  support  \
# 0  http://dbpedia.org/resource/Christoph_Willibal...      NaN
#
#                                   types  similarityScore  \
# 0  DBpedia:Person,DBpedia:MusicalArtist              NaN
#
#    percentageOfSecondRank
# 0                     NaN
# retrieved
# []
# retrieved
# [[Sussex, 7, 37], [captain, 19, 22], [Clara, 24, 46, 56, 62, 73, 76], [Rootham, 83, 102], [Butt, 107, 124, 136, 144, 153, 165]]
# /tmp/ipykernel_100/2006060584.py:19: DeprecationWarning: NotImplemented should not be used in a boolean context
#   res = list(filter((None).__ne__, res1))
# /tmp/ipykernel_100/2367422593.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   coref_df['corefEntityValue'] = coref_df['corefEntityValue'].astype(str)
# [Sussex, 7, 37]
# GPE
# Filter: 3 0 34 Sussex
# ENTIRY ROW                                    URI  support  \
# 38  http://dbpedia.org/resource/Sussex    12070
# 61  http://dbpedia.org/resource/Sussex    12070
#
#                                                 types  entity  offset  \
# 38  Wikidata:Q3455524,Schema:Place,Schema:Administ...  Sussex      34
# 61  Wikidata:Q3455524,Schema:Place,Schema:Administ...  Sussex      34
#
#     similarityScore  percentageOfSecondRank  \
# 38         0.952048                0.050315
# 61         0.952048                0.050315
#
#                                              sentence  sentenceIndex  \
# 38  Clara Butt was born in Southwick, Sussex, the ...              0
# 61  Clara Butt was born in Southwick, Sussex, the ...              0
#
#     paragraphIndex                      section entType  wikiPageID
# 38               3  == Early life and career ==   place     2444917
# 61               3  == Early life and career ==   place     2444917
# coref_temp_df    tokenIndex   token charIndex entType sentIndex corefEntityValue
# 0           7  Sussex        34     GPE         0           Sussex
# 1          37    city        38                 1           Sussex
# linkedEntities_temp_df     sentenceIndex                                        URI  support  \
# 0               0     http://dbpedia.org/resource/Clara_Butt      148
# 1               0  http://dbpedia.org/resource/Clara_Clemens       37
# 2               0     http://dbpedia.org/resource/Clara_Butt      148
# 3               0  http://dbpedia.org/resource/Clara_Clemens       37
# 4               0     http://dbpedia.org/resource/Clara_Butt      148
# 5               0  http://dbpedia.org/resource/Clara_Clemens       37
# 6               0     http://dbpedia.org/resource/Clara_Butt      148
# 7               0  http://dbpedia.org/resource/Clara_Clemens       37
# 8               0         http://dbpedia.org/resource/Sussex    12070
# 9               1        http://dbpedia.org/resource/Bristol    29302
# 10              1   http://dbpedia.org/resource/West_Country     1221
# 11              0         http://dbpedia.org/resource/Sussex    12070
# 12              1        http://dbpedia.org/resource/Bristol    29302
# 13              1   http://dbpedia.org/resource/West_Country     1221
# 14              1           http://dbpedia.org/resource/City    21174
# 15              1        http://dbpedia.org/resource/England   148862
# 16              1           http://dbpedia.org/resource/City    21174
# 17              1        http://dbpedia.org/resource/England   148862
#
#                                                 types        entity  offset  \
# 0   Http://xmlns.com/foaf/0.1/Person,Wikidata:Q729...    Clara Butt       0
# 1   Http://xmlns.com/foaf/0.1/Person,Wikidata:Q729...         Clara     112
# 2   Http://xmlns.com/foaf/0.1/Person,Wikidata:Q729...    Clara Butt       0
# 3   Http://xmlns.com/foaf/0.1/Person,Wikidata:Q729...         Clara     112
# 4   Http://xmlns.com/foaf/0.1/Person,Wikidata:Q729...    Clara Butt       0
# 5   Http://xmlns.com/foaf/0.1/Person,Wikidata:Q729...         Clara     112
# 6   Http://xmlns.com/foaf/0.1/Person,Wikidata:Q729...    Clara Butt       0
# 7   Http://xmlns.com/foaf/0.1/Person,Wikidata:Q729...         Clara     112
# 8   Wikidata:Q3455524,Schema:Place,Schema:Administ...        Sussex      34
# 9   Wikidata:Q515,Wikidata:Q486972,Schema:Place,Sc...       Bristol      46
# 10  Wikidata:Q486972,Schema:Place,DBpedia:Populate...  West Country      67
# 11  Wikidata:Q3455524,Schema:Place,Schema:Administ...        Sussex      34
# 12  Wikidata:Q515,Wikidata:Q486972,Schema:Place,Sc...       Bristol      46
# 13  Wikidata:Q486972,Schema:Place,DBpedia:Populate...  West Country      67
# 14             http://dbpedia.org/ontology/Settlement          city      38
# 15                http://dbpedia.org/ontology/Country       England      57
# 16             http://dbpedia.org/ontology/Settlement          city      38
# 17                http://dbpedia.org/ontology/Country       England      57
#
#     similarityScore  percentageOfSecondRank  \
# 0          1.000000                0.000000
# 1          0.553819                0.680232
# 2          1.000000                0.000000
# 3          0.553819                0.680232
# 4          1.000000                0.000000
# 5          0.553819                0.680232
# 6          1.000000                0.000000
# 7          0.553819                0.680232
# 8          0.952048                0.050315
# 9          0.999542                0.000351
# 10         0.993682                0.003446
# 11         0.952048                0.050315
# 12         0.999542                0.000351
# 13         0.993682                0.003446
# 14         0.611223                0.554183
# 15         0.963693                0.019700
# 16         0.611223                0.554183
# 17         0.963693                0.019700
#
#                                              sentence  paragraphIndex  \
# 0   Clara Butt was born in Southwick, Sussex, the ...               3
# 1   Clara Butt was born in Southwick, Sussex, the ...               3
# 2   Clara Butt was born in Southwick, Sussex, the ...               3
# 3   Clara Butt was born in Southwick, Sussex, the ...               3
# 4   Clara Butt was born in Southwick, Sussex, the ...               3
# 5   Clara Butt was born in Southwick, Sussex, the ...               3
# 6   Clara Butt was born in Southwick, Sussex, the ...               3
# 7   Clara Butt was born in Southwick, Sussex, the ...               3
# 8   Clara Butt was born in Southwick, Sussex, the ...               3
# 9   In 1880, the family moved to the port city of ...               3
# 10  In 1880, the family moved to the port city of ...               3
# 11  Clara Butt was born in Southwick, Sussex, the ...               3
# 12  In 1880, the family moved to the port city of ...               3
# 13  In 1880, the family moved to the port city of ...               3
# 14  In 1880, the family moved to the port city of ...               3
# 15  In 1880, the family moved to the port city of ...               3
# 16  In 1880, the family moved to the port city of ...               3
# 17  In 1880, the family moved to the port city of ...               3
#
#                         section entType  wikiPageID
# 0   == Early life and career ==  person     2444917
# 1   == Early life and career ==  person     2444917
# 2   == Early life and career ==  person     2444917
# 3   == Early life and career ==  person     2444917
# 4   == Early life and career ==  person     2444917
# 5   == Early life and career ==  person     2444917
# 6   == Early life and career ==  person     2444917
# 7   == Early life and career ==  person     2444917
# 8   == Early life and career ==   place     2444917
# 9   == Early life and career ==   place     2444917
# 10  == Early life and career ==   place     2444917
# 11  == Early life and career ==   place     2444917
# 12  == Early life and career ==   place     2444917
# 13  == Early life and career ==   place     2444917
# 14  == Early life and career ==   place     2444917
# 15  == Early life and career ==   place     2444917
# 16  == Early life and career ==   place     2444917
# 17  == Early life and career ==   place     2444917
# ==1, DFs
# [0 1] [0] [1]
# coref_temp_df    sentenceIndex  tokenIndex token charIndex entType corefEntityValue
# 0              1          37  city        38                   Sussex
# new_linkedEntities_df    sentenceIndex                                          sentences  \
# 0              1  In 1880, the family moved to the port city of ...
#
#    paragraphIndex                      section   wikiId
# 0               3  == Early life and career ==  2444917
#                                            sentences  sentenceIndex  \
# 0  In 1880, the family moved to the port city of ...              1
#
#    paragraphIndex                      section  wikiPageID offset entType  \
# 0               3  == Early life and career ==     2444917     38   place
#
#    entity                                 URI  support  \
# 0  Sussex  http://dbpedia.org/resource/Sussex      NaN
#
#                                                types  similarityScore  \
# 0  Wikidata:Q3455524,Schema:Place,Schema:Administ...              NaN
#
#    percentageOfSecondRank
# 0                     NaN
# [captain, 19, 22]
# [Clara, 24, 46, 56, 62, 73, 76]
# PERSON
# Filter: 3 0 112 Clara
# ENTIRY ROW                                           URI  support  \
# 3   http://dbpedia.org/resource/Clara_Clemens       37
# 19  http://dbpedia.org/resource/Clara_Clemens       37
# 33  http://dbpedia.org/resource/Clara_Clemens       37
# 36  http://dbpedia.org/resource/Clara_Clemens       37
#
#                                                 types entity  offset  \
# 3   Http://xmlns.com/foaf/0.1/Person,Wikidata:Q729...  Clara     112
# 19  Http://xmlns.com/foaf/0.1/Person,Wikidata:Q729...  Clara     112
# 33  Http://xmlns.com/foaf/0.1/Person,Wikidata:Q729...  Clara     112
# 36  Http://xmlns.com/foaf/0.1/Person,Wikidata:Q729...  Clara     112
#
#     similarityScore  percentageOfSecondRank  \
# 3          0.553819                0.680232
# 19         0.553819                0.680232
# 33         0.553819                0.680232
# 36         0.553819                0.680232
#
#                                              sentence  sentenceIndex  \
# 3   Clara Butt was born in Southwick, Sussex, the ...              0
# 19  Clara Butt was born in Southwick, Sussex, the ...              0
# 33  Clara Butt was born in Southwick, Sussex, the ...              0
# 36  Clara Butt was born in Southwick, Sussex, the ...              0
#
#     paragraphIndex                      section entType  wikiPageID
# 3                3  == Early life and career ==  person     2444917
# 19               3  == Early life and career ==  person     2444917
# 33               3  == Early life and career ==  person     2444917
# 36               3  == Early life and career ==  person     2444917
# coref_temp_df    tokenIndex  token charIndex entType sentIndex corefEntityValue
# 0          24  Clara       112  PERSON         0            Clara
# 1          46  Clara         0  PERSON         2            Clara
# 2          56    her        55                 2            Clara
# 3          62    her        94                 2            Clara
# 4          73    her        18                 3            Clara
# 5          76    she        36                 3            Clara
# linkedEntities_temp_df     sentenceIndex                                        URI  support  \
# 0               0     http://dbpedia.org/resource/Clara_Butt      148
# 1               0  http://dbpedia.org/resource/Clara_Clemens       37
# 2               0     http://dbpedia.org/resource/Clara_Butt      148
# 3               0  http://dbpedia.org/resource/Clara_Clemens       37
# 4               0     http://dbpedia.org/resource/Clara_Butt      148
# 5               0  http://dbpedia.org/resource/Clara_Clemens       37
# 6               0     http://dbpedia.org/resource/Clara_Butt      148
# 7               0  http://dbpedia.org/resource/Clara_Clemens       37
# 8               0         http://dbpedia.org/resource/Sussex    12070
# 9               2        http://dbpedia.org/resource/Bristol    29302
# 10              3        http://dbpedia.org/resource/Bristol    29302
# 11              0         http://dbpedia.org/resource/Sussex    12070
# 12              2        http://dbpedia.org/resource/Bristol    29302
# 13              3        http://dbpedia.org/resource/Bristol    29302
# 14              3    http://dbpedia.org/resource/Bass_guitar    43162
# 15              3  http://dbpedia.org/resource/Cyril_Rootham       75
# 16              3    http://dbpedia.org/resource/Bass_guitar    43162
# 17              3  http://dbpedia.org/resource/Cyril_Rootham       75
#
#                                                 types         entity  offset  \
# 0   Http://xmlns.com/foaf/0.1/Person,Wikidata:Q729...     Clara Butt       0
# 1   Http://xmlns.com/foaf/0.1/Person,Wikidata:Q729...          Clara     112
# 2   Http://xmlns.com/foaf/0.1/Person,Wikidata:Q729...     Clara Butt       0
# 3   Http://xmlns.com/foaf/0.1/Person,Wikidata:Q729...          Clara     112
# 4   Http://xmlns.com/foaf/0.1/Person,Wikidata:Q729...     Clara Butt       0
# 5   Http://xmlns.com/foaf/0.1/Person,Wikidata:Q729...          Clara     112
# 6   Http://xmlns.com/foaf/0.1/Person,Wikidata:Q729...     Clara Butt       0
# 7   Http://xmlns.com/foaf/0.1/Person,Wikidata:Q729...          Clara     112
# 8   Wikidata:Q3455524,Schema:Place,Schema:Administ...         Sussex      34
# 9   Wikidata:Q515,Wikidata:Q486972,Schema:Place,Sc...        Bristol      28
# 10  Wikidata:Q515,Wikidata:Q486972,Schema:Place,Sc...        Bristol     133
# 11  Wikidata:Q3455524,Schema:Place,Schema:Administ...         Sussex      34
# 12  Wikidata:Q515,Wikidata:Q486972,Schema:Place,Sc...        Bristol      28
# 13  Wikidata:Q515,Wikidata:Q486972,Schema:Place,Sc...        Bristol     133
# 14               DBpedia:Person,DBpedia:MusicalArtist           bass      59
# 15               DBpedia:Person,DBpedia:MusicalArtist  Cyril Rootham     103
# 16               DBpedia:Person,DBpedia:MusicalArtist           bass      59
# 17               DBpedia:Person,DBpedia:MusicalArtist  Cyril Rootham     103
#
#     similarityScore  percentageOfSecondRank  \
# 0          1.000000                0.000000
# 1          0.553819                0.680232
# 2          1.000000                0.000000
# 3          0.553819                0.680232
# 4          1.000000                0.000000
# 5          0.553819                0.680232
# 6          1.000000                0.000000
# 7          0.553819                0.680232
# 8          0.952048                0.050315
# 9          0.999622                0.000223
# 10         0.999996                0.000002
# 11         0.952048                0.050315
# 12         0.999622                0.000223
# 13         0.999996                0.000002
# 14         0.702696                0.421365
# 15         1.000000                0.000000
# 16         0.702696                0.421365
# 17         1.000000                0.000000
#
#                                              sentence  paragraphIndex  \
# 0   Clara Butt was born in Southwick, Sussex, the ...               3
# 1   Clara Butt was born in Southwick, Sussex, the ...               3
# 2   Clara Butt was born in Southwick, Sussex, the ...               3
# 3   Clara Butt was born in Southwick, Sussex, the ...               3
# 4   Clara Butt was born in Southwick, Sussex, the ...               3
# 5   Clara Butt was born in Southwick, Sussex, the ...               3
# 6   Clara Butt was born in Southwick, Sussex, the ...               3
# 7   Clara Butt was born in Southwick, Sussex, the ...               3
# 8   Clara Butt was born in Southwick, Sussex, the ...               3
# 9   Clara was educated at South Bristol High Schoo...               3
# 10  At the request of her headmistress, she was tr...               3
# 11  Clara Butt was born in Southwick, Sussex, the ...               3
# 12  Clara was educated at South Bristol High Schoo...               3
# 13  At the request of her headmistress, she was tr...               3
# 14  At the request of her headmistress, she was tr...               3
# 15  At the request of her headmistress, she was tr...               3
# 16  At the request of her headmistress, she was tr...               3
# 17  At the request of her headmistress, she was tr...               3
#
#                         section entType  wikiPageID
# 0   == Early life and career ==  person     2444917
# 1   == Early life and career ==  person     2444917
# 2   == Early life and career ==  person     2444917
# 3   == Early life and career ==  person     2444917
# 4   == Early life and career ==  person     2444917
# 5   == Early life and career ==  person     2444917
# 6   == Early life and career ==  person     2444917
# 7   == Early life and career ==  person     2444917
# 8   == Early life and career ==   place     2444917
# 9   == Early life and career ==   place     2444917
# 10  == Early life and career ==   place     2444917
# 11  == Early life and career ==   place     2444917
# 12  == Early life and career ==   place     2444917
# 13  == Early life and career ==   place     2444917
# 14  == Early life and career ==  person     2444917
# 15  == Early life and career ==  person     2444917
# 16  == Early life and career ==  person     2444917
# 17  == Early life and career ==  person     2444917
# ==1, DFs
# [0 2 3] [0] [2, 3]
# coref_temp_df    sentenceIndex  tokenIndex  token charIndex entType corefEntityValue
# 0              2          46  Clara         0  PERSON            Clara
# 3              3          73    her        18                    Clara
# new_linkedEntities_df    sentenceIndex                                          sentences  \
# 0              2  Clara was educated at South Bristol High Schoo...
# 1              3  At the request of her headmistress, she was tr...
#
#    paragraphIndex                      section   wikiId
# 0               3  == Early life and career ==  2444917
# 1               3  == Early life and career ==  2444917
#                                            sentences  sentenceIndex  \
# 0  Clara was educated at South Bristol High Schoo...              2
# 1  At the request of her headmistress, she was tr...              3
#
#    paragraphIndex                      section  wikiPageID offset entType  \
# 0               3  == Early life and career ==     2444917      0  person
# 1               3  == Early life and career ==     2444917     18  person
#
#   entity                                        URI  support  \
# 0  Clara  http://dbpedia.org/resource/Clara_Clemens      NaN
# 1  Clara  http://dbpedia.org/resource/Clara_Clemens      NaN
#
#                                                types  similarityScore  \
# 0  Http://xmlns.com/foaf/0.1/Person,Wikidata:Q729...              NaN
# 1  Http://xmlns.com/foaf/0.1/Person,Wikidata:Q729...              NaN
#
#    percentageOfSecondRank
# 0                     NaN
# 1                     NaN
# [Rootham, 83, 102]
# PERSON
# Filter: 3 3 71 Rootham
# ENTIRY ROW                                            URI  support  \
# 94   http://dbpedia.org/resource/Cyril_Rootham       75
# 114  http://dbpedia.org/resource/Cyril_Rootham       75
#
#                                     types         entity  offset  \
# 94   DBpedia:Person,DBpedia:MusicalArtist  Cyril Rootham     103
# 114  DBpedia:Person,DBpedia:MusicalArtist  Cyril Rootham     103
#
#      similarityScore  percentageOfSecondRank  \
# 94               1.0                     0.0
# 114              1.0                     0.0
#
#                                               sentence  sentenceIndex  \
# 94   At the request of her headmistress, she was tr...              3
# 114  At the request of her headmistress, she was tr...              3
#
#      paragraphIndex                      section entType  wikiPageID
# 94                3  == Early life and career ==  person     2444917
# 114               3  == Early life and career ==  person     2444917
# coref_temp_df    tokenIndex    token charIndex entType sentIndex corefEntityValue
# 0          83  Rootham        71  PERSON         3          Rootham
# 1         102  Rootham       174  PERSON         3          Rootham
# linkedEntities_temp_df    sentenceIndex                                        URI  support  \
# 0              3        http://dbpedia.org/resource/Bristol    29302
# 1              3        http://dbpedia.org/resource/Bristol    29302
# 2              3    http://dbpedia.org/resource/Bass_guitar    43162
# 3              3  http://dbpedia.org/resource/Cyril_Rootham       75
# 4              3    http://dbpedia.org/resource/Bass_guitar    43162
# 5              3  http://dbpedia.org/resource/Cyril_Rootham       75
#
#                                                types         entity  offset  \
# 0  Wikidata:Q515,Wikidata:Q486972,Schema:Place,Sc...        Bristol     133
# 1  Wikidata:Q515,Wikidata:Q486972,Schema:Place,Sc...        Bristol     133
# 2               DBpedia:Person,DBpedia:MusicalArtist           bass      59
# 3               DBpedia:Person,DBpedia:MusicalArtist  Cyril Rootham     103
# 4               DBpedia:Person,DBpedia:MusicalArtist           bass      59
# 5               DBpedia:Person,DBpedia:MusicalArtist  Cyril Rootham     103
#
#    similarityScore  percentageOfSecondRank  \
# 0         0.999996                0.000002
# 1         0.999996                0.000002
# 2         0.702696                0.421365
# 3         1.000000                0.000000
# 4         0.702696                0.421365
# 5         1.000000                0.000000
#
#                                             sentence  paragraphIndex  \
# 0  At the request of her headmistress, she was tr...               3
# 1  At the request of her headmistress, she was tr...               3
# 2  At the request of her headmistress, she was tr...               3
# 3  At the request of her headmistress, she was tr...               3
# 4  At the request of her headmistress, she was tr...               3
# 5  At the request of her headmistress, she was tr...               3
#
#                        section entType  wikiPageID
# 0  == Early life and career ==   place     2444917
# 1  == Early life and career ==   place     2444917
# 2  == Early life and career ==  person     2444917
# 3  == Early life and career ==  person     2444917
# 4  == Early life and career ==  person     2444917
# 5  == Early life and career ==  person     2444917
# ==1, DFs
# [3] [3] []
# [Butt, 107, 124, 136, 144, 153, 165]
# PERSON
# Filter: 3 4 0 Butt
# ENTIRY ROW                                        URI  support  \
# 2   http://dbpedia.org/resource/Clara_Butt      148
# 18  http://dbpedia.org/resource/Clara_Butt      148
# 32  http://dbpedia.org/resource/Clara_Butt      148
# 35  http://dbpedia.org/resource/Clara_Butt      148
#
#                                                 types      entity  offset  \
# 2   Http://xmlns.com/foaf/0.1/Person,Wikidata:Q729...  Clara Butt       0
# 18  Http://xmlns.com/foaf/0.1/Person,Wikidata:Q729...  Clara Butt       0
# 32  Http://xmlns.com/foaf/0.1/Person,Wikidata:Q729...  Clara Butt       0
# 35  Http://xmlns.com/foaf/0.1/Person,Wikidata:Q729...  Clara Butt       0
#
#     similarityScore  percentageOfSecondRank  \
# 2               1.0                     0.0
# 18              1.0                     0.0
# 32              1.0                     0.0
# 35              1.0                     0.0
#
#                                              sentence  sentenceIndex  \
# 2   Clara Butt was born in Southwick, Sussex, the ...              0
# 18  Clara Butt was born in Southwick, Sussex, the ...              0
# 32  Clara Butt was born in Southwick, Sussex, the ...              0
# 35  Clara Butt was born in Southwick, Sussex, the ...              0
#
#     paragraphIndex                      section entType  wikiPageID
# 2                3  == Early life and career ==  person     2444917
# 18               3  == Early life and career ==  person     2444917
# 32               3  == Early life and career ==  person     2444917
# 35               3  == Early life and career ==  person     2444917
# coref_temp_df    tokenIndex token charIndex entType sentIndex corefEntityValue
# 0         107  Butt         0  PERSON         4             Butt
# 1         124   Her         0                 5             Butt
# 2         136   her        68                 5             Butt
# 3         144   her         7                 6             Butt
# 4         153   she        55                 6             Butt
# 5         165   She         0                 7             Butt
# linkedEntities_temp_df     sentenceIndex                                           URI  support  \
# 0               5     http://dbpedia.org/resource/John_W._Henry      136
# 1               6    http://dbpedia.org/resource/Queen_Victoria    13526
# 2               5     http://dbpedia.org/resource/John_W._Henry      136
# 3               6    http://dbpedia.org/resource/Queen_Victoria    13526
# 4               6             http://dbpedia.org/resource/Paris   148693
# 5               7            http://dbpedia.org/resource/Berlin    94467
# 6               7             http://dbpedia.org/resource/Italy   158246
# 7               6             http://dbpedia.org/resource/Paris   148693
# 8               7            http://dbpedia.org/resource/Berlin    94467
# 9               7             http://dbpedia.org/resource/Italy   158246
# 10              5  http://dbpedia.org/resource/Marmaduke_Barton       16
# 11              5  http://dbpedia.org/resource/Marmaduke_Barton       16
#
#                                                 types            entity  \
# 0   Http://xmlns.com/foaf/0.1/Person,Wikidata:Q829...        John Henry
# 1   Http://xmlns.com/foaf/0.1/Person,Wikidata:Q729...    Queen Victoria
# 2   Http://xmlns.com/foaf/0.1/Person,Wikidata:Q829...        John Henry
# 3   Http://xmlns.com/foaf/0.1/Person,Wikidata:Q729...    Queen Victoria
# 4   Wikidata:Q486972,Schema:Place,DBpedia:Populate...             Paris
# 5   Wikidata:Q515,Wikidata:Q486972,Schema:Place,Sc...            Berlin
# 6   Wikidata:Q6256,Schema:Place,Schema:Country,DBp...             Italy
# 7   Wikidata:Q486972,Schema:Place,DBpedia:Populate...             Paris
# 8   Wikidata:Q515,Wikidata:Q486972,Schema:Place,Sc...            Berlin
# 9   Wikidata:Q6256,Schema:Place,Schema:Country,DBp...             Italy
# 10               DBpedia:Person,DBpedia:MusicalArtist  Marmaduke Barton
# 11               DBpedia:Person,DBpedia:MusicalArtist  Marmaduke Barton
#
#     offset  similarityScore  percentageOfSecondRank  \
# 0       24         0.808086                0.200988
# 1      109         0.999987                0.000009
# 2       24         0.808086                0.200988
# 3      109         0.999987                0.000009
# 4       90         0.999604                0.000396
# 5       20         0.996300                0.003540
# 6       31         0.993150                0.004381
# 7       90         0.999604                0.000396
# 8       20         0.996300                0.003540
# 9       31         0.993150                0.004381
# 10      90         1.000000                0.000000
# 11      90         1.000000                0.000000
#
#                                              sentence  paragraphIndex  \
# 0   Her voice teachers were John Henry Blower and ...               3
# 1   During her fourth year of vocal lessons at the...               3
# 2   Her voice teachers were John Henry Blower and ...               3
# 3   During her fourth year of vocal lessons at the...               3
# 4   During her fourth year of vocal lessons at the...               3
# 5               She also studied in Berlin and Italy.               3
# 6               She also studied in Berlin and Italy.               3
# 7   During her fourth year of vocal lessons at the...               3
# 8               She also studied in Berlin and Italy.               3
# 9               She also studied in Berlin and Italy.               3
# 10  Her voice teachers were John Henry Blower and ...               3
# 11  Her voice teachers were John Henry Blower and ...               3
#
#                         section entType  wikiPageID
# 0   == Early life and career ==  person     2444917
# 1   == Early life and career ==  person     2444917
# 2   == Early life and career ==  person     2444917
# 3   == Early life and career ==  person     2444917
# 4   == Early life and career ==   place     2444917
# 5   == Early life and career ==   place     2444917
# 6   == Early life and career ==   place     2444917
# 7   == Early life and career ==   place     2444917
# 8   == Early life and career ==   place     2444917
# 9   == Early life and career ==   place     2444917
# 10  == Early life and career ==  person     2444917
# 11  == Early life and career ==  person     2444917
# ==1, DFs
# [4 5 6 7] [] [4, 5, 6, 7]
# coref_temp_df    sentenceIndex  tokenIndex token charIndex entType corefEntityValue
# 0              4         107  Butt         0  PERSON             Butt
# 1              5         124   Her         0                     Butt
# 3              6         144   her         7                     Butt
# 5              7         165   She         0                     Butt
# new_linkedEntities_df    sentenceIndex                                          sentences  \
# 0              4  Butt won a scholarship to the Royal College of...
# 1              5  Her voice teachers were John Henry Blower and ...
# 2              6  During her fourth year of vocal lessons at the...
# 3              7              She also studied in Berlin and Italy.
#
#    paragraphIndex                      section   wikiId
# 0               3  == Early life and career ==  2444917
# 1               3  == Early life and career ==  2444917
# 2               3  == Early life and career ==  2444917
# 3               3  == Early life and career ==  2444917
#                                            sentences  sentenceIndex  \
# 0  Butt won a scholarship to the Royal College of...              4
# 1  Her voice teachers were John Henry Blower and ...              5
# 2  During her fourth year of vocal lessons at the...              6
# 3              She also studied in Berlin and Italy.              7
#
#    paragraphIndex                      section  wikiPageID offset entType  \
# 0               3  == Early life and career ==     2444917      0  person
# 1               3  == Early life and career ==     2444917      0  person
# 2               3  == Early life and career ==     2444917      7  person
# 3               3  == Early life and career ==     2444917      0  person
#
#   entity                                     URI  support  \
# 0   Butt  http://dbpedia.org/resource/Clara_Butt      NaN
# 1   Butt  http://dbpedia.org/resource/Clara_Butt      NaN
# 2   Butt  http://dbpedia.org/resource/Clara_Butt      NaN
# 3   Butt  http://dbpedia.org/resource/Clara_Butt      NaN
#
#                                                types  similarityScore  \
# 0  Http://xmlns.com/foaf/0.1/Person,Wikidata:Q729...              NaN
# 1  Http://xmlns.com/foaf/0.1/Person,Wikidata:Q729...              NaN
# 2  Http://xmlns.com/foaf/0.1/Person,Wikidata:Q729...              NaN
# 3  Http://xmlns.com/foaf/0.1/Person,Wikidata:Q729...              NaN
#
#    percentageOfSecondRank
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# retrieved
# [[She, 0, 2], [London, 15, 27], [critic, 62, 69, 89, 92, 94, 114, 118], [Saëns, 112, 121], [representation, 132, 147], [Butt, 174, 180, 201, 208, 212, 220, 228, 246, 260, 272, 274, 281, 317, 323], [Elgar, 303, 306]]
# /tmp/ipykernel_100/2006060584.py:19: DeprecationWarning: NotImplemented should not be used in a boolean context
#   res = list(filter((None).__ne__, res1))
# /tmp/ipykernel_100/2367422593.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   coref_df['corefEntityValue'] = coref_df['corefEntityValue'].astype(str)
# [She, 0, 2]
# [London, 15, 27]
# GPE
# Filter: 4 0 79 London
# ENTIRY ROW                                    URI  support  \
# 46  http://dbpedia.org/resource/London   251270
# 69  http://dbpedia.org/resource/London   251270
#
#                                                 types  entity  offset  \
# 46  Wikidata:Q515,Wikidata:Q486972,Schema:Place,Sc...  London      79
# 69  Wikidata:Q515,Wikidata:Q486972,Schema:Place,Sc...  London      79
#
#     similarityScore  percentageOfSecondRank  \
# 46         0.999472                0.000296
# 69         0.999472                0.000296
#
#                                              sentence  sentenceIndex  \
# 46  She made her professional debut on 7 December ...              0
# 69  She made her professional debut on 7 December ...              0
#
#     paragraphIndex                      section entType  wikiPageID
# 46               4  == Early life and career ==   place     2444917
# 69               4  == Early life and career ==   place     2444917
# coref_temp_df    tokenIndex   token charIndex entType sentIndex corefEntityValue
# 0          15  London        79     GPE         0           London
# 1          27     she        17                 1           London
# linkedEntities_temp_df    sentenceIndex                                                URI  support  \
# 0              0                 http://dbpedia.org/resource/London   251270
# 1              0                 http://dbpedia.org/resource/London   251270
# 2              0        http://dbpedia.org/resource/Arthur_Sullivan     1385
# 3              1  http://dbpedia.org/resource/Christoph_Willibal...     1290
# 4              0        http://dbpedia.org/resource/Arthur_Sullivan     1385
# 5              1  http://dbpedia.org/resource/Christoph_Willibal...     1290
#
#                                                types    entity  offset  \
# 0  Wikidata:Q515,Wikidata:Q486972,Schema:Place,Sc...    London      79
# 1  Wikidata:Q515,Wikidata:Q486972,Schema:Place,Sc...    London      79
# 2               DBpedia:Person,DBpedia:MusicalArtist  Sullivan      89
# 3               DBpedia:Person,DBpedia:MusicalArtist     Gluck      42
# 4               DBpedia:Person,DBpedia:MusicalArtist  Sullivan      89
# 5               DBpedia:Person,DBpedia:MusicalArtist     Gluck      42
#
#    similarityScore  percentageOfSecondRank  \
# 0         0.999472            2.959908e-04
# 1         0.999472            2.959908e-04
# 2         0.999987            1.309008e-05
# 3         1.000000            1.518909e-11
# 4         0.999987            1.309008e-05
# 5         1.000000            1.518909e-11
#
#                                             sentence  paragraphIndex  \
# 0  She made her professional debut on 7 December ...               4
# 1  She made her professional debut on 7 December ...               4
# 2  She made her professional debut on 7 December ...               4
# 3  Three days later she appeared as Orfeo in Gluc...               4
# 4  She made her professional debut on 7 December ...               4
# 5  Three days later she appeared as Orfeo in Gluc...               4
#
#                        section entType  wikiPageID
# 0  == Early life and career ==   place     2444917
# 1  == Early life and career ==   place     2444917
# 2  == Early life and career ==  person     2444917
# 3  == Early life and career ==  person     2444917
# 4  == Early life and career ==  person     2444917
# 5  == Early life and career ==  person     2444917
# ==1, DFs
# [0 1] [0] [1]
# coref_temp_df    sentenceIndex  tokenIndex token charIndex entType corefEntityValue
# 0              1          27   she        17                   London
# new_linkedEntities_df    sentenceIndex                                          sentences  \
# 0              1  Three days later she appeared as Orfeo in Gluc...
#
#    paragraphIndex                      section   wikiId
# 0               4  == Early life and career ==  2444917
#                                            sentences  sentenceIndex  \
# 0  Three days later she appeared as Orfeo in Gluc...              1
#
#    paragraphIndex                      section  wikiPageID offset entType  \
# 0               4  == Early life and career ==     2444917     17   place
#
#    entity                                 URI  support  \
# 0  London  http://dbpedia.org/resource/London      NaN
#
#                                                types  similarityScore  \
# 0  Wikidata:Q515,Wikidata:Q486972,Schema:Place,Sc...              NaN
#
#    percentageOfSecondRank
# 0                     NaN
# [critic, 62, 69, 89, 92, 94, 114, 118]
# [Saëns, 112, 121]
# PERSON
# Filter: 4 5 34 Saëns
# ENTIRY ROW Empty DataFrame
# Columns: [URI, support, types, entity, offset, similarityScore, percentageOfSecondRank, sentence, sentenceIndex, paragraphIndex, section, entType, wikiPageID]
# Index: []
# [representation, 132, 147]
# [Butt, 174, 180, 201, 208, 212, 220, 228, 246, 260, 272, 274, 281, 317, 323]
# PERSON
# Filter: 4 6 116 Butt
# ENTIRY ROW Empty DataFrame
# Columns: [URI, support, types, entity, offset, similarityScore, percentageOfSecondRank, sentence, sentenceIndex, paragraphIndex, section, entType, wikiPageID]
# Index: []
# [Elgar, 303, 306]
# PERSON
# Filter: 4 12 46 Elgar
# ENTIRY ROW                                           URI  support  \
# 101  http://dbpedia.org/resource/Edward_Elgar     2222
# 121  http://dbpedia.org/resource/Edward_Elgar     2222
#
#                                     types        entity  offset  \
# 101  DBpedia:Person,DBpedia:MusicalArtist  Edward Elgar      39
# 121  DBpedia:Person,DBpedia:MusicalArtist  Edward Elgar      39
#
#      similarityScore  percentageOfSecondRank  \
# 101              1.0            2.800925e-16
# 121              1.0            2.800925e-16
#
#                                               sentence  sentenceIndex  \
# 101  Britain's leading composer of the era, Edward ...             12
# 121  Britain's leading composer of the era, Edward ...             12
#
#      paragraphIndex                      section entType  wikiPageID
# 101               4  == Early life and career ==  person     2444917
# 121               4  == Early life and career ==  person     2444917
# coref_temp_df    tokenIndex  token charIndex entType sentIndex corefEntityValue
# 0         303  Elgar        46  PERSON        12            Elgar
# 1         306    his        62                12            Elgar
# linkedEntities_temp_df    sentenceIndex                                         URI  support  \
# 0             12  http://dbpedia.org/resource/United_Kingdom   174100
# 1             12  http://dbpedia.org/resource/United_Kingdom   174100
# 2             12    http://dbpedia.org/resource/Edward_Elgar     2222
# 3             12    http://dbpedia.org/resource/Edward_Elgar     2222
#
#                                                types        entity  offset  \
# 0  Wikidata:Q6256,Schema:Place,Schema:Country,DBp...       Britain       0
# 1  Wikidata:Q6256,Schema:Place,Schema:Country,DBp...       Britain       0
# 2               DBpedia:Person,DBpedia:MusicalArtist  Edward Elgar      39
# 3               DBpedia:Person,DBpedia:MusicalArtist  Edward Elgar      39
#
#    similarityScore  percentageOfSecondRank  \
# 0         0.692379            3.773824e-01
# 1         0.692379            3.773824e-01
# 2         1.000000            2.800925e-16
# 3         1.000000            2.800925e-16
#
#                                             sentence  paragraphIndex  \
# 0  Britain's leading composer of the era, Edward ...               4
# 1  Britain's leading composer of the era, Edward ...               4
# 2  Britain's leading composer of the era, Edward ...               4
# 3  Britain's leading composer of the era, Edward ...               4
#
#                        section entType  wikiPageID
# 0  == Early life and career ==   place     2444917
# 1  == Early life and career ==   place     2444917
# 2  == Early life and career ==  person     2444917
# 3  == Early life and career ==  person     2444917
# ==1, DFs
# [12] [12] []
# retrieved
# []
# retrieved
# [[Butt, 4, 37, 54, 82, 119, 149, 169, 177, 193, 213, 231], [baritone, 7, 20], [Rumford, 9, 16], [number, 162, 191], [time, 174, 184], [Hook, 242, 249]]
# /tmp/ipykernel_100/2006060584.py:19: DeprecationWarning: NotImplemented should not be used in a boolean context
#   res = list(filter((None).__ne__, res1))
# /tmp/ipykernel_100/2367422593.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   coref_df['corefEntityValue'] = coref_df['corefEntityValue'].astype(str)
# [Butt, 4, 37, 54, 82, 119, 149, 169, 177, 193, 213, 231]
# PERSON
# Filter: 6 0 16 Butt
# ENTIRY ROW                                        URI  support  \
# 13  http://dbpedia.org/resource/Clara_Butt      148
# 29  http://dbpedia.org/resource/Clara_Butt      148
# 34  http://dbpedia.org/resource/Clara_Butt      148
# 37  http://dbpedia.org/resource/Clara_Butt      148
#
#                                                 types      entity  offset  \
# 13  Http://xmlns.com/foaf/0.1/Person,Wikidata:Q729...  Clara Butt       0
# 29  Http://xmlns.com/foaf/0.1/Person,Wikidata:Q729...  Clara Butt       0
# 34  Http://xmlns.com/foaf/0.1/Person,Wikidata:Q729...  Clara Butt       0
# 37  Http://xmlns.com/foaf/0.1/Person,Wikidata:Q729...  Clara Butt       0
#
#     similarityScore  percentageOfSecondRank  \
# 13              1.0                     0.0
# 29              1.0                     0.0
# 34              1.0                     0.0
# 37              1.0                     0.0
#
#                                              sentence  sentenceIndex  \
# 13  Clara Butt performed 110 times at the Royal Al...              7
# 29  Clara Butt performed 110 times at the Royal Al...              7
# ...
# 3   Http://xmlns.com/foaf/0.1/Person,Wikidata:Q829...                 Che
# 4   Http://xmlns.com/foaf/0.1/Person,Wikidata:Q729...          Clara Butt
# 5   Http://xmlns.com/foaf/0.1/Person,Wikidata:Q729...      Queen Victoria
# 6   Http://xmlns.com/foaf/0.1/Person,Wikidata:Q729...     King Edward VII
# 7   Http://xmlns.com/foaf/0.1/Person,Wikidata:Q729...       King George V
# 8   Http://xmlns.com/foaf/0.1/Person,Wikidata:Q829...                 Che
# 9   Http://xmlns.com/foaf/0.1/Person,Wikidata:Q729...          Clara Butt
# 10  Http://xmlns.com/foaf/0.1/Person,Wikidata:Q729...          Clara Butt
# 11  Http://xmlns.com/foaf/0.1/Person,Wikidata:Q729...          Clara Butt
# 12  Wikidata:Q6256,Schema:Place,Schema:Country,DBp...           Australia
# 13  Wikidata:Q6256,Schema:Place,Schema:Country,DBp...               Japan
# 14  Wikidata:Q6256,Schema:Place,Schema:Country,DBp...              Canada
# 15  Wikidata:Q6256,Schema:Place,Schema:Country,DBp...       United States
# 16  Wikidata:Q6256,Schema:Place,Schema:Country,DBp...              Empire
# 17  Wikidata:Q6256,Schema:Place,Schema:Country,DBp...           Australia
# 18  Wikidata:Q6256,Schema:Place,Schema:Country,DBp...               Japan
# 19  Wikidata:Q6256,Schema:Place,Schema:Country,DBp...              Canada
# 20  Wikidata:Q6256,Schema:Place,Schema:Country,DBp...       United States
# 21  Wikidata:Q6256,Schema:Place,Schema:Country,DBp...              Empire
# 22  Wikidata:Q1656682,DUL:Event,Schema:Event,DBped...     First World War
# 23  Wikidata:Q1656682,DUL:Event,Schema:Event,DBped...     First World War
# 24  Wikidata:Q1656682,DUL:Event,Schema:Event,DBped...     First World War
# 25  Wikidata:Q1656682,DUL:Event,Schema:Event,DBped...     First World War
# 26               DBpedia:Person,DBpedia:MusicalArtist   Kennerley Rumford
# 27               DBpedia:Person,DBpedia:MusicalArtist               Gluck
# 28               DBpedia:Person,DBpedia:MusicalArtist      Miriam Licette
# 29               DBpedia:Person,DBpedia:MusicalArtist  Sir Thomas Beecham
# 30               DBpedia:Person,DBpedia:MusicalArtist      Thomas Beecham
# 31               DBpedia:Person,DBpedia:MusicalArtist   Kennerley Rumford
# 32               DBpedia:Person,DBpedia:MusicalArtist               Gluck
# 33               DBpedia:Person,DBpedia:MusicalArtist      Miriam Licette
# 34               DBpedia:Person,DBpedia:MusicalArtist  Sir Thomas Beecham
# 35               DBpedia:Person,DBpedia:MusicalArtist      Thomas Beecham
#
#     offset  similarityScore  percentageOfSecondRank  \
# 0       96         1.000000            3.557979e-08
# 1      112         0.999982            1.783693e-05
# 2      133         0.999982            1.692953e-05
# 3       85         1.000000            1.118482e-08
# 4        0         1.000000            0.000000e+00
# 5       96         1.000000            3.557979e-08
# 6      112         0.999982            1.783693e-05
# 7      133         0.999982            1.692953e-05
# 8       85         1.000000            1.118482e-08
# 9        0         1.000000            0.000000e+00
# 10       0         1.000000            0.000000e+00
# 11       0         1.000000            0.000000e+00
# 12     166         0.998582            8.687743e-04
# 13     177         0.997465            1.228162e-03
# 14     184         0.999525            3.229511e-04
# 15     209         0.999585            2.737697e-04
# 16     162         0.994946            3.028229e-03
# 17     166         0.998582            8.687743e-04
# 18     177         0.997465            1.228162e-03
# 19     184         0.999525            3.229511e-04
# 20     209         0.999585            2.737697e-04
# 21     162         0.994946            3.028229e-03
# 22      11         0.999988            1.096137e-05
# 23     144         0.999909            9.026399e-05
# 24      11         0.999988            1.096137e-05
# 25     144         0.999909            9.026399e-05
# 26      42         1.000000            0.000000e+00
# 27      40         1.000000            2.402550e-15
# 28      89         1.000000            0.000000e+00
# 29     124         1.000000            0.000000e+00
# 30     128         1.000000            1.792446e-23
# 31      42         1.000000            0.000000e+00
# 32      40         1.000000            2.402550e-15
# 33      89         1.000000            0.000000e+00
# 34     124         1.000000            0.000000e+00
# 35     128         1.000000            1.792446e-23
#
#                                              sentence  paragraphIndex  \
# 0   Besides singing in many important festivals an...               6
# 1   Besides singing in many important festivals an...               6
# 2   Besides singing in many important festivals an...               6
# 3   According to The Times she was ill at ease on ...               6
# 4   Clara Butt performed 110 times at the Royal Al...               6
# 5   Besides singing in many important festivals an...               6
# 6   Besides singing in many important festivals an...               6
# 7   Besides singing in many important festivals an...               6
# 8   According to The Times she was ill at ease on ...               6
# 9   Clara Butt performed 110 times at the Royal Al...               6
# 10  Clara Butt performed 110 times at the Royal Al...               6
# 11  Clara Butt performed 110 times at the Royal Al...               6
# 12  Besides singing in many important festivals an...               6
# 13  Besides singing in many important festivals an...               6
# 14  Besides singing in many important festivals an...               6
# 15  Besides singing in many important festivals an...               6
# 16  During the First World War, Butt organised and...               6
# 17  Besides singing in many important festivals an...               6
# 18  Besides singing in many important festivals an...               6
# 19  Besides singing in many important festivals an...               6
# 20  Besides singing in many important festivals an...               6
# 21  During the First World War, Butt organised and...               6
# 22  During the First World War, Butt organised and...               6
# 23  Clara Butt performed 110 times at the Royal Al...               6
# 24  During the First World War, Butt organised and...               6
# 25  Clara Butt performed 110 times at the Royal Al...               6
# 26  On 26 June 1900 Butt married the baritone Kenn...               6
# 27  That year she sang four performances of Gluck'...               6
# 28  That year she sang four performances of Gluck'...               6
# 29  That year she sang four performances of Gluck'...               6
# 30  That year she sang four performances of Gluck'...               6
# 31  On 26 June 1900 Butt married the baritone Kenn...               6
# 32  That year she sang four performances of Gluck'...               6
# 33  That year she sang four performances of Gluck'...               6
# 34  That year she sang four performances of Gluck'...               6
# 35  That year she sang four performances of Gluck'...               6
#
#              section entType  wikiPageID
# 0   == Later life ==  person     2444917
# 1   == Later life ==  person     2444917
# 2   == Later life ==  person     2444917
# 3   == Later life ==  person     2444917
# 4   == Later life ==  person     2444917
# 5   == Later life ==  person     2444917
# 6   == Later life ==  person     2444917
# 7   == Later life ==  person     2444917
# 8   == Later life ==  person     2444917
# 9   == Later life ==  person     2444917
# 10  == Later life ==  person     2444917
# 11  == Later life ==  person     2444917
# 12  == Later life ==   place     2444917
# 13  == Later life ==   place     2444917
# 14  == Later life ==   place     2444917
# 15  == Later life ==   place     2444917
# 16  == Later life ==   place     2444917
# 17  == Later life ==   place     2444917
# 18  == Later life ==   place     2444917
# 19  == Later life ==   place     2444917
# 20  == Later life ==   place     2444917
# 21  == Later life ==   place     2444917
# 22  == Later life ==   event     2444917
# 23  == Later life ==   event     2444917
# 24  == Later life ==   event     2444917
# 25  == Later life ==   event     2444917
# 26  == Later life ==  person     2444917
# 27  == Later life ==  person     2444917
# 28  == Later life ==  person     2444917
# 29  == Later life ==  person     2444917
# 30  == Later life ==  person     2444917
# 31  == Later life ==  person     2444917
# 32  == Later life ==  person     2444917
# 33  == Later life ==  person     2444917
# 34  == Later life ==  person     2444917
# 35  == Later life ==  person     2444917
# ==1, DFs
# [0 2 3 4 5 6 7 8] [7] [0, 2, 3, 4, 5, 6, 8]
# coref_temp_df    sentenceIndex  tokenIndex token charIndex entType corefEntityValue
# 0              0           4  Butt        16  PERSON             Butt
# 1              2          37  Butt        58  PERSON             Butt
# 3              3          82  Butt        28  PERSON             Butt
# 4              4         119   she        10                     Butt
# 5              5         149   she        23                     Butt
# 8              6         193   her         7                     Butt
# 9              8         231  Butt         0  PERSON             Butt
# new_linkedEntities_df    sentenceIndex                                          sentences  \
# 0              0  On 26 June 1900 Butt married the baritone Kenn...
# 1              2  Besides singing in many important festivals an...
# 2              3  During the First World War, Butt organised and...
# 3              4  That year she sang four performances of Gluck'...
# 4              5  According to The Times she was ill at ease on ...
# 5              6  It was her only appearance on the professional...
# 6              8            Butt's three sisters were also singers.
#
#    paragraphIndex           section   wikiId
# 0               6  == Later life ==  2444917
# 1               6  == Later life ==  2444917
# 2               6  == Later life ==  2444917
# 3               6  == Later life ==  2444917
# 4               6  == Later life ==  2444917
# 5               6  == Later life ==  2444917
# 6               6  == Later life ==  2444917
#                                            sentences  sentenceIndex  \
# 0  On 26 June 1900 Butt married the baritone Kenn...              0
# 1  Besides singing in many important festivals an...              2
# 2  During the First World War, Butt organised and...              3
# 3  That year she sang four performances of Gluck'...              4
# 4  According to The Times she was ill at ease on ...              5
# 5  It was her only appearance on the professional...              6
# 6            Butt's three sisters were also singers.              8
#
#    paragraphIndex           section  wikiPageID offset entType entity  \
# 0               6  == Later life ==     2444917     16  person   Butt
# 1               6  == Later life ==     2444917     58  person   Butt
# 2               6  == Later life ==     2444917     28  person   Butt
# 3               6  == Later life ==     2444917     10  person   Butt
# 4               6  == Later life ==     2444917     23  person   Butt
# 5               6  == Later life ==     2444917      7  person   Butt
# 6               6  == Later life ==     2444917      0  person   Butt
#
#                                       URI  support  \
# 0  http://dbpedia.org/resource/Clara_Butt      NaN
# 1  http://dbpedia.org/resource/Clara_Butt      NaN
# 2  http://dbpedia.org/resource/Clara_Butt      NaN
# 3  http://dbpedia.org/resource/Clara_Butt      NaN
# 4  http://dbpedia.org/resource/Clara_Butt      NaN
# 5  http://dbpedia.org/resource/Clara_Butt      NaN
# 6  http://dbpedia.org/resource/Clara_Butt      NaN
#
#                                                types  similarityScore  \
# 0  Http://xmlns.com/foaf/0.1/Person,Wikidata:Q729...              NaN
# 1  Http://xmlns.com/foaf/0.1/Person,Wikidata:Q729...              NaN
# 2  Http://xmlns.com/foaf/0.1/Person,Wikidata:Q729...              NaN
# 3  Http://xmlns.com/foaf/0.1/Person,Wikidata:Q729...              NaN
# 4  Http://xmlns.com/foaf/0.1/Person,Wikidata:Q729...              NaN
# 5  Http://xmlns.com/foaf/0.1/Person,Wikidata:Q729...              NaN
# 6  Http://xmlns.com/foaf/0.1/Person,Wikidata:Q729...              NaN
#
#    percentageOfSecondRank
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# 5                     NaN
# 6                     NaN
# [baritone, 7, 20]
# [Rumford, 9, 16]
# PERSON
# Filter: 6 0 52 Rumford
# ENTIRY ROW                                                URI  support  \
# 102  http://dbpedia.org/resource/Kennerley_Rumford       13
# 122  http://dbpedia.org/resource/Kennerley_Rumford       13
#
#                                     types             entity  offset  \
# 102  DBpedia:Person,DBpedia:MusicalArtist  Kennerley Rumford      42
# 122  DBpedia:Person,DBpedia:MusicalArtist  Kennerley Rumford      42
#
#      similarityScore  percentageOfSecondRank  \
# 102              1.0                     0.0
# 122              1.0                     0.0
#
#                                               sentence  sentenceIndex  \
# 102  On 26 June 1900 Butt married the baritone Kenn...              0
# 122  On 26 June 1900 Butt married the baritone Kenn...              0
#
#      paragraphIndex           section entType  wikiPageID
# 102               6  == Later life ==  person     2444917
# 122               6  == Later life ==  person     2444917
# coref_temp_df    tokenIndex    token charIndex entType sentIndex corefEntityValue
# 0           9  Rumford        52  PERSON         0          Rumford
# 1          16      him        99                 0          Rumford
# linkedEntities_temp_df    sentenceIndex                                            URI  support  \
# 0              0  http://dbpedia.org/resource/Kennerley_Rumford       13
# 1              0  http://dbpedia.org/resource/Kennerley_Rumford       13
#
#                                   types             entity  offset  \
# 0  DBpedia:Person,DBpedia:MusicalArtist  Kennerley Rumford      42
# 1  DBpedia:Person,DBpedia:MusicalArtist  Kennerley Rumford      42
#
#    similarityScore  percentageOfSecondRank  \
# 0              1.0                     0.0
# 1              1.0                     0.0
#
#                                             sentence  paragraphIndex  \
# 0  On 26 June 1900 Butt married the baritone Kenn...               6
# 1  On 26 June 1900 Butt married the baritone Kenn...               6
#
#             section entType  wikiPageID
# 0  == Later life ==  person     2444917
# 1  == Later life ==  person     2444917
# ==1, DFs
# [0] [0] []
# [number, 162, 191]
# [time, 174, 184]
# [Hook, 242, 249]
# PERSON
# Filter: 6 9 11 Hook
# ENTIRY ROW Empty DataFrame
# Columns: [URI, support, types, entity, offset, similarityScore, percentageOfSecondRank, sentence, sentenceIndex, paragraphIndex, section, entType, wikiPageID]
# Index: []
# retrieved
# [[She, 0, 6, 12, 15, 21, 31, 45, 58]]
# /tmp/ipykernel_100/2006060584.py:19: DeprecationWarning: NotImplemented should not be used in a boolean context
#   res = list(filter((None).__ne__, res1))
# [She, 0, 6, 12, 15, 21, 31, 45, 58]
# /tmp/ipykernel_100/2367422593.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   coref_df['corefEntityValue'] = coref_df['corefEntityValue'].astype(str)

# %%
# http://dbpedia.org/resource/Composer
# http://dbpedia.org/resource/Solicitor
# http://dbpedia.org/resource/Conducting
# http://dbpedia.org/resource/Contralto
# http://dbpedia.org/resource/Tempo

dct:subject dbc:Occupations_in_music
<http://purl.org/dc/terms/subject> https://dbpedia.org/page/Category:Occupations_in_music
rdf:type dbo:PersonFunction
# <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://dbpedia.org/ontology/PersonFunction>

# %% [markdown]
# ### Run the COREFERENCE task

# %%
# def corefText(doc):
#     doc._.coref_chains.print()
#     tok_list = list(token.text for token in doc)
#     c = 0
#     for chain in doc._.coref_chains:
#         for mention in chain:
#             res1 = [doc._.coref_chains.resolve(doc[i]) for i in mention]
#             res = list(filter((None).__ne__, res1))
#             if len(res) != 0:
#                 if len(res[0]) == 1:
#                     tok_list[mention[0] + c] = str(res[0][0])
#                 elif len(res[0]) > 1:
#                     tok_list[mention[0] + c] = str(res[0][0])
#                     for j in range(1, len(res[0])):
#                         tok_list.insert(mention[0] + c + j, str(res[0][j]))
#                         c = c + 1
#     textres = " ".join(tok_list)
#     print(textres)
#     return textres

# def executeCoreferenceParagraph(paragraph_df,file_name_item):
#     for paragraph_row in paragraph_df.itertuples():
#         doc = nlp(paragraph_row.paragraph)
#         print(doc)
#         break

# def executeCoreference(sentencesCandidates_df,meetupCandidate_df,file_name_item):
#     # filter only INCOMPLETE meetups
#     # to_check_df = sentencesCandidates_df.query("meetup!='Y'")
    
#     # paragraphSentences_df = meetupCandidate_df.query("paragraphIndex=={}".format(sentence_row.paragraphIndex))
#     paragraphSentences_df = pd.read_csv('indexedSentences/'+file_name_item.file_name.replace(".txt",".csv"))
    
#     count = 0
#      # iterate all the paragraphs
#     for paragraph_row in paragraphSentences_df.itertuples():
        
#         count+=1
#         print(paragraph_row.paragraphIndex)
#         doc = nlp(paragraph_row.paragraph)
        
#         for entity in doc.ents:
#             print(entity.text, entity.label_)
            
#             if entity.label_ == "PERSON" or entity.label_ == "GPE":
#                 continue_next_bool = False
#         crText_string = corefText(doc)
        
#         if count == 3:
#             break
# #     # iterate all the sentences
# #     for sentence_row in to_check_df.itertuples():
# #         print(sentence_row.paragraphIndex)
# #         print(sentence_row.sentenceIndex)                                           
# #         doc = nlp(sentence_row.sentences)
# #         continue_next_bool = True
        
# #         # run a process to double check if there are not entities, use corereference library if there is any entity: type PERSON, GPE, DATE
# #         for entity in doc.ents:
# #             print(entity.text, entity.label_)
            
# #             if entity.label_ == "PERSON" or entity.label_ == "GPE":
# #                 crText_string = corefText(doc)
# #                 continue_next_bool = False
                
#     # return
    

# def obtainEntitiesTypes(doc):
#     corefEnts_df = pd.DataFrame(columns=["type","entity","index"])
    
#     # print("Ents: ")
#     for entity in doc.ents:
#         # print(entity)
#         for i in entity:
#             # print(entity)
#             print(entity.text, entity.label_)
#         if "PERSON" in entity.label_ or "DATE" in entity.label_ or "GPE" in entity.label_:
#             # print("store")
#             datarow = pd.Series(data={'type':entity.label_,'entity':entity.text,'index':0})
#             corefEnts_df = corefEnts_df.append(datarow, ignore_index=True)

# def obtainCoref(doc):
#     coref = []
#     coref_ents = []
#     print("Chains:")
#     doc._.coref_chains.print()
#     n_tokens_int = 0
#     for chain in doc._.coref_chains:
#         indexes_coref = []
#         # indexes = [doc._.coref_chains.resolve(doc[i]) for i in mention]
        
#         for mention in chain:
#             print(mention)
#             indexes_coref.append(mention)
#             print(indexes_coref)
#             # store the indexes of the entities
#             # for i in mention:
#             #     value = doc._.coref_chains.resolve(doc[i])
#             #     # print(type(value))
#             #     # print(i)# position
#             #     # print(value)# the named entity
#             #     indexes_coref.append(i)
#         value.append(indexes_coref)
#         # print(value)
#         coref_ents.append(value)
#     print(coref_ents)
            

    
    # for sent in doc.sents:
    #     print(sent)
    #     # sent.string.strip()
    #     # for token in sent:
    #         # print(token, token.idx)
    #     n_tokens_int = n_tokens_int + len(sent)
    #     print(len(sent))
    #     print(n_tokens_int)
# doc = nlp("Sir Edward William Elgar, 1st Baronet,  ( (listen); 2 June 1857 – 23 February 1934) was an English composer, many of whose works have entered the British and international classical concert repertoire. Among his best-known compositions are orchestral works including the Enigma Variations, the Pomp and Circumstance Marches, concertos for violin and cello, and two symphonies. He also composed choral works, including The Dream of Gerontius, chamber music and songs. He was appointed Master of the King's Musick in 1924.")

# doc = nlp("Although Elgar is often regarded as a typically English composer, most of his musical influences were not from England but from continental Europe. He felt himself to be an outsider, not only musically, but socially. In musical circles dominated by academics, he was a self-taught composer; in Protestant Britain, his Roman Catholicism was regarded with suspicion in some quarters; and in the class-conscious society of Victorian and Edwardian Britain, he was acutely sensitive about his humble origins even after he achieved recognition. He nevertheless married the daughter of a senior British Army officer. She inspired him both musically and socially, but he struggled to achieve success until his forties, when after a series of moderately successful works his Enigma Variations (1899) became immediately popular in Britain and overseas. He followed the Variations with a choral work, The Dream of Gerontius (1900), based on a Roman Catholic text that caused some disquiet in the Anglican establishment in Britain, but it became, and has remained, a core repertory work in Britain and elsewhere. His later full-length religious choral works were well received but have not entered the regular repertory.")


# for i, token in enumerate(doc):
#     print(i, token)
obtainCoref(doc)

# for chain in doc._.coref_chains:
#     print("Chain: ")
#     print(chain)
#     for mention in chain:
#         print("Mention: ")
#         print(mention)
#         for i in mention:
#             print("i: ")            
#             print(i)
#             value = doc._.coref_chains.resolve(doc[i])
#             print(value)
#     print("----")
# obtainEntitiesCoref(doc)
# Out:
# /opt/conda/lib/python3.9/site-packages/torch/autocast_mode.py:162: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# Chains:
# 0: Elgar(1), he(5), Elgar(44), his(48)
# 1: Alice(18), Alice(46)
# [1]
# [[1]]
# [5]
# [[1], 1, [5]]
# [44]
# [[1], 1, [5], 5, [44]]
# [48]
# [[1], 1, [5], 5, [44], 44, [48]]
# [18]
# [[18]]
# [46]
# [[18], 18, [46]]
# [[Elgar, [[1], 1, [5], 5, [44], 44, [48], 48]], [Alice, [[18], 18, [46], 46]]]

# %%
# doc = nlp('Sir Edward William Elgar, 1st Baronet,  listen; 2 June 1857 – 23 February 1934) was an English composer, ')
# many of whose works have entered the British and international classical concert repertoire.
# doc = nlp("Although Elgar is often regarded as a typically English composer, most of his musical influences were not from England but from continental Europe.")
doc = nlp("Sir Edward William Elgar, 1st Baronet,  ( (listen); 2 June 1857 – 23 February 1934) was an English composer, many of whose works have entered the British and international classical concert repertoire. Among his best-known compositions are orchestral works including the Enigma Variations, the Pomp and Circumstance Marches, concertos for violin and cello, and two symphonies. He also composed choral works, including The Dream of Gerontius, chamber music and songs. He was appointed Master of the King's Musick in 1924.")

# %%
print("Chains:")
doc._.coref_chains.print()
print("[]:")
doc[25]._.coref_chains.print()
print("resolve:")
value = doc._.coref_chains.resolve(doc[25])
print(value)
print("Ents: ")
for entity in doc.ents:
    print(entity.text, entity.label_)
print("====")
# print("Print tokens: ")
# for i in doc:
#     print(i.text, i.label_)
for chain in doc._.coref_chains:
    print("Chain: ")
    print(chain)
    for mention in chain:
        print("Mention: ")
        print(mention)
        for i in mention:
            print("i: ")            
            print(i)
            value = doc._.coref_chains.resolve(doc[i])
            print(value)
    print("----")
# Out:
# Chains:
# 0: composer(25), his(42), He(71), He(88)
# []:
# 0: composer(25), his(42), He(71), He(88)
# resolve:
# None
# Ents:
# Edward William Elgar PERSON
# 1st ORDINAL
# 2 June 1857 – 23 February 1934 DATE
# English NORP
# British NORP
# the Enigma Variations WORK_OF_ART
# the Pomp and Circumstance Marches WORK_OF_ART
# two CARDINAL
# The Dream of Gerontius WORK_OF_ART
# 1924 DATE
# ====
# Chain:
# 0: [25], [42], [71], [88]
# Mention:
# [25]
# i:
# 25
# None
# Mention:
# [42]
# i:
# 42
# [composer]
# Mention:
# [71]
# i:
# 71
# [composer]
# Mention:
# [88]
# i:
# 88
# [composer]
# ----

# %%
print("Chains:")
doc._.coref_chains.print()
n_tokens_int = 0
for sent in doc.sents:
    print(sent)
    # sent.string.strip()
    # for token in sent:
        # print(token, token.idx)
    n_tokens_int = n_tokens_int + len(sent)
    print(len(sent))
    print(n_tokens_int)
# Out:
# Chains:
# 0: Elgar(1), his(13), He(25), himself(27), he(47), his(59), he(83), his(88), he(93), He(97), him(111), he(118), his(124), his(135), He(149), His(200)
# 1: Britain(57), Britain(81), Britain(145), Britain(181), Britain(196)
# 2: daughter(101), She(109)
# 3: Variations(137), Variations(152)
# 4: disquiet(175), it(184)
# Although Elgar is often regarded as a typically English composer, most of his musical influences were not from England but from continental Europe.
# 25
# 25
# He felt himself to be an outsider, not only musically, but socially.
# 15
# 40
# In musical circles dominated by academics, he was a self-taught composer; in Protestant Britain, his Roman Catholicism was regarded with suspicion in some quarters; and in the class-conscious society of Victorian and Edwardian Britain, he was acutely sensitive about his humble origins even after he achieved recognition.
# 57
# 97
# He nevertheless married the daughter of a senior British Army officer.
# 12
# 109
# She inspired him both musically and socially, but he struggled to achieve success until his forties, when after a series of moderately successful works his Enigma Variations (1899) became immediately popular in Britain and overseas.
# 40
# 149
# He followed the Variations with a choral work, The Dream of Gerontius (1900), based on a Roman Catholic text that caused some disquiet in the Anglican establishment in Britain, but it became, and has remained, a core repertory work in Britain and elsewhere.
# 51
# 200
# His later full-length religious choral works were well received but have not entered the regular repertory.
# 19
# 219

# %%
doc = nlp("Although Elgar is often regarded as a typically English composer, most of his musical influences were not from England but from continental Europe. He felt himself to be an outsider, not only musically, but socially. In musical circles dominated by academics, he was a self-taught composer; in Protestant Britain, his Roman Catholicism was regarded with suspicion in some quarters; and in the class-conscious society of Victorian and Edwardian Britain, he was acutely sensitive about his humble origins even after he achieved recognition. He nevertheless married the daughter of a senior British Army officer. She inspired him both musically and socially, but he struggled to achieve success until his forties, when after a series of moderately successful works his Enigma Variations (1899) became immediately popular in Britain and overseas. He followed the Variations with a choral work, The Dream of Gerontius (1900), based on a Roman Catholic text that caused some disquiet in the Anglican establishment in Britain, but it became, and has remained, a core repertory work in Britain and elsewhere. His later full-length religious choral works were well received but have not entered the regular repertory.")
# Out:
# /opt/conda/lib/python3.9/site-packages/torch/autocast_mode.py:162: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')

# %%
print("Chains:")
doc._.coref_chains.print()
print("[]:")
doc[25]._.coref_chains.print()
print("resolve:")
value = doc._.coref_chains.resolve(doc[25])
print(value)
print("====")
# print("Print tokens: ")
# for i in doc:
#     print(i.text, i.label_)
for chain in doc._.coref_chains:
    print("Chain: ")
    print(chain)
    for mention in chain:
        print("Mention: ")
        print(mention)
        for i in mention:
            print("i: ")            
            print(i)
            value = doc._.coref_chains.resolve(doc[i])
            print(value)
    print("----")
# Out:
# Chains:
# 0: Elgar(1), his(13), He(25), himself(27), he(47), his(59), he(83), his(88), he(93), He(97), him(111), he(118), his(124), his(135), He(149), His(200)
# 1: Britain(57), Britain(81), Britain(145), Britain(181), Britain(196)
# 2: daughter(101), She(109)
# 3: Variations(137), Variations(152)
# 4: disquiet(175), it(184)
# []:
# 0: Elgar(1), his(13), He(25), himself(27), he(47), his(59), he(83), his(88), he(93), He(97), him(111), he(118), his(124), his(135), He(149), His(200)
# resolve:
# [Elgar]
# ====
# Chain:
# 0: [1], [13], [25], [27], [47], [59], [83], [88], [93], [97], [111], [118], [124], [135], [149], [200]
# Mention:
# [1]
# i:
# 1
# None
# Mention:
# [13]
# i:
# 13
# [Elgar]
# Mention:
# [25]
# i:
# 25
# [Elgar]
# Mention:
# [27]
# i:
# 27
# [Elgar]
# Mention:
# [47]
# i:
# 47
# [Elgar]
# Mention:
# [59]
# i:
# 59
# [Elgar]
# Mention:
# [83]
# i:
# 83
# [Elgar]
# Mention:
# [88]
# i:
# 88
# [Elgar]
# Mention:
# [93]
# i:
# 93
# [Elgar]
# Mention:
# [97]
# i:
# 97
# [Elgar]
# Mention:
# [111]
# i:
# 111
# [Elgar]
# Mention:
# [118]
# i:
# 118
# [Elgar]
# Mention:
# [124]
# i:
# 124
# [Elgar]
# Mention:
# [135]
# i:
# 135
# [Elgar]
# Mention:
# [149]
# i:
# 149
# [Elgar]
# Mention:
# [200]
# i:
# 200
# [Elgar]
# ----
# Chain:
# 1: [57], [81], [145], [181], [196]
# Mention:
# [57]
# i:
# 57
# None
# Mention:
# [81]
# i:
# 81
# [Britain]
# Mention:
# [145]
# i:
# 145
# [Britain]
# Mention:
# [181]
# i:
# 181
# [Britain]
# Mention:
# [196]
# i:
# 196
# [Britain]
# ----
# Chain:
# 2: [101], [109]
# Mention:
# [101]
# i:
# 101
# None
# Mention:
# [109]
# i:
# 109
# [daughter]
# ----
# Chain:
# 3: [137], [152]
# Mention:
# [137]
# i:
# 137
# None
# Mention:
# [152]
# i:
# 152
# [Variations]
# ----
# Chain:
# 4: [175], [184]
# Mention:
# [175]
# i:
# 175
# None
# Mention:
# [184]
# i:
# 184
# [disquiet]
# ----

# %%
doc._.coref_chains.print()
# Out:
# 0: he(7), his(19)
# 1: composer(13), he(43), his(48), he(53)
# 2: Britain(17), Britain(41)
# In musical circles dominated by academics , he was a self - taught composer ; in Protestant Britain , he Roman Catholicism was regarded with suspicion in some quarters ; and in the class - conscious society of Victorian and Edwardian Britain , composer was acutely sensitive about composer humble origins even after composer achieved recognition .
# /tmp/ipykernel_234/325409124.py:14: DeprecationWarning: NotImplemented should not be used in a boolean context
#   res = list(filter((None).__ne__, res1))

# %%
doc._.coref_chains.resolve(doc[1])

# %%
# Analyze syntax
print("Noun phrases:", [chunk.text for chunk in doc.noun_chunks])
print("Verbs:", [token.lemma_ for token in doc if token.pos_ == "VERB"])

# Find named entities, phrases and concepts
for entity in doc.ents:
    print(entity.text, entity.label_)
# Out:
# Noun phrases: ['musical circles', 'academics', 'he', 'a self-taught composer', 'Protestant Britain', 'his Roman Catholicism', 'suspicion', 'some quarters', 'the class-conscious society', 'Victorian and Edwardian Britain', 'he', 'his humble origins', 'he', 'recognition']
# Verbs: ['dominate', 'teach', 'regard', 'achieve']
# Protestant NORP
# Britain GPE
# Roman Catholicism NORP
# Victorian DATE
# Edwardian NORP
# Britain GPE

# %%
print(doc.ents)
for entity in doc.ents:
    print(entity)
    
doc_nouns = list(doc.noun_chunks)
print(doc_nouns)
# Out:
# (Elgar, English, England, Europe)
# Elgar
# English
# England
# Europe
# [Elgar, a typically English composer, his musical influences, England, continental Europe]

# %%
[(i, i.ent_type_, i.is_stop) for i in doc]
# Out:
# [(Sir, '', False),
#  (Edward, 'PERSON', False),
#  (William, 'PERSON', False),
#  (Elgar, 'PERSON', False),
#  (,, '', False),
#  (1st, 'ORDINAL', False),
#  (Baronet, '', False),
#  (,, '', False),
#  ( , '', False),
#  ((, '', False),
#  ((, '', False),
#  (listen, '', False),
#  (), '', False),
#  (;, '', False),
#  (2, 'DATE', False),
#  (June, 'DATE', False),
#  (1857, 'DATE', False),
#  (–, 'DATE', False),
#  (23, 'DATE', False),
#  (February, 'DATE', False),
#  (1934, 'DATE', False),
#  (), '', False),
#  (was, '', True),
#  (an, '', True),
#  (English, 'NORP', False),
#  (composer, '', False),
#  (,, '', False),
#  (many, '', True),
#  (of, '', True),
#  (whose, '', True),
#  (works, '', False),
#  (have, '', True),
#  (entered, '', False),
#  (the, '', True),
#  (British, 'NORP', False),
#  (and, '', True),
#  (international, '', False),
#  (classical, '', False),
#  (concert, '', False),
#  (repertoire, '', False),
#  (., '', False)]

# %%
doc.to_json()
# Out:
# {'text': 'Although he was very busy with his work, Peter had had enough of it. He and his wife decided they needed a holiday. They travelled to Spain because they loved the country very much.',
#  'ents': [{'start': 41, 'end': 46, 'label': 'PERSON'},
#   {'start': 134, 'end': 139, 'label': 'GPE'}],
#  'sents': [{'start': 0, 'end': 68},
#   {'start': 69, 'end': 115},
#   {'start': 116, 'end': 181}],
#  'tokens': [{'id': 0,
#    'start': 0,
#    'end': 8,
#    'tag': 'IN',
#    'pos': 'SCONJ',
#    'morph': '',
#    'lemma': 'although',
#    'dep': 'mark',
#    'head': 2},
#   {'id': 1,
#    'start': 9,
#    'end': 11,
#    'tag': 'PRP',
#    'pos': 'PRON',
#    'morph': 'Case=Nom|Gender=Masc|Number=Sing|Person=3|PronType=Prs',
#    'lemma': 'he',
#    'dep': 'nsubj',
#    'head': 2},
#   {'id': 2,
#    'start': 12,
#    'end': 15,
#    'tag': 'VBD',
#    'pos': 'AUX',
#    'morph': 'Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin',
#    'lemma': 'be',
#    'dep': 'advcl',
#    'head': 11},
#   {'id': 3,
#    'start': 16,
#    'end': 20,
#    'tag': 'RB',
#    'pos': 'ADV',
#    'morph': '',
#    'lemma': 'very',
#    'dep': 'advmod',
#    'head': 4},
#   {'id': 4,
#    'start': 21,
#    'end': 25,
#    'tag': 'JJ',
#    'pos': 'ADJ',
#    'morph': 'Degree=Pos',
#    'lemma': 'busy',
#    'dep': 'acomp',
#    'head': 2},
#   {'id': 5,
#    'start': 26,
#    'end': 30,
#    'tag': 'IN',
#    'pos': 'ADP',
#    'morph': '',
#    'lemma': 'with',
#    'dep': 'prep',
#    'head': 4},
#   {'id': 6,
#    'start': 31,
#    'end': 34,
#    'tag': 'PRP$',
#    'pos': 'PRON',
#    'morph': 'Gender=Masc|Number=Sing|Person=3|Poss=Yes|PronType=Prs',
#    'lemma': 'his',
#    'dep': 'poss',
#    'head': 7},
#   {'id': 7,
#    'start': 35,
#    'end': 39,
#    'tag': 'NN',
#    'pos': 'NOUN',
#    'morph': 'Number=Sing',
#    'lemma': 'work',
#    'dep': 'pobj',
#    'head': 5},
#   {'id': 8,
#    'start': 39,
#    'end': 40,
#    'tag': ',',
#    'pos': 'PUNCT',
#    'morph': 'PunctType=Comm',
#    'lemma': ',',
#    'dep': 'punct',
#    'head': 11},
#   {'id': 9,
#    'start': 41,
#    'end': 46,
#    'tag': 'NNP',
#    'pos': 'PROPN',
#    'morph': 'Number=Sing',
#    'lemma': 'Peter',
#    'dep': 'nsubj',
#    'head': 11},
#   {'id': 10,
#    'start': 47,
#    'end': 50,
#    'tag': 'VBD',
#    'pos': 'AUX',
#    'morph': 'Tense=Past|VerbForm=Fin',
#    'lemma': 'have',
#    'dep': 'aux',
#    'head': 11},
#   {'id': 11,
#    'start': 51,
#    'end': 54,
#    'tag': 'VBN',
#    'pos': 'VERB',
#    'morph': 'Aspect=Perf|Tense=Past|VerbForm=Part',
#    'lemma': 'have',
#    'dep': 'ROOT',
#    'head': 11},
#   {'id': 12,
#    'start': 55,
#    'end': 61,
#    'tag': 'JJ',
#    'pos': 'ADJ',
#    'morph': 'Degree=Pos',
#    'lemma': 'enough',
#    'dep': 'dobj',
#    'head': 11},
#   {'id': 13,
#    'start': 62,
#    'end': 64,
#    'tag': 'IN',
#    'pos': 'ADP',
#    'morph': '',
#    'lemma': 'of',
#    'dep': 'prep',
#    'head': 12},
#   {'id': 14,
#    'start': 65,
#    'end': 67,
#    'tag': 'PRP',
#    'pos': 'PRON',
#    'morph': 'Case=Acc|Gender=Neut|Number=Sing|Person=3|PronType=Prs',
#    'lemma': 'it',
#    'dep': 'pobj',
#    'head': 13},
#   {'id': 15,
#    'start': 67,
#    'end': 68,
#    'tag': '.',
#    'pos': 'PUNCT',
#    'morph': 'PunctType=Peri',
#    'lemma': '.',
#    'dep': 'punct',
#    'head': 11},
#   {'id': 16,
#    'start': 69,
#    'end': 71,
#    'tag': 'PRP',
#    'pos': 'PRON',
#    'morph': 'Case=Nom|Gender=Masc|Number=Sing|Person=3|PronType=Prs',
#    'lemma': 'he',
#    'dep': 'nsubj',
#    'head': 20},
#   {'id': 17,
#    'start': 72,
#    'end': 75,
#    'tag': 'CC',
#    'pos': 'CCONJ',
#    'morph': 'ConjType=Cmp',
#    'lemma': 'and',
#    'dep': 'cc',
#    'head': 16},
#   {'id': 18,
#    'start': 76,
#    'end': 79,
#    'tag': 'PRP$',
#    'pos': 'PRON',
#    'morph': 'Gender=Masc|Number=Sing|Person=3|Poss=Yes|PronType=Prs',
#    'lemma': 'his',
#    'dep': 'poss',
#    'head': 19},
#   {'id': 19,
#    'start': 80,
#    'end': 84,
#    'tag': 'NN',
#    'pos': 'NOUN',
#    'morph': 'Number=Sing',
#    'lemma': 'wife',
#    'dep': 'conj',
#    'head': 16},
#   {'id': 20,
#    'start': 85,
#    'end': 92,
#    'tag': 'VBD',
#    'pos': 'VERB',
#    'morph': 'Tense=Past|VerbForm=Fin',
#    'lemma': 'decide',
#    'dep': 'ROOT',
#    'head': 20},
#   {'id': 21,
#    'start': 93,
#    'end': 97,
#    'tag': 'PRP',
#    'pos': 'PRON',
#    'morph': 'Case=Nom|Number=Plur|Person=3|PronType=Prs',
#    'lemma': 'they',
#    'dep': 'nsubj',
#    'head': 22},
#   {'id': 22,
#    'start': 98,
#    'end': 104,
#    'tag': 'VBD',
#    'pos': 'VERB',
#    'morph': 'Tense=Past|VerbForm=Fin',
#    'lemma': 'need',
#    'dep': 'ccomp',
#    'head': 20},
#   {'id': 23,
#    'start': 105,
#    'end': 106,
#    'tag': 'DT',
#    'pos': 'DET',
#    'morph': 'Definite=Ind|PronType=Art',
#    'lemma': 'a',
#    'dep': 'det',
#    'head': 24},
#   {'id': 24,
#    'start': 107,
#    'end': 114,
#    'tag': 'NN',
#    'pos': 'NOUN',
#    'morph': 'Number=Sing',
#    'lemma': 'holiday',
#    'dep': 'dobj',
#    'head': 22},
#   {'id': 25,
#    'start': 114,
#    'end': 115,
#    'tag': '.',
#    'pos': 'PUNCT',
#    'morph': 'PunctType=Peri',
#    'lemma': '.',
#    'dep': 'punct',
#    'head': 20},
#   {'id': 26,
#    'start': 116,
#    'end': 120,
#    'tag': 'PRP',
#    'pos': 'PRON',
#    'morph': 'Case=Nom|Number=Plur|Person=3|PronType=Prs',
#    'lemma': 'they',
#    'dep': 'nsubj',
#    'head': 27},
#   {'id': 27,
#    'start': 121,
#    'end': 130,
#    'tag': 'VBD',
#    'pos': 'VERB',
#    'morph': 'Tense=Past|VerbForm=Fin',
#    'lemma': 'travel',
#    'dep': 'ROOT',
#    'head': 27},
#   {'id': 28,
#    'start': 131,
#    'end': 133,
#    'tag': 'IN',
#    'pos': 'ADP',
#    'morph': '',
#    'lemma': 'to',
#    'dep': 'prep',
#    'head': 27},
#   {'id': 29,
#    'start': 134,
#    'end': 139,
#    'tag': 'NNP',
#    'pos': 'PROPN',
#    'morph': 'Number=Sing',
#    'lemma': 'Spain',
#    'dep': 'pobj',
#    'head': 28},
#   {'id': 30,
#    'start': 140,
#    'end': 147,
#    'tag': 'IN',
#    'pos': 'SCONJ',
#    'morph': '',
#    'lemma': 'because',
#    'dep': 'mark',
#    'head': 32},
#   {'id': 31,
#    'start': 148,
#    'end': 152,
#    'tag': 'PRP',
#    'pos': 'PRON',
#    'morph': 'Case=Nom|Number=Plur|Person=3|PronType=Prs',
#    'lemma': 'they',
#    'dep': 'nsubj',
#    'head': 32},
#   {'id': 32,
#    'start': 153,
#    'end': 158,
#    'tag': 'VBD',
#    'pos': 'VERB',
#    'morph': 'Tense=Past|VerbForm=Fin',
#    'lemma': 'love',
#    'dep': 'advcl',
#    'head': 27},
#   {'id': 33,
#    'start': 159,
#    'end': 162,
#    'tag': 'DT',
#    'pos': 'DET',
#    'morph': 'Definite=Def|PronType=Art',
#    'lemma': 'the',
#    'dep': 'det',
#    'head': 34},
#   {'id': 34,
#    'start': 163,
#    'end': 170,
#    'tag': 'NN',
#    'pos': 'NOUN',
#    'morph': 'Number=Sing',
#    'lemma': 'country',
#    'dep': 'dobj',
#    'head': 32},
#   {'id': 35,
#    'start': 171,
#    'end': 175,
#    'tag': 'RB',
#    'pos': 'ADV',
#    'morph': '',
#    'lemma': 'very',
#    'dep': 'advmod',
#    'head': 36},
#   {'id': 36,
#    'start': 176,
#    'end': 180,
#    'tag': 'RB',
#    'pos': 'ADV',
#    'morph': '',
#    'lemma': 'much',
#    'dep': 'advmod',
#    'head': 32},
#   {'id': 37,
#    'start': 180,
#    'end': 181,
#    'tag': '.',
#    'pos': 'PUNCT',
#    'morph': 'PunctType=Peri',
#    'lemma': '.',
#    'dep': 'punct',
#    'head': 27}]}

# %%
# Nice display of sentence organisation
#displacy.serve(doc, style="dep")

# %%
# Analyze syntax
print("Noun phrases:", [chunk.text for chunk in doc.noun_chunks])
print("Verbs:", [token.lemma_ for token in doc if token.pos_ == "VERB"])

# Find named entities, phrases and concepts
for entity in doc.ents:
    print(entity.text, entity.label_)
# Out:
# Noun phrases: ['he', 'his work', 'Peter', 'it', 'He', 'his wife', 'they', 'a holiday', 'They', 'Spain', 'they', 'the country']
# Verbs: ['have', 'decide', 'need', 'travel', 'love']
# Peter PERSON
# Spain GPE

# %%
doc1 = nlp('My sister has a dog. She loves him.')
doc1._.coref_chains.print()
print(doc1._.coref_chains.resolve(doc1[6]))
# Out:
# 0: sister(1), She(6)
# 1: dog(4), him(8)
# [sister]

# %%
tok_list = list(token.text for token in doc1)
c = 0
for chain in doc1._.coref_chains:
    for mention in chain:
        res1 = [doc1._.coref_chains.resolve(doc1[i]) for i in mention]
        res = list(filter((None).__ne__, res1))
        if len(res) != 0:
            if len(res[0]) == 1:
                tok_list[mention[0] + c] = str(res[0][0])
            elif len(res[0]) > 1:
                tok_list[mention[0] + c] = str(res[0][0])
                for j in range(1, len(res[0])):
                    tok_list.insert(mention[0] + c + j, str(res[0][j]))
                    c = c + 1
textres = " ".join(tok_list)
print(textres)
# Out:
# My sister has a dog . sister loves dog .
# /tmp/ipykernel_141/1859683582.py:6: DeprecationWarning: NotImplemented should not be used in a boolean context
#   res = list(filter((None).__ne__, res1))
