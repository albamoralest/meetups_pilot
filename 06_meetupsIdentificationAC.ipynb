# %% [markdown]
# # MEETUPS IDENTIFICATION AFTER COREFERENCE

# %% [markdown]
# Coreference process already completed

# %% [markdown]
# ANNOTATIONS:
#
#     HM = historical meetup
#     HT = historical trace,
#     N = it is not a meetup
#
# INPUT:
#
#     Coreference:
#         People and places stored in meetupsFastCorefOutputPP/
#     Time in extractedTimeExpressions/
#     Theme in extractedMeetupTypes/

# %%
import os
import pandas as pd
from operator import countOf
import numpy as np
import json
from _datetime import date
from datetime import datetime
import time
from pandas import json_normalize 
import sys
from timeit import default_timer as timer
# tracing memory
import tracemalloc

# wikidata api 
from SPARQLWrapper import SPARQLWrapper, JSON
# from qwikidata.sparql import return_sparql_query_results

# For DBpedia spotlight, PPE entities
import requests
# import pycurl
from urllib.request import urlopen
from urllib.parse import quote
import gc
pd.options.mode.copy_on_write = True

# %%
# using DBPedia spotlight to search for entities
def executeQueryDbpedia(q, f='application/json'):
    epr = "http://dbpedia.org/sparql"
    try:
        params = {'query': q}
        resp = requests.get(epr, params=params, headers={'Accept': f})
        return resp
    except Exception as e:
        print(e, file=sys.stdout)
        raise

def queryBiographyInformationByDBpediaID(id_number):
    values = []
    variables = []
    # SELECT * WHERE {
    # VALUES ?id { "10085"^^xsd:integer }
    # OPTIONAL { ?s dbo:wikiPageID ?id . ?s rdfs:label ?label .  FILTER langMatches( lang(?label), "EN" )  } .
    #  OPTIONAL { ?s dbo:thumbnail ?image } .
    # OPTIONAL { ?s dbp:birthDate ?dob } .
    # OPTIONAL { ?s dbp:deathDate ?dod } .
    # OPTIONAL { ?s dbo:wikiPageID ?wikiId } .
    # OPTIONAL { ?s dbo:abstract ?abstract .  FILTER langMatches( lang(?abstract), "EN" ) } .
    # }
    query_text = """SELECT * WHERE { VALUES ?id { '"""+id_number+"""'^^xsd:integer } OPTIONAL { ?s dbo:wikiPageID ?id . ?s rdfs:label ?label .  FILTER langMatches( lang(?label), "EN" )  } . 
    OPTIONAL { ?s dbo:thumbnail ?image } . OPTIONAL { ?s dbp:birthDate ?birthdate } . OPTIONAL { ?s dbp:deathDate ?deathdate } . 
    OPTIONAL { ?s owl:sameAs ?wikidataId . FILTER regex (?wikidataId, "http://www.wikidata.org/entity/" ) }
    OPTIONAL { ?s dbo:abstract ?abstract .  FILTER langMatches( lang(?abstract), "EN" ) } . }"""
    results = executeQueryDbpedia(query_text).json()
    # if query returns a response
    if len(results['results']['bindings']) == 0:
        print("No entity", id_number)
    else:
        # return a list, with [lat, long]
        result_list = list(results['results']['bindings'])[0]
        variables = list(results['head']['vars'])
        for label in variables:
            if label in result_list:
                if (label=='birthdate' or label=='deathdate'):
                    if evaluateDateFormat(result_list[label]['value']):
                        values.append(result_list[label]['value'])
                    else:
                        values.append(np.NaN)
                else:
                    values.append(result_list[label]['value'])
            else:
                values.append(np.NaN)
    return variables,values
   
def setWikidateParams(query):
    endpoint_url = "https://query.wikidata.org/sparql"
    user_agent = "Polifonia-MEETUPSPilot0.1 (https://polifonia-project.eu/pilots/meetups/; alba.morales-tirado@open.ac.uk) /%s.%s" % (sys.version_info[0], sys.version_info[1])
    # TODO adjust user agent; see https://w.wiki/CX6
    sparql = SPARQLWrapper(endpoint_url, agent=user_agent)
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    return sparql.query().convert()

def queryWikidataEndpoint(uri):
    values = []
    variables = []
    # """SELECT * WHERE { <http://www.wikidata.org/entity/Q212692> wdt:P569 ?birthdate ; 
    # OPTIONAL { <http://www.wikidata.org/entity/Q212692> wdt:P570 ?deathdate } . }"""
    sparql_query = """SELECT * WHERE { <"""+uri+"""> wdt:P569 ?birthdate ; 
    OPTIONAL { <"""+uri+"""> wdt:P570 ?deathdate } . }"""
    # results = return_sparql_query_results(sparql_query)
    results = setWikidateParams(sparql_query)
    
    if len(results['results']['bindings']) == 0:
        print("No entity", uri)
    else:
        # return a list, with [lat, long]
        result_list = list(results['results']['bindings'])[0]
        variables = list(results['head']['vars'])
        for label in variables:
            if label in result_list:
                # values.append(result_list[label]['value'])
                values.append(result_list[label]['value'].split("T",1)[0])
                # dic['birthdate'].split("T",1)[0]
            else:
                values.append(np.NaN)
    return variables,values

def evaluateDateFormat(dateValue):
    # initializing format
    format = "%Y-%m-%d"
    # checking if format matches the date
    res = True
    # using try-except to check for truth value
    try:
        res = bool(datetime.strptime(dateValue, format))
    except ValueError:
        res = False
    return res

# %%
# True = both sentences have the same entities
# False = the sentences do not have the same entities
def aSameAsb(entType, aSent_indx,bSent_indx, ent_df):
    # print("aSameAsb")
    if sentenceHas(entType, aSent_indx, ent_df, '') and sentenceHas(entType, bSent_indx, ent_df, ''):
        # Check if all elements are the same
        # Diferent for time
        if entType =="person":
            aEnts_df = ent_df.query("entType == '{}' & sentenceIndex == {}".format(entType,int(aSent_indx)))
            aEnts_df = aEnts_df[~aEnts_df['URI'].isna()]
            bEnts_df = ent_df.query("entType == '{}' & sentenceIndex == {}".format(entType,int(bSent_indx)))
            bEnts_df = bEnts_df[~bEnts_df['URI'].isna()]
            # print("A -> ",aEnts_df)
            # print("B -> ",bEnts_df)
            # Check if the shape (number of rows and columns) is the same
            if aEnts_df.shape != bEnts_df.shape:
                # print("aSameAsb->people->False")
                return False
            aSubEnts_df = aEnts_df[['URI']]
            bSubEnts_df = bEnts_df[['URI']]
            comparison_matrix = aSubEnts_df.values == bSubEnts_df.values
            return comparison_matrix.all()
        elif entType == "place":
            aEnts_df = ent_df.query("entType == '{}' & sentenceIndex == {}".format(entType,int(aSent_indx)))
            bEnts_df = ent_df.query("entType == '{}' & sentenceIndex == {}".format(entType,int(bSent_indx)))
            # print("A -> ",aEnts_df)
            # print("B -> ",bEnts_df)
            # # Check if the shape (number of rows and columns) is the same
            # if aEnts_df.shape != bEnts_df.shape:
            #     print("aSameAsb->place->False")
            #     return False
            aSubEnts_df = aEnts_df[['URI']]
            bSubEnts_df = bEnts_df[['URI']]
            # comparison_matrix = aSubEnts_df.values == bSubEnts_df.values
            # return comparison_matrix.all()
            # Check if at least one row is the same
            return have_common_rows(aSubEnts_df, bSubEnts_df)
        elif entType =="time":
            aEnts_df = ent_df.query("sentenceIndex == {}".format(int(aSent_indx)))
            bEnts_df = ent_df.query("sentenceIndex == {}".format(int(bSent_indx)))
            # print("A -> ",aEnts_df)
            # print("B -> ",bEnts_df)
            # Check if the shape (number of rows and columns) is the same
            # if aEnts_df.shape != bEnts_df.shape:
            #     print("aSameAsb->time->False")
            #     return False
            aSubEnts_df = aEnts_df[~aEnts_df['normalised_value_start'].isna()]
            bSubEnts_df = bEnts_df[~bEnts_df['normalised_value_start'].isna()]
            aSubEnts_df = aSubEnts_df[['normalised_value_start','normalised_value_end']]
            bSubEnts_df = bSubEnts_df[['normalised_value_start','normalised_value_end']]
            # Check if at least one row is the same
            value =  have_common_rows(aSubEnts_df, bSubEnts_df)
            if not value and (len(pd.isnull(aEnts_df.normalised_value_start))>0 or len(pd.isnull(bEnts_df.normalised_value_start))>0):
                aSubEnts_df = aEnts_df[aEnts_df['normalised_value_start'].isna()]
                bSubEnts_df = bEnts_df[bEnts_df['normalised_value_start'].isna()]
                aSubEnts_df = aSubEnts_df[['normalised_value_start','normalised_value_end','time_expression']]
                bSubEnts_df = bSubEnts_df[['normalised_value_start','normalised_value_end','time_expression']]
                # Check if at least one row is the same
                return have_common_rows(aSubEnts_df, bSubEnts_df)
            return value
            # comparison_matrix = aSubEnts_df.values == bSubEnts_df.values
            # return comparison_matrix.all()
    else:
        # print("no sentence has->False")
        return False
    
def have_common_rows(df1, df2):
    # Merge the two dataframes based on common columns
    merged_df = pd.merge(df1, df2, how='inner')

    # Check if the merged dataframe has any rows
    return not merged_df.empty

# True = sentence has entities
# False = sentence does not have an entity
def sentenceHas(entityType, index, df_ent, entIRI):
    if entityType == "time":
        # print("sentenceHas->Time")
        df_ent = df_ent[df_ent['sentenceIndex']==int(index)]
        # df_ent.drop_duplicates(subset=['sentenceIndex','paragraphIndex'],inplace=True)
        if len(df_ent) > 0:
            # print("sentenceHas->Time->True")
            return True
        else:
            # print("sentenceHas->Time->False")
            return False
    elif entityType == "place":
        if len(df_ent[(df_ent['sentenceIndex']==int(index)) & (df_ent['entType']=="place")]) > 0:
            # print("sentenceHas->place->True")
            return True
        else:
            # print("sentenceHas->place->False")
            return False
    elif entityType == "person":
        # At least two people
        if len(df_ent[(df_ent['sentenceIndex']==int(index)) & (df_ent['entType']=="person")]) >= 2:
            # print("sentenceHas->person->True")
            return True
        else:
            # print("sentenceHas->person->False")
            return False
    elif entityType == "OnePerson":
        # At least one person
        if len(df_ent[(df_ent['sentenceIndex']==int(index)) & (df_ent['entType']=="person")]) >= 1:
            # print("sentenceHas->OnePerson->True")
            return True
        else:
            # print("sentenceHas->OnePerson->False")
            return False
        
def createDfFromList(data_list):
    # Extracting data for each column
    column1 = [item[0][0] if item[0] else None for item in data_list]
    column2 = [item[0][1] if len(item[0]) > 1 else None for item in data_list]
    column3 = [item[1] for item in data_list]
    column4 = [item[2] for item in data_list]
    # Creating a DataFrame
    df = pd.DataFrame({'after': column1, 'before': column2, 'paragraphIndex': column3, 'annotation':column4})
    # print(df)
    return df

# %%
# for chunk in pd.read_csv('totalBiographiesBenchmark.csv', chunksize=50):
# for chunk in pd.read_csv('list_wikiIdSample.csv', chunksize=10):
for chunk in pd.read_csv('toAnnotatePart6.csv', chunksize=10):
    df_file_name = pd.DataFrame()
    df_file_name['file_name'] = chunk['file_name']
    # for each file
    entities_df = pd.DataFrame()
    for file_name_item in df_file_name.itertuples():
        print("FILE: ",file_name_item.file_name) # FILE name using the DBPedia ID
        if os.path.isfile('meetupsAnnotations/'+str(file_name_item.file_name)):
            print("Already exists. Next.")
            continue
        tracemalloc.start()
        # READ Files
        # startRead = timer()
        try:
            # read time 
            time_df = pd.read_csv('extractedTimeExpressions/'+file_name_item.file_name, usecols=['time_expression','sentenceIndex','paragraphIndex','normalised_value_start','normalised_value_end'])
        except pd.errors.EmptyDataError:    
            print("EmptyDataError: Time expression. No columns to parse from file")
            # What happends when there is no TIME? We still could have people, places and themes, therefor a HT? Shall continue?
            time_df = pd.DataFrame(columns=['time_expression','sentenceIndex','paragraphIndex','normalised_value_start','normalised_value_end'])
        except FileNotFoundError:
            print("FileNotFoundError: No time.")
            time_df = pd.DataFrame(columns=['time_expression','sentenceIndex','paragraphIndex','normalised_value_start','normalised_value_end'])
        try:
            # read people and places
            pp_df = pd.read_csv('meetupsFastCorefOutputPP/'+file_name_item.file_name, usecols=['URI','entity','offset','similarityScore','sentenceIndex','paragraphIndex','entType'])
        except pd.errors.EmptyDataError:
            print("People and places not found. Continue to next biography")
            print("EmptyDataError: PP. No columns to parse from file.")
            pp_df = pd.DataFrame(columns=['URI','entity','offset','similarityScore','sentenceIndex','paragraphIndex','entType'])
            # continue
        except FileNotFoundError:
            print("FileNotFoundError: People and places not found. Continue to next biography")
            continue
        # The process is sentence by sentence. Read indexedSentences/
        sentences_df = pd.read_csv('indexedSentences/'+file_name_item.file_name, usecols=['sentenceIndex','paragraphIndex'])
        # endRead = timer()
        # print("Reading time: ", str(endRead - startRead))
#         # Obtain the IRI
#         labels,values = queryBiographyInformationByDBpediaID(file_name_item.file_name.replace(".csv",""))
#         if len(values) > 0:
#             row_dict = dict(zip(labels, values))
#             datarow = pd.Series(data=row_dict)
#             entities_df = pd.concat([entities_df,datarow.to_frame().T],ignore_index=True)
#             entities_df.rename(columns={'s': 'URI','label':'entity'}, inplace=True)
            
#             # IRI is important to identify the subject in each MEETUP
#             subject_IRI = entities_df.iloc[0]['URI']
            
        startFile = timer()
        bioAnnotationsList = []
        # everytime it will start a new paragraph, the before sentence is NA
        paragraph_indx_list = sorted(sentences_df.paragraphIndex.unique())
        print("Paragraphs to process",len(paragraph_indx_list))
        for paragraph_indx in paragraph_indx_list:
            # print()
            # print("Paragraph: ", paragraph_indx)
            # startParag = timer()
            time_prg_df = time_df[time_df['paragraphIndex'] == int(paragraph_indx)]
            pp_prg_df = pp_df[pp_df['paragraphIndex'] == int(paragraph_indx)]
            # if there are no entities in the given paragraph
            if len(pp_prg_df)==0:
                # print("No person or place entities in given paragraph. Continue to next paragraph")
                continue
            sentences_parag_df = sentences_df[sentences_df['paragraphIndex'] == int(paragraph_indx)]
            sentences_indx_list = sorted(sentences_parag_df.sentenceIndex.unique())
            # annotationsList each item is a list [[indexes],annotation]
            # indexes can be [bSent_indx] or [aSent_indx,bSent_indx]
            # annotation can take HM, HT, N values
            annotationsList = []
            for sent_indx in sentences_indx_list:
                # startSent = timer()
                aSent_indx = sent_indx
                bSent_indx = sent_indx-1
                # print("Sentences. After: ", aSent_indx, ". Before: ",bSent_indx)
                aHasBtime = False
                aHasBplace = False
                aHasBperson = False
                joinAandB = False
                # by default N, meaning DISCARD sentence.
                annotation = "N"
                
                if sentenceHas("person",aSent_indx, pp_prg_df,'') and (sentenceHas("place",aSent_indx, pp_prg_df,'')  or sentenceHas("time",aSent_indx, time_prg_df,'')):
                    annotation = "HT"
                    joinAandB = False
                    # print("annotation",annotation)
                # if !A.time & A.place == B.place -> A.time = B.time
                # print("if !A.time & A.place == B.place -> A.time = B.time")
                if not sentenceHas("time",aSent_indx, time_prg_df,'') and (aSameAsb("place",aSent_indx,bSent_indx,pp_prg_df)):
                    # THEN A.time = B.time
                    if sentenceHas("time",bSent_indx, time_prg_df,''):
                        aHasBtime = True
                        joinAandB = True
                        annotation = "HT"
                        # print("aHasBtime: TRUE. joinAandB: TRUE")
                # print("if !A.place & A.time == B.time -> A.place = B.place")
                # if !A.place & A.time == B.time -> A.place = B.place
                if not sentenceHas("place",aSent_indx, pp_prg_df,'') and (aHasBtime or aSameAsb("time",aSent_indx,bSent_indx,time_prg_df)):
                    # THEN A.place = B.place
                    if sentenceHas("place",bSent_indx, pp_prg_df,''):
                        aHasBplace = True
                        annotation = "HT"
                        joinAandB = True
                        # print("aHasBplace: TRUE. joinAandB: TRUE. Annotation: ",annotation)
                # print("if !A.person & A.time == B.time & A.place == B.place -> A.person = B.person")
                # if !A.person & A.time == B.time & A.place == B.place -> A.person = B.person
                if not sentenceHas("person",aSent_indx, pp_prg_df,'') and (aHasBtime or aSameAsb("time",aSent_indx,bSent_indx,time_prg_df)) and (aHasBplace or aSameAsb("place",aSent_indx,bSent_indx,pp_prg_df)):
                    # THEN A.person = B.person
                    aHasBperson = True
                    annotation = "HT"
                    joinAandB = True
                    # print("aHasBperson: TRUE. joinAandB: TRUE. Annotation: ",annotation)
                # print("if !A.time & !A.place & A.person == B.person -> A.time = B.time & A.place = B.place")
                # if !A.time & !A.place & A.person == B.person -> A.time = B.time & A.place = B.place
                if not sentenceHas("time",aSent_indx, time_prg_df,'') and not sentenceHas("place",aSent_indx, pp_prg_df,'') and aSameAsb("person",aSent_indx,bSent_indx,pp_prg_df):
                    # THEN A.time = B.time & A.place = B.place
                    if (sentenceHas("time",bSent_indx, time_prg_df,'')) and (sentenceHas("place",bSent_indx, pp_prg_df,'')): 
                        aHasBtime = True
                        aHasBplace = True
                        joinAandB = True
                        annotation = "HT"
                        # print("aHasBtime: TRUE. aHasBplace: TRUE. joinAandB: TRUE. Annotation: ",annotation)
                # print("if A.time & A.place & A.person -> A.meetup")
                # if A.time & A.place & A.person -> A.meetup
                if (sentenceHas("time",aSent_indx, time_prg_df,'') or aHasBtime) and (sentenceHas("place",aSent_indx, pp_prg_df,'') or aHasBplace) and (sentenceHas("person",aSent_indx, pp_prg_df,'') or aHasBperson):
                    annotation = "HM"
                    # joinAandB = False
                    # print("TRUE -> A is a MEETUPS")
                    # if aHasBtime or aHasBplace or aHasBperson:
                    #     joinAandB = True
                    # gather the meetups
                    # B+A 
                    if aHasBtime or aHasBplace or aHasBperson:
                        joinAandB = True
                        # print("joinAandB: ", joinAandB)
                    else:
                        # if A.time = B.time & A.place = B.place & A.person = B.person -> B+A 
                        # print("if A.time = B.time & A.place = B.place & A.person = B.person -> B+A ")
                        if (aSameAsb("time",aSent_indx,bSent_indx,time_prg_df) or aHasBtime) and (aSameAsb("place",aSent_indx,bSent_indx,pp_prg_df) or aHasBplace) and (aSameAsb("person",aSent_indx,bSent_indx,pp_prg_df) or aHasBperson):
                            # add B + A
                            joinAandB = True
                            # print("joinAandB: TRUE ", annotation)
                            
                        # if (A.time = B.time & !B.person & !B.place) OR (A.person = B.person & !B.time & !B.place) OR (A.place = B.place & !B.person & !B.time)
                        # print("if (A.time = B.time & !B.person & !B.place) OR (A.person = B.person & !B.time & !B.place) OR (A.place = B.place & !B.person & !B.time)")
                        if (aSameAsb("time",aSent_indx,bSent_indx,time_prg_df) and not sentenceHas("person",bSent_indx, pp_prg_df,'') and not sentenceHas("place",bSent_indx, pp_prg_df,'')) or (aSameAsb("person",aSent_indx,bSent_indx,pp_prg_df) and not sentenceHas("time",bSent_indx, time_prg_df,'') and not sentenceHas("place",bSent_indx, pp_prg_df,'')) or (aSameAsb("place",aSent_indx,bSent_indx,pp_prg_df) and not sentenceHas("person",bSent_indx, pp_prg_df,'') and not sentenceHas("time",bSent_indx, time_prg_df,'')):
                            # THEN B + A
                            joinAandB = True
                            # print("TRUE", annotation)
                        
                #  A.sentences += B.sentences & A.themes += B.themes & B.discard = true
                if annotation == "N" and sentenceHas("OnePerson",aSent_indx, pp_prg_df,''):
                    if (sentenceHas("place",aSent_indx, pp_prg_df,'')  or sentenceHas("time",aSent_indx, time_prg_df,'')):
                        annotation = "HT"
                        joinAandB = False
                        # print("annotation",annotation)
                if joinAandB:
                    # append the indexes to build the meetup from two sentences
                    annotationsList.extend([[[aSent_indx,bSent_indx],paragraph_indx,annotation]])
                else:
                    annotationsList.extend([[[aSent_indx],paragraph_indx,annotation]])
                # print()
                # print("FINAL Parag: ",paragraph_indx,"Sentences a: ",aSent_indx," and b: ", bSent_indx)
                # print("FINAL annotation for sentence index: ", annotation, "joinAandB: ", joinAandB)
                # print("aHasBtime: ",aHasBtime,". aHasBplace: ", aHasBplace, ". aHasBperson: ",aHasBperson)
                # endSent = timer()
                # print("Time to process sentence: ", str(endSent-startSent))
            bioAnnotationsList.extend(annotationsList)
            print("annotationsList of paragraph",annotationsList)
            del annotationsList
            del sentences_indx_list
            gc.collect()
            # endParag = timer()
            # print("Time to process a paragraph: ", str(endParag - startParag))
            # break
        # break
        # print("bio annotations -> ",bioAnnotationsList)
        bioAnnotations_df = createDfFromList(bioAnnotationsList)
        bioAnnotations_df = bioAnnotations_df[['before','after','paragraphIndex','annotation']]
        bioAnnotations_df.to_csv('meetupsAnnotations/'+file_name_item.file_name,index=False)    
        
        del paragraph_indx_list
        gc.collect()
        endFile = timer()        
        print("Time to process file: ", str(endFile-startFile))
        # else:
        #     print("Missing biography {} IRI from dbpedia. No MEETUPS identification executed.".format(file_name_item))
        print("Memory use", tracemalloc.get_traced_memory())
        tracemalloc.stop()
        # break
# Out:
# FILE:  1965784.csv
# Paragraphs to process 24
# annotationsList of paragraph [[[0], 0, 'N'], [[1], 0, 'HT']]
# annotationsList of paragraph [[[0], 3, 'N'], [[1], 3, 'N']]
# annotationsList of paragraph [[[0], 6, 'N'], [[1], 6, 'N'], [[2], 6, 'N'], [[3], 6, 'N']]
# annotationsList of paragraph [[[0], 7, 'HT'], [[1], 7, 'HT']]
# annotationsList of paragraph [[[0], 8, 'N'], [[1], 8, 'N']]
# annotationsList of paragraph [[[0], 9, 'N'], [[1], 9, 'HT']]
# annotationsList of paragraph [[[0], 10, 'HT'], [[1], 10, 'N'], [[2], 10, 'N'], [[3], 10, 'N']]
# Time to process file:  0.9964531459845603
# Memory use (53708, 317108)
# FILE:  32264675.csv
# Paragraphs to process 25
# annotationsList of paragraph [[[0], 0, 'HT'], [[1], 0, 'N'], [[2], 0, 'N'], [[3], 0, 'N'], [[4], 0, 'HT'], [[5], 0, 'N'], [[6], 0, 'N']]
# annotationsList of paragraph [[[0], 2, 'N'], [[1], 2, 'N'], [[2], 2, 'HT'], [[3], 2, 'N'], [[4], 2, 'N']]
# annotationsList of paragraph [[[0], 4, 'N'], [[1], 4, 'HT'], [[2], 4, 'HT'], [[3], 4, 'N'], [[4], 4, 'N']]
# annotationsList of paragraph [[[0], 6, 'HT'], [[1], 6, 'N'], [[2], 6, 'N'], [[3], 6, 'N'], [[4], 6, 'N'], [[5], 6, 'N'], [[6], 6, 'HT']]
# annotationsList of paragraph [[[0], 7, 'N']]
# annotationsList of paragraph [[[0], 8, 'N'], [[1], 8, 'HT'], [[2], 8, 'HM'], [[3], 8, 'N']]
# annotationsList of paragraph [[[0], 13, 'HT']]
# annotationsList of paragraph [[[0], 16, 'N']]
# Time to process file:  0.9633153527975082
# Memory use (64338, 320928)
# FILE:  2934315.csv
# Paragraphs to process 106
# annotationsList of paragraph [[[0], 0, 'HT'], [[1], 0, 'HT'], [[2], 0, 'N'], [[3], 0, 'HT'], [[4], 0, 'N'], [[5], 0, 'N']]
# annotationsList of paragraph [[[0], 2, 'HT'], [[1], 2, 'HT'], [[2], 2, 'N'], [[3], 2, 'HT'], [[4], 2, 'HT'], [[5], 2, 'N'], [[6], 2, 'N'], [[7], 2, 'N'], [[8], 2, 'HT'], [[9], 2, 'N'], [[10], 2, 'N'], [[11], 2, 'N'], [[12], 2, 'N'], [[13], 2, 'HT']]
# annotationsList of paragraph [[[0], 4, 'HT'], [[1], 4, 'HT'], [[2], 4, 'N'], [[3], 4, 'HT'], [[4], 4, 'HT'], [[5], 4, 'N'], [[6], 4, 'HT'], [[7], 4, 'HT'], [[8], 4, 'HT'], [[9], 4, 'HT'], [[10], 4, 'HT'], [[11], 4, 'HT'], [[12], 4, 'N'], [[13], 4, 'HT'], [[14], 4, 'N'], [[15], 4, 'HT'], [[16], 4, 'HT'], [[17], 4, 'N'], [[18], 4, 'N'], [[19], 4, 'N']]
# annotationsList of paragraph [[[0], 5, 'N'], [[1], 5, 'N'], [[2], 5, 'N'], [[3], 5, 'HT'], [[4], 5, 'N'], [[5], 5, 'N'], [[6], 5, 'N'], [[7], 5, 'N'], [[8], 5, 'N'], [[9], 5, 'N'], [[10], 5, 'N'], [[11], 5, 'N'], [[12], 5, 'N'], [[13], 5, 'N'], [[14, 13], 5, 'HM']]
# annotationsList of paragraph [[[0], 8, 'HT'], [[1], 8, 'N'], [[2], 8, 'N'], [[3], 8, 'HT']]
# annotationsList of paragraph [[[0], 10, 'N'], [[1], 10, 'N'], [[2], 10, 'HT'], [[3], 10, 'HT']]
# annotationsList of paragraph [[[0], 13, 'HT']]
# annotationsList of paragraph [[[0], 40, 'N']]
# annotationsList of paragraph [[[0], 46, 'HT']]
# annotationsList of paragraph [[[0], 48, 'N'], [[1], 48, 'HT']]
# annotationsList of paragraph [[[0], 50, 'HT']]
# annotationsList of paragraph [[[0], 51, 'N']]
# annotationsList of paragraph [[[0], 53, 'N'], [[1], 53, 'N']]
# annotationsList of paragraph [[[0], 56, 'N']]
# annotationsList of paragraph [[[0], 57, 'N']]
# annotationsList of paragraph [[[0], 58, 'N']]
# annotationsList of paragraph [[[0], 63, 'N']]
# annotationsList of paragraph [[[0], 76, 'N']]
# annotationsList of paragraph [[[0], 80, 'HT']]
# annotationsList of paragraph [[[0], 81, 'HT']]
# annotationsList of paragraph [[[0], 91, 'HT']]
# annotationsList of paragraph [[[0], 92, 'N'], [[1], 92, 'N']]
# annotationsList of paragraph [[[0], 97, 'N'], [[1], 97, 'HT']]
# annotationsList of paragraph [[[0], 101, 'HT']]
# annotationsList of paragraph [[[0], 105, 'HT']]
# Time to process file:  2.5682259742170572
# Memory use (161490, 366111)
# FILE:  28312254.csv
# Paragraphs to process 15
# annotationsList of paragraph [[[0], 0, 'HT'], [[1], 0, 'HT'], [[2], 0, 'N'], [[3], 0, 'HT'], [[4], 0, 'HT'], [[5], 0, 'N']]
# Time to process file:  0.15992107428610325
# Memory use (59219, 314481)
# FILE:  8040240.csv
# Paragraphs to process 8
# annotationsList of paragraph [[[0], 0, 'HT'], [[1], 0, 'HT']]
# annotationsList of paragraph [[[0], 2, 'HT'], [[1], 2, 'HT'], [[2], 2, 'HT']]
# annotationsList of paragraph [[[0], 4, 'N'], [[1], 4, 'HT'], [[2], 4, 'N'], [[3], 4, 'HT'], [[4], 4, 'N']]
# annotationsList of paragraph [[[0], 6, 'HM'], [[1], 6, 'HT'], [[2], 6, 'HT'], [[3], 6, 'HT'], [[4], 6, 'N']]
# Time to process file:  0.43418556870892644
# Memory use (52979, 321069)
# FILE:  22459257.csv
# Paragraphs to process 9
# annotationsList of paragraph [[[0], 0, 'HT'], [[1], 0, 'N']]
# annotationsList of paragraph [[[0], 1, 'N'], [[1], 1, 'N'], [[2], 1, 'N'], [[3], 1, 'HT'], [[4], 1, 'HT'], [[5], 1, 'HT'], [[6], 1, 'HT'], [[7], 1, 'HM'], [[8], 1, 'HT']]
# annotationsList of paragraph [[[0], 4, 'HT']]
# Time to process file:  0.40598540799692273
# Memory use (47752, 315226)
# FILE:  3362986.csv
# Paragraphs to process 50
# annotationsList of paragraph [[[0], 0, 'HT'], [[1], 0, 'N']]
# annotationsList of paragraph [[[0], 2, 'HT'], [[1], 2, 'N'], [[2], 2, 'HT'], [[3], 2, 'N'], [[4], 2, 'HT'], [[5], 2, 'N'], [[6], 2, 'N'], [[7], 2, 'N'], [[8], 2, 'HT'], [[9], 2, 'HT']]
# annotationsList of paragraph [[[0], 13, 'HT']]
# annotationsList of paragraph [[[0], 18, 'HT']]
# annotationsList of paragraph [[[0], 25, 'N']]
# annotationsList of paragraph [[[0], 33, 'HT']]
# annotationsList of paragraph [[[0], 35, 'HT']]
# Time to process file:  0.6089485222473741
# Memory use (65434, 327289)
# FILE:  19474675.csv
# Paragraphs to process 30
# annotationsList of paragraph [[[0], 0, 'HT']]
# annotationsList of paragraph [[[0], 2, 'N']]
# annotationsList of paragraph [[[0], 3, 'N'], [[1], 3, 'N'], [[2], 3, 'N']]
# annotationsList of paragraph [[[0], 4, 'HT'], [[1], 4, 'N'], [[2], 4, 'N']]
# annotationsList of paragraph [[[0], 5, 'N'], [[1], 5, 'HT'], [[2], 5, 'HT']]
# annotationsList of paragraph [[[0], 6, 'HT']]
# annotationsList of paragraph [[[0], 9, 'N']]
# annotationsList of paragraph [[[0], 10, 'N']]
# annotationsList of paragraph [[[0], 11, 'N']]
# annotationsList of paragraph [[[0], 14, 'N']]
# annotationsList of paragraph [[[0], 15, 'N']]
# annotationsList of paragraph [[[0], 16, 'N']]
# annotationsList of paragraph [[[0], 18, 'N']]
# annotationsList of paragraph [[[0], 21, 'N']]
# annotationsList of paragraph [[[0], 22, 'N']]
# annotationsList of paragraph [[[0], 23, 'N']]
# annotationsList of paragraph [[[0], 25, 'N']]
# annotationsList of paragraph [[[0], 26, 'N']]
# Time to process file:  0.8675073268823326
# Memory use (61623, 321670)
# FILE:  51596657.csv
# Paragraphs to process 36
# annotationsList of paragraph [[[0], 3, 'HT'], [[1], 3, 'N'], [[2], 3, 'N'], [[3], 3, 'N']]
# annotationsList of paragraph [[[0], 5, 'HT'], [[1], 5, 'N'], [[2], 5, 'HT'], [[3], 5, 'HT'], [[4], 5, 'HT'], [[5], 5, 'HT']]
# annotationsList of paragraph [[[0], 6, 'HT'], [[1], 6, 'HT'], [[2], 6, 'N']]
# annotationsList of paragraph [[[0], 7, 'HT']]
# annotationsList of paragraph [[[0], 8, 'N'], [[1], 8, 'N'], [[2], 8, 'N'], [[3], 8, 'N']]
# annotationsList of paragraph [[[0], 9, 'HT'], [[1], 9, 'N'], [[2], 9, 'HT']]
# annotationsList of paragraph [[[0], 17, 'N'], [[1], 17, 'N']]
# annotationsList of paragraph [[[0], 19, 'HT']]
# annotationsList of paragraph [[[0], 25, 'N'], [[1], 25, 'N'], [[2], 25, 'N']]
# Time to process file:  0.838671026751399
# Memory use (66439, 330951)
# FILE:  484364.csv
# Paragraphs to process 38
# annotationsList of paragraph [[[0], 0, 'HT'], [[1], 0, 'HT'], [[2], 0, 'HT'], [[3], 0, 'N']]
# annotationsList of paragraph [[[0], 2, 'HT'], [[1], 2, 'N'], [[2], 2, 'N'], [[3], 2, 'N'], [[4], 2, 'HT'], [[5], 2, 'HT'], [[6], 2, 'HT'], [[7], 2, 'N'], [[8], 2, 'HT']]
# annotationsList of paragraph [[[0], 3, 'N'], [[1], 3, 'HT'], [[2], 3, 'HT'], [[3], 3, 'HT']]
# annotationsList of paragraph [[[0], 5, 'HT'], [[1], 5, 'N'], [[2], 5, 'N'], [[3], 5, 'HT'], [[4], 5, 'N'], [[5], 5, 'HM'], [[6], 5, 'HT'], [[7], 5, 'N'], [[8], 5, 'N'], [[9], 5, 'N'], [[10], 5, 'N'], [[11], 5, 'HT'], [[12], 5, 'HT'], [[13], 5, 'N'], [[14], 5, 'HT']]
# annotationsList of paragraph [[[0], 7, 'N'], [[1], 7, 'HT'], [[2], 7, 'N'], [[3], 7, 'N'], [[4], 7, 'N'], [[5], 7, 'N'], [[6], 7, 'HT'], [[7], 7, 'N']]
# annotationsList of paragraph [[[0], 8, 'HT'], [[1], 8, 'N'], [[2], 8, 'N'], [[3], 8, 'HT'], [[4], 8, 'N']]
# annotationsList of paragraph [[[0], 9, 'HT'], [[1], 9, 'HT']]
# annotationsList of paragraph [[[0], 10, 'HT']]
# annotationsList of paragraph [[[0], 12, 'HT']]
# annotationsList of paragraph [[[0], 13, 'HT'], [[1], 13, 'HT'], [[2], 13, 'HT']]
# annotationsList of paragraph [[[0], 14, 'HT'], [[1], 14, 'N']]
# annotationsList of paragraph [[[0], 15, 'HT'], [[1], 15, 'HT'], [[2], 15, 'HM'], [[3], 15, 'HT'], [[4], 15, 'HT'], [[5], 15, 'N'], [[6], 15, 'HT'], [[7], 15, 'HT'], [[8], 15, 'HT'], [[9], 15, 'HT']]
# annotationsList of paragraph [[[0], 29, 'N']]
# annotationsList of paragraph [[[0], 30, 'N']]
# Time to process file:  1.6834134738892317
# Memory use (105381, 362137)
# FILE:  4241227.csv
# Paragraphs to process 38
# annotationsList of paragraph [[[0], 0, 'HT']]
# annotationsList of paragraph [[[0], 2, 'HM'], [[1], 2, 'HT'], [[2], 2, 'N']]
# annotationsList of paragraph [[[0], 4, 'HT'], [[1], 4, 'HM'], [[2], 4, 'HM'], [[3], 4, 'N'], [[4], 4, 'HT'], [[5], 4, 'N'], [[6], 4, 'N'], [[7], 4, 'HT']]
# annotationsList of paragraph [[[0], 5, 'HT']]
# annotationsList of paragraph [[[0], 7, 'HM'], [[1], 7, 'HT'], [[2], 7, 'N'], [[3], 7, 'HT'], [[4], 7, 'HT'], [[5], 7, 'HT'], [[6], 7, 'N'], [[7], 7, 'N'], [[8], 7, 'N'], [[9], 7, 'N'], [[10], 7, 'N'], [[11], 7, 'N']]
# annotationsList of paragraph [[[0], 8, 'HT'], [[1], 8, 'N']]
# annotationsList of paragraph [[[0], 10, 'HT'], [[1], 10, 'N']]
# annotationsList of paragraph [[[0], 12, 'HM'], [[1], 12, 'HT'], [[2], 12, 'HT']]
# Time to process file:  1.3570782872848213
# Memory use (77789, 337071)
# FILE:  46385848.csv
# Paragraphs to process 10
# annotationsList of paragraph [[[0], 0, 'HT'], [[1], 0, 'HT'], [[2], 0, 'HT'], [[3], 0, 'N'], [[4], 0, 'HT']]
# annotationsList of paragraph [[[0], 2, 'HM'], [[1], 2, 'HT']]
# annotationsList of paragraph [[[0], 6, 'HT'], [[1], 6, 'N'], [[2], 6, 'N'], [[3], 6, 'N']]
# Time to process file:  0.43529561907052994
# Memory use (46437, 315814)
# FILE:  52279001.csv
# Paragraphs to process 13
# annotationsList of paragraph [[[0], 0, 'HT'], [[1], 0, 'HT'], [[2], 0, 'HT'], [[3], 0, 'HT'], [[4], 0, 'HT']]
# annotationsList of paragraph [[[0], 2, 'HT'], [[1], 2, 'N'], [[2], 2, 'HT'], [[3], 2, 'HT'], [[4], 2, 'HT'], [[5], 2, 'HM'], [[6], 2, 'HT'], [[7], 2, 'HT'], [[8], 2, 'N'], [[9], 2, 'N'], [[10], 2, 'HT']]
# annotationsList of paragraph [[[0], 4, 'N'], [[1], 4, 'HT'], [[2], 4, 'HT']]
# Time to process file:  0.6438193158246577
# Memory use (53222, 324370)
# FILE:  8064528.csv
# Paragraphs to process 12
# annotationsList of paragraph [[[0], 0, 'HM']]
# annotationsList of paragraph [[[0], 2, 'HT'], [[1], 2, 'N'], [[2], 2, 'N']]
# annotationsList of paragraph [[[0], 3, 'HT'], [[1], 3, 'HT'], [[2], 3, 'N']]
# Time to process file:  0.30205019004642963
# Memory use (43637, 315304)
# FILE:  5143989.csv
# Paragraphs to process 45
# annotationsList of paragraph [[[0], 0, 'HT'], [[1], 0, 'N']]
# annotationsList of paragraph [[[0], 2, 'HT'], [[1], 2, 'N'], [[2], 2, 'N'], [[3], 2, 'HT'], [[4], 2, 'N'], [[5], 2, 'N'], [[6], 2, 'N'], [[7], 2, 'HT'], [[8], 2, 'HT'], [[9], 2, 'HT'], [[10], 2, 'HT'], [[11], 2, 'HT']]
# annotationsList of paragraph [[[0], 5, 'HT']]
# annotationsList of paragraph [[[0], 15, 'N']]
# annotationsList of paragraph [[[0], 23, 'N']]
# annotationsList of paragraph [[[0], 24, 'HT']]
# annotationsList of paragraph [[[0], 27, 'HT']]
# annotationsList of paragraph [[[0], 28, 'HT']]
# annotationsList of paragraph [[[0], 29, 'HT']]
# annotationsList of paragraph [[[0], 31, 'HT']]
# annotationsList of paragraph [[[0], 32, 'HT']]
# annotationsList of paragraph [[[0], 33, 'HT']]
# annotationsList of paragraph [[[0], 34, 'HT']]
# annotationsList of paragraph [[[0], 39, 'HT']]
# annotationsList of paragraph [[[0], 40, 'HT']]
# Time to process file:  0.9030420077033341
# Memory use (73046, 331339)
# FILE:  15182641.csv
# Paragraphs to process 56
# annotationsList of paragraph [[[0], 0, 'HM']]
# annotationsList of paragraph [[[0], 2, 'N'], [[1], 2, 'N'], [[2], 2, 'N'], [[3], 2, 'N']]
# annotationsList of paragraph [[[0], 5, 'HM'], [[1], 5, 'HM'], [[2], 5, 'N'], [[3], 5, 'HT'], [[4], 5, 'N']]
# annotationsList of paragraph [[[0], 7, 'HT'], [[1], 7, 'N'], [[2], 7, 'HT'], [[3], 7, 'HT'], [[4], 7, 'HT'], [[5], 7, 'HT'], [[6], 7, 'N'], [[7], 7, 'HM'], [[8], 7, 'N'], [[9], 7, 'N'], [[10], 7, 'HM']]
# annotationsList of paragraph [[[0], 8, 'HT'], [[1], 8, 'N']]
# annotationsList of paragraph [[[0], 10, 'HT'], [[1], 10, 'HT'], [[2], 10, 'HM'], [[3], 10, 'N'], [[4], 10, 'HT']]
# annotationsList of paragraph [[[0], 11, 'HT'], [[1], 11, 'HT'], [[2], 11, 'N'], [[3], 11, 'HT'], [[4], 11, 'HT']]
# annotationsList of paragraph [[[0], 13, 'HT'], [[1], 13, 'HT'], [[2], 13, 'HT'], [[3], 13, 'HT'], [[4], 13, 'HT']]
# annotationsList of paragraph [[[0], 15, 'HT']]
# annotationsList of paragraph [[[0], 16, 'HT']]
# annotationsList of paragraph [[[0], 17, 'HT']]
# annotationsList of paragraph [[[0], 18, 'HT']]
# annotationsList of paragraph [[[0], 19, 'HT']]
# annotationsList of paragraph [[[0], 20, 'HT']]
# annotationsList of paragraph [[[0], 21, 'HT']]
# annotationsList of paragraph [[[0], 23, 'HT']]
# annotationsList of paragraph [[[0], 24, 'HT']]
# annotationsList of paragraph [[[0], 25, 'HT']]
# annotationsList of paragraph [[[0], 26, 'HT']]
# annotationsList of paragraph [[[0], 27, 'HT']]
# annotationsList of paragraph [[[0], 28, 'HT']]
# annotationsList of paragraph [[[0], 29, 'HT']]
# annotationsList of paragraph [[[0], 30, 'HT']]
# annotationsList of paragraph [[[0], 31, 'HT']]
# annotationsList of paragraph [[[0], 32, 'HT']]
# annotationsList of paragraph [[[0], 33, 'HT']]
# annotationsList of paragraph [[[0], 34, 'HT']]
# annotationsList of paragraph [[[0], 35, 'HT']]
# annotationsList of paragraph [[[0], 36, 'HT']]
# annotationsList of paragraph [[[0], 38, 'HT']]
# annotationsList of paragraph [[[0], 39, 'HT']]
# annotationsList of paragraph [[[0], 40, 'HT']]
# annotationsList of paragraph [[[0], 41, 'HT']]
# annotationsList of paragraph [[[0], 42, 'HT']]
# annotationsList of paragraph [[[0], 44, 'HT']]
# annotationsList of paragraph [[[0], 45, 'HT']]
# annotationsList of paragraph [[[0], 46, 'HT']]
# annotationsList of paragraph [[[0], 47, 'HT']]
# annotationsList of paragraph [[[0], 48, 'HT']]
# annotationsList of paragraph [[[0], 49, 'HT']]
# annotationsList of paragraph [[[0], 50, 'HT']]
# annotationsList of paragraph [[[0], 51, 'HT']]
# annotationsList of paragraph [[[0], 52, 'HT']]
# annotationsList of paragraph [[[0], 53, 'HT']]
# annotationsList of paragraph [[[0], 54, 'HT']]
# Time to process file:  2.4520231522619724
# Memory use (128995, 390077)
# FILE:  6975970.csv
# Paragraphs to process 110
# annotationsList of paragraph [[[0], 0, 'HM'], [[1], 0, 'N'], [[2], 0, 'N']]
# annotationsList of paragraph [[[0], 1, 'HT'], [[1], 1, 'N']]
# annotationsList of paragraph [[[0], 4, 'N'], [[1], 4, 'HT'], [[2], 4, 'N'], [[3], 4, 'HT'], [[4], 4, 'N'], [[5], 4, 'N']]
# annotationsList of paragraph [[[0], 8, 'HT'], [[1], 8, 'N'], [[2], 8, 'N'], [[3], 8, 'N']]
# annotationsList of paragraph [[[0], 10, 'N'], [[1], 10, 'N'], [[2], 10, 'N'], [[3], 10, 'HT'], [[4], 10, 'HT'], [[5], 10, 'N'], [[6], 10, 'N'], [[7], 10, 'N']]
# annotationsList of paragraph [[[0], 11, 'HT'], [[1], 11, 'HT']]
# annotationsList of paragraph [[[0], 13, 'N'], [[1], 13, 'N']]
# annotationsList of paragraph [[[0], 15, 'N'], [[1], 15, 'N'], [[2], 15, 'N'], [[3], 15, 'HT']]
# annotationsList of paragraph [[[0], 16, 'HT'], [[1], 16, 'N'], [[2], 16, 'N'], [[3], 16, 'N'], [[4], 16, 'N'], [[5], 16, 'N'], [[6], 16, 'HT']]
# annotationsList of paragraph [[[0], 17, 'N'], [[1], 17, 'N'], [[2], 17, 'N'], [[3], 17, 'N']]
# annotationsList of paragraph [[[0], 19, 'N'], [[1], 19, 'N'], [[2], 19, 'N'], [[3], 19, 'N']]
# annotationsList of paragraph [[[0], 20, 'N'], [[1], 20, 'N']]
# annotationsList of paragraph [[[0], 24, 'HT'], [[1], 24, 'N'], [[2], 24, 'HT'], [[3], 24, 'HT']]
# annotationsList of paragraph [[[0], 29, 'HT'], [[1], 29, 'N']]
# annotationsList of paragraph [[[0], 42, 'N'], [[1], 42, 'HT']]
# annotationsList of paragraph [[[0], 45, 'N'], [[1], 45, 'HT']]
# annotationsList of paragraph [[[0], 46, 'N'], [[1], 46, 'HT']]
# annotationsList of paragraph [[[0], 47, 'N'], [[1], 47, 'HT']]
# annotationsList of paragraph [[[0], 48, 'N'], [[1], 48, 'N']]
# annotationsList of paragraph [[[0], 52, 'HT']]
# annotationsList of paragraph [[[0], 61, 'N']]
# annotationsList of paragraph [[[0], 62, 'HT']]
# annotationsList of paragraph [[[0], 63, 'N']]
# annotationsList of paragraph [[[0], 64, 'N']]
# annotationsList of paragraph [[[0], 65, 'HT']]
# annotationsList of paragraph [[[0], 66, 'HT']]
# annotationsList of paragraph [[[0], 68, 'HT']]
# annotationsList of paragraph [[[0], 69, 'N'], [[1], 69, 'N']]
# annotationsList of paragraph [[[0], 70, 'HT']]
# annotationsList of paragraph [[[0], 71, 'N'], [[1], 71, 'HT']]
# annotationsList of paragraph [[[0], 72, 'HT']]
# annotationsList of paragraph [[[0], 73, 'HT']]
# annotationsList of paragraph [[[0], 74, 'N']]
# annotationsList of paragraph [[[0], 75, 'HT']]
# annotationsList of paragraph [[[0], 77, 'N']]
# annotationsList of paragraph [[[0], 79, 'HT']]
# annotationsList of paragraph [[[0], 81, 'HT']]
# annotationsList of paragraph [[[0], 82, 'HT']]
# annotationsList of paragraph [[[0], 83, 'HT']]
# annotationsList of paragraph [[[0], 84, 'HT']]
# annotationsList of paragraph [[[0], 85, 'HT']]
# annotationsList of paragraph [[[0], 87, 'HT']]
# annotationsList of paragraph [[[0], 89, 'HT']]
# annotationsList of paragraph [[[0], 91, 'N']]
# annotationsList of paragraph [[[0], 93, 'HT']]
# annotationsList of paragraph [[[0], 94, 'HT']]
# annotationsList of paragraph [[[0], 99, 'HT']]
# annotationsList of paragraph [[[0], 101, 'HT']]
# annotationsList of paragraph [[[0], 102, 'HT']]
# annotationsList of paragraph [[[0], 103, 'HT']]
# annotationsList of paragraph [[[0], 105, 'HT']]
# Time to process file:  2.9004856240935624
# Memory use (141962, 386924)
# FILE:  1949333.csv
# Paragraphs to process 33
# annotationsList of paragraph [[[0], 0, 'HT'], [[1], 0, 'N'], [[2], 0, 'N'], [[3], 0, 'HT']]
# annotationsList of paragraph [[[0], 2, 'HT'], [[1], 2, 'N'], [[2], 2, 'HT'], [[3], 2, 'N'], [[4], 2, 'N']]
# annotationsList of paragraph [[[0], 4, 'HT'], [[1], 4, 'N'], [[2], 4, 'HT'], [[3], 4, 'HT'], [[4], 4, 'HT'], [[5], 4, 'HT'], [[6], 4, 'HT'], [[7], 4, 'HT']]
# annotationsList of paragraph [[[0], 5, 'HT'], [[1], 5, 'N'], [[2], 5, 'N'], [[3], 5, 'HT'], [[4], 5, 'N']]
# annotationsList of paragraph [[[0], 6, 'HT'], [[1], 6, 'HM'], [[2], 6, 'HT']]
# annotationsList of paragraph [[[0], 7, 'HM'], [[1], 7, 'HT'], [[2], 7, 'N'], [[3], 7, 'HT']]
# annotationsList of paragraph [[[0], 8, 'HT'], [[1], 8, 'HM'], [[2], 8, 'HT']]
# annotationsList of paragraph [[[0], 9, 'HT'], [[1], 9, 'HT'], [[2], 9, 'HT'], [[3], 9, 'HM'], [[4], 9, 'HT']]
# annotationsList of paragraph [[[0], 10, 'N'], [[1, 0], 10, 'HM'], [[2], 10, 'N'], [[3], 10, 'N'], [[4], 10, 'N'], [[5], 10, 'HM'], [[6], 10, 'HT'], [[7], 10, 'HT']]
# annotationsList of paragraph [[[0], 11, 'N']]
# annotationsList of paragraph [[[0], 13, 'N']]
# annotationsList of paragraph [[[0], 15, 'N'], [[1], 15, 'HT'], [[2], 15, 'N'], [[3], 15, 'N'], [[4], 15, 'N']]
# annotationsList of paragraph [[[0], 17, 'HT'], [[1], 17, 'HT'], [[2], 17, 'HT'], [[3], 17, 'HT'], [[4], 17, 'HT']]
# annotationsList of paragraph [[[0], 18, 'N']]
# Time to process file:  2.02580559020862
# Memory use (117931, 369685)
# FILE:  2470630.csv
# Paragraphs to process 73
# annotationsList of paragraph [[[0], 0, 'HM'], [[1], 0, 'HT'], [[2], 0, 'N'], [[3], 0, 'N']]
# annotationsList of paragraph [[[0], 2, 'N'], [[1], 2, 'HT'], [[2], 2, 'HT'], [[3], 2, 'HT'], [[4], 2, 'HT']]
# annotationsList of paragraph [[[0], 3, 'HT'], [[1], 3, 'HM']]
# annotationsList of paragraph [[[0], 4, 'HM'], [[1], 4, 'HT'], [[2], 4, 'HM'], [[3], 4, 'HT']]
# annotationsList of paragraph [[[0], 5, 'N'], [[1], 5, 'N']]
# annotationsList of paragraph [[[0], 6, 'HT'], [[1], 6, 'HT']]
# annotationsList of paragraph [[[0], 10, 'N']]
# annotationsList of paragraph [[[0], 11, 'HT']]
# annotationsList of paragraph [[[0], 12, 'HT']]
# annotationsList of paragraph [[[0], 13, 'HT']]
# annotationsList of paragraph [[[0], 14, 'N'], [[1], 14, 'N']]
# annotationsList of paragraph [[[0], 15, 'HT']]
# annotationsList of paragraph [[[0], 16, 'N'], [[1], 16, 'N'], [[2], 16, 'N']]
# annotationsList of paragraph [[[0], 17, 'HT']]
# annotationsList of paragraph [[[0], 18, 'HT']]
# annotationsList of paragraph [[[0], 19, 'N'], [[1], 19, 'HT']]
# annotationsList of paragraph [[[0], 21, 'HT']]
# annotationsList of paragraph [[[0], 23, 'HT']]
# annotationsList of paragraph [[[0], 24, 'HT']]
# annotationsList of paragraph [[[0], 25, 'HT']]
# annotationsList of paragraph [[[0], 26, 'N'], [[1], 26, 'N']]
# annotationsList of paragraph [[[0], 27, 'N'], [[1], 27, 'N']]
# annotationsList of paragraph [[[0], 28, 'HT']]
# annotationsList of paragraph [[[0], 34, 'N'], [[1], 34, 'HT']]
# annotationsList of paragraph [[[0], 35, 'HT']]
# annotationsList of paragraph [[[0], 36, 'HT']]
# annotationsList of paragraph [[[0], 37, 'N'], [[1], 37, 'HT']]
# annotationsList of paragraph [[[0], 38, 'HT']]
# annotationsList of paragraph [[[0], 43, 'HT']]
# annotationsList of paragraph [[[0], 44, 'HT']]
# annotationsList of paragraph [[[0], 45, 'HT'], [[1], 45, 'N']]
# annotationsList of paragraph [[[0], 47, 'HT']]
# annotationsList of paragraph [[[0], 48, 'HT']]
# annotationsList of paragraph [[[0], 49, 'HT']]
# annotationsList of paragraph [[[0], 51, 'HT']]
# annotationsList of paragraph [[[0], 52, 'N'], [[1], 52, 'N']]
# annotationsList of paragraph [[[0], 58, 'HT']]
# annotationsList of paragraph [[[0], 59, 'N'], [[1], 59, 'N']]
# annotationsList of paragraph [[[0], 60, 'HT']]
# annotationsList of paragraph [[[0], 61, 'HT']]
# annotationsList of paragraph [[[0], 63, 'HT']]
# annotationsList of paragraph [[[0], 64, 'HT']]
# Time to process file:  2.2026338879950345
# Memory use (122964, 353811)
# FILE:  18713679.csv
# Paragraphs to process 5
# annotationsList of paragraph [[[0], 0, 'HM']]
# annotationsList of paragraph [[[0], 1, 'N'], [[1], 1, 'HT'], [[2], 1, 'HT']]
# annotationsList of paragraph [[[0], 2, 'HT']]
# Time to process file:  0.18732917215675116
# Memory use (45350, 317350)
# FILE:  23394028.csv
# Paragraphs to process 27
# annotationsList of paragraph [[[0], 0, 'HM']]
# annotationsList of paragraph [[[0], 2, 'HT'], [[1], 2, 'N'], [[2], 2, 'N']]
# annotationsList of paragraph [[[0], 3, 'N'], [[1], 3, 'HT'], [[2], 3, 'HT'], [[3], 3, 'N']]
# annotationsList of paragraph [[[0], 4, 'HT'], [[1], 4, 'HT']]
# annotationsList of paragraph [[[0], 5, 'HT']]
# annotationsList of paragraph [[[0], 6, 'N']]
# annotationsList of paragraph [[[0], 7, 'N'], [[1], 7, 'N']]
# annotationsList of paragraph [[[0], 8, 'N']]
# annotationsList of paragraph [[[0], 9, 'N'], [[1], 9, 'N']]
# annotationsList of paragraph [[[0], 10, 'HT'], [[1], 10, 'N'], [[2], 10, 'N']]
# annotationsList of paragraph [[[0], 11, 'N']]
# annotationsList of paragraph [[[0], 13, 'N']]
# annotationsList of paragraph [[[0], 15, 'N']]
# annotationsList of paragraph [[[0], 16, 'N']]
# annotationsList of paragraph [[[0], 17, 'N']]
# annotationsList of paragraph [[[0], 18, 'N']]
# annotationsList of paragraph [[[0], 19, 'N']]
# annotationsList of paragraph [[[0], 20, 'N']]
# annotationsList of paragraph [[[0], 21, 'N']]
# annotationsList of paragraph [[[0], 22, 'HT']]
# Time to process file:  0.9658194347284734
# Memory use (69868, 340632)
# FILE:  1862380.csv
# Paragraphs to process 49
# annotationsList of paragraph [[[0], 0, 'HM'], [[1], 0, 'N']]
# annotationsList of paragraph [[[0], 2, 'HT'], [[1], 2, 'HT'], [[2], 2, 'HM']]
# annotationsList of paragraph [[[0], 3, 'HT'], [[1], 3, 'N'], [[2], 3, 'N'], [[3], 3, 'N'], [[4], 3, 'N'], [[5], 3, 'N']]
# annotationsList of paragraph [[[0], 4, 'HT'], [[1], 4, 'N'], [[2], 4, 'N'], [[3], 4, 'N'], [[4], 4, 'N'], [[5], 4, 'HT'], [[6], 4, 'N'], [[7], 4, 'HT'], [[8], 4, 'N'], [[9], 4, 'HT'], [[10], 4, 'HT'], [[11], 4, 'N']]
# annotationsList of paragraph [[[0], 9, 'N'], [[1], 9, 'HT']]
# annotationsList of paragraph [[[0], 20, 'HT']]
# annotationsList of paragraph [[[0], 31, 'HT'], [[1], 31, 'N']]
# annotationsList of paragraph [[[0], 35, 'HT']]
# annotationsList of paragraph [[[0], 38, 'N']]
# annotationsList of paragraph [[[0], 43, 'HT']]
# Time to process file:  0.8101056939922273
# Memory use (76779, 333399)
# FILE:  14565496.csv
# Paragraphs to process 13
# annotationsList of paragraph [[[0], 0, 'HT']]
# annotationsList of paragraph [[[0], 2, 'HT'], [[1], 2, 'N'], [[2], 2, 'HT'], [[3], 2, 'N'], [[4], 2, 'N'], [[5], 2, 'N'], [[6], 2, 'HT']]
# annotationsList of paragraph [[[0], 3, 'HT'], [[1], 3, 'HT'], [[2], 3, 'HT'], [[3], 3, 'HT']]
# annotationsList of paragraph [[[0], 4, 'HT'], [[1], 4, 'HT'], [[2], 4, 'HT'], [[3], 4, 'HT'], [[4], 4, 'HT'], [[5], 4, 'HT'], [[6], 4, 'HT'], [[7], 4, 'HT'], [[8], 4, 'HT'], [[9], 4, 'HT'], [[10], 4, 'HT'], [[11], 4, 'HT'], [[12], 4, 'HT'], [[13], 4, 'HT'], [[14], 4, 'HT'], [[15], 4, 'HT'], [[16], 4, 'N'], [[17], 4, 'N']]
# annotationsList of paragraph [[[0], 6, 'HT'], [[1], 6, 'HT']]
# annotationsList of paragraph [[[0], 8, 'HT']]
# Time to process file:  1.0524299181997776
# Memory use (74150, 339412)
# FILE:  21438871.csv
# Paragraphs to process 24
# annotationsList of paragraph [[[0], 0, 'HT'], [[1], 0, 'HT']]
# annotationsList of paragraph [[[0], 2, 'HT'], [[1], 2, 'HT'], [[2], 2, 'N'], [[3], 2, 'N'], [[4], 2, 'HT'], [[5], 2, 'N'], [[6], 2, 'N'], [[7], 2, 'N'], [[8], 2, 'HT'], [[9], 2, 'HT'], [[10], 2, 'N'], [[11], 2, 'N']]
# annotationsList of paragraph [[[0], 20, 'N']]
# Time to process file:  0.32871416863054037
# Memory use (51445, 323568)
# FILE:  43618783.csv
# Paragraphs to process 11
# annotationsList of paragraph [[[0], 0, 'N']]
# annotationsList of paragraph [[[0], 2, 'HT'], [[1], 2, 'HM'], [[2], 2, 'HT'], [[3], 2, 'HT'], [[4], 2, 'N'], [[5], 2, 'HT'], [[6], 2, 'HM'], [[7, 6], 2, 'HM'], [[8], 2, 'HT'], [[9], 2, 'N'], [[10], 2, 'HT'], [[11], 2, 'HT'], [[12], 2, 'HT'], [[13], 2, 'HT'], [[14], 2, 'HM'], [[15], 2, 'N']]
# Time to process file:  0.45929327700287104
# Memory use (56398, 321668)
# FILE:  37029067.csv
# Paragraphs to process 36
# annotationsList of paragraph [[[0], 0, 'HT'], [[1], 0, 'HT'], [[2], 0, 'HT']]
# annotationsList of paragraph [[[0], 1, 'HT'], [[1], 1, 'N']]
# annotationsList of paragraph [[[0], 2, 'HT'], [[1], 2, 'N']]
# annotationsList of paragraph [[[0], 5, 'HT'], [[1], 5, 'N'], [[2], 5, 'N'], [[3], 5, 'N'], [[4], 5, 'N'], [[5], 5, 'N'], [[6], 5, 'HT']]
# annotationsList of paragraph [[[0], 7, 'HT'], [[1], 7, 'N'], [[2], 7, 'N'], [[3], 7, 'N']]
# annotationsList of paragraph [[[0], 8, 'HT'], [[1], 8, 'N'], [[2], 8, 'N'], [[3], 8, 'N'], [[4], 8, 'HT']]
# annotationsList of paragraph [[[0], 9, 'HT'], [[1], 9, 'HT']]
# annotationsList of paragraph [[[0], 11, 'HT'], [[1], 11, 'HT'], [[2], 11, 'N'], [[3], 11, 'HT'], [[4], 11, 'HT']]
# annotationsList of paragraph [[[0], 12, 'N'], [[1], 12, 'N'], [[2], 12, 'N'], [[3], 12, 'N'], [[4], 12, 'N']]
# annotationsList of paragraph [[[0], 14, 'HT'], [[1], 14, 'N'], [[2], 14, 'N'], [[3], 14, 'N'], [[4], 14, 'N'], [[5], 14, 'HT']]
# annotationsList of paragraph [[[0], 15, 'HT'], [[1], 15, 'N'], [[2], 15, 'N']]
# annotationsList of paragraph [[[0], 16, 'HT'], [[1], 16, 'HT'], [[2], 16, 'N'], [[3], 16, 'HT'], [[4], 16, 'N'], [[5], 16, 'HT'], [[6], 16, 'N']]
# annotationsList of paragraph [[[0], 17, 'HT'], [[1], 17, 'N']]
# annotationsList of paragraph [[[0], 18, 'HT'], [[1], 18, 'HT']]
# annotationsList of paragraph [[[0], 20, 'HT'], [[1], 20, 'HT'], [[2], 20, 'N'], [[3], 20, 'HT'], [[4], 20, 'HT'], [[5], 20, 'HT']]
# annotationsList of paragraph [[[0], 21, 'HT'], [[1], 21, 'N']]
# annotationsList of paragraph [[[0], 22, 'N'], [[1], 22, 'N'], [[2], 22, 'N'], [[3], 22, 'N'], [[4], 22, 'HT']]
# annotationsList of paragraph [[[0], 24, 'HT'], [[1], 24, 'N'], [[2], 24, 'N'], [[3], 24, 'N']]
# annotationsList of paragraph [[[0], 25, 'HT']]
# annotationsList of paragraph [[[0], 28, 'HT'], [[1], 28, 'N']]
# Time to process file:  1.8566512428224087
# Memory use (94614, 362454)
# FILE:  8623467.csv
# Paragraphs to process 35
# annotationsList of paragraph [[[0], 0, 'HT']]
# annotationsList of paragraph [[[0], 2, 'HT'], [[1], 2, 'HT'], [[2], 2, 'HM'], [[3], 2, 'HT'], [[4], 2, 'HT']]
# annotationsList of paragraph [[[0], 4, 'HT'], [[1], 4, 'HT']]
# annotationsList of paragraph [[[0], 6, 'N'], [[1], 6, 'N'], [[2], 6, 'N']]
# annotationsList of paragraph [[[0], 9, 'N'], [[1], 9, 'N']]
# annotationsList of paragraph [[[0], 10, 'HT']]
# annotationsList of paragraph [[[0], 11, 'N']]
# annotationsList of paragraph [[[0], 12, 'HT']]
# annotationsList of paragraph [[[0], 13, 'HT']]
# annotationsList of paragraph [[[0], 14, 'HT']]
# annotationsList of paragraph [[[0], 15, 'HT']]
# Time to process file:  0.690374162979424
# Memory use (69195, 331902)
# FILE:  65518206.csv
# Paragraphs to process 6
# annotationsList of paragraph [[[0], 0, 'HT'], [[1], 0, 'N'], [[2], 0, 'N'], [[3], 0, 'N']]
# annotationsList of paragraph [[[0], 2, 'N'], [[1], 2, 'N'], [[2], 2, 'HT'], [[3], 2, 'N'], [[4], 2, 'N'], [[5], 2, 'HT'], [[6], 2, 'HT'], [[7], 2, 'HT'], [[8], 2, 'HT'], [[9], 2, 'N'], [[10], 2, 'HT'], [[11], 2, 'HT'], [[12], 2, 'HT'], [[13], 2, 'N'], [[14], 2, 'HT'], [[15], 2, 'N']]
# Time to process file:  0.4243710502050817
# Memory use (48171, 322836)
# FILE:  80664.csv
# Paragraphs to process 51
# annotationsList of paragraph [[[0], 0, 'HT'], [[1], 0, 'N'], [[2], 0, 'N'], [[3], 0, 'N'], [[4], 0, 'N']]
# annotationsList of paragraph [[[0], 2, 'HT'], [[1], 2, 'HT'], [[2], 2, 'N'], [[3], 2, 'HT'], [[4], 2, 'HT']]
# annotationsList of paragraph [[[0], 4, 'N'], [[1], 4, 'HT']]
# annotationsList of paragraph [[[0], 5, 'HT'], [[1], 5, 'N'], [[2], 5, 'N'], [[3], 5, 'N'], [[4], 5, 'HT'], [[5], 5, 'HT']]
# annotationsList of paragraph [[[0], 6, 'HT'], [[1], 6, 'HT'], [[2], 6, 'N'], [[3], 6, 'HT'], [[4], 6, 'HT'], [[5], 6, 'N'], [[6], 6, 'N']]
# annotationsList of paragraph [[[0], 7, 'HT']]
# annotationsList of paragraph [[[0], 8, 'HT'], [[1], 8, 'HT'], [[2], 8, 'HT'], [[3], 8, 'HT']]
# annotationsList of paragraph [[[0], 9, 'N']]
# annotationsList of paragraph [[[0], 10, 'HT'], [[1], 10, 'N'], [[2], 10, 'N']]
# annotationsList of paragraph [[[0], 11, 'HT']]
# annotationsList of paragraph [[[0], 12, 'HT'], [[1], 12, 'HT'], [[2], 12, 'N'], [[3], 12, 'N']]
# annotationsList of paragraph [[[0], 13, 'HT']]
# annotationsList of paragraph [[[0], 14, 'HT'], [[1], 14, 'N'], [[2], 14, 'HT']]
# annotationsList of paragraph [[[0], 15, 'HT'], [[1], 15, 'N']]
# annotationsList of paragraph [[[0], 16, 'N'], [[1], 16, 'N'], [[2], 16, 'HT'], [[3], 16, 'N'], [[4], 16, 'HT'], [[5], 16, 'N'], [[6], 16, 'N']]
# annotationsList of paragraph [[[0], 18, 'N'], [[1], 18, 'HT'], [[2], 18, 'HT'], [[3], 18, 'N']]
# annotationsList of paragraph [[[0], 23, 'HT']]
# annotationsList of paragraph [[[0], 26, 'N']]
# annotationsList of paragraph [[[0], 27, 'N']]
# annotationsList of paragraph [[[0], 28, 'HT'], [[1], 28, 'N']]
# annotationsList of paragraph [[[0], 30, 'HT'], [[1], 30, 'HT'], [[2], 30, 'N'], [[3], 30, 'HT']]
# annotationsList of paragraph [[[0], 33, 'N'], [[1], 33, 'HT']]
# annotationsList of paragraph [[[0], 35, 'N']]
# annotationsList of paragraph [[[0], 36, 'N']]
# annotationsList of paragraph [[[0], 37, 'N'], [[1], 37, 'N']]
# annotationsList of paragraph [[[0], 38, 'N']]
# annotationsList of paragraph [[[0], 39, 'N'], [[1], 39, 'HT']]
# annotationsList of paragraph [[[0], 40, 'HT']]
# annotationsList of paragraph [[[0], 41, 'N'], [[1], 41, 'HT']]
# annotationsList of paragraph [[[0], 42, 'HT'], [[1], 42, 'HT']]
# annotationsList of paragraph [[[0], 44, 'HT']]
# annotationsList of paragraph [[[0], 46, 'HT']]
# annotationsList of paragraph [[[0], 48, 'N'], [[1], 48, 'N']]
# Time to process file:  2.2246738700196147
# Memory use (118073, 372273)
# FILE:  36018341.csv
# Paragraphs to process 24
# annotationsList of paragraph [[[0], 0, 'HT'], [[1], 0, 'N'], [[2], 0, 'HT'], [[3], 0, 'N'], [[4], 0, 'HT']]
# annotationsList of paragraph [[[0], 2, 'N'], [[1], 2, 'N'], [[2], 2, 'N']]
# annotationsList of paragraph [[[0], 3, 'HT'], [[1], 3, 'HT'], [[2], 3, 'N'], [[3], 3, 'N'], [[4], 3, 'N'], [[5], 3, 'HT'], [[6], 3, 'HT'], [[7], 3, 'HT']]
# annotationsList of paragraph [[[0], 4, 'N'], [[1], 4, 'HT'], [[2], 4, 'N']]
# annotationsList of paragraph [[[0], 11, 'HT']]
# annotationsList of paragraph [[[0], 16, 'N']]
# Time to process file:  0.5880932807922363
# Memory use (60874, 323505)
# FILE:  37882107.csv
# Paragraphs to process 24
# annotationsList of paragraph [[[0], 0, 'HT']]
# annotationsList of paragraph [[[0], 1, 'HT'], [[1], 1, 'HT'], [[2], 1, 'HT'], [[3], 1, 'HT'], [[4], 1, 'N']]
# annotationsList of paragraph [[[0], 3, 'N'], [[1], 3, 'HT'], [[2], 3, 'HT'], [[3], 3, 'N'], [[4], 3, 'N'], [[5], 3, 'HT'], [[6], 3, 'HT'], [[7], 3, 'HT'], [[8], 3, 'HT']]
# annotationsList of paragraph [[[0], 6, 'HT'], [[1], 6, 'HT'], [[2], 6, 'HT'], [[3], 6, 'N'], [[4], 6, 'HT'], [[5], 6, 'N'], [[6], 6, 'N'], [[7], 6, 'N'], [[8], 6, 'N'], [[9], 6, 'HT'], [[10], 6, 'HT'], [[11], 6, 'N'], [[12], 6, 'N'], [[13], 6, 'N'], [[14], 6, 'N'], [[15], 6, 'N']]
# annotationsList of paragraph [[[0], 8, 'HT'], [[1], 8, 'HT'], [[2], 8, 'N'], [[3], 8, 'N'], [[4], 8, 'N'], [[5], 8, 'N'], [[6], 8, 'N'], [[7], 8, 'N'], [[8], 8, 'HT'], [[9], 8, 'HT'], [[10], 8, 'N'], [[11], 8, 'N'], [[12], 8, 'HT'], [[13], 8, 'HT'], [[14], 8, 'HT'], [[15], 8, 'N'], [[16], 8, 'HT'], [[17], 8, 'HT'], [[18], 8, 'N']]
# annotationsList of paragraph [[[0], 10, 'HT'], [[1], 10, 'HT'], [[2], 10, 'N'], [[3], 10, 'N'], [[4], 10, 'HT'], [[5], 10, 'HT'], [[6], 10, 'HT'], [[7], 10, 'HT'], [[8], 10, 'HT'], [[9], 10, 'HT']]
# annotationsList of paragraph [[[0], 12, 'HT'], [[1], 12, 'HT'], [[2], 12, 'N'], [[3], 12, 'HT'], [[4], 12, 'N'], [[5], 12, 'N'], [[6], 12, 'HT']]
# Time to process file:  1.5411607269197702
# Memory use (102902, 368440)
# FILE:  27043626.csv
# Paragraphs to process 28
# annotationsList of paragraph [[[0], 0, 'HT'], [[1], 0, 'N'], [[2], 0, 'N']]
# annotationsList of paragraph [[[0], 2, 'HT'], [[1], 2, 'N']]
# annotationsList of paragraph [[[0], 4, 'N'], [[1], 4, 'N'], [[2], 4, 'N'], [[3], 4, 'HT'], [[4], 4, 'N'], [[5], 4, 'N'], [[6], 4, 'N'], [[7], 4, 'N'], [[8], 4, 'HT']]
# annotationsList of paragraph [[[0], 5, 'HT'], [[1], 5, 'HT'], [[2], 5, 'HT']]
# Time to process file:  0.4126165807247162
# Memory use (52379, 324281)
# FILE:  2887963.csv
# Paragraphs to process 11
# annotationsList of paragraph [[[0], 0, 'HT'], [[1], 0, 'HT']]
# annotationsList of paragraph [[[0], 2, 'N'], [[1], 2, 'HT'], [[2], 2, 'N'], [[3], 2, 'N'], [[4], 2, 'N'], [[5], 2, 'N'], [[6], 2, 'HT'], [[7], 2, 'N'], [[8], 2, 'HT'], [[9], 2, 'HM'], [[10], 2, 'HT']]
# annotationsList of paragraph [[[0], 3, 'HT'], [[1], 3, 'N'], [[2], 3, 'N'], [[3], 3, 'HT'], [[4], 3, 'HT']]
# annotationsList of paragraph [[[0], 5, 'HT'], [[1], 5, 'HT']]
# annotationsList of paragraph [[[0], 7, 'HT']]
# Time to process file:  0.6552754421718419
# Memory use (60510, 323677)
# FILE:  34546475.csv
# Paragraphs to process 23
# annotationsList of paragraph [[[0], 0, 'HT']]
# annotationsList of paragraph [[[0], 2, 'HT'], [[1], 2, 'N']]
# annotationsList of paragraph [[[0], 5, 'HT'], [[1], 5, 'N'], [[2], 5, 'N']]
# annotationsList of paragraph [[[0], 6, 'HT'], [[1], 6, 'N'], [[2], 6, 'N'], [[3], 6, 'N'], [[4], 6, 'N'], [[5], 6, 'N']]
# annotationsList of paragraph [[[0], 8, 'N'], [[1], 8, 'N'], [[2], 8, 'N'], [[3], 8, 'N']]
# annotationsList of paragraph [[[0], 10, 'HT'], [[1], 10, 'N'], [[2], 10, 'N'], [[3], 10, 'N'], [[4], 10, 'N'], [[5], 10, 'N'], [[6], 10, 'N']]
# Time to process file:  0.6641931240446866
# Memory use (59509, 325323)
# FILE:  4636486.csv
# Paragraphs to process 52
# annotationsList of paragraph [[[0], 0, 'HT'], [[1], 0, 'N'], [[2], 0, 'N']]
# annotationsList of paragraph [[[0], 2, 'N'], [[1], 2, 'N']]
# annotationsList of paragraph [[[0], 3, 'HT'], [[1], 3, 'HT'], [[2], 3, 'HT'], [[3], 3, 'HT']]
# annotationsList of paragraph [[[0], 5, 'HM'], [[1], 5, 'N'], [[2], 5, 'N'], [[3], 5, 'N'], [[4], 5, 'HT'], [[5], 5, 'HT'], [[6], 5, 'HT'], [[7], 5, 'N'], [[8], 5, 'HT'], [[9], 5, 'HT'], [[10], 5, 'N'], [[11], 5, 'HT'], [[12], 5, 'N'], [[13], 5, 'HT'], [[14], 5, 'HT'], [[15], 5, 'N'], [[16], 5, 'HT'], [[17], 5, 'N'], [[18], 5, 'HT'], [[19], 5, 'HT'], [[20], 5, 'HT'], [[21], 5, 'N'], [[22], 5, 'HT'], [[23], 5, 'N'], [[24], 5, 'HT']]
# annotationsList of paragraph [[[0], 7, 'HT'], [[1], 7, 'HT']]
# annotationsList of paragraph [[[0], 9, 'N']]
# annotationsList of paragraph [[[0], 12, 'HT']]
# annotationsList of paragraph [[[0], 13, 'HT']]
# annotationsList of paragraph [[[0], 14, 'N']]
# annotationsList of paragraph [[[0], 15, 'HT']]
# annotationsList of paragraph [[[0], 16, 'HT']]
# annotationsList of paragraph [[[0], 18, 'HT']]
# annotationsList of paragraph [[[0], 19, 'HT']]
# annotationsList of paragraph [[[0], 20, 'HT']]
# annotationsList of paragraph [[[0], 23, 'HT']]
# annotationsList of paragraph [[[0], 24, 'N']]
# annotationsList of paragraph [[[0], 25, 'HT']]
# annotationsList of paragraph [[[0], 28, 'HT']]
# annotationsList of paragraph [[[0], 30, 'HT']]
# annotationsList of paragraph [[[0], 31, 'HT']]
# annotationsList of paragraph [[[0], 33, 'HT']]
# annotationsList of paragraph [[[0], 34, 'N']]
# annotationsList of paragraph [[[0], 35, 'HT']]
# annotationsList of paragraph [[[0], 36, 'HT']]
# annotationsList of paragraph [[[0], 37, 'HT']]
# annotationsList of paragraph [[[0], 38, 'HT']]
# annotationsList of paragraph [[[0], 39, 'N']]
# annotationsList of paragraph [[[0], 41, 'N'], [[1], 41, 'HT']]
# annotationsList of paragraph [[[0], 42, 'HT']]
# annotationsList of paragraph [[[0], 43, 'HT']]
# annotationsList of paragraph [[[0], 45, 'HT']]
# annotationsList of paragraph [[[0], 46, 'N'], [[1], 46, 'N']]
# annotationsList of paragraph [[[0], 47, 'HT']]
# annotationsList of paragraph [[[0], 48, 'HT']]
# annotationsList of paragraph [[[0], 49, 'HT']]
# annotationsList of paragraph [[[0], 50, 'N']]
# Time to process file:  2.1338650179095566
# Memory use (100222, 346240)
# FILE:  9342621.csv
# Paragraphs to process 7
# annotationsList of paragraph [[[0], 0, 'HT'], [[1], 0, 'N'], [[2], 0, 'N'], [[3], 0, 'HT'], [[4], 0, 'HT']]
# annotationsList of paragraph [[[0], 1, 'HT'], [[1], 1, 'N'], [[2], 1, 'HT'], [[3], 1, 'N']]
# annotationsList of paragraph [[[0], 2, 'HT'], [[1], 2, 'N']]
# annotationsList of paragraph [[[0], 3, 'HM'], [[1], 3, 'N']]
# Time to process file:  0.3694173679687083
# Memory use (48154, 315748)
# FILE:  757045.csv
# Paragraphs to process 32
# annotationsList of paragraph [[[0], 0, 'HT'], [[1], 0, 'N']]
# annotationsList of paragraph [[[0], 2, 'HT'], [[1], 2, 'HT'], [[2], 2, 'HT'], [[3], 2, 'HT'], [[4], 2, 'N'], [[5], 2, 'N']]
# annotationsList of paragraph [[[0], 4, 'HM'], [[1], 4, 'HT'], [[2], 4, 'N'], [[3], 4, 'HT'], [[4], 4, 'HT'], [[5], 4, 'N'], [[6], 4, 'N'], [[7], 4, 'HT'], [[8], 4, 'N'], [[9], 4, 'HT'], [[10], 4, 'N'], [[11], 4, 'HT'], [[12], 4, 'N'], [[13], 4, 'N'], [[14], 4, 'N'], [[15], 4, 'N'], [[16], 4, 'HT'], [[17], 4, 'HT'], [[18], 4, 'N'], [[19], 4, 'HM']]
# annotationsList of paragraph [[[0], 6, 'N'], [[1], 6, 'N']]
# annotationsList of paragraph [[[0], 7, 'HT']]
# annotationsList of paragraph [[[0], 10, 'HT']]
# annotationsList of paragraph [[[0], 14, 'HT']]
# annotationsList of paragraph [[[0], 16, 'HT'], [[1], 16, 'N']]
# annotationsList of paragraph [[[0], 18, 'HT']]
# annotationsList of paragraph [[[0], 21, 'HT']]
# annotationsList of paragraph [[[0], 24, 'HT']]
# annotationsList of paragraph [[[0], 25, 'HT']]
# annotationsList of paragraph [[[0], 26, 'HT']]
# Time to process file:  1.0664945980533957
# Memory use (78683, 336808)
# FILE:  22840223.csv
# Paragraphs to process 13
# annotationsList of paragraph [[[0], 0, 'HT'], [[1], 0, 'HT']]
# annotationsList of paragraph [[[0], 2, 'HT'], [[1], 2, 'N'], [[2], 2, 'HT'], [[3], 2, 'HT'], [[4], 2, 'HT'], [[5], 2, 'N']]
# annotationsList of paragraph [[[0], 6, 'HT']]
# Time to process file:  0.29501609364524484
# Memory use (44620, 314102)
# FILE:  54322005.csv
# Paragraphs to process 30
# annotationsList of paragraph [[[0], 0, 'HT'], [[1], 0, 'N'], [[2], 0, 'N'], [[3], 0, 'N'], [[4], 0, 'N']]
# annotationsList of paragraph [[[0], 2, 'HT'], [[1], 2, 'HT'], [[2], 2, 'HT'], [[3], 2, 'HT'], [[4], 2, 'HT'], [[5], 2, 'HT'], [[6], 2, 'HT']]
# annotationsList of paragraph [[[0], 5, 'HT'], [[1], 5, 'N'], [[2], 5, 'N'], [[3], 5, 'N']]
# annotationsList of paragraph [[[0], 7, 'N'], [[1], 7, 'N'], [[2], 7, 'N'], [[3], 7, 'N']]
# annotationsList of paragraph [[[0], 8, 'N'], [[1], 8, 'HT'], [[2], 8, 'N'], [[3], 8, 'N'], [[4], 8, 'N'], [[5], 8, 'N'], [[6], 8, 'N'], [[7], 8, 'N'], [[8], 8, 'HT'], [[9], 8, 'HT']]
# annotationsList of paragraph [[[0], 10, 'HT'], [[1], 10, 'N'], [[2], 10, 'N'], [[3], 10, 'HT'], [[4], 10, 'HT'], [[5], 10, 'HT'], [[6], 10, 'HT'], [[7], 10, 'N'], [[8], 10, 'HT']]
# annotationsList of paragraph [[[0], 13, 'HT']]
# Time to process file:  0.9870779691264033
# Memory use (73950, 340183)
# FILE:  56753343.csv
# Paragraphs to process 25
# annotationsList of paragraph [[[0], 0, 'HT'], [[1], 0, 'HT']]
# annotationsList of paragraph [[[0], 3, 'HM'], [[1], 3, 'N'], [[2], 3, 'HT'], [[3], 3, 'N'], [[4], 3, 'HT']]
# annotationsList of paragraph [[[0], 6, 'N']]
# annotationsList of paragraph [[[0], 8, 'N'], [[1], 8, 'HT'], [[2], 8, 'N']]
# annotationsList of paragraph [[[0], 9, 'HT'], [[1], 9, 'HT'], [[2], 9, 'HT'], [[3], 9, 'HT'], [[4], 9, 'N'], [[5], 9, 'HT'], [[6], 9, 'HT'], [[7], 9, 'HT'], [[8], 9, 'HT'], [[9], 9, 'N']]
# annotationsList of paragraph [[[0], 11, 'HT'], [[1], 11, 'HT'], [[2], 11, 'HT']]
# annotationsList of paragraph [[[0], 13, 'N'], [[1], 13, 'N'], [[2], 13, 'N'], [[3], 13, 'N']]
# annotationsList of paragraph [[[0], 15, 'HT'], [[1], 15, 'HT']]
# annotationsList of paragraph [[[0], 17, 'N'], [[1], 17, 'N']]
# annotationsList of paragraph [[[0], 19, 'HT'], [[1], 19, 'HT']]
# Time to process file:  0.9756915983743966
# Memory use (69511, 331345)
# FILE:  1471378.csv
# Paragraphs to process 24
# annotationsList of paragraph [[[0], 0, 'HT'], [[1], 0, 'HT']]
# annotationsList of paragraph [[[0], 2, 'N'], [[1], 2, 'N'], [[2], 2, 'N'], [[3], 2, 'N'], [[4], 2, 'N'], [[5], 2, 'N'], [[6], 2, 'N'], [[7], 2, 'N'], [[8], 2, 'N'], [[9], 2, 'N'], [[10], 2, 'HT'], [[11], 2, 'N']]
# annotationsList of paragraph [[[0], 4, 'HT'], [[1], 4, 'N'], [[2], 4, 'N'], [[3], 4, 'N'], [[4], 4, 'N'], [[5], 4, 'N'], [[6], 4, 'N'], [[7], 4, 'N'], [[8], 4, 'N'], [[9], 4, 'HT'], [[10], 4, 'N'], [[11], 4, 'N'], [[12], 4, 'HT'], [[13], 4, 'N'], [[14], 4, 'N'], [[15], 4, 'HT'], [[16], 4, 'HT'], [[17], 4, 'HT'], [[18], 4, 'N'], [[19], 4, 'N'], [[20], 4, 'HM'], [[21], 4, 'N'], [[22], 4, 'HT'], [[23], 4, 'N'], [[24], 4, 'HT'], [[25], 4, 'N'], [[26], 4, 'HT'], [[27], 4, 'N'], [[28], 4, 'N'], [[29], 4, 'N'], [[30], 4, 'HT'], [[31], 4, 'HT'], [[32], 4, 'N']]
# annotationsList of paragraph [[[0], 5, 'N'], [[1], 5, 'N'], [[2], 5, 'N'], [[3], 5, 'N'], [[4], 5, 'HT'], [[5], 5, 'N'], [[6], 5, 'N'], [[7], 5, 'N'], [[8], 5, 'HT'], [[9], 5, 'N'], [[10], 5, 'HT'], [[11], 5, 'HT'], [[12], 5, 'HT'], [[13], 5, 'HM'], [[14], 5, 'N'], [[15], 5, 'N'], [[16], 5, 'HT'], [[17], 5, 'HT']]
# annotationsList of paragraph [[[0], 7, 'HT'], [[1], 7, 'HT']]
# annotationsList of paragraph [[[0], 9, 'N'], [[1], 9, 'HT'], [[2], 9, 'N'], [[3], 9, 'N'], [[4], 9, 'HT'], [[5], 9, 'HT']]
# annotationsList of paragraph [[[0], 11, 'HT'], [[1, 0], 11, 'HM'], [[2], 11, 'HT'], [[3], 11, 'N'], [[4], 11, 'N'], [[5], 11, 'N'], [[6], 11, 'HT'], [[7, 6], 11, 'HM'], [[8], 11, 'HT'], [[9, 8], 11, 'HM'], [[10], 11, 'HT'], [[11], 11, 'HT'], [[12], 11, 'N'], [[13], 11, 'N'], [[14], 11, 'N'], [[15, 14], 11, 'HM'], [[16], 11, 'N'], [[17], 11, 'HT'], [[18], 11, 'HT'], [[19], 11, 'N'], [[20], 11, 'N'], [[21], 11, 'N'], [[22], 11, 'HT'], [[23, 22], 11, 'HM'], [[24], 11, 'HT']]
# annotationsList of paragraph [[[0], 12, 'N'], [[1], 12, 'HT']]
# Time to process file:  1.9371244618669152
# Memory use (104310, 375791)
# FILE:  33727377.csv
# Paragraphs to process 12
# annotationsList of paragraph [[[0], 0, 'N'], [[1], 0, 'N'], [[2], 0, 'HT']]
# annotationsList of paragraph [[[0], 2, 'N'], [[1], 2, 'N']]
# annotationsList of paragraph [[[0], 4, 'N'], [[1], 4, 'N'], [[2], 4, 'HT']]
# annotationsList of paragraph [[[0], 6, 'N'], [[1], 6, 'N'], [[2], 6, 'N']]
# Time to process file:  0.28600476076826453
# Memory use (51857, 315300)
# FILE:  13259839.csv
# Paragraphs to process 14
# annotationsList of paragraph [[[0], 0, 'HT'], [[1], 0, 'N']]
# annotationsList of paragraph [[[0], 3, 'HT'], [[1], 3, 'N'], [[2], 3, 'N']]
# annotationsList of paragraph [[[0], 4, 'N'], [[1], 4, 'N'], [[2], 4, 'N'], [[3], 4, 'N'], [[4], 4, 'N'], [[5], 4, 'HT']]
# annotationsList of paragraph [[[0], 5, 'N'], [[1], 5, 'HT'], [[2], 5, 'N'], [[3], 5, 'N']]
# annotationsList of paragraph [[[0], 6, 'N'], [[1], 6, 'N'], [[2], 6, 'N'], [[3], 6, 'N'], [[4], 6, 'N'], [[5], 6, 'N'], [[6], 6, 'HT'], [[7], 6, 'N'], [[8], 6, 'N']]
# Time to process file:  0.6265657003968954
# Memory use (56049, 321304)
# FILE:  4032265.csv
# Paragraphs to process 45
# annotationsList of paragraph [[[0], 0, 'HT'], [[1], 0, 'HT'], [[2], 0, 'N']]
# annotationsList of paragraph [[[0], 2, 'N'], [[1], 2, 'N'], [[2], 2, 'N']]
# annotationsList of paragraph [[[0], 3, 'N'], [[1], 3, 'N'], [[2], 3, 'N'], [[3], 3, 'HT'], [[4], 3, 'HT'], [[5], 3, 'N']]
# annotationsList of paragraph [[[0], 5, 'HT']]
# annotationsList of paragraph [[[0], 24, 'N'], [[1], 24, 'N']]
# annotationsList of paragraph [[[0], 25, 'N'], [[1], 25, 'HT']]
# Time to process file:  0.5317766689695418
# Memory use (62328, 326773)
# FILE:  11728784.csv
# Paragraphs to process 7
# annotationsList of paragraph [[[0], 0, 'HT']]
# annotationsList of paragraph [[[0], 2, 'HT'], [[1], 2, 'HT'], [[2], 2, 'HT'], [[3], 2, 'HT'], [[4], 2, 'N'], [[5], 2, 'N']]
# annotationsList of paragraph [[[0], 3, 'HT'], [[1], 3, 'N']]
# annotationsList of paragraph [[[0], 4, 'N']]
# Time to process file:  0.260618481785059
# Memory use (48501, 316346)
# FILE:  6008101.csv
# Paragraphs to process 22
# annotationsList of paragraph [[[0], 0, 'HT']]
# annotationsList of paragraph [[[0], 2, 'HT'], [[1], 2, 'N'], [[2], 2, 'N'], [[3], 2, 'HT'], [[4], 2, 'N']]
# annotationsList of paragraph [[[0], 4, 'HT'], [[1], 4, 'HT'], [[2], 4, 'N'], [[3], 4, 'N'], [[4], 4, 'N']]
# annotationsList of paragraph [[[0], 6, 'HT'], [[1], 6, 'HT'], [[2], 6, 'N']]
# annotationsList of paragraph [[[0], 7, 'HT'], [[1], 7, 'N']]
# annotationsList of paragraph [[[0], 9, 'HT'], [[1], 9, 'HT']]
# annotationsList of paragraph [[[0], 10, 'N']]
# annotationsList of paragraph [[[0], 11, 'N'], [[1], 11, 'N'], [[2], 11, 'HT']]
# annotationsList of paragraph [[[0], 13, 'HT']]
# annotationsList of paragraph [[[0], 15, 'HT'], [[1], 15, 'HT'], [[2], 15, 'N'], [[3], 15, 'N'], [[4], 15, 'N']]
# annotationsList of paragraph [[[0], 17, 'HT'], [[1], 17, 'N'], [[2], 17, 'HT'], [[3], 17, 'HT']]
# annotationsList of paragraph [[[0], 18, 'HT']]
# annotationsList of paragraph [[[0], 20, 'HT'], [[1], 20, 'N']]
# Time to process file:  0.9818334672600031
# Memory use (71445, 339997)
# FILE:  4412606.csv
# Paragraphs to process 25
# annotationsList of paragraph [[[0], 0, 'HT']]
# annotationsList of paragraph [[[0], 2, 'HT'], [[1], 2, 'HT'], [[2], 2, 'HT'], [[3], 2, 'N'], [[4], 2, 'HM'], [[5], 2, 'HT'], [[6], 2, 'HT'], [[7], 2, 'N'], [[8, 7], 2, 'HM'], [[9], 2, 'N'], [[10], 2, 'N'], [[11], 2, 'N'], [[12], 2, 'N'], [[13], 2, 'HT'], [[14], 2, 'N']]
# annotationsList of paragraph [[[0], 3, 'N'], [[1], 3, 'N'], [[2, 1], 3, 'HM'], [[3], 3, 'N'], [[4], 3, 'N']]
# annotationsList of paragraph [[[0], 6, 'N']]
# annotationsList of paragraph [[[0], 14, 'HT']]
# annotationsList of paragraph [[[0], 15, 'N']]
# annotationsList of paragraph [[[0], 18, 'HT']]
# Time to process file:  0.8120188028551638
# Memory use (68485, 321693)
# FILE:  46935921.csv
# Paragraphs to process 18
# annotationsList of paragraph [[[0], 0, 'HT']]
# annotationsList of paragraph [[[0], 2, 'N'], [[1], 2, 'N'], [[2], 2, 'HT'], [[3], 2, 'HT']]
# annotationsList of paragraph [[[0], 12, 'N'], [[1], 12, 'N']]
# Time to process file:  0.24519454687833786
# Memory use (46778, 314525)
# FILE:  4118252.csv
# Paragraphs to process 40
# annotationsList of paragraph [[[0], 0, 'HT'], [[1], 0, 'HT'], [[2], 0, 'HT'], [[3], 0, 'N']]
# annotationsList of paragraph [[[0], 1, 'HT'], [[1], 1, 'HT']]
# annotationsList of paragraph [[[0], 2, 'HT'], [[1], 2, 'HT']]
# annotationsList of paragraph [[[0], 4, 'HT'], [[1], 4, 'N'], [[2], 4, 'N'], [[3], 4, 'N'], [[4], 4, 'HM'], [[5], 4, 'N'], [[6], 4, 'N'], [[7], 4, 'N']]
# annotationsList of paragraph [[[0], 5, 'HT'], [[1], 5, 'N'], [[2], 5, 'N'], [[3], 5, 'N']]
# annotationsList of paragraph [[[0], 7, 'HT'], [[1], 7, 'N'], [[2], 7, 'N'], [[3], 7, 'N']]
# ...
# annotationsList of paragraph [[[0], 20, 'HT']]
# annotationsList of paragraph [[[0], 21, 'HT']]
# annotationsList of paragraph [[[0], 22, 'HT']]
# annotationsList of paragraph [[[0], 23, 'HT']]
# annotationsList of paragraph [[[0], 24, 'HT']]
# annotationsList of paragraph [[[0], 26, 'HT']]
# annotationsList of paragraph [[[0], 29, 'HT']]
# annotationsList of paragraph [[[0], 32, 'HT']]
# annotationsList of paragraph [[[0], 41, 'HT']]
# annotationsList of paragraph [[[0], 43, 'HT']]
# annotationsList of paragraph [[[0], 47, 'HT']]
# annotationsList of paragraph [[[0], 50, 'HT']]
# annotationsList of paragraph [[[0], 53, 'HT']]
# annotationsList of paragraph [[[0], 55, 'HT']]
# annotationsList of paragraph [[[0], 56, 'HT']]
# annotationsList of paragraph [[[0], 57, 'HT']]
# annotationsList of paragraph [[[0], 58, 'HT']]
# annotationsList of paragraph [[[0], 60, 'HT']]
# annotationsList of paragraph [[[0], 64, 'N'], [[1], 64, 'N']]
# annotationsList of paragraph [[[0], 65, 'HT']]
# annotationsList of paragraph [[[0], 66, 'HT']]
# annotationsList of paragraph [[[0], 67, 'N']]
# annotationsList of paragraph [[[0], 70, 'HT']]
# annotationsList of paragraph [[[0], 71, 'HT']]
# annotationsList of paragraph [[[0], 72, 'N']]
# Time to process file:  2.154938696883619
# Memory use (140123, 364406)
# FILE:  858790.csv
# Paragraphs to process 90
# annotationsList of paragraph [[[0], 0, 'HT'], [[1], 0, 'HT']]
# annotationsList of paragraph [[[0], 2, 'HT']]
# annotationsList of paragraph [[[0], 3, 'N'], [[1], 3, 'HT'], [[2], 3, 'N'], [[3], 3, 'N'], [[4], 3, 'N'], [[5], 3, 'N'], [[6], 3, 'N'], [[7], 3, 'HT'], [[8], 3, 'HT'], [[9], 3, 'HT'], [[10], 3, 'HT']]
# annotationsList of paragraph [[[0], 4, 'N'], [[1], 4, 'HT'], [[2], 4, 'HT']]
# annotationsList of paragraph [[[0], 5, 'HT']]
# annotationsList of paragraph [[[0], 6, 'N']]
# annotationsList of paragraph [[[0], 7, 'HT'], [[1], 7, 'N'], [[2], 7, 'HT'], [[3], 7, 'HT']]
# annotationsList of paragraph [[[0], 8, 'N'], [[1], 8, 'HT']]
# annotationsList of paragraph [[[0], 10, 'HT'], [[1], 10, 'N'], [[2], 10, 'N'], [[3], 10, 'N'], [[4], 10, 'N'], [[5], 10, 'N'], [[6], 10, 'N'], [[7], 10, 'HT'], [[8], 10, 'N'], [[9], 10, 'N'], [[10], 10, 'HT'], [[11], 10, 'HT'], [[12], 10, 'HT']]
# annotationsList of paragraph [[[0], 31, 'HT']]
# annotationsList of paragraph [[[0], 55, 'HT']]
# annotationsList of paragraph [[[0], 61, 'HT']]
# annotationsList of paragraph [[[0], 62, 'HT']]
# annotationsList of paragraph [[[0], 63, 'HT']]
# annotationsList of paragraph [[[0], 67, 'HT']]
# annotationsList of paragraph [[[0], 68, 'HT']]
# annotationsList of paragraph [[[0], 72, 'HT']]
# annotationsList of paragraph [[[0], 73, 'HT']]
# annotationsList of paragraph [[[0], 74, 'HT']]
# annotationsList of paragraph [[[0], 75, 'HT']]
# annotationsList of paragraph [[[0], 76, 'HT']]
# annotationsList of paragraph [[[0], 77, 'HT']]
# annotationsList of paragraph [[[0], 79, 'HT']]
# annotationsList of paragraph [[[0], 80, 'HT']]
# annotationsList of paragraph [[[0], 82, 'HT'], [[1], 82, 'HT'], [[2], 82, 'HT']]
# annotationsList of paragraph [[[0], 83, 'HT'], [[1], 83, 'HT'], [[2], 83, 'HT']]
# Time to process file:  1.7548436322249472
# Memory use (125779, 372907)
# FILE:  8942293.csv
# Paragraphs to process 16
# annotationsList of paragraph [[[0], 0, 'N']]
# annotationsList of paragraph [[[0], 3, 'HT'], [[1, 0], 3, 'HM'], [[2], 3, 'N'], [[3], 3, 'HT'], [[4], 3, 'HT'], [[5], 3, 'N'], [[6], 3, 'HT'], [[7, 6], 3, 'HM'], [[8], 3, 'HT'], [[9], 3, 'HT']]
# annotationsList of paragraph [[[0], 5, 'HT'], [[1], 5, 'N'], [[2], 5, 'N'], [[3], 5, 'N'], [[4], 5, 'N'], [[5], 5, 'N']]
# annotationsList of paragraph [[[0], 10, 'N'], [[1], 10, 'N']]
# Time to process file:  0.5275683510117233
# Memory use (59323, 323358)
# FILE:  50021491.csv
# Paragraphs to process 112
# annotationsList of paragraph [[[0], 0, 'HT'], [[1], 0, 'N'], [[2], 0, 'HT'], [[3], 0, 'HT'], [[4, 3], 0, 'HM']]
# annotationsList of paragraph [[[0], 2, 'N'], [[1], 2, 'N'], [[2], 2, 'N'], [[3], 2, 'N'], [[4], 2, 'N'], [[5], 2, 'N'], [[6], 2, 'HT'], [[7], 2, 'N'], [[8], 2, 'HT'], [[9], 2, 'N'], [[10], 2, 'HT'], [[11], 2, 'N'], [[12], 2, 'HT'], [[13], 2, 'N'], [[14], 2, 'HT'], [[15], 2, 'N'], [[16], 2, 'N'], [[17], 2, 'N']]
# annotationsList of paragraph [[[0], 5, 'N'], [[1], 5, 'N'], [[2], 5, 'N']]
# annotationsList of paragraph [[[0], 6, 'N'], [[1], 6, 'HT']]
# annotationsList of paragraph [[[0], 7, 'N'], [[1], 7, 'N'], [[2], 7, 'N']]
# annotationsList of paragraph [[[0], 8, 'N'], [[1], 8, 'N']]
# annotationsList of paragraph [[[0], 9, 'HT']]
# annotationsList of paragraph [[[0], 10, 'HT']]
# annotationsList of paragraph [[[0], 11, 'HT']]
# annotationsList of paragraph [[[0], 12, 'HT']]
# annotationsList of paragraph [[[0], 13, 'HT']]
# annotationsList of paragraph [[[0], 14, 'HT']]
# annotationsList of paragraph [[[0], 15, 'HT']]
# annotationsList of paragraph [[[0], 16, 'HT']]
# annotationsList of paragraph [[[0], 17, 'HT']]
# annotationsList of paragraph [[[0], 18, 'HT']]
# annotationsList of paragraph [[[0], 19, 'HT']]
# annotationsList of paragraph [[[0], 20, 'N'], [[1], 20, 'HT']]
# annotationsList of paragraph [[[0], 21, 'HT']]
# annotationsList of paragraph [[[0], 22, 'N'], [[1], 22, 'N']]
# annotationsList of paragraph [[[0], 23, 'N'], [[1], 23, 'N']]
# annotationsList of paragraph [[[0], 24, 'N'], [[1], 24, 'N']]
# annotationsList of paragraph [[[0], 25, 'N'], [[1], 25, 'N']]
# annotationsList of paragraph [[[0], 26, 'N'], [[1], 26, 'HT']]
# annotationsList of paragraph [[[0], 27, 'N'], [[1], 27, 'N']]
# annotationsList of paragraph [[[0], 28, 'N'], [[1], 28, 'HT']]
# annotationsList of paragraph [[[0], 29, 'N'], [[1], 29, 'N']]
# annotationsList of paragraph [[[0], 30, 'N'], [[1], 30, 'N']]
# annotationsList of paragraph [[[0], 31, 'N'], [[1], 31, 'N']]
# annotationsList of paragraph [[[0], 32, 'N'], [[1], 32, 'N']]
# annotationsList of paragraph [[[0], 33, 'N'], [[1], 33, 'N']]
# annotationsList of paragraph [[[0], 34, 'N'], [[1], 34, 'N']]
# annotationsList of paragraph [[[0], 35, 'N'], [[1], 35, 'N']]
# annotationsList of paragraph [[[0], 36, 'N'], [[1], 36, 'N'], [[2], 36, 'N']]
# annotationsList of paragraph [[[0], 37, 'N'], [[1], 37, 'N']]
# annotationsList of paragraph [[[0], 38, 'N'], [[1], 38, 'N']]
# annotationsList of paragraph [[[0], 39, 'N'], [[1], 39, 'N']]
# annotationsList of paragraph [[[0], 40, 'N'], [[1], 40, 'N']]
# annotationsList of paragraph [[[0], 41, 'N'], [[1], 41, 'N']]
# annotationsList of paragraph [[[0], 42, 'N'], [[1], 42, 'N']]
# annotationsList of paragraph [[[0], 43, 'N'], [[1], 43, 'N']]
# annotationsList of paragraph [[[0], 44, 'N'], [[1], 44, 'N']]
# annotationsList of paragraph [[[0], 45, 'N'], [[1], 45, 'HT']]
# annotationsList of paragraph [[[0], 46, 'N'], [[1], 46, 'N']]
# annotationsList of paragraph [[[0], 47, 'N'], [[1], 47, 'N']]
# annotationsList of paragraph [[[0], 48, 'N'], [[1], 48, 'N']]
# annotationsList of paragraph [[[0], 49, 'N'], [[1], 49, 'N']]
# annotationsList of paragraph [[[0], 50, 'N'], [[1], 50, 'N']]
# annotationsList of paragraph [[[0], 51, 'N'], [[1], 51, 'N']]
# annotationsList of paragraph [[[0], 52, 'N'], [[1], 52, 'N']]
# annotationsList of paragraph [[[0], 53, 'N'], [[1], 53, 'N']]
# annotationsList of paragraph [[[0], 54, 'HT']]
# annotationsList of paragraph [[[0], 55, 'N'], [[1], 55, 'HT']]
# annotationsList of paragraph [[[0], 56, 'N'], [[1], 56, 'N']]
# annotationsList of paragraph [[[0], 57, 'N'], [[1], 57, 'N']]
# annotationsList of paragraph [[[0], 58, 'N'], [[1], 58, 'N']]
# annotationsList of paragraph [[[0], 59, 'N'], [[1], 59, 'N']]
# annotationsList of paragraph [[[0], 60, 'N'], [[1], 60, 'N']]
# annotationsList of paragraph [[[0], 61, 'HT']]
# annotationsList of paragraph [[[0], 62, 'HT']]
# annotationsList of paragraph [[[0], 63, 'N'], [[1], 63, 'N']]
# annotationsList of paragraph [[[0], 64, 'N'], [[1], 64, 'N']]
# annotationsList of paragraph [[[0], 65, 'N'], [[1], 65, 'N']]
# annotationsList of paragraph [[[0], 66, 'N'], [[1], 66, 'N']]
# annotationsList of paragraph [[[0], 67, 'N'], [[1], 67, 'HT']]
# annotationsList of paragraph [[[0], 68, 'N'], [[1], 68, 'N']]
# annotationsList of paragraph [[[0], 69, 'N'], [[1], 69, 'N']]
# annotationsList of paragraph [[[0], 70, 'N'], [[1], 70, 'N']]
# annotationsList of paragraph [[[0], 71, 'N'], [[1], 71, 'N']]
# annotationsList of paragraph [[[0], 72, 'N'], [[1], 72, 'N']]
# annotationsList of paragraph [[[0], 73, 'N'], [[1], 73, 'HT']]
# annotationsList of paragraph [[[0], 74, 'N'], [[1], 74, 'N']]
# annotationsList of paragraph [[[0], 75, 'N'], [[1], 75, 'N']]
# annotationsList of paragraph [[[0], 76, 'N'], [[1], 76, 'N']]
# annotationsList of paragraph [[[0], 77, 'N'], [[1], 77, 'N']]
# annotationsList of paragraph [[[0], 78, 'N'], [[1], 78, 'N']]
# annotationsList of paragraph [[[0], 79, 'N'], [[1], 79, 'N']]
# annotationsList of paragraph [[[0], 80, 'N'], [[1], 80, 'N']]
# annotationsList of paragraph [[[0], 81, 'N'], [[1], 81, 'N']]
# annotationsList of paragraph [[[0], 82, 'N'], [[1], 82, 'N']]
# annotationsList of paragraph [[[0], 83, 'N'], [[1], 83, 'N']]
# annotationsList of paragraph [[[0], 84, 'N'], [[1], 84, 'N']]
# annotationsList of paragraph [[[0], 85, 'N'], [[1], 85, 'N']]
# annotationsList of paragraph [[[0], 87, 'HT']]
# annotationsList of paragraph [[[0], 88, 'HT']]
# annotationsList of paragraph [[[0], 89, 'HT']]
# annotationsList of paragraph [[[0], 90, 'HT']]
# annotationsList of paragraph [[[0], 91, 'N'], [[1], 91, 'N']]
# annotationsList of paragraph [[[0], 92, 'N'], [[1], 92, 'N']]
# annotationsList of paragraph [[[0], 93, 'N'], [[1], 93, 'HT']]
# annotationsList of paragraph [[[0], 94, 'N'], [[1], 94, 'HT']]
# annotationsList of paragraph [[[0], 95, 'N'], [[1], 95, 'N']]
# annotationsList of paragraph [[[0], 96, 'N'], [[1], 96, 'N']]
# annotationsList of paragraph [[[0], 97, 'N'], [[1], 97, 'N']]
# annotationsList of paragraph [[[0], 98, 'N'], [[1], 98, 'N']]
# annotationsList of paragraph [[[0], 99, 'N'], [[1], 99, 'HT']]
# annotationsList of paragraph [[[0], 100, 'N'], [[1], 100, 'N']]
# annotationsList of paragraph [[[0], 101, 'N'], [[1], 101, 'N']]
# annotationsList of paragraph [[[0], 102, 'HT']]
# annotationsList of paragraph [[[0], 103, 'HT']]
# annotationsList of paragraph [[[0], 104, 'HT']]
# annotationsList of paragraph [[[0], 105, 'N'], [[1], 105, 'N']]
# annotationsList of paragraph [[[0], 106, 'HT']]
# annotationsList of paragraph [[[0], 107, 'HT'], [[1], 107, 'N']]
# annotationsList of paragraph [[[0], 108, 'N'], [[1], 108, 'N']]
# annotationsList of paragraph [[[0], 110, 'N'], [[1], 110, 'N']]
# Time to process file:  5.944810182787478
# Memory use (188155, 386256)
# FILE:  7961205.csv
# Paragraphs to process 19
# annotationsList of paragraph [[[0], 0, 'HT']]
# annotationsList of paragraph [[[0], 2, 'N'], [[1], 2, 'N'], [[2], 2, 'N'], [[3], 2, 'HT'], [[4], 2, 'HT']]
# annotationsList of paragraph [[[0], 3, 'N'], [[1], 3, 'N']]
# annotationsList of paragraph [[[0], 5, 'HT'], [[1], 5, 'N'], [[2], 5, 'N']]
# annotationsList of paragraph [[[0], 7, 'HT'], [[1], 7, 'HT'], [[2], 7, 'HT'], [[3], 7, 'HT'], [[4], 7, 'HT'], [[5], 7, 'HT']]
# annotationsList of paragraph [[[0], 9, 'HT'], [[1], 9, 'N']]
# annotationsList of paragraph [[[0], 10, 'HT'], [[1], 10, 'N']]
# annotationsList of paragraph [[[0], 12, 'HT'], [[1], 12, 'HT'], [[2], 12, 'HT'], [[3], 12, 'HT'], [[4], 12, 'HM'], [[5, 4], 12, 'HM'], [[6], 12, 'N']]
# annotationsList of paragraph [[[0], 14, 'N'], [[1], 14, 'N'], [[2], 14, 'HT'], [[3], 14, 'HT']]
# Time to process file:  1.016759485937655
# Memory use (71333, 334389)
# FILE:  2203320.csv
# Paragraphs to process 12
# annotationsList of paragraph [[[0], 0, 'HT'], [[1], 0, 'HT']]
# annotationsList of paragraph [[[0], 2, 'N'], [[1], 2, 'N'], [[2], 2, 'N']]
# annotationsList of paragraph [[[0], 3, 'N'], [[1], 3, 'N'], [[2], 3, 'N']]
# annotationsList of paragraph [[[0], 4, 'HT'], [[1], 4, 'HT']]
# annotationsList of paragraph [[[0], 5, 'HT'], [[1], 5, 'N']]
# Time to process file:  0.41436469182372093
# Memory use (48972, 310318)
# FILE:  45597776.csv
# Paragraphs to process 13
# annotationsList of paragraph [[[0], 0, 'HT'], [[1], 0, 'HT'], [[2], 0, 'HT'], [[3], 0, 'HT']]
# annotationsList of paragraph [[[0], 2, 'HT'], [[1], 2, 'N']]
# annotationsList of paragraph [[[0], 4, 'N'], [[1], 4, 'HT'], [[2], 4, 'N']]
# annotationsList of paragraph [[[0], 5, 'HT'], [[1], 5, 'HT'], [[2], 5, 'HT']]
# annotationsList of paragraph [[[0], 7, 'HT'], [[1], 7, 'HT'], [[2], 7, 'HT']]
# annotationsList of paragraph [[[0], 11, 'N']]
# Time to process file:  0.45836623292416334
# Memory use (52296, 320230)
# FILE:  1860229.csv
# Paragraphs to process 57
# annotationsList of paragraph [[[0], 0, 'HT'], [[1], 0, 'N']]
# annotationsList of paragraph [[[0], 3, 'HT'], [[1], 3, 'N'], [[2], 3, 'HT'], [[3], 3, 'N'], [[4], 3, 'HT']]
# annotationsList of paragraph [[[0], 5, 'HT'], [[1], 5, 'N'], [[2, 1], 5, 'HM']]
# annotationsList of paragraph [[[0], 6, 'HM']]
# annotationsList of paragraph [[[0], 7, 'HT'], [[1], 7, 'N']]
# annotationsList of paragraph [[[0], 8, 'HT'], [[1], 8, 'N'], [[2], 8, 'N']]
# annotationsList of paragraph [[[0], 9, 'HT']]
# annotationsList of paragraph [[[0], 10, 'HT']]
# annotationsList of paragraph [[[0], 11, 'HT']]
# annotationsList of paragraph [[[0], 13, 'N'], [[1], 13, 'N'], [[2], 13, 'N']]
# annotationsList of paragraph [[[0], 17, 'HT']]
# annotationsList of paragraph [[[0], 25, 'HT']]
# annotationsList of paragraph [[[0], 27, 'HT']]
# annotationsList of paragraph [[[0], 30, 'HT']]
# annotationsList of paragraph [[[0], 42, 'HT']]
# annotationsList of paragraph [[[0], 51, 'N']]
# Time to process file:  0.9476463650353253
# Memory use (76741, 329140)
# FILE:  24439193.csv
# Paragraphs to process 5
# annotationsList of paragraph [[[0], 0, 'HT']]
# annotationsList of paragraph [[[0], 1, 'HT'], [[1], 1, 'N'], [[2], 1, 'N'], [[3], 1, 'HT'], [[4], 1, 'N'], [[5], 1, 'HT'], [[6], 1, 'N']]
# Time to process file:  0.21707814931869507
# Memory use (38917, 312059)
# FILE:  13265949.csv
# Paragraphs to process 6
# annotationsList of paragraph [[[0], 0, 'HT']]
# annotationsList of paragraph [[[0], 1, 'N'], [[1], 1, 'N']]
# annotationsList of paragraph [[[0], 2, 'HT'], [[1], 2, 'N'], [[2], 2, 'N'], [[3], 2, 'N']]
# Time to process file:  0.24315085308626294
# Memory use (44724, 312028)
# FILE:  2850174.csv
# Paragraphs to process 19
# annotationsList of paragraph [[[0], 0, 'HT'], [[1], 0, 'HT'], [[2], 0, 'HT']]
# annotationsList of paragraph [[[0], 3, 'HT'], [[1], 3, 'N'], [[2], 3, 'N'], [[3], 3, 'HT'], [[4], 3, 'N']]
# annotationsList of paragraph [[[0], 5, 'HT'], [[1], 5, 'HT'], [[2], 5, 'N'], [[3], 5, 'HT'], [[4], 5, 'N'], [[5], 5, 'N']]
# annotationsList of paragraph [[[0], 7, 'HT'], [[1], 7, 'N'], [[2], 7, 'N'], [[3], 7, 'N'], [[4], 7, 'HT'], [[5], 7, 'HT'], [[6], 7, 'HT'], [[7], 7, 'N'], [[8], 7, 'N'], [[9], 7, 'N'], [[10], 7, 'N']]
# annotationsList of paragraph [[[0], 9, 'N'], [[1], 9, 'N'], [[2], 9, 'HT'], [[3], 9, 'HT'], [[4], 9, 'N']]
# annotationsList of paragraph [[[0], 14, 'N']]
# Time to process file:  0.8498934647068381
# Memory use (67082, 332942)
# FILE:  3003683.csv
# Paragraphs to process 52
# annotationsList of paragraph [[[0], 0, 'HT'], [[1], 0, 'N'], [[2], 0, 'N']]
# annotationsList of paragraph [[[0], 1, 'HT'], [[1], 1, 'HT'], [[2], 1, 'N'], [[3], 1, 'N'], [[4], 1, 'N']]
# annotationsList of paragraph [[[0], 2, 'HT'], [[1], 2, 'HT']]
# annotationsList of paragraph [[[0], 3, 'N'], [[1], 3, 'N'], [[2], 3, 'N']]
# annotationsList of paragraph [[[0], 6, 'HM'], [[1, 0], 6, 'HM'], [[2], 6, 'HT'], [[3], 6, 'HT'], [[4], 6, 'N'], [[5], 6, 'N'], [[6], 6, 'N'], [[7], 6, 'HM'], [[8], 6, 'N'], [[9], 6, 'HT'], [[10], 6, 'N'], [[11], 6, 'N'], [[12], 6, 'HT'], [[13], 6, 'HT'], [[14], 6, 'HT'], [[15], 6, 'N'], [[16], 6, 'N'], [[17], 6, 'HT'], [[18], 6, 'N'], [[19], 6, 'N'], [[20], 6, 'HT'], [[21], 6, 'N'], [[22], 6, 'N']]
# annotationsList of paragraph [[[0], 7, 'N'], [[1], 7, 'N'], [[2], 7, 'N']]
# annotationsList of paragraph [[[0], 8, 'HT'], [[1], 8, 'N'], [[2], 8, 'N'], [[3], 8, 'N'], [[4], 8, 'N'], [[5], 8, 'N'], [[6], 8, 'N'], [[7], 8, 'HT'], [[8], 8, 'HT'], [[9], 8, 'N'], [[10], 8, 'N'], [[11], 8, 'HT'], [[12], 8, 'HM'], [[13], 8, 'N'], [[14], 8, 'N'], [[15], 8, 'N'], [[16], 8, 'N'], [[17], 8, 'N'], [[18], 8, 'N'], [[19], 8, 'HT'], [[20], 8, 'N'], [[21], 8, 'HT'], [[22], 8, 'HT'], [[23], 8, 'N'], [[24], 8, 'N'], [[25], 8, 'N']]

# %% [markdown]
# # Add information about the sentence, piece of text as evidence

# %%
# Read files in batches
# for chunk in pd.read_csv('totalTest.csv', chunksize=10):
for chunk in pd.read_csv('toAnnotatePart6.csv', chunksize=10):
    df_file_name = pd.DataFrame()
    df_file_name['file_name'] = chunk['file_name']
    # for each file
    entities_df = pd.DataFrame()
    for file_name_item in df_file_name.itertuples():
        print("FILE: ",file_name_item.file_name) # FILE name using the DBPedia ID
        tracemalloc.start()
        # READ Files
        # startRead = timer()
        try:
            # Read Annotation file
            meetupsAnnotations_df = pd.read_csv('meetupsAnnotations/'+str(file_name_item.file_name))
        
            if len(meetupsAnnotations_df) == 0:
                print("No annotations")
                continue

            # The process is sentence by sentence. Read indexedSentences/
            sentences_df = pd.read_csv('indexedSentences/'+file_name_item.file_name, usecols=['sentenceIndex','paragraphIndex','sentences'])
            
            text_list = []
            for meetup in meetupsAnnotations_df.itertuples():
                if meetup.annotation == 'N':
                    text = ''
                else:
                    if pd.isnull(meetup.before):
                        sent_df = sentences_df.loc[(sentences_df.paragraphIndex == int(meetup.paragraphIndex))&(sentences_df.sentenceIndex == int(meetup.after))].copy()
                        text = str(sent_df.iloc[0]['sentences'])
                    else:
                        sent_df = sentences_df[(sentences_df['paragraphIndex'] == meetup.paragraphIndex) & (sentences_df['sentenceIndex'].isin([int(meetup.before), int(meetup.after)]))].copy()
                        text = str(sent_df.iloc[0]['sentences']) + " " + str(sent_df.iloc[1]['sentences'])
                text_list.append(text)
            
            meetupsAnnotations_df['sentences'] = text_list
            meetupsAnnotations_df.to_csv('meetupsAnnotations/'+file_name_item.file_name,index=False)    
        except Exception as e:
            # print("Identifier: ",str(meetup.after)," ",str(meetup.paragraphIndex))
            print(e, file=sys.stdout)
                
        print("Memory use", tracemalloc.get_traced_memory())
        tracemalloc.stop()
# Out:
# FILE:  1965784.csv
# Memory use (33020, 308951)
# FILE:  32264675.csv
# Memory use (35178, 300195)
# FILE:  2934315.csv
# Memory use (70830, 316713)
# FILE:  28312254.csv
# Memory use (25611, 297483)
# FILE:  8040240.csv
# Memory use (31236, 299878)
# FILE:  22459257.csv
# Memory use (28255, 296419)
# FILE:  3362986.csv
# Memory use (34120, 305685)
# FILE:  19474675.csv
# Memory use (29231, 301854)
# FILE:  51596657.csv
# Memory use (36999, 310626)
# FILE:  484364.csv
# Memory use (62636, 326829)
# FILE:  4241227.csv
# Memory use (43455, 311304)
# FILE:  46385848.csv
# Memory use (28328, 297378)
# FILE:  52279001.csv
# Memory use (34932, 304508)
# FILE:  8064528.csv
# Memory use (25247, 298729)
# FILE:  5143989.csv
# Memory use (39861, 306644)
# FILE:  15182641.csv
# Memory use (69903, 319639)
# FILE:  6975970.csv
# Memory use (79195, 347751)
# FILE:  1949333.csv
# Memory use (64298, 326679)
# FILE:  2470630.csv
# Memory use (58752, 317039)
# FILE:  18713679.csv
# Memory use (24503, 298673)
# FILE:  23394028.csv
# Memory use (36127, 310438)
# FILE:  1862380.csv
# Memory use (40517, 309053)
# FILE:  14565496.csv
# Memory use (43897, 305655)
# FILE:  21438871.csv
# Memory use (31122, 303564)
# FILE:  43618783.csv
# Memory use (35269, 299229)
# FILE:  37029067.csv
# Memory use (59985, 334079)
# FILE:  8623467.csv
# Memory use (35935, 305948)
# FILE:  65518206.csv
# Memory use (31443, 302437)
# FILE:  80664.csv
# Memory use (68997, 330722)
# FILE:  36018341.csv
# Memory use (33994, 302974)
# FILE:  37882107.csv
# Memory use (57769, 329791)
# FILE:  27043626.csv
# Memory use (31751, 305615)
# FILE:  2887963.csv
# Memory use (33408, 301149)
# FILE:  34546475.csv
# Memory use (30763, 305822)
# FILE:  4636486.csv
# Memory use (61234, 317468)
# FILE:  9342621.csv
# Memory use (26839, 295974)
# FILE:  757045.csv
# Memory use (43850, 309831)
# FILE:  22840223.csv
# Memory use (29430, 296514)
# FILE:  54322005.csv
# Memory use (43511, 317801)
# FILE:  56753343.csv
# Memory use (40877, 308934)
# FILE:  1471378.csv
# Memory use (68185, 331731)
# FILE:  33727377.csv
# Memory use (24893, 297384)
# FILE:  13259839.csv
# Memory use (29593, 304398)
# FILE:  4032265.csv
# Memory use (32206, 309109)
# FILE:  11728784.csv
# Memory use (26051, 299198)
# FILE:  6008101.csv
# Memory use (42049, 310010)
# FILE:  4412606.csv
# Memory use (34253, 299801)
# FILE:  46935921.csv
# Memory use (25050, 297183)
# FILE:  4118252.csv
# Memory use (48428, 315320)
# FILE:  2568814.csv
# Memory use (23986, 295282)
# FILE:  2742461.csv
# Memory use (32741, 297944)
# FILE:  39989000.csv
# Memory use (26153, 303831)
# FILE:  2177859.csv
# Memory use (31536, 299570)
# FILE:  67794551.csv
# Memory use (35400, 308659)
# FILE:  27539399.csv
# Memory use (47082, 316930)
# FILE:  33599262.csv
# Memory use (33777, 303507)
# FILE:  241976.csv
# Memory use (47558, 318086)
# FILE:  20614582.csv
# Memory use (90619, 363719)
# FILE:  3639488.csv
# Memory use (34125, 306424)
# FILE:  27672035.csv
# Memory use (40824, 309451)
# FILE:  45303952.csv
# Memory use (24188, 298978)
# FILE:  68265086.csv
# Memory use (41533, 321545)
# FILE:  41025333.csv
# Memory use (43566, 312399)
# FILE:  33429767.csv
# Memory use (20928, 294472)
# FILE:  1428081.csv
# Memory use (28867, 298603)
# FILE:  944408.csv
# Memory use (56102, 327973)
# FILE:  38206522.csv
# Memory use (43189, 310380)
# FILE:  57010402.csv
# Memory use (23425, 296817)
# FILE:  45719525.csv
# Memory use (36172, 310550)
# FILE:  26179378.csv
# Memory use (28128, 299328)
# FILE:  144108.csv
# Memory use (47214, 305441)
# FILE:  7074351.csv
# Memory use (35529, 300786)
# FILE:  46330765.csv
# Memory use (35129, 307837)
# FILE:  58687892.csv
# Memory use (51753, 325921)
# FILE:  28527621.csv
# Memory use (48896, 313402)
# FILE:  25184131.csv
# Memory use (42000, 311052)
# FILE:  22911033.csv
# Memory use (21135, 296616)
# FILE:  14323839.csv
# Memory use (47434, 312115)
# FILE:  47122240.csv
# Memory use (35653, 303924)
# FILE:  49408567.csv
# Memory use (24628, 298278)
# FILE:  717461.csv
# Memory use (59596, 325088)
# FILE:  33163.csv
# Memory use (158609, 423492)
# FILE:  4090380.csv
# Memory use (58249, 325342)
# FILE:  43430636.csv
# Memory use (64184, 336272)
# FILE:  47361554.csv
# Memory use (31856, 298669)
# FILE:  3675696.csv
# Memory use (24187, 295738)
# FILE:  3644176.csv
# Memory use (57509, 321685)
# FILE:  17466551.csv
# Memory use (25876, 297618)
# FILE:  62600349.csv
# Memory use (32642, 303010)
# FILE:  417943.csv
# Memory use (65095, 335704)
# FILE:  18465479.csv
# Memory use (35206, 309425)
# FILE:  50189380.csv
# Memory use (28633, 297776)
# FILE:  24743081.csv
# Memory use (37884, 311120)
# FILE:  3398287.csv
# Memory use (40039, 312303)
# FILE:  5364241.csv
# Memory use (40976, 305642)
# FILE:  23985242.csv
# Memory use (31821, 298107)
# FILE:  39157783.csv
# Memory use (28110, 297781)
# FILE:  15686516.csv
# Memory use (27271, 298715)
# FILE:  12790770.csv
# Memory use (38791, 303482)
# FILE:  14744253.csv
# Memory use (26707, 300578)
# FILE:  43030609.csv
# Memory use (50438, 317637)
# FILE:  5361721.csv
# Memory use (92627, 349386)
# FILE:  58127026.csv
# Memory use (34976, 299105)
# FILE:  16792359.csv
# Memory use (32486, 303569)
# FILE:  7993785.csv
# Memory use (30450, 300387)
# FILE:  156548.csv
# Memory use (64895, 335196)
# FILE:  502049.csv
# Memory use (131773, 372408)
# FILE:  2199503.csv
# Memory use (73572, 339323)
# FILE:  30852436.csv
# Memory use (33099, 304582)
# FILE:  31809036.csv
# Memory use (44828, 314003)
# FILE:  44534569.csv
# Memory use (21886, 297799)
# FILE:  7865718.csv
# Memory use (26351, 303175)
# FILE:  6872652.csv
# Memory use (29509, 300688)
# FILE:  35602950.csv
# Memory use (29381, 300282)
# FILE:  204111.csv
# Memory use (34021, 308911)
# FILE:  27870486.csv
# Memory use (23189, 296558)
# FILE:  1105138.csv
# Memory use (40087, 313389)
# FILE:  5492798.csv
# Memory use (29808, 298014)
# FILE:  56787494.csv
# Memory use (27893, 296742)
# FILE:  4146500.csv
# Memory use (43673, 322475)
# FILE:  4845677.csv
# Memory use (22901, 294596)
# FILE:  1629703.csv
# Memory use (63658, 332436)
# FILE:  3380438.csv
# Memory use (33465, 304125)
# FILE:  51793446.csv
# Memory use (32673, 309741)
# FILE:  3204102.csv
# Memory use (54489, 328858)
# FILE:  30292257.csv
# Memory use (42109, 307672)
# FILE:  18864208.csv
# Memory use (35264, 299514)
# FILE:  12331112.csv
# Memory use (39664, 304061)
# FILE:  2038949.csv
# Memory use (55723, 317406)
# FILE:  52812700.csv
# Memory use (29622, 297694)
# FILE:  41387440.csv
# Memory use (25486, 295882)
# FILE:  42284587.csv
# Memory use (26791, 304389)
# FILE:  1260006.csv
# Memory use (24285, 298129)
# FILE:  25115916.csv
# Memory use (27155, 296694)
# FILE:  2990705.csv
# Memory use (24209, 295535)
# FILE:  529384.csv
# Memory use (28033, 299304)
# FILE:  31560875.csv
# Memory use (22467, 294924)
# FILE:  21126067.csv
# Memory use (21034, 295639)
# FILE:  13030.csv
# Memory use (54487, 321195)
# FILE:  2335917.csv
# Memory use (39415, 310593)
# FILE:  1832369.csv
# Memory use (47771, 324073)
# FILE:  2362546.csv
# Memory use (52344, 330479)
# FILE:  7957737.csv
# Memory use (40688, 310094)
# FILE:  49339406.csv
# Memory use (30619, 298197)
# FILE:  2964420.csv
# Memory use (35036, 304268)
# FILE:  28293180.csv
# Memory use (29854, 303877)
# FILE:  147084.csv
# Memory use (56399, 324590)
# FILE:  13405210.csv
# Memory use (25632, 298209)
# FILE:  43272496.csv
# Memory use (105155, 382837)
# FILE:  50341616.csv
# Memory use (21433, 295113)
# FILE:  533046.csv
# Memory use (67275, 334327)
# FILE:  273476.csv
# Memory use (112946, 372187)
# FILE:  26478717.csv
# Memory use (21489, 294697)
# FILE:  1045155.csv
# Memory use (79498, 345125)
# FILE:  44746211.csv
# Memory use (38515, 297798)
# FILE:  18220967.csv
# Memory use (27507, 296546)
# FILE:  9300263.csv
# Memory use (22219, 294438)
# FILE:  2098670.csv
# Memory use (41238, 311687)
# FILE:  3661796.csv
# Memory use (46343, 323075)
# FILE:  3145813.csv
# Memory use (47297, 305799)
# FILE:  18015305.csv
# Memory use (39213, 308474)
# FILE:  43339821.csv
# Memory use (23702, 295751)
# FILE:  1817766.csv
# Memory use (76709, 340201)
# FILE:  57636412.csv
# Memory use (36487, 310532)
# FILE:  3302825.csv
# Memory use (69704, 338090)
# FILE:  3054621.csv
# Memory use (41500, 311024)
# FILE:  5182768.csv
# Memory use (32094, 302095)
# FILE:  27143565.csv
# Memory use (65114, 330753)
# FILE:  1139039.csv
# Memory use (106571, 370974)
# FILE:  15570857.csv
# Memory use (43008, 312268)
# FILE:  4271961.csv
# Memory use (37383, 311561)
# FILE:  22617457.csv
# Memory use (22530, 297525)
# FILE:  20292040.csv
# Memory use (24829, 301492)
# FILE:  4028385.csv
# Memory use (50529, 319481)
# FILE:  2007372.csv
# Memory use (33280, 298648)
# FILE:  2822871.csv
# Memory use (38901, 318722)
# FILE:  53188795.csv
# Memory use (28192, 295886)
# FILE:  3928641.csv
# Memory use (48138, 317271)
# FILE:  33305210.csv
# Memory use (21006, 295956)
# FILE:  17417485.csv
# Memory use (51379, 331032)
# FILE:  1058169.csv
# Memory use (76447, 345230)
# FILE:  22670909.csv
# Memory use (37018, 310065)
# FILE:  4566780.csv
# Memory use (60675, 334840)
# FILE:  1725814.csv
# Memory use (96866, 362527)
# FILE:  12598737.csv
# Memory use (58327, 319803)
# FILE:  35885055.csv
# Memory use (53484, 318754)
# FILE:  39753.csv
# Memory use (77729, 344197)
# FILE:  3492026.csv
# Memory use (24193, 295832)
# FILE:  51660074.csv
# Memory use (46429, 321217)
# FILE:  16273.csv
# Memory use (272597, 602055)
# FILE:  60626.csv
# Memory use (31450, 301446)
# FILE:  26311302.csv
# Memory use (46730, 312476)
# FILE:  42581561.csv
# Memory use (122569, 385405)
# FILE:  2214986.csv
# Memory use (58601, 333282)
# FILE:  1241409.csv
# Memory use (98299, 347984)
# FILE:  20023357.csv
# Memory use (27980, 298267)
# FILE:  31543667.csv
# Memory use (26340, 302025)
# FILE:  40411160.csv
# Memory use (34476, 306233)
# FILE:  5840192.csv
# Memory use (21499, 294584)
# FILE:  46597673.csv
# Memory use (38475, 310412)
# FILE:  17697652.csv
# Memory use (34025, 304697)
# FILE:  5966393.csv
# Memory use (31677, 304483)
# FILE:  35893883.csv
# Memory use (50355, 320543)
# FILE:  11149541.csv
# Memory use (82970, 337835)
# FILE:  4697496.csv
# Memory use (63316, 334869)
# FILE:  42575595.csv
# Memory use (25777, 297190)
# FILE:  3747287.csv
# Memory use (38739, 301085)
# FILE:  34915104.csv
# Memory use (38404, 308482)
# FILE:  38303689.csv
# Memory use (31240, 298335)
# FILE:  63477250.csv
# Memory use (33523, 300437)
# FILE:  732898.csv
# Memory use (41015, 312462)
# FILE:  23413939.csv
# Memory use (22652, 298399)
# FILE:  13559193.csv
# Memory use (25415, 297314)
# FILE:  393992.csv
# Memory use (41428, 310553)
# FILE:  12583978.csv
# Memory use (31261, 299311)
# FILE:  34250110.csv
# Memory use (35738, 307664)
# FILE:  3294459.csv
# Memory use (33050, 302792)
# FILE:  29080164.csv
# Memory use (38609, 306628)
# FILE:  2213837.csv
# Memory use (58790, 323456)
# FILE:  58361892.csv
# Memory use (41039, 315729)
# FILE:  583196.csv
# Memory use (36744, 300745)
# FILE:  30177158.csv
# Memory use (24125, 297679)
# FILE:  1608159.csv
# Memory use (23173, 295307)
# FILE:  1449346.csv
# Memory use (37280, 309396)
# FILE:  536880.csv
# Memory use (67384, 329971)
# FILE:  11278985.csv
# Memory use (33154, 302929)
# FILE:  42208644.csv
# Memory use (28779, 296714)
# FILE:  46720243.csv
# Memory use (40551, 310799)
# FILE:  37652529.csv
# Memory use (24852, 296978)
# FILE:  14141885.csv
# Memory use (22319, 294638)
# FILE:  51035085.csv
# Memory use (27790, 297374)
# FILE:  5175128.csv
# Memory use (63298, 335640)
# FILE:  2684804.csv
# Memory use (22715, 295025)
# FILE:  51562413.csv
# Memory use (24932, 316681)
# FILE:  39741081.csv
# Memory use (22402, 296986)
# FILE:  40234193.csv
# Memory use (22584, 295865)
# FILE:  4296013.csv
# Memory use (30406, 298950)
# FILE:  15475257.csv
# Memory use (40486, 311867)
# FILE:  62334121.csv
# Memory use (31963, 302513)
# FILE:  2974975.csv
# Memory use (60681, 323749)
# FILE:  217837.csv
# Memory use (54927, 323416)
# FILE:  32832417.csv
# Memory use (17167, 294699)
# FILE:  53630594.csv
# Memory use (36968, 312789)
# FILE:  36809553.csv
# Memory use (30455, 304461)
# FILE:  36688059.csv
# Memory use (32483, 299752)
# FILE:  49306093.csv
# Memory use (41858, 310335)
# FILE:  1572895.csv
# Memory use (37996, 306158)
# FILE:  1428166.csv
# Memory use (31987, 303234)
# FILE:  38939964.csv
# Memory use (50313, 319525)
# FILE:  2852428.csv
# Memory use (38830, 303534)
# FILE:  16806412.csv
# Memory use (31951, 300978)
# FILE:  91116.csv
# Memory use (64375, 333517)
# FILE:  43920959.csv
# Memory use (35489, 299444)
# FILE:  45515607.csv
# Memory use (24371, 297915)
# FILE:  700097.csv
# Memory use (49288, 321933)
# FILE:  974689.csv
# Memory use (27976, 300053)
# FILE:  45355130.csv
# Memory use (25348, 299750)
# FILE:  3275272.csv
# Memory use (41270, 307879)
# FILE:  14789518.csv
# Memory use (24024, 295342)
# FILE:  4458727.csv
# Memory use (35094, 303513)
# FILE:  22698602.csv
# Memory use (37882, 312782)
# FILE:  45027555.csv
# Memory use (23805, 296327)
# FILE:  32598446.csv
# Memory use (24589, 296393)
# FILE:  45424063.csv
# Memory use (42852, 311457)
# FILE:  2941953.csv
# Memory use (43534, 307356)
# FILE:  15068807.csv
# Memory use (30638, 306907)
# FILE:  9785341.csv
# Memory use (38039, 301303)
# FILE:  16230148.csv
# Memory use (28672, 301416)
# FILE:  1272308.csv
# Memory use (36152, 305465)
# FILE:  30196117.csv
# Memory use (55078, 333354)
# FILE:  14989909.csv
# Memory use (47177, 325559)
# FILE:  4678931.csv
# Memory use (25354, 297795)
# FILE:  2802656.csv
# Memory use (39965, 301406)
# FILE:  44723265.csv
# Memory use (29251, 298482)
# FILE:  36239530.csv
# Memory use (36306, 308539)
# FILE:  22298122.csv
# Memory use (24529, 301367)
# FILE:  7253179.csv
# Memory use (36868, 313685)
# FILE:  1374195.csv
# Memory use (37653, 310344)
# FILE:  1492509.csv
# Memory use (78446, 349230)
# FILE:  567621.csv
# Memory use (34522, 307875)
# FILE:  38949146.csv
# Memory use (41070, 313947)
# FILE:  43487809.csv
# Memory use (26963, 297695)
# FILE:  55441319.csv
# Memory use (19057, 299712)
# FILE:  39579845.csv
# Memory use (37214, 306724)
# FILE:  13162023.csv
# Memory use (29430, 300549)
# FILE:  14324036.csv
# Memory use (26953, 297866)
# FILE:  47360791.csv
# Memory use (24043, 295536)
# FILE:  44929876.csv
# Memory use (30200, 302307)
# FILE:  4263092.csv
# Memory use (22352, 294933)
# FILE:  27621426.csv
# Memory use (40112, 308919)
# FILE:  15800418.csv
# Memory use (31496, 304532)
# FILE:  6921772.csv
# Memory use (43283, 311012)
# FILE:  41614678.csv
# Memory use (22398, 299042)
# FILE:  2468437.csv
# Memory use (43444, 311276)
# FILE:  41355775.csv
# Memory use (29014, 300775)
# FILE:  52795480.csv
# Memory use (32654, 300733)
# FILE:  7159986.csv
# Memory use (31015, 302361)
# FILE:  57149968.csv
# Memory use (23565, 298521)
# FILE:  75785.csv
# Memory use (81057, 342006)
# FILE:  26459915.csv
# Memory use (28560, 299999)
# FILE:  22207962.csv
# Memory use (22448, 295652)
# FILE:  46358127.csv
# Memory use (44593, 304717)
# FILE:  20057.csv
# Memory use (122807, 401841)
# FILE:  1881320.csv
# Memory use (77350, 346748)
# FILE:  11772222.csv
# Memory use (61193, 322216)
# FILE:  5642600.csv
# Memory use (25874, 296628)
# FILE:  47609314.csv
# Memory use (46228, 315191)
# FILE:  12205410.csv
# Memory use (30531, 298740)
# FILE:  53736016.csv
# Memory use (32052, 303820)
# FILE:  43147495.csv
# Memory use (32508, 305943)
# FILE:  145534.csv
# Memory use (59025, 330198)
# FILE:  8346043.csv
# Memory use (26954, 300780)
# FILE:  10562974.csv
# Memory use (49559, 318054)
# FILE:  2365819.csv
# Memory use (28171, 298710)
# FILE:  47912995.csv
# Memory use (30204, 307082)
# FILE:  38951372.csv
# Memory use (39767, 315385)
# FILE:  57841592.csv
# Memory use (25483, 296313)
# FILE:  48823467.csv
# Memory use (25902, 296104)
# FILE:  18603.csv
# Memory use (38924, 308460)
# FILE:  1102000.csv
# Memory use (198702, 469984)
# FILE:  2105362.csv
# Memory use (55695, 313061)
# FILE:  2642394.csv
# Memory use (37388, 309655)
# FILE:  263671.csv
# Memory use (58446, 328284)
# FILE:  1181117.csv
# Memory use (52012, 314544)
# FILE:  26544226.csv
# Memory use (27867, 301183)
# FILE:  6573816.csv
# Memory use (29347, 302523)
# FILE:  55864945.csv
# Memory use (31582, 298494)
# FILE:  34658900.csv
# Memory use (52061, 313961)
# FILE:  1689813.csv
# Memory use (25633, 298408)
# FILE:  2657736.csv
# Memory use (39893, 314752)
# FILE:  45716158.csv
# Memory use (27882, 296430)
# FILE:  30150271.csv
# Memory use (63260, 328382)
# FILE:  2416191.csv
# Memory use (70761, 338314)
# FILE:  15869518.csv
# Memory use (29965, 303481)
# FILE:  52361712.csv
# Memory use (26043, 301557)
# FILE:  67530630.csv
# Memory use (43005, 313639)
# FILE:  3733827.csv
# Memory use (25112, 297541)
# FILE:  65268313.csv
# Memory use (39927, 308671)
# FILE:  29572931.csv
# Memory use (32757, 298901)
# FILE:  55198620.csv
# Memory use (33087, 298771)
# FILE:  14937840.csv
# Memory use (57451, 329727)
# FILE:  44544785.csv
# Memory use (49898, 324522)
# FILE:  59087296.csv
# Memory use (34922, 309028)
# FILE:  47696135.csv
# Memory use (32183, 298575)
# FILE:  161482.csv
# Memory use (103216, 382837)
# FILE:  5895793.csv
# Memory use (34027, 304620)
# FILE:  53390426.csv
# Memory use (35751, 307511)
# FILE:  5608144.csv
# Memory use (40260, 306930)
# FILE:  15977195.csv
# Memory use (47185, 317162)
# FILE:  33355906.csv
# Memory use (30778, 299489)
# FILE:  30861519.csv
# Memory use (83867, 349365)
# FILE:  2332880.csv
# Memory use (71532, 339590)
# FILE:  53935890.csv
# Memory use (29711, 300387)
# FILE:  18698482.csv
# Memory use (33562, 300344)
# FILE:  13246614.csv
# Memory use (34580, 305895)
# FILE:  3876457.csv
# Memory use (42218, 315675)
# FILE:  28014438.csv
# Memory use (28777, 301757)
# FILE:  33934074.csv
# Memory use (50222, 323995)
# FILE:  24424310.csv
# Memory use (57908, 324118)
# FILE:  2741441.csv
# Memory use (40533, 310515)
# FILE:  511169.csv
# Memory use (39805, 300897)
# FILE:  50510602.csv
# Memory use (26610, 296674)
# FILE:  33891230.csv
# Memory use (27934, 304794)
# FILE:  17228819.csv
# Memory use (52719, 316145)
# FILE:  32693459.csv
# Memory use (21351, 296291)
# FILE:  1370495.csv
# Memory use (22970, 296367)
# FILE:  48216421.csv
# Memory use (32743, 298701)
# FILE:  15978811.csv
# Memory use (25709, 298904)
# FILE:  20471352.csv
# Memory use (77847, 341334)
# FILE:  2740465.csv
# Memory use (31760, 304572)
# FILE:  15682115.csv
# Memory use (27334, 299850)
# FILE:  41667524.csv
# Memory use (28254, 298130)
# FILE:  37136298.csv
# Memory use (50694, 316695)
# FILE:  9193714.csv
# Memory use (38870, 305648)
# FILE:  66897449.csv
# Memory use (30825, 298865)
# FILE:  8539590.csv
# Memory use (33717, 300817)
# FILE:  52848479.csv
# Memory use (38961, 303515)
# FILE:  30282982.csv
# Memory use (30865, 302613)
# FILE:  22492868.csv
# Memory use (20632, 296056)
# FILE:  63901419.csv
# Memory use (38004, 303180)
# FILE:  3526726.csv
# Memory use (68276, 331501)
# FILE:  62664361.csv
# Memory use (25562, 299928)
# FILE:  3427285.csv
# Memory use (25404, 302270)
# FILE:  30587193.csv
# Memory use (21289, 296745)
# FILE:  3855682.csv
# Memory use (39082, 307317)
# FILE:  20657574.csv
# Memory use (29215, 301921)
# FILE:  35071238.csv
# Memory use (22403, 298434)
# FILE:  35866244.csv
# Memory use (26919, 300540)
# FILE:  8649462.csv
# Memory use (30457, 310585)
# FILE:  26580382.csv
# Memory use (31329, 308405)
# FILE:  807921.csv
# Memory use (44377, 315307)
# FILE:  45321432.csv
# Memory use (39724, 310757)
# FILE:  454347.csv
# Memory use (99771, 363188)
# FILE:  5051666.csv
# Memory use (25261, 298250)
# FILE:  25641728.csv
# Memory use (29333, 302376)
# FILE:  55186679.csv
# Memory use (59979, 332038)
# FILE:  21079563.csv
# Memory use (39731, 309462)
# FILE:  211080.csv
# Memory use (92641, 372146)
# FILE:  3011734.csv
# Memory use (30555, 307035)
# FILE:  3059720.csv
# Memory use (25321, 298197)
# FILE:  52302884.csv
# Memory use (30603, 301532)
# FILE:  11893793.csv
# Memory use (46412, 318565)
# FILE:  27208396.csv
# Memory use (27982, 302934)
# FILE:  18544298.csv
# Memory use (54743, 320773)
# FILE:  16931551.csv
# Memory use (25259, 299110)
# FILE:  1596439.csv
# Memory use (58205, 326674)
# FILE:  4595936.csv
# Memory use (27911, 298923)
# FILE:  884942.csv
# Memory use (49136, 321878)
# FILE:  33971.csv
# Memory use (137173, 402232)
# FILE:  1202003.csv
# Memory use (33353, 298909)
# FILE:  23727865.csv
# Memory use (24003, 296884)
# FILE:  29309178.csv
# Memory use (41652, 310394)
# FILE:  47445010.csv
# Memory use (42014, 312872)
# FILE:  3317618.csv
# Memory use (121938, 393452)
# FILE:  619068.csv
# Memory use (103215, 370618)
# FILE:  34132820.csv
# Memory use (37989, 300117)
# FILE:  40023572.csv
# Memory use (56402, 326578)
# FILE:  2822358.csv
# Memory use (32690, 305093)
# FILE:  23419537.csv
# Memory use (38602, 301902)
# FILE:  673723.csv
# Memory use (46346, 312926)
# FILE:  7520718.csv
# Memory use (26635, 300379)
# FILE:  508570.csv
# Memory use (84131, 332962)
# FILE:  2188980.csv
# Memory use (49314, 325552)
# FILE:  17622605.csv
# Memory use (21730, 294318)
# FILE:  23985478.csv
# Memory use (29450, 301844)
# FILE:  62056281.csv
# Memory use (26608, 297827)
# FILE:  217696.csv
# Memory use (52702, 318078)
# FILE:  60317847.csv
# Memory use (37092, 312199)
# FILE:  1797730.csv
# Memory use (47076, 314683)
# FILE:  15693144.csv
# Memory use (27628, 296939)
# FILE:  17742366.csv
# Memory use (29736, 298305)
# FILE:  901202.csv
# Memory use (55882, 330732)
# FILE:  48561740.csv
# Memory use (23619, 299305)
# FILE:  1461596.csv
# Memory use (36764, 300775)
# FILE:  462193.csv
# Memory use (29830, 300540)
# FILE:  56153589.csv
# Memory use (42055, 312137)
# FILE:  62840348.csv
# Memory use (41547, 314647)
# FILE:  3101416.csv
# Memory use (62386, 328339)
# FILE:  44643854.csv
# Memory use (32186, 304669)
# FILE:  4593082.csv
# Memory use (31351, 298231)
# FILE:  1255387.csv
# Memory use (42478, 303723)
# FILE:  4993064.csv
# Memory use (81783, 345969)
# FILE:  880433.csv
# Memory use (112413, 388622)
# FILE:  1119420.csv
# Memory use (40255, 315103)
# FILE:  6122676.csv
# Memory use (28913, 302371)
# FILE:  13233333.csv
# Memory use (41434, 314970)
# FILE:  2730702.csv
# Memory use (50137, 318936)
# FILE:  9717213.csv
# Memory use (34441, 303523)
# FILE:  526546.csv
# Memory use (74710, 337803)
# FILE:  46974941.csv
# Memory use (23553, 295482)
# FILE:  1573838.csv
# Memory use (89098, 359948)
# FILE:  1476321.csv
# Memory use (20572, 294341)
# FILE:  45619707.csv
# Memory use (24311, 296066)
# FILE:  48792664.csv
# Memory use (63863, 343301)
# FILE:  23875064.csv
# Memory use (31912, 301056)
# FILE:  37008034.csv
# Memory use (25510, 297370)
# FILE:  30774188.csv
# Memory use (28844, 302781)
# FILE:  63258897.csv
# Memory use (36502, 306156)
# FILE:  29697911.csv
# Memory use (55468, 327460)
# FILE:  53072720.csv
# Memory use (23325, 301178)
# FILE:  6740971.csv
# Memory use (109182, 403357)
# FILE:  29297605.csv
# Memory use (33311, 301038)
# FILE:  23264619.csv
# Memory use (90280, 352772)
# FILE:  768228.csv
# Memory use (49382, 315524)
# FILE:  27857316.csv
# Memory use (29914, 298348)
# FILE:  3193313.csv
# Memory use (52453, 315182)
# FILE:  385882.csv
# Memory use (59782, 320602)
# FILE:  27703020.csv
# Memory use (28775, 298716)
# FILE:  2310846.csv
# Memory use (32852, 307601)
# FILE:  25123102.csv
# Memory use (37644, 309071)
# FILE:  46687552.csv
# Memory use (33736, 305868)
# FILE:  505963.csv
# Memory use (49245, 318750)
# FILE:  77735.csv
# Memory use (54561, 325813)
# FILE:  13471698.csv
# Memory use (30007, 316051)
# FILE:  3596773.csv
# Memory use (50112, 313038)
# FILE:  2430067.csv
# Memory use (40623, 310932)
# FILE:  2451984.csv
# Memory use (50321, 322034)
# FILE:  5171707.csv
# Memory use (48627, 322646)
# FILE:  1726430.csv
# Memory use (26862, 296809)
# FILE:  6191098.csv
# Memory use (30961, 303754)
# FILE:  473338.csv
# Memory use (48524, 314744)
# FILE:  14276016.csv
# Memory use (41951, 311529)
# FILE:  16234807.csv
# Memory use (31181, 300027)
# FILE:  28646834.csv
# Memory use (26986, 297790)
# FILE:  11694264.csv
# Memory use (35635, 308158)
# FILE:  2326209.csv
# Memory use (32810, 302191)
# FILE:  4265825.csv
# Memory use (27094, 296265)
# FILE:  57456473.csv
# Memory use (46199, 307451)
# FILE:  4505647.csv
# Memory use (44547, 322377)
# FILE:  25536151.csv
# Memory use (38432, 299651)
# FILE:  16363276.csv
# Memory use (24390, 296417)
# FILE:  30834179.csv
# Memory use (26480, 300446)
# FILE:  8843392.csv
# Memory use (43914, 314823)
# FILE:  17751902.csv
# Memory use (33707, 304308)
# FILE:  3846285.csv
# Memory use (34620, 305581)
# FILE:  25047670.csv
# Memory use (42935, 301785)
# FILE:  979884.csv
# Memory use (33562, 304831)
# FILE:  10521966.csv
# Memory use (57314, 324637)
# FILE:  62878595.csv
# Memory use (22270, 294877)
# FILE:  4263237.csv
# Memory use (31802, 304033)
# FILE:  19189086.csv
# Memory use (25070, 296416)
# FILE:  59771460.csv
# Memory use (46889, 319383)
# FILE:  3221018.csv
# Memory use (41984, 309196)
# FILE:  38757183.csv
# Memory use (29570, 301227)
# FILE:  6086015.csv
# Memory use (53707, 317639)
# FILE:  50539761.csv
# Memory use (20899, 299278)
# FILE:  6845093.csv
# Memory use (43143, 309739)
# FILE:  155464.csv
# Memory use (49044, 319997)
# FILE:  3988098.csv
# Memory use (23755, 295812)
# FILE:  20700814.csv
# Memory use (44071, 310542)
# FILE:  24823344.csv
# Memory use (32118, 298377)
# FILE:  30001493.csv
# Memory use (23639, 298194)
# FILE:  2260975.csv
# Memory use (24652, 295642)
# FILE:  45143652.csv
# Memory use (37298, 307930)
# FILE:  42498909.csv
# Memory use (31504, 305076)
# FILE:  633238.csv
# Memory use (66717, 345674)
# FILE:  30163202.csv
# Memory use (37486, 306020)
# FILE:  10970683.csv
# Memory use (47924, 312273)
# FILE:  23633101.csv
# Memory use (50444, 319652)
# FILE:  54161089.csv
# Memory use (32332, 304807)
# FILE:  3343154.csv
# Memory use (33270, 299909)
# FILE:  17850347.csv
# Memory use (43461, 321690)
# FILE:  25478752.csv
# Memory use (39457, 307470)
# FILE:  21196642.csv
# Memory use (26691, 298340)
# FILE:  298781.csv
# Memory use (60938, 334269)
# FILE:  1148481.csv
# Memory use (48080, 317223)
# FILE:  3261771.csv
# Memory use (34710, 303036)
# FILE:  14612798.csv
# Memory use (22546, 297100)
# FILE:  45228905.csv
# Memory use (31352, 299863)
# FILE:  55590935.csv
# Memory use (36374, 304266)
# FILE:  1579006.csv
# Memory use (51668, 323803)
# FILE:  28401646.csv
# Memory use (44768, 303956)
# FILE:  57853556.csv
# Memory use (37475, 315114)
# FILE:  780623.csv
# Memory use (25366, 296642)
# FILE:  18882736.csv
# Memory use (22958, 295386)
# FILE:  59216.csv
# Memory use (99816, 356958)
# FILE:  57040810.csv
# Memory use (37250, 307860)
# FILE:  46829033.csv
# Memory use (22246, 296350)
# FILE:  33569936.csv
# Memory use (39721, 313437)
# FILE:  17367517.csv
# Memory use (26404, 299789)
# FILE:  42198936.csv
# Memory use (113053, 379316)
# FILE:  40896554.csv
# Memory use (25683, 296567)
# FILE:  13736167.csv
# Memory use (314365, 705349)
# FILE:  21269559.csv
# Memory use (27720, 296718)
# FILE:  43228296.csv
# Memory use (31999, 305705)
# FILE:  20443257.csv
# Memory use (24153, 296924)
# FILE:  32423698.csv
# Memory use (50400, 319311)
# FILE:  18796822.csv
# Memory use (25272, 296404)
# FILE:  762236.csv
# Memory use (58926, 317694)
# FILE:  1038736.csv
# Memory use (41203, 309625)
# FILE:  7359332.csv
# Memory use (38281, 308625)
# FILE:  1952310.csv
# Memory use (45860, 319658)
# FILE:  13482967.csv
# Memory use (23140, 295344)
# FILE:  57889058.csv
# Memory use (25538, 301353)
# FILE:  47928654.csv
# Memory use (32120, 304718)
# FILE:  37211759.csv
# Memory use (35470, 306658)
# FILE:  7572752.csv
# Memory use (26602, 299562)
# FILE:  22617369.csv
# Memory use (25282, 298090)
# FILE:  44647758.csv
# Memory use (26586, 296753)
# FILE:  44028127.csv
# Memory use (24476, 296020)
# FILE:  47862991.csv
# Memory use (32169, 299087)
# FILE:  39301777.csv
# Memory use (39013, 300775)
# FILE:  20528714.csv
# Memory use (41965, 313448)
# FILE:  24310527.csv
# Memory use (25133, 297743)
# FILE:  28384496.csv
# Memory use (32907, 299453)
# FILE:  33464489.csv
# Memory use (21475, 294782)
# FILE:  41613169.csv
# Memory use (22443, 297364)
# FILE:  2294646.csv
# Memory use (29309, 297720)
# FILE:  30664175.csv
# Memory use (30739, 301849)
# FILE:  15642616.csv
# Memory use (29528, 301859)
# FILE:  1847399.csv
# Memory use (27101, 300555)
# FILE:  2770615.csv
# Memory use (150931, 415407)
# FILE:  49336781.csv
# Memory use (50023, 307786)
# FILE:  2615004.csv
# Memory use (50174, 336298)
# FILE:  4093570.csv
# Memory use (54265, 323371)
# FILE:  611805.csv
# Memory use (46487, 313891)
# FILE:  54093941.csv
# Memory use (30990, 304035)
# FILE:  62266561.csv
# Memory use (36203, 312959)
# FILE:  23135314.csv
# Memory use (50234, 315673)
# FILE:  12375108.csv
# Memory use (24352, 297419)
# FILE:  31563128.csv
# Memory use (24302, 299663)
# FILE:  10130566.csv
# Memory use (38721, 300285)
# FILE:  9654804.csv
# Memory use (43359, 323128)
# FILE:  35961648.csv
# Memory use (22940, 295701)
# FILE:  10185599.csv
# Memory use (37968, 315717)
# FILE:  1566906.csv
# Memory use (50264, 329587)
# FILE:  46488439.csv
# Memory use (38970, 311658)
# FILE:  60825607.csv
# Memory use (35477, 308721)
# FILE:  19583441.csv
# Memory use (29646, 304829)
# FILE:  16297394.csv
# Memory use (27553, 297078)
# FILE:  30095378.csv
# Memory use (23789, 296150)
# FILE:  979072.csv
# Memory use (51348, 316268)
# FILE:  24137134.csv
# Memory use (24119, 295557)
# FILE:  52996548.csv
# Memory use (35676, 305463)
# FILE:  12633444.csv
# Memory use (36309, 301267)
# FILE:  389471.csv
# Memory use (73512, 336522)
# FILE:  7188488.csv
# Memory use (57285, 321447)
# FILE:  2053320.csv
# Memory use (31166, 298481)
# FILE:  30037010.csv
# Memory use (75564, 345569)
# FILE:  18985395.csv
# Memory use (30599, 300626)
# FILE:  59839551.csv
# Memory use (23940, 295420)
# FILE:  63157801.csv
# Memory use (41501, 312396)
# FILE:  48782400.csv
# Memory use (38441, 309045)
# FILE:  18853379.csv
# Memory use (20945, 294063)
# FILE:  8921669.csv
# Memory use (23559, 295716)
# FILE:  6528370.csv
# Memory use (28104, 302054)
# FILE:  6746772.csv
# Memory use (37670, 310892)
# FILE:  1480643.csv
# Memory use (44686, 312447)
# FILE:  2399532.csv
# Memory use (46125, 316046)
# FILE:  41999743.csv
# Memory use (20649, 296810)
# FILE:  24520995.csv
# Memory use (173887, 470323)
# FILE:  4808127.csv
# Memory use (27268, 297735)
# FILE:  25901189.csv
# Memory use (58687, 330073)
# FILE:  5135770.csv
# Memory use (67398, 341388)
# FILE:  33642618.csv
# Memory use (31286, 298298)
# FILE:  1375693.csv
# Memory use (42537, 312806)
# FILE:  30651570.csv
# Memory use (35407, 309636)
# FILE:  251379.csv
# Memory use (82877, 348466)
# FILE:  22617443.csv
# Memory use (22684, 294698)
# FILE:  696631.csv
# Memory use (110150, 367994)
# FILE:  48614188.csv
# Memory use (50645, 337739)
# FILE:  14419303.csv
# Memory use (29726, 301559)
# FILE:  28423711.csv
# Memory use (28538, 298173)
# FILE:  6595261.csv
# Memory use (77181, 338956)
# FILE:  32254086.csv
# Memory use (45058, 319829)
# FILE:  2899427.csv
# Memory use (59507, 333501)
# FILE:  1594144.csv
# Memory use (46108, 319730)
# FILE:  14156395.csv
# Memory use (38454, 305788)
# FILE:  53858225.csv
# Memory use (21931, 295119)
# FILE:  1704691.csv
# Memory use (40815, 309069)
# FILE:  9590626.csv
# Memory use (65326, 335372)
# FILE:  234978.csv
# Memory use (73237, 338636)
# FILE:  150093.csv
# Memory use (26662, 298016)
# FILE:  36451129.csv
# Memory use (31036, 305852)
# FILE:  8112651.csv
# Memory use (30270, 304062)
# FILE:  613474.csv
# Memory use (109384, 385343)
# FILE:  1672987.csv
# Memory use (31155, 303718)
# FILE:  1868891.csv
# Memory use (32730, 305606)
# FILE:  30796491.csv
# Memory use (36618, 306862)
# FILE:  2636367.csv
# Memory use (51541, 315058)
# FILE:  3223224.csv
# Memory use (40716, 324403)
# FILE:  536739.csv
# Memory use (101643, 376399)
# FILE:  6761528.csv
# Memory use (45869, 315610)
# FILE:  6785960.csv
# Memory use (31431, 304936)
# FILE:  34211523.csv
# Memory use (42066, 312215)
# FILE:  43464169.csv
# Memory use (31669, 305926)
# FILE:  20064379.csv
# Memory use (26543, 300853)
# FILE:  5030223.csv
# Memory use (34071, 307844)
# FILE:  33765476.csv
# Memory use (49474, 301568)
# FILE:  12236890.csv
# Memory use (25458, 296325)
# FILE:  52205221.csv
# Memory use (28387, 298758)
# FILE:  33429917.csv
# Memory use (16887, 294419)
# FILE:  65799929.csv
# Memory use (32032, 304408)
# FILE:  38806960.csv
# Memory use (16257, 301084)
# FILE:  2456990.csv
# Memory use (66130, 336086)
# FILE:  37110180.csv
# Memory use (71734, 341902)
# FILE:  34759328.csv
# Memory use (40127, 309418)
# FILE:  63715382.csv
# Memory use (42783, 308476)
# FILE:  1090562.csv
# Memory use (62581, 329963)
# FILE:  1262163.csv
# Memory use (68690, 344140)
# FILE:  19787142.csv
# Memory use (22385, 296365)
# FILE:  37801409.csv
# Memory use (21110, 296741)
# FILE:  7273721.csv
# Memory use (37172, 308526)
# FILE:  354604.csv
# Memory use (53522, 321958)
# FILE:  4480563.csv
# Memory use (41508, 307758)
# FILE:  11511476.csv
# Memory use (28691, 299829)
# FILE:  31774383.csv
# Memory use (22387, 295302)
# FILE:  15116498.csv
# Memory use (26519, 301056)
# FILE:  7611435.csv
# Memory use (67386, 333302)
# FILE:  4123604.csv
# Memory use (51464, 325487)
# FILE:  23874536.csv
# Memory use (28873, 301006)
# FILE:  1028178.csv
# Memory use (292892, 612703)
# FILE:  2796751.csv
# Memory use (31861, 298830)
# FILE:  47764066.csv
# Memory use (51033, 316140)
# FILE:  13001518.csv
# Memory use (26406, 302347)
# FILE:  526477.csv
# Memory use (52556, 305878)
# FILE:  1861034.csv
# Memory use (30887, 303205)
# FILE:  432650.csv
# Memory use (100623, 383200)
# FILE:  916874.csv
# Memory use (94500, 361886)
# FILE:  62060481.csv
# Memory use (51409, 330775)
# FILE:  302324.csv
# Memory use (80997, 345894)
# FILE:  11152154.csv
# Memory use (23055, 295116)
# FILE:  2900106.csv
# Memory use (45718, 313334)
# FILE:  39044624.csv
# Memory use (34897, 299294)
# FILE:  2457330.csv
# Memory use (44048, 312060)
# FILE:  35698810.csv
# Memory use (29149, 296666)
# FILE:  37578543.csv
# Memory use (29741, 303972)
# FILE:  25731026.csv
# Memory use (29964, 301712)
# FILE:  1745424.csv
# Memory use (51252, 323152)
# FILE:  47749711.csv
# Memory use (21467, 298101)
# FILE:  523032.csv
# Memory use (387308, 890663)
# FILE:  1005009.csv
# Memory use (59175, 327458)
# FILE:  7251423.csv
# Memory use (38778, 307952)
# FILE:  49047299.csv
# Memory use (33669, 306846)
# FILE:  52499535.csv
# Memory use (29406, 299314)
# FILE:  247094.csv
# Memory use (45564, 306494)
# FILE:  6322771.csv
# Memory use (39647, 300821)
# FILE:  54689260.csv
# Memory use (31950, 303529)
# FILE:  481781.csv
# Memory use (113406, 374043)
# FILE:  1595365.csv
# Memory use (58669, 332775)
# FILE:  318375.csv
# Memory use (113114, 360870)
# FILE:  30402663.csv
# Memory use (51318, 319656)
# FILE:  55257325.csv
# Memory use (118842, 380878)
# FILE:  27661638.csv
# Memory use (51698, 315343)
# FILE:  22217542.csv
# Memory use (45923, 313322)
# FILE:  21578798.csv
# Memory use (52075, 317872)
# FILE:  1471422.csv
# Memory use (33320, 307934)
# FILE:  45198301.csv
# Memory use (26840, 298581)
# FILE:  21723350.csv
# Memory use (24658, 299653)
# FILE:  51109716.csv
# Memory use (33143, 298353)
# FILE:  28764072.csv
# Memory use (30918, 302709)
# FILE:  2830059.csv
# Memory use (45575, 310503)
# FILE:  23823389.csv
# Memory use (33092, 302893)
# FILE:  33496220.csv
# Memory use (23556, 307816)
# FILE:  44640408.csv
# Memory use (38717, 313620)
# FILE:  4156707.csv
# Memory use (30759, 300576)
# FILE:  26651473.csv
# Memory use (75757, 340045)
# FILE:  5419079.csv
# Memory use (24332, 296012)
# FILE:  1296267.csv
# Memory use (40569, 311210)
# FILE:  1934197.csv
# Memory use (30253, 303772)
# FILE:  2541302.csv
# Memory use (36062, 306695)
# FILE:  2261547.csv
# Memory use (64530, 325118)
# FILE:  2232359.csv
# Memory use (57314, 319541)
# FILE:  7375500.csv
# Memory use (45585, 312933)
# FILE:  1784265.csv
# Memory use (33360, 299888)
# FILE:  17334430.csv
# Memory use (65808, 327712)
# FILE:  31388537.csv
# Memory use (26371, 301678)
# FILE:  41726058.csv
# Memory use (23459, 298178)
# FILE:  41251990.csv
# Memory use (24214, 296441)
# FILE:  29962724.csv
# Memory use (26820, 301157)
# FILE:  935096.csv
# Memory use (32590, 302901)
# FILE:  31583685.csv
# Memory use (35394, 309345)
# FILE:  49123642.csv
# Memory use (52356, 305221)
# FILE:  4409875.csv
# Memory use (48530, 317329)
# FILE:  13103724.csv
# Memory use (30178, 303199)
# FILE:  27899499.csv
# Memory use (32511, 303861)
# FILE:  58430110.csv
# Memory use (34415, 298484)
# FILE:  210052.csv
# Memory use (67150, 334022)
# FILE:  14476699.csv
# Memory use (45319, 304771)
# FILE:  14227477.csv
# Memory use (43693, 314244)
# FILE:  889446.csv
# Memory use (51224, 331851)
# FILE:  1707780.csv
# Memory use (40575, 308367)
# FILE:  1433271.csv
# Memory use (31117, 303051)
# FILE:  166247.csv
# Memory use (83613, 354323)
# FILE:  1765748.csv
# Memory use (34315, 307880)
# FILE:  21881151.csv
# Memory use (40240, 307373)
# FILE:  53557582.csv
# Memory use (21061, 295508)
# FILE:  921454.csv
# Memory use (81786, 349846)
# FILE:  47008022.csv
# Memory use (39042, 305161)
# FILE:  16754765.csv
# Memory use (37426, 309623)
# FILE:  31853822.csv
# Memory use (53161, 305229)
# FILE:  1267466.csv
# Memory use (50216, 306928)
# FILE:  55526270.csv
# Memory use (25112, 296185)
# FILE:  4993996.csv
# Memory use (85701, 362609)
# FILE:  1525884.csv
# Memory use (60453, 325747)
# FILE:  1310120.csv
# Memory use (38015, 312667)
# FILE:  1945773.csv
# Memory use (46368, 310613)
# FILE:  48484631.csv
# Memory use (57116, 333817)
# FILE:  63176883.csv
# Memory use (37211, 310541)
# FILE:  53068891.csv
# Memory use (41776, 313233)
# FILE:  23307.csv
# Memory use (75278, 341409)
# FILE:  41837570.csv
# Memory use (33049, 300656)
# FILE:  24896876.csv
# Memory use (40508, 302266)
# FILE:  39544236.csv
# Memory use (32667, 303700)
# FILE:  40574341.csv
# Memory use (37637, 310445)
# FILE:  11715044.csv
# Memory use (24534, 295309)
# FILE:  30468519.csv
# Memory use (25487, 296709)
# FILE:  25907985.csv
# Memory use (36266, 301898)
# FILE:  3000553.csv
# Memory use (28648, 300316)
# FILE:  1739180.csv
# Memory use (100324, 380175)
# FILE:  43784280.csv
# Memory use (36724, 302033)
# FILE:  40656158.csv
# Memory use (28845, 302194)
# FILE:  167504.csv
# Memory use (91116, 361443)
# FILE:  36044136.csv
# Memory use (21339, 298664)
# FILE:  1196107.csv
# Memory use (45439, 313326)
# FILE:  12378248.csv
# Memory use (33517, 306211)
# FILE:  6482450.csv
# Memory use (26082, 297155)
# FILE:  33776035.csv
# Memory use (19542, 297228)
# FILE:  1171819.csv
# Memory use (52099, 327719)
# FILE:  2250259.csv
# Memory use (59917, 319858)
# FILE:  2016018.csv
# Memory use (28551, 298103)
# FILE:  26320069.csv
# Memory use (23324, 295242)
# FILE:  42201354.csv
# Memory use (32601, 306580)
# FILE:  62509789.csv
# Memory use (47606, 319664)
# FILE:  29003553.csv
# Memory use (45034, 322686)
# FILE:  44616882.csv
# Memory use (43049, 311543)
# FILE:  8470389.csv
# Memory use (27870, 298748)
# FILE:  40218684.csv
# Memory use (37809, 315963)
# FILE:  1353591.csv
# Memory use (94031, 361742)
# FILE:  32814639.csv
# Memory use (26387, 303534)
# FILE:  63917013.csv
# Memory use (32268, 297485)
# FILE:  30553782.csv
# Memory use (22718, 295687)
# FILE:  4503565.csv
# Memory use (48893, 318453)
# FILE:  67663898.csv
# Memory use (31022, 303464)
# FILE:  22134547.csv
# Memory use (44541, 316605)
# FILE:  1349055.csv
# Memory use (53531, 310583)
# FILE:  12589949.csv
# Memory use (27313, 300678)
# FILE:  27379323.csv
# Memory use (23463, 297089)
# FILE:  2273480.csv
# Memory use (30620, 302171)
# FILE:  49933822.csv
# Memory use (25562, 297542)
# FILE:  20929413.csv
# Memory use (24516, 295369)
# FILE:  716743.csv
# Memory use (33783, 305471)
# FILE:  52702863.csv
# Memory use (32976, 306398)
# FILE:  5102500.csv
# Memory use (28707, 301028)
# FILE:  289465.csv
# Memory use (55065, 324844)
# FILE:  1298368.csv
# Memory use (37923, 303702)
# FILE:  36223421.csv
# Memory use (45438, 306361)
# FILE:  5496238.csv
# Memory use (39342, 304201)
# FILE:  1857363.csv
# Memory use (30787, 301092)
# FILE:  14068650.csv
# Memory use (32377, 309629)
# FILE:  52825621.csv
# Memory use (30320, 297745)
# FILE:  5845290.csv
# Memory use (30522, 303223)
# FILE:  38559153.csv
# Memory use (60755, 320259)
# FILE:  57215197.csv
# Memory use (24680, 299140)
# FILE:  1673773.csv
# Memory use (60610, 326493)
# FILE:  32200549.csv
# Memory use (23318, 295416)
# FILE:  1028243.csv
# Memory use (38913, 307895)
# FILE:  398338.csv
# Memory use (92106, 353375)
# FILE:  31590880.csv
# Memory use (39763, 316420)
# FILE:  19611869.csv
# Memory use (42601, 306710)
# FILE:  4483589.csv
# Memory use (23595, 295942)
# FILE:  23225205.csv
# Memory use (24721, 297798)
# FILE:  19570720.csv
# Memory use (36555, 306190)
# FILE:  38758059.csv
# Memory use (21753, 294327)
# FILE:  56419027.csv
# Memory use (34109, 307744)
# FILE:  29337575.csv
# Memory use (33147, 303978)
# FILE:  1931951.csv
# Memory use (57565, 322435)
# FILE:  47487077.csv
# Memory use (38506, 315011)
# FILE:  56341765.csv
# Memory use (22233, 294869)
# FILE:  48434635.csv
# Memory use (71662, 345994)
# FILE:  7810903.csv
# Memory use (71058, 370779)
# FILE:  53257.csv
# Memory use (176948, 436831)
# FILE:  16868592.csv
# Memory use (94911, 359918)
# FILE:  910078.csv
# Memory use (55258, 330276)
# FILE:  28284267.csv
# Memory use (37681, 305288)
# FILE:  8561753.csv
# Memory use (26678, 295877)
# FILE:  756707.csv
# Memory use (48033, 315830)
# FILE:  18938952.csv
# Memory use (27102, 297101)
# FILE:  42788698.csv
# Memory use (61089, 323709)
# FILE:  13439129.csv
# Memory use (38415, 300799)
# FILE:  1473383.csv
# Memory use (23829, 297201)
# FILE:  31672834.csv
# Memory use (35652, 303870)
# FILE:  49448566.csv
# Memory use (48468, 321263)
# FILE:  2997876.csv
# Memory use (34151, 298452)
# FILE:  30036483.csv
# Memory use (22897, 296593)
# FILE:  47564252.csv
# Memory use (30954, 298762)
# FILE:  30049602.csv
# Memory use (40622, 313799)
# FILE:  66155084.csv
# Memory use (25907, 296749)
# FILE:  740971.csv
# Memory use (60671, 325362)
# FILE:  6731464.csv
# Memory use (47609, 316467)
# FILE:  33153825.csv
# Memory use (29356, 300145)
# FILE:  1181490.csv
# Memory use (40011, 307697)
# FILE:  50901952.csv
# Memory use (41189, 316321)
# FILE:  30077569.csv
# Memory use (27147, 296596)
# FILE:  36687454.csv
# Memory use (47299, 320572)
# FILE:  23779155.csv
# Memory use (21682, 296554)
# FILE:  168623.csv
# Memory use (63508, 335082)
# FILE:  64122922.csv
# Memory use (67890, 327216)
# FILE:  58924300.csv
# Memory use (46965, 321459)
# FILE:  13131813.csv
# Memory use (27143, 298459)
# FILE:  17437864.csv
# Memory use (24629, 298379)
# FILE:  166613.csv
# Memory use (73743, 336129)
# FILE:  22268024.csv
# Memory use (29025, 297703)
# FILE:  42093437.csv
# Memory use (26282, 295465)
# FILE:  27784.csv
# Memory use (112092, 378900)
# FILE:  240828.csv
# Memory use (56172, 325315)
# FILE:  24164252.csv
# Memory use (90797, 360588)
# FILE:  11045849.csv
# Memory use (57972, 321319)
# FILE:  33127515.csv
# Memory use (30598, 302706)
# FILE:  2131179.csv
# Memory use (44394, 312575)
# FILE:  1533271.csv
# Memory use (50843, 319169)
# FILE:  39593567.csv
# Memory use (27830, 296551)
# FILE:  623083.csv
# Memory use (39857, 315666)
# FILE:  842587.csv
# Memory use (40483, 310897)
# FILE:  2661267.csv
# Memory use (43688, 315876)
# FILE:  6260.csv
# Memory use (183429, 443489)
# FILE:  30398716.csv
# Memory use (23365, 295734)
# FILE:  8933639.csv
# Memory use (36614, 306198)
# FILE:  21418071.csv
# Memory use (59585, 322993)
# FILE:  24593797.csv
# Memory use (47963, 316133)
# FILE:  27112694.csv
# Memory use (28029, 298052)
# FILE:  2455533.csv
# Memory use (62709, 336980)
# FILE:  1418522.csv
# Memory use (31808, 298059)
# FILE:  10191544.csv
# Memory use (28745, 301430)
# FILE:  54553757.csv
# Memory use (31944, 299655)
# FILE:  13512074.csv
# Memory use (31611, 302217)
# FILE:  10524096.csv
# Memory use (22328, 296096)
# FILE:  17047314.csv
# Memory use (31262, 306186)
# FILE:  46220664.csv
# Memory use (40374, 308008)
# FILE:  2036427.csv
# Memory use (57074, 321384)
# FILE:  38614799.csv
# Memory use (25662, 298661)
# FILE:  2982761.csv
# Memory use (33129, 303176)
# FILE:  599356.csv
# Memory use (110102, 369157)
# FILE:  23279641.csv
# Memory use (28371, 298688)
# FILE:  1293316.csv
# Memory use (34678, 305503)
# FILE:  15403598.csv
# Memory use (20855, 294287)
# FILE:  13592932.csv
# Memory use (56612, 320950)
# FILE:  21344555.csv
# Memory use (26366, 298657)
# FILE:  8306261.csv
# Memory use (29901, 306275)
# FILE:  1698238.csv
# Memory use (176555, 438403)
# FILE:  66261770.csv
# Memory use (31225, 302058)
# FILE:  8002901.csv
# Memory use (28222, 297682)
# FILE:  68165082.csv
# Memory use (32164, 304942)
# FILE:  26546983.csv
# Memory use (42863, 309933)
# FILE:  33068119.csv
# Memory use (33846, 299447)
# FILE:  7299436.csv
# Memory use (25529, 296517)
# FILE:  1462817.csv
# Memory use (37355, 311481)
# FILE:  37920859.csv
# Memory use (39754, 301516)
# FILE:  30207836.csv
# Memory use (55375, 305873)
# FILE:  34121366.csv
# Memory use (31050, 300631)
# FILE:  179630.csv
# Memory use (48004, 318054)
# FILE:  220760.csv
# Memory use (82958, 366352)
# FILE:  43153797.csv
# Memory use (60940, 332610)
# FILE:  25640741.csv
# Memory use (17193, 295290)
# FILE:  54066274.csv
# Memory use (53224, 326237)
# FILE:  598993.csv
# Memory use (82986, 337717)
# FILE:  16147753.csv
# Memory use (62126, 304912)
# FILE:  55376393.csv
# Memory use (34463, 304537)
# FILE:  48176973.csv
# Memory use (29406, 302116)
# FILE:  33801554.csv
# Memory use (22931, 295455)
# FILE:  149681.csv
# Memory use (174677, 436262)
# FILE:  15736.csv
# Memory use (212906, 471006)
# FILE:  35252031.csv
# Memory use (31649, 304077)
# FILE:  33988308.csv
# Memory use (28369, 299389)
# FILE:  786344.csv
# Memory use (37947, 309230)
# FILE:  1603208.csv
# Memory use (46109, 312691)
# FILE:  312204.csv
# Memory use (32896, 305836)
# FILE:  1282560.csv
# Memory use (55429, 307208)
# FILE:  11852621.csv
# Memory use (28509, 300274)
# FILE:  18775016.csv
# Memory use (41024, 308745)
# FILE:  4324315.csv
# Memory use (54783, 331907)
# FILE:  1325913.csv
# Memory use (36708, 301620)
# FILE:  6723838.csv
# Memory use (50959, 318848)
# FILE:  66828963.csv
# Memory use (29248, 299234)
# FILE:  5166924.csv
# Memory use (27454, 300322)
# FILE:  20576488.csv
# Memory use (30123, 306125)
# FILE:  4941527.csv
# Memory use (26977, 297522)
# FILE:  20377985.csv
# Memory use (22697, 296621)
# FILE:  2935908.csv
# Memory use (73267, 339343)
# FILE:  54184861.csv
# Memory use (27185, 303043)
# FILE:  68407464.csv
# Memory use (31782, 305460)
# FILE:  6129702.csv
# Memory use (30584, 301833)
# FILE:  30402013.csv
# Memory use (46088, 316313)
# FILE:  8278967.csv
# Memory use (24150, 296939)
# FILE:  6550750.csv
# Memory use (30507, 298700)
# FILE:  2127408.csv
# Memory use (31860, 300323)
# FILE:  62125386.csv
# Memory use (34928, 300683)
# FILE:  19798307.csv
# Memory use (42760, 317203)
# FILE:  41052069.csv
# Memory use (56296, 328881)
# FILE:  2357143.csv
# Memory use (42929, 311653)
# FILE:  13816718.csv
# Memory use (31882, 305202)
# FILE:  22479868.csv
# Memory use (21782, 295261)
# FILE:  159492.csv
# Memory use (108319, 384851)
# FILE:  2815597.csv
# Memory use (56487, 322168)
# FILE:  7189845.csv
# Memory use (34959, 308919)
# FILE:  7624873.csv
# Memory use (38555, 302854)
# FILE:  582776.csv
# Memory use (32503, 298802)
# FILE:  402061.csv
# Memory use (56370, 334581)
# FILE:  536350.csv
# Memory use (34625, 307043)
# FILE:  66075729.csv
# Memory use (23832, 295721)
# FILE:  17563401.csv
# Memory use (38871, 300216)
# FILE:  31843000.csv
# Memory use (54794, 308766)
# FILE:  1072970.csv
# Memory use (96258, 369164)
# FILE:  22492854.csv
# Memory use (23683, 297709)
# FILE:  34672657.csv
# Memory use (24354, 297514)
# FILE:  12410543.csv
# Memory use (23159, 296630)
# FILE:  352614.csv
# Memory use (44393, 312198)
# FILE:  30253761.csv
# Memory use (21627, 299822)
# FILE:  701905.csv
# Memory use (27726, 299396)
# FILE:  12604499.csv
# Memory use (32182, 298925)
# FILE:  33453692.csv
# Memory use (24548, 299605)
# FILE:  46313541.csv
# Memory use (40988, 312812)
# FILE:  45482553.csv
# Memory use (24120, 295933)
# FILE:  758438.csv
# Memory use (69531, 340054)
# FILE:  207593.csv
# Memory use (109808, 372322)
# FILE:  23406267.csv
# Memory use (30490, 302469)
# FILE:  56737593.csv
# Memory use (34976, 307343)
# FILE:  19207601.csv
# Memory use (59229, 316535)
# FILE:  166529.csv
# Memory use (70505, 344437)
# FILE:  20625848.csv
# Memory use (50750, 316181)
# FILE:  41841893.csv
# Memory use (28671, 299342)
# FILE:  12190980.csv
# Memory use (32887, 299053)
# FILE:  17872657.csv
# Memory use (40986, 312909)
# FILE:  2458189.csv
# Memory use (82797, 349081)
# FILE:  1174350.csv
# Memory use (66528, 332579)
# FILE:  55845723.csv
# Memory use (33677, 303073)
# FILE:  1183872.csv
# Memory use (31919, 304152)
# FILE:  5487919.csv
# Memory use (53359, 330741)
# FILE:  19749657.csv
# Memory use (28090, 296999)
# FILE:  3206811.csv
# Memory use (25661, 295939)
# FILE:  41545200.csv
# Memory use (27781, 300233)
# FILE:  34578410.csv
# Memory use (42478, 316335)
# FILE:  54488532.csv
# Memory use (36659, 307610)
# FILE:  5952803.csv
# Memory use (22791, 296564)
# FILE:  3622246.csv
# Memory use (38100, 310789)
# FILE:  22591226.csv
# Memory use (19504, 297669)
# FILE:  725887.csv
# Memory use (50595, 321303)
# FILE:  21301941.csv
# Memory use (41828, 315975)
# FILE:  35603455.csv
# Memory use (36748, 304369)
# FILE:  41984994.csv
# Memory use (33358, 302692)
# FILE:  59895664.csv
# Memory use (45715, 302827)
# FILE:  18502883.csv
# Memory use (81129, 326006)
# FILE:  53869851.csv
# Memory use (44378, 316323)
# FILE:  30528002.csv
# Memory use (200648, 438362)
# FILE:  12979534.csv
# Memory use (33934, 304762)
# FILE:  20300872.csv
# Memory use (46448, 317396)
# FILE:  5328705.csv
# Memory use (46416, 315898)
# FILE:  26250343.csv
# Memory use (38804, 311055)
# FILE:  36307921.csv
# Memory use (63658, 350659)
# FILE:  41429271.csv
# Memory use (22151, 295104)
# FILE:  50820771.csv
# Memory use (20785, 294323)
# FILE:  2425874.csv
# Memory use (55860, 329227)
# FILE:  1760868.csv
# Memory use (39484, 311035)
# FILE:  1775018.csv
# Memory use (94477, 366203)
# FILE:  15876499.csv
# Memory use (30039, 300457)
# FILE:  22617433.csv
# Memory use (21921, 296144)
# FILE:  9206990.csv
# Memory use (55259, 319779)
# FILE:  10426850.csv
# Memory use (43787, 321053)
# FILE:  147776.csv
# Memory use (40102, 309840)
# FILE:  18763126.csv
# Memory use (26504, 297497)
# FILE:  523806.csv
# Memory use (35138, 304514)
# FILE:  1611839.csv
# Memory use (37010, 304317)
# FILE:  338818.csv
# Memory use (53281, 307405)
# FILE:  3940151.csv
# Memory use (67892, 331819)
# FILE:  5561536.csv
# Memory use (31441, 298843)
# FILE:  633326.csv
# Memory use (51047, 317699)
# FILE:  2187788.csv
# Memory use (30169, 298668)
# FILE:  65907127.csv
# Memory use (25403, 299897)
# FILE:  14142720.csv
# Memory use (42455, 310839)
# FILE:  16552823.csv
# Memory use (27528, 299590)
# FILE:  4236677.csv
# Memory use (25160, 299843)
# FILE:  9925025.csv
# Memory use (21834, 295312)
# FILE:  64070000.csv
# ...
# FILE:  46236447.csv
# Memory use (34320, 299926)
# FILE:  2078983.csv
# Memory use (32501, 300097)
# FILE:  34363700.csv
# Memory use (28520, 297522)
# FILE:  29500332.csv
# Memory use (22193, 295953)
# FILE:  4842137.csv
# Memory use (35754, 296652)
# FILE:  31409148.csv
# Memory use (29214, 299640)
# FILE:  28137440.csv
# Memory use (23510, 296708)
# FILE:  5034284.csv
# Memory use (57026, 330908)
# FILE:  47346652.csv
# Memory use (35629, 308902)
# FILE:  35297615.csv
# Memory use (22250, 296051)
# FILE:  169941.csv
# Memory use (177143, 432754)
# FILE:  2566786.csv
# Memory use (36062, 315100)
# FILE:  442330.csv
# Memory use (35346, 304361)
# FILE:  29902577.csv
# Memory use (37442, 310216)
# FILE:  3029594.csv
# Memory use (77701, 331148)
# FILE:  1229341.csv
# Memory use (24564, 303436)
# FILE:  17250983.csv
# Memory use (26365, 296151)
# FILE:  25866442.csv
# Memory use (53065, 320238)
# FILE:  58759768.csv
# Memory use (39404, 302912)
# FILE:  38586602.csv
# Memory use (56913, 331916)
# FILE:  18202531.csv
# Memory use (32848, 300067)
# FILE:  38043415.csv
# Memory use (39920, 302304)
# FILE:  45002808.csv
# Memory use (24603, 295858)
# FILE:  160965.csv
# Memory use (132320, 389040)
# FILE:  26764447.csv
# Memory use (26247, 300663)
# FILE:  4791385.csv
# Memory use (48941, 318398)
# FILE:  23415016.csv
# Memory use (34868, 300033)
# FILE:  17388324.csv
# Memory use (24714, 298434)
# FILE:  1051840.csv
# Memory use (47186, 306024)
# FILE:  26118669.csv
# Memory use (29798, 301673)
# FILE:  33664183.csv
# Memory use (25777, 297070)
# FILE:  20583840.csv
# Memory use (84421, 366461)
# FILE:  2281945.csv
# Memory use (104302, 373972)
# FILE:  54258831.csv
# Memory use (34101, 306610)
# FILE:  64299508.csv
# Memory use (57264, 326342)
# FILE:  2157363.csv
# Memory use (95259, 357002)
# FILE:  6749829.csv
# Memory use (29662, 301183)
# FILE:  4113877.csv
# Memory use (41057, 307930)
# FILE:  42168712.csv
# Memory use (40604, 315227)
# FILE:  9030934.csv
# Memory use (66501, 332159)
# FILE:  63847367.csv
# Memory use (48809, 321012)
# FILE:  59871333.csv
# Memory use (28696, 299786)
# FILE:  1147434.csv
# Memory use (170661, 464323)
# FILE:  30317204.csv
# Memory use (25194, 297313)
# FILE:  53832245.csv
# Memory use (30673, 298771)
# FILE:  43367968.csv
# Memory use (34066, 306207)
# FILE:  30865726.csv
# Memory use (29386, 301337)
# FILE:  4831502.csv
# Memory use (54475, 320310)
# FILE:  7181689.csv
# Memory use (36259, 301346)
# FILE:  34857505.csv
# Memory use (52224, 321182)
# FILE:  455297.csv
# Memory use (47661, 323430)
# FILE:  18022296.csv
# Memory use (24723, 297122)
# FILE:  26000998.csv
# Memory use (38099, 308022)
# FILE:  56717216.csv
# Memory use (23909, 300873)
# FILE:  99422.csv
# Memory use (29606, 299339)
# FILE:  7169447.csv
# Memory use (68095, 313309)
# FILE:  37607535.csv
# Memory use (98414, 361988)
# FILE:  50123066.csv
# Memory use (23087, 297646)
# FILE:  15386564.csv
# Memory use (24652, 295618)
# FILE:  598583.csv
# Memory use (49125, 318823)
# FILE:  213099.csv
# Memory use (65529, 329760)
# FILE:  24890426.csv
# Memory use (26112, 301456)
# FILE:  16800497.csv
# Memory use (77142, 338301)
# FILE:  1593492.csv
# Memory use (91764, 360602)
# FILE:  10951542.csv
# Memory use (44260, 315732)
# FILE:  54735816.csv
# Memory use (24518, 297410)
# FILE:  5287439.csv
# Memory use (24179, 295758)
# FILE:  880023.csv
# Memory use (56284, 320023)
# FILE:  42548147.csv
# Memory use (27567, 296142)
# FILE:  42025612.csv
# Memory use (31127, 301067)
# FILE:  23985098.csv
# Memory use (34180, 302087)
# FILE:  49142289.csv
# Memory use (30096, 306847)
# FILE:  63869924.csv
# Memory use (39383, 309962)
# FILE:  414744.csv
# Memory use (84174, 347725)
# FILE:  38433250.csv
# Memory use (28324, 302112)
# FILE:  47209005.csv
# Memory use (29901, 303792)
# FILE:  7715728.csv
# Memory use (26344, 296506)
# FILE:  2989936.csv
# Memory use (67994, 346827)
# FILE:  51526229.csv
# Memory use (29804, 297113)
# FILE:  2497159.csv
# Memory use (32673, 302004)
# FILE:  15282299.csv
# Memory use (23098, 297910)
# FILE:  3538487.csv
# Memory use (40503, 311815)
# FILE:  2198937.csv
# Memory use (39114, 313076)
# FILE:  630138.csv
# Memory use (48574, 314047)
# FILE:  11252981.csv
# Memory use (42271, 315871)
# FILE:  43017006.csv
# Memory use (34024, 305589)
# FILE:  15413917.csv
# Memory use (31597, 306000)
# FILE:  27024050.csv
# Memory use (27467, 296620)
# FILE:  30604514.csv
# Memory use (31296, 302181)
# FILE:  3093587.csv
# Memory use (42036, 315688)
# FILE:  17093227.csv
# Memory use (27994, 299132)
# FILE:  48401939.csv
# Memory use (26532, 299831)
# FILE:  10416069.csv
# Memory use (36303, 312841)
# FILE:  19164317.csv
# Memory use (39189, 319969)
# FILE:  5664964.csv
# Memory use (33679, 300672)
# FILE:  34942493.csv
# Memory use (29910, 296618)
# FILE:  154183.csv
# Memory use (138164, 399219)
# FILE:  13353558.csv
# Memory use (31050, 303699)
# FILE:  33799173.csv
# Memory use (20696, 294240)
# FILE:  62729629.csv
# Memory use (41231, 311348)
# FILE:  33477012.csv
# Memory use (22027, 296297)
# FILE:  25029319.csv
# Memory use (26852, 300746)
# FILE:  2715684.csv
# Memory use (29109, 301576)
# FILE:  963637.csv
# Memory use (51510, 322398)
# FILE:  6180325.csv
# Memory use (29448, 303077)
# FILE:  33117263.csv
# Memory use (39401, 311648)
# FILE:  6234638.csv
# Memory use (30397, 298208)
# FILE:  24340980.csv
# Memory use (36645, 313513)
# FILE:  55183195.csv
# Memory use (27639, 297268)
# FILE:  33239640.csv
# Memory use (73181, 338130)
# FILE:  7242487.csv
# Memory use (35500, 298890)
# FILE:  5891106.csv
# Memory use (29658, 304765)
# FILE:  55949790.csv
# Memory use (32193, 298394)
# FILE:  60448364.csv
# Memory use (28509, 302704)
# FILE:  7619112.csv
# Memory use (46248, 322061)
# FILE:  36993869.csv
# Memory use (22977, 298797)
# FILE:  33279264.csv
# Memory use (21839, 295762)
# FILE:  39601173.csv
# Memory use (31595, 301984)
# FILE:  2154483.csv
# Memory use (42049, 313805)
# FILE:  299149.csv
# Memory use (100919, 357188)
# FILE:  38430995.csv
# Memory use (41301, 317587)
# FILE:  695584.csv
# Memory use (119233, 366736)
# FILE:  13351429.csv
# Memory use (50241, 323085)
# FILE:  12164717.csv
# Memory use (45757, 310971)
# FILE:  6112121.csv
# Memory use (22398, 294946)
# FILE:  32881756.csv
# Memory use (60918, 335136)
# FILE:  39740885.csv
# Memory use (30426, 297922)
# FILE:  47769260.csv
# Memory use (69742, 321541)
# FILE:  29315955.csv
# Memory use (30479, 297777)
# FILE:  12210990.csv
# Memory use (43775, 316965)
# FILE:  43610240.csv
# Memory use (29601, 299014)
# FILE:  4001730.csv
# Memory use (38588, 302396)
# FILE:  2167049.csv
# Memory use (39807, 315264)
# FILE:  25071614.csv
# Memory use (23572, 295370)
# FILE:  54670153.csv
# Memory use (28470, 299514)
# FILE:  36898900.csv
# Memory use (32905, 304123)
# FILE:  22905764.csv
# Memory use (28118, 298006)
# FILE:  6984701.csv
# Memory use (34225, 306662)
# FILE:  56283455.csv
# Memory use (25771, 295888)
# FILE:  2138565.csv
# Memory use (41239, 309791)
# FILE:  34226089.csv
# Memory use (28616, 302238)
# FILE:  3875132.csv
# Memory use (49056, 316761)
# FILE:  42193007.csv
# Memory use (36470, 308897)
# FILE:  16147411.csv
# Memory use (43135, 311211)
# FILE:  40908552.csv
# Memory use (26105, 297575)
# FILE:  2178141.csv
# Memory use (33314, 308911)
# FILE:  38084989.csv
# Memory use (66154, 334571)
# FILE:  157461.csv
# Memory use (144881, 403170)
# FILE:  14720719.csv
# Memory use (24845, 298523)
# FILE:  45417194.csv
# Memory use (30351, 302798)
# FILE:  17248464.csv
# Memory use (41669, 307317)
# FILE:  60596395.csv
# Memory use (41779, 310115)
# FILE:  4301777.csv
# Memory use (66002, 313891)
# FILE:  2155004.csv
# Memory use (46024, 316500)
# FILE:  29545478.csv
# Memory use (45219, 318183)
# FILE:  796700.csv
# Memory use (52346, 314744)
# FILE:  262462.csv
# Memory use (84832, 347723)
# FILE:  6899793.csv
# Memory use (50428, 313203)
# FILE:  18284827.csv
# Memory use (66353, 335116)
# FILE:  8601641.csv
# Memory use (23923, 299771)
# FILE:  3227065.csv
# Memory use (39395, 301638)
# FILE:  392949.csv
# Memory use (75620, 344352)
# FILE:  3112700.csv
# Memory use (39545, 312960)
# FILE:  70928.csv
# Memory use (42277, 309966)
# FILE:  3555864.csv
# Memory use (25926, 299531)
# FILE:  57489963.csv
# Memory use (44301, 316224)
# FILE:  39027310.csv
# Memory use (41830, 315271)
# FILE:  3983667.csv
# Memory use (41916, 309860)
# FILE:  2563027.csv
# Memory use (25490, 297547)
# FILE:  10997115.csv
# Memory use (32276, 299282)
# FILE:  45372557.csv
# Memory use (28225, 297509)
# FILE:  22318124.csv
# Memory use (34048, 303136)
# FILE:  21581218.csv
# Memory use (27411, 296829)
# FILE:  50420.csv
# Memory use (201154, 470617)
# FILE:  24603469.csv
# Memory use (37980, 313506)
# FILE:  3128488.csv
# Memory use (29621, 297524)
# FILE:  2167061.csv
# Memory use (34960, 298470)
# FILE:  6018356.csv
# Memory use (26232, 297981)
# FILE:  518156.csv
# Memory use (35578, 307962)
# FILE:  315629.csv
# Memory use (72447, 336141)
# FILE:  24151809.csv
# Memory use (25890, 296865)
# FILE:  3837467.csv
# Memory use (33942, 304614)
# FILE:  4951037.csv
# Memory use (39119, 305879)
# FILE:  2175303.csv
# Memory use (64638, 327682)
# FILE:  5274764.csv
# Memory use (58011, 331665)
# FILE:  5684112.csv
# Memory use (49233, 313321)
# FILE:  61317048.csv
# Memory use (34160, 309649)
# FILE:  6956121.csv
# Memory use (40044, 302186)
# FILE:  6744672.csv
# Memory use (63260, 308022)
# FILE:  32904760.csv
# Memory use (63283, 340106)
# FILE:  44930248.csv
# Memory use (28243, 302640)
# FILE:  47957783.csv
# Memory use (27794, 296558)
# FILE:  8438911.csv
# Memory use (48664, 314522)
# FILE:  63484570.csv
# Memory use (33660, 307095)
# FILE:  30016363.csv
# Memory use (21375, 295180)
# FILE:  897946.csv
# Memory use (103961, 373242)
# FILE:  23831930.csv
# Memory use (43041, 321263)
# FILE:  7130095.csv
# Memory use (49117, 316529)
# FILE:  40267035.csv
# Memory use (66579, 344872)
# FILE:  64798620.csv
# Memory use (26517, 296143)
# FILE:  4741167.csv
# Memory use (41799, 312439)
# FILE:  11324195.csv
# Memory use (52239, 328915)
# FILE:  3140085.csv
# Memory use (56597, 305839)
# FILE:  22052730.csv
# Memory use (44407, 315668)
# FILE:  40891165.csv
# Memory use (64194, 339019)
# FILE:  16754622.csv
# Memory use (37469, 305755)
# FILE:  47026704.csv
# Memory use (25239, 297156)
# FILE:  6271358.csv
# Memory use (34727, 308300)
# FILE:  16523406.csv
# Memory use (30455, 298737)
# FILE:  8727137.csv
# Memory use (22612, 295681)
# FILE:  36373801.csv
# Memory use (26890, 299764)
# FILE:  624603.csv
# Memory use (74058, 340631)
# FILE:  7539246.csv
# Memory use (41171, 315931)
# FILE:  5201489.csv
# Memory use (24985, 295444)
# FILE:  11767529.csv
# Memory use (28267, 297183)
# FILE:  867479.csv
# Memory use (55799, 322061)
# FILE:  2565495.csv
# Memory use (42538, 312450)
# FILE:  730104.csv
# Memory use (45000, 310806)
# FILE:  44557896.csv
# Memory use (64017, 336193)
# FILE:  27859809.csv
# Memory use (32217, 306518)
# FILE:  30176483.csv
# Memory use (24517, 296568)
# FILE:  42656100.csv
# Memory use (24062, 297483)
# FILE:  11314730.csv
# Memory use (22284, 302130)
# FILE:  26416114.csv
# Memory use (70841, 352990)
# FILE:  37854945.csv
# Memory use (38593, 319544)
# FILE:  1548731.csv
# Memory use (94928, 357861)
# FILE:  296246.csv
# Memory use (154749, 414296)
# FILE:  26949099.csv
# Memory use (24888, 295940)
# FILE:  42332117.csv
# Memory use (51134, 319314)
# FILE:  44626782.csv
# Memory use (30984, 299919)
# FILE:  1540386.csv
# Memory use (32802, 305626)
# FILE:  50354068.csv
# Memory use (29211, 298586)
# FILE:  55799427.csv
# Memory use (31579, 300615)
# FILE:  64259274.csv
# Memory use (42222, 317929)
# FILE:  59168236.csv
# Memory use (115722, 383611)
# FILE:  693122.csv
# Memory use (65952, 332533)
# FILE:  740408.csv
# Memory use (41002, 315675)
# FILE:  33494438.csv
# Memory use (21170, 294274)
# FILE:  5860128.csv
# Memory use (16581, 294106)
# FILE:  5955839.csv
# Memory use (32330, 305095)
# FILE:  883066.csv
# Memory use (56840, 320917)
# FILE:  38867539.csv
# Memory use (44547, 307728)
# FILE:  35569161.csv
# Memory use (33736, 303469)
# FILE:  60986533.csv
# Memory use (35421, 310095)
# FILE:  35624967.csv
# Memory use (37051, 313028)
# FILE:  53554005.csv
# Memory use (44948, 317631)
# FILE:  21161133.csv
# Memory use (21963, 296564)
# FILE:  4261901.csv
# Memory use (52707, 319296)
# FILE:  43309525.csv
# Memory use (27687, 299223)
# FILE:  20033548.csv
# Memory use (34739, 299462)
# FILE:  17192850.csv
# Memory use (32218, 300007)
# FILE:  50245171.csv
# Memory use (35519, 317283)
# FILE:  3447284.csv
# Memory use (44665, 318089)
# FILE:  30062409.csv
# Memory use (25561, 299570)
# FILE:  16754811.csv
# Memory use (25580, 295822)
# FILE:  33630322.csv
# Memory use (35924, 312258)
# FILE:  28775616.csv
# Memory use (80311, 351108)
# FILE:  21092911.csv
# Memory use (26438, 302033)
# FILE:  493830.csv
# Memory use (84861, 353958)
# FILE:  4458303.csv
# Memory use (31759, 302677)
# FILE:  49723612.csv
# Memory use (25591, 296031)
# FILE:  13957649.csv
# Memory use (40158, 308625)
# FILE:  45693210.csv
# Memory use (37073, 301017)
# FILE:  703243.csv
# Memory use (36472, 304653)
# FILE:  6939519.csv
# Memory use (30007, 300215)
# FILE:  275650.csv
# Memory use (40852, 318975)
# FILE:  337311.csv
# Memory use (63621, 328095)
# FILE:  351094.csv
# Memory use (78008, 338548)
# FILE:  2220379.csv
# Memory use (41616, 303381)
# FILE:  1256967.csv
# Memory use (60380, 326989)
# FILE:  34682523.csv
# Memory use (42856, 312469)
# FILE:  12225056.csv
# Memory use (30571, 302200)
# FILE:  59608799.csv
# Memory use (26996, 300364)
# FILE:  32181855.csv
# Memory use (32168, 303193)
# FILE:  64061035.csv
# Memory use (27350, 297491)
# FILE:  8886445.csv
# Memory use (25102, 298321)
# FILE:  168875.csv
# Memory use (72107, 344239)
# FILE:  37702667.csv
# Memory use (50826, 322857)
# FILE:  43124369.csv
# Memory use (26222, 302421)
# FILE:  16763071.csv
# Memory use (42011, 317813)
# FILE:  164097.csv
# Memory use (62728, 327097)
# FILE:  3370115.csv
# Memory use (24356, 295666)
# FILE:  7027264.csv
# Memory use (28803, 304557)
# FILE:  758535.csv
# Memory use (44212, 311867)
# FILE:  20814951.csv
# Memory use (29455, 299087)
# FILE:  4605916.csv
# Memory use (63949, 329769)
# FILE:  49746934.csv
# Memory use (45747, 316278)
# FILE:  60261208.csv
# Memory use (30021, 302170)
# FILE:  5039145.csv
# Memory use (22468, 299505)
# FILE:  23098489.csv
# Memory use (28126, 299614)
# FILE:  6738222.csv
# Memory use (42383, 310095)
# FILE:  26181074.csv
# Memory use (31277, 299350)
# FILE:  2273721.csv
# Memory use (31121, 303289)
# FILE:  905217.csv
# Memory use (37490, 308124)
# FILE:  4059598.csv
# Memory use (33450, 316497)
# FILE:  21514029.csv
# Memory use (42219, 313287)
# FILE:  7728318.csv
# Memory use (55380, 317048)
# FILE:  7930600.csv
# Memory use (25346, 297370)
# FILE:  2126798.csv
# Memory use (25133, 297684)
# FILE:  5974613.csv
# Memory use (26581, 296408)
# FILE:  6037410.csv
# Memory use (25611, 302111)
# FILE:  1994576.csv
# Memory use (45517, 319732)
# FILE:  39634645.csv
# Memory use (36880, 312072)
# FILE:  66212140.csv
# Memory use (36256, 307392)
# FILE:  8241086.csv
# Memory use (26954, 299739)
# FILE:  2033381.csv
# Memory use (24451, 295216)
# FILE:  37963694.csv
# Memory use (36089, 307356)
# FILE:  46553286.csv
# Memory use (24290, 295204)
# FILE:  62620194.csv
# Memory use (56624, 324838)
# FILE:  60052646.csv
# Memory use (26482, 302609)
# FILE:  25919329.csv
# Memory use (35492, 306739)
# FILE:  66558206.csv
# Memory use (37086, 312007)
# FILE:  790365.csv
# Memory use (32582, 299285)
# FILE:  327880.csv
# Memory use (86242, 347526)
# FILE:  12128284.csv
# Memory use (35756, 315011)
# FILE:  46273319.csv
# Memory use (25340, 302559)
# FILE:  274572.csv
# Memory use (101244, 341769)
# FILE:  34417972.csv
# Memory use (34972, 299016)
# FILE:  16934256.csv
# Memory use (33014, 312646)
# FILE:  4677370.csv
# Memory use (54812, 323722)
# FILE:  66027631.csv
# Memory use (41439, 307851)
# FILE:  8429613.csv
# Memory use (24089, 298274)
# FILE:  2014058.csv
# Memory use (51613, 314018)
# FILE:  43677556.csv
# Memory use (26837, 303317)
# FILE:  29871340.csv
# Memory use (38794, 308603)
# FILE:  47102117.csv
# Memory use (36860, 305668)
# FILE:  31081487.csv
# Memory use (38460, 307218)
# FILE:  3429561.csv
# Memory use (37369, 305840)
# FILE:  43618191.csv
# Memory use (42390, 310826)
# FILE:  104987.csv
# Memory use (47335, 315606)
# FILE:  32702085.csv
# Memory use (22484, 296491)
# FILE:  36819211.csv
# Memory use (64124, 311940)
# FILE:  12706336.csv
# Memory use (33990, 301314)
# FILE:  2349481.csv
# Memory use (26248, 296535)
# FILE:  16553122.csv
# Memory use (27277, 298410)
# FILE:  8569551.csv
# Memory use (49166, 319266)
# FILE:  13520712.csv
# Memory use (45953, 314038)
# FILE:  2084339.csv
# Memory use (56715, 324668)
# FILE:  51060074.csv
# Memory use (55274, 305562)
# FILE:  4222804.csv
# Memory use (40980, 304138)
# FILE:  7950876.csv
# Memory use (32836, 302510)
# FILE:  12949776.csv
# Memory use (43709, 312712)
# FILE:  42480529.csv
# Memory use (45361, 315641)
# FILE:  6141586.csv
# Memory use (23415, 297014)
